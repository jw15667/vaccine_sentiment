# %%
#browser = webdriver.Chrome(executable_path = '/Users/carolinvogt/Becoming_Data_Analyst/chromedriver')
#browser.get('https://www.waterqualitydata.us/portal/')

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from time import sleep
import re

# %%
import time
from random import randint

# %%
#!pip install zeit-online

# %% [markdown]
# https://skriptum.github.io/zeit/

# %%
import zeit

# %%
KEY='91b085bd0328b937cedf331bb2ac9a0bf47d6076c36fb804816f'

# %%
api = zeit.API()
api.set_token(KEY) #put your key in here

# %%
api.get_status()
# Out:
# 'everything ok'

# %%
test=api.search_for("corona",limit=100)
test
# Out:
#  Search for 'corona': 11318 results, limit: 100, matches :
#
# Prozess um milliardenschwere Cum-Ex-Aktiendeals hat begonnen: http://api.zeit.de/content/3s3YhJKy2dehj9xoGrDpM9
# Coronaaaaaaaaaargghhh!: http://api.zeit.de/content/6YyGGlsBHt9mTl8QkVnrr6
# Erst Selbstkritik, dann Selbstverteidigung: http://api.zeit.de/content/6Ux163KMzgplMUcaejSUIQ
# Die Last der Erwartung: http://api.zeit.de/content/31Dsx9ZRJZ2atPIMsvZla9
# Haftbefehl und eine Festnahme in der Maskenaffäre: http://api.zeit.de/content/1AoHRPchEPrODNj4J7HIzp
# Positiver Corona-Test in der Fußballnationalmannschaft: http://api.zeit.de/content/5s0zkP0iNOnxucf7UryTns
# Streit um Impfstoffverteilung und Exportkontrollen: http://api.zeit.de/content/V5mg2tY0jnP32xpzwXw1l
# Saarland plant Lockerungen nach Ostern: http://api.zeit.de/content/1kI8Yw0ogDHEh30SQNNkK7
# Maja Göpel, wie können wir die Welt neu denken?: http://api.zeit.de/content/4ZD2UDcxIgF3PbnmZasUTK
# AstraZeneca korrigiert Wirksamkeit seines Impfstoffes nach unten: http://api.zeit.de/content/538zqBwwLdW8oVWlZ2q9Jp
# Bayern oder NRW, was ist besser?: http://api.zeit.de/content/6I0o9cccMpkBBK1Liio5rw
# "Wir haben zu lange geglaubt, der Markt werde das Problem lösen": http://api.zeit.de/content/1B144cBunBxUKdPmq26LKz
# Mindestens 150 Schiffe durch feststeckenden Frachter blockiert: http://api.zeit.de/content/4VpGMYrhZwnfDxhyO4SgJV
# "Wir werden dieses Virus besiegen": http://api.zeit.de/content/7JWDt7dkFr3PF73wf6y0zP
# Jetzt live: Angela Merkel gibt Regierungserklärung ab: http://api.zeit.de/content/77yvBt2KPs8v2usBduTId6
# Impftempo stagniert bei deutlich unter 300.000 Impfungen pro Tag: http://api.zeit.de/content/227unSuNGUZpBq55bUzit8
# Angela Merkels Schuld, eine Havarie und steigende Zahlen: http://api.zeit.de/content/peEdGOLL34XEtSUE8FBrM
# Eric Dooh zeigt, wie es geht: http://api.zeit.de/content/BqF7luTPglN2CcQJBo4Bn
# "Vom Hoodie bis zum Anzug ist alles in Ordnung": http://api.zeit.de/content/Ew0IpzEtO8aY66mzGQtHY
# Es geht auch anders: http://api.zeit.de/content/24Y25YNeZVf4GyuiSJKuQb
# Viel Diskussionsbedarf und ein besonderer Gast: http://api.zeit.de/content/335BzYQeHGPKRVy2tMKFyB
# Fast alle Pflegeheimbewohner laut RKI geimpft: http://api.zeit.de/content/36itswdSW0JtLGRxwyWXTy
# Dritte Welle laut RKI-Chef nur mit Lockdown zu stoppen: http://api.zeit.de/content/48DikAXNqmJezt4YVLoMhz
# US-Außenminister stellt EU enge Zusammenarbeit in Aussicht: http://api.zeit.de/content/7F0QUJDD8rbk7LJM2iIwgn
# Bundesregierung prüft Verbot von Auslandsreisen: http://api.zeit.de/content/13vPkzOimFOfvkcLp2bUXK
# RKI registriert gut 5.000 Neuinfektionen mehr als vor einer Woche: http://api.zeit.de/content/6uTeBQX2eYAb9zK40AvRhQ
# Angela Merkel lehnt Vertrauensfrage ab: http://api.zeit.de/content/7xzmc4S70a1FIyWw9rDea5
# Warum gerade jetzt mehr Kinder Corona kriegen: http://api.zeit.de/content/6NbtygoCmS6eAj1gpwOaIE
# Darauf kommt es bei einer Vorsorgevollmacht an: http://api.zeit.de/content/6tPLZI8RIAJPsbv3Rhai5k
# Schwere Nebenwirkungen nach Corona-Impfung weiterhin die Ausnahme: http://api.zeit.de/content/7ffPlIgNBBgvBtNSIpOL1t
# Angela Merkels Kalkül könnte aufgehen: http://api.zeit.de/content/4cHpUa7ubbZSFb2N0hcfLh
# Bundesregierung plant mit 81,5 Milliarden neuen Schulden für 2022: http://api.zeit.de/content/25AF0UIwcGpbDdoZM3qFmb
# EU verschärft Kontrolle von Impfstoffexporten: http://api.zeit.de/content/69JIVt1W9QZu4g1CzYe42x
# Angela Merkel übernimmt Verantwortung: http://api.zeit.de/content/6vzg6RO7KZ0V8eVhQtKvjD
# "Kein Grund, hoffnungslos zu sein": http://api.zeit.de/content/6lmkoZSiBpG7wWQT11Qybi
# "Mit dem Tod offen umgehen": http://api.zeit.de/content/6eYN46kHAUS4Cdg3pPRwGg
# Schau mich doch an: http://api.zeit.de/content/7II51zRl4cZJf4LXxIuYlx
# Gute Besserung!: http://api.zeit.de/content/71FLvZ1wsCfu0s3hGIHsA1
# Anwalt in eigener Sache: http://api.zeit.de/content/6HDekuZjENuKoJKjrsxd5T
# Der Seuchenfahnder: http://api.zeit.de/content/5hN2zPFIyYx4QVDwfK8NOy
# "Die Leute wollen Haltung sehen": http://api.zeit.de/content/27g73KZUKIf4sJlbgXHG4T
# Kreuzfahrtkönig unter Druck: http://api.zeit.de/content/2A4zMOrKNLt7ohL53DRCpz
# "Der Mensch kann Fürchterliches anrichten" – "Die meisten sind tief in ihrem Inneren anständig": http://api.zeit.de/content/3BJD02k2SW8maH0XD9isCT
# Für ein paar Lira mehr: http://api.zeit.de/content/2uj6T6jf2LBkR2km7ztk7w
# Das Gewicht der weiblichen Stimme: http://api.zeit.de/content/2FxcePIFNVu9GXsp7rU1c3
# Lern mal deine Nachbarn kennen: http://api.zeit.de/content/2BPTdj0HtujeYrDSunQg3N
# Überlebensfrage: http://api.zeit.de/content/6shnFYASAaQn3Sd7vq977y
# Der neue Sputnik-Schock: http://api.zeit.de/content/f62B8Adnt0JYRE1wycOyo
# Wie viel soll man machen?: http://api.zeit.de/content/WbmzC6x1oTGkWZUeTDaFS
# Der Junge aus dem Bergwerk: http://api.zeit.de/content/5z3CgXmtoT5Hubj8jg1SDv
# Frischer Wind vom Land: http://api.zeit.de/content/6gzAvAPaKtL9EGI2eOHk3R
# Macht Wissenschaft zur Vorsorge!: http://api.zeit.de/content/6Tu4zX2trHlCu5X5w4C8n4
# Suchbild ohne Chefin: http://api.zeit.de/content/3dRDfUNDqFtFfw8zkJBxxe
# Diagnose Arztsohn: http://api.zeit.de/content/3CuospYyDKYkUesLp9QJCw
# "Mein Klassenlehrer ist ein echtes Highlight!": http://api.zeit.de/content/4BpACuwXM1lcFK2Ow3jPri
# Ab in die Präsidialrepublik: http://api.zeit.de/content/5mB59iquqZfdFDyxE3OXsL
# Ein Land dreht auf: http://api.zeit.de/content/7h62xyad51wj5KT22IAJj9
# Unsere Quellen: http://api.zeit.de/content/8dI9LkAc8yQl6glMfjNAf
# Vizekanzler und Länderchefs übernehmen Mitschuld für Osterbeschluss: http://api.zeit.de/content/6A6R8G9WneLZ9T9BW2faBY
# Das Röcheln beim Rachenabstrich: http://api.zeit.de/content/7MMMaEZF19Cbcz4waSQ0j2
# Warum greift die Polizei nicht härter durch?: http://api.zeit.de/content/6NiyKPFDNugTpLcqk9jLQQ
# Was auf Malle geht, geht auch hier: http://api.zeit.de/content/64w4vdVkaS0QW3rg4p14so
# Deutschland fordert Sputnik-V-Bestellung über EU: http://api.zeit.de/content/57j7GgHFbxBEhjz1fPqPU0
# Kanzlerin weist Ländern Verantwortung für Testmangel an Schulen zu: http://api.zeit.de/content/5MN9XGE5oCsUW8EqXLTNQz
# Angela Merkel stellt sich Fragen zur Corona-Politik: http://api.zeit.de/content/20Fk79q0SkxKx0faAS1ogj
# Regiert da wer?: http://api.zeit.de/content/20MUf1R1jIxMGNX3Vr1umm
# "Dieser Fehler ist einzig und allein mein Fehler": http://api.zeit.de/content/2ZBP9Qjts86OpiKsj7s5nv
# Unionspolitiker kritisieren Beschlüsse zu Gottesdiensten: http://api.zeit.de/content/1cKmSEshX2nOstyWDRuJKa
# Die Macht des Ziehvaters: http://api.zeit.de/content/cYIzCmroUm0a10CTeE3V9
# Institute senken Konjunkturprognosen auf bis zu drei Prozent: http://api.zeit.de/content/4wNo3mZwjBEVkQy9FWosRu
# Ruhetage, eine Wahl in Israel und eine Waffendebatte in den USA: http://api.zeit.de/content/6Um3LioNj0kmKI8SwLUr47
# "Auf Facebook wird wenigstens gestritten": http://api.zeit.de/content/6NgZ5e2bCSkf28rkbsqSPg
# Ein Lockdown, der keiner sein soll: http://api.zeit.de/content/3UoHjVzHHnAS6TSuGEKGmz
# In Frankreich wächst der Unmut: http://api.zeit.de/content/3rpHAL2M7F5k2SSBkhaje1
# RKI registriert erneut mehr Neuinfektionen: http://api.zeit.de/content/10IrQbU5TmH1MzjOxqx6t2
# Pattsituation könnte Neuwahlen erzwingen: http://api.zeit.de/content/kLYiGB4ch0LiYx0MTLPtU
# Hart gebremst, leer weitergefahren: http://api.zeit.de/content/59HUACnYQ36QowyDKOjgJw
# "Die Fußballwelt war zu eng, zu fremdbestimmt": http://api.zeit.de/content/57SYRdixe9qx4ms23hJIIz
# Was bedeutet der Ruhetag an Gründonnerstag?: http://api.zeit.de/content/1kCMxuo3JwleUgz2YB9iIc
# "Wir haben 55.000 Euro aus unserem Ersparten investiert": http://api.zeit.de/content/13iM3a4PpQKRcm4u8XnBzp
# Ein linksradikaler Vorschlag: http://api.zeit.de/content/3gJvVYWeLelcLGESNvZDST
# "Ich wünsche mir ein Durchschnittsabitur": http://api.zeit.de/content/2CAT5OqNyuTB7rGyAUoraj
# Gesundheitsministerium rechtfertigt sich für Maskendeal: http://api.zeit.de/content/6oniEIyJWqg0WFgTdlTPTg
# "Wichtiges Signal an die Bevölkerung, wie ernst die Lage ist": http://api.zeit.de/content/OZ8cO3Sh4drzTM7YQ9FfQ
# Klare Kante: http://api.zeit.de/content/1LfvZEDpjn91piNPU36zVQ
# Lockdown zu Ostern, Schüsse in Colorado, Eltern-Burn-out: http://api.zeit.de/content/5TQK7OTq3S2fu73CbRqe7g
# Die Stimmung kippt: http://api.zeit.de/content/5YBbGvgg8dIY9BQfG4yF3k
# Simulierte Handlungsfähigkeit: http://api.zeit.de/content/1LVEQ8bP668NnytdnqkMJa
# Zwölf Stunden für zwei Tage Osterlockdown: http://api.zeit.de/content/jG7SPTTLuG47261DeNwNl
# Bund und Länder beschließen strengeren Lockdown über Ostern: http://api.zeit.de/content/6h9aYlAqEhbZsL82BqoFAB
# Angela Merkel zu den neuen Corona-Beschlüssen: http://api.zeit.de/content/7ffpqCEqAMrby2jSV7SlR
# RKI registriert etwa 2.000 Infizierte mehr als vor einer Woche: http://api.zeit.de/content/7l5ltsQz3Q5GNt1POR3qa2
# Minister tritt im Streit um Corona-Krisenmanagement zurück: http://api.zeit.de/content/6TebNMUVr0wdGufNs2yntt
# Mein Corona-Kopf macht pff, ahhhhh, mrrrrr: http://api.zeit.de/content/4HcoBIUNHBFntQpPLTIyhj
# Liegt die Zukunft auf dem Land?: http://api.zeit.de/content/4Feru7Zggs4zy72Q3c5jzC
# Olaf Scholz plant weitere Neuverschuldung: http://api.zeit.de/content/6eedQU3OleeCUagAD6WYay
# Tempo 200: http://api.zeit.de/content/1N0wa3vphubFNjsIKBECA1
# Europas Sanktionen gegen China – historisch, aber harmlos: http://api.zeit.de/content/5DfxsDlJ5UEwvv9tV9ZfkF
# Die bekannten Unbekannten: http://api.zeit.de/content/78TpiYB3xH6GUaz2cZfrmC
# Alfred Sauter tritt aus CSU-Landtagsfraktion aus: http://api.zeit.de/content/3PM3BmcL7HFbXpigPEIHSJ

# %%
test2=api.get(url = "http://api.zeit.de/content", limit = 10000, search = "corona")
test2
# Out:
# {'matches': [{'subtitle': 'Der Prozess um den größten bekannten Steuerskandal der deutschen Geschichte hat begonnen. Einer der Angeklagten lebt in der Schweiz und tauchte zum Auftakt nicht auf.',
#    'uuid': '3s3YhJKy2dehj9xoGrDpM9',
#    'title': 'Prozess um milliardenschwere Cum-Ex-Aktiendeals hat begonnen',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/cum-ex-skandal-steuerbetrug-aktiendeal-hanno-berger-prozess',
#    'release_date': '2021-03-25T14:25:38Z',
#    'uri': 'http://api.zeit.de/content/3s3YhJKy2dehj9xoGrDpM9',
#    'snippet': ' Frankfurt hatte schon im Mai 2018 ihre Anklage öffentlich gemacht. Sie wurde aber lange geprüft und der Prozess wegen <em>Corona</em>-Pandemie mehrfach vertagt.\nUrsprünglich waren sechs Menschen angeklagt. Das',
#    'supertitle': 'Steuerbetrug',
#    'teaser_text': 'Der Prozess um den größten bekannten Steuerskandal der deutschen Geschichte hat begonnen. Einer der Angeklagten lebt in der Schweiz und tauchte zum Auftakt nicht auf.',
#    'teaser_title': 'Prozess um milliardenschwere Cum-Ex-Aktiendeals hat begonnen'},
#   {'subtitle': 'Noch drei, vier schwere Monate? Nur noch ein bisschen zusammenreißen? Schluss damit! Hier können Sie Ihren Frust rauslassen, schreien Sie uns an!',
#    'uuid': '6YyGGlsBHt9mTl8QkVnrr6',
#    'title': 'Coronaaaaaaaaaargghhh!',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2021-03/corona-krise-lockdown-wut-frust-verzweiflung-angst-leseraufruf',
#    'release_date': '2021-03-25T14:12:53Z',
#    'uri': 'http://api.zeit.de/content/6YyGGlsBHt9mTl8QkVnrr6',
#    'snippet': ',\nschimpfen,\nweinen,\nsingen,\nerzählen, was Ihnen zum Thema <em>Corona</em> auf der Seele liegt.\nSenden Sie uns eine Sprachnachricht an 0157 57551398 und machen Sie sich Luft. Sie können WhatsApp, Signal oder Telegram',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Noch drei, vier schwere Monate? Nur noch ein bisschen zusammenreißen? Schluss damit! Hier können Sie Ihren Frust rauslassen, schreien Sie uns an!',
#    'teaser_title': 'Coronaaaaaaaaaargghhh!'},
#   {'subtitle': 'Nach ihrer öffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.',
#    'uuid': '6Ux163KMzgplMUcaejSUIQ',
#    'title': 'Erst Selbstkritik, dann Selbstverteidigung',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-corona-lockdown-ostern-eu-gipfel-intensivstationen',
#    'release_date': '2021-03-25T12:53:01Z',
#    'uri': 'http://api.zeit.de/content/6Ux163KMzgplMUcaejSUIQ',
#    'snippet': ' berichtet sie dem Parlament über die Themen des anstehenden Europäischen Rates. Sie lobt den europäischen Resilienzfonds, der helfen soll, die schwere Wirtschaftskrise infolge der <em>Corona</em>-Pandemie zu',
#    'supertitle': 'Angela Merkel',
#    'teaser_text': 'Nach ihrer öffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.',
#    'teaser_title': 'Erst Selbstkritik, dann Selbstverteidigung'},
#   {'subtitle': 'Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.',
#    'uuid': '31Dsx9ZRJZ2atPIMsvZla9',
#    'title': 'Die Last der Erwartung',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/europa-eu-von-der-leyen-corona-gipfel',
#    'release_date': '2021-03-25T12:14:24Z',
#    'uri': 'http://api.zeit.de/content/31Dsx9ZRJZ2atPIMsvZla9',
#    'snippet': ' erneut eines der bestimmenden Themen sein wird. Im internationalen Kampf gegen <em>Corona</em> scheint die EU tatsächlich keine allzu gute Figur zu machen: Die Impfquote in ihren Mitgliedstaaten liegt deutlich',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.',
#    'teaser_title': 'Die Last der Erwartung'},
#   {'subtitle': 'Die Münchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaffäre in der Union festnehmen lassen. In Thüringer CDU-Büros gab es Durchsuchungen.',
#    'uuid': '1AoHRPchEPrODNj4J7HIzp',
#    'title': 'Haftbefehl und eine Festnahme in der Maskenaffäre',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/haftbefehl-in-der-maskenaffaere-erlassen',
#    'release_date': '2021-03-25T11:40:50Z',
#    'uri': 'http://api.zeit.de/content/1AoHRPchEPrODNj4J7HIzp',
#    'snippet': 'In der Affäre um Korruptionsvorwürfe beim Kauf von <em>Corona</em>-Schutzmasken hat es nach Angaben der Münchener Generalstaatsanwaltschaft eine Festnahme gegeben. Ein Haftbefehl sei erlassen worden, teilte',
#    'supertitle': 'München',
#    'teaser_text': 'Die Münchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaffäre in der Union festnehmen lassen. In Thüringer CDU-Büros gab es Durchsuchungen.',
#    'teaser_title': 'Haftbefehl und Festnahme in der Maskenaffäre'},
#   {'subtitle': 'Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.',
#    'uuid': '5s0zkP0iNOnxucf7UryTns',
#    'title': 'Positiver Corona-Test in der Fußballnationalmannschaft',
#    'href': 'http://www.zeit.de/sport/2021-03/dfb-corona-test-nationalmannschaft-wm-qualifikationsspiel',
#    'release_date': '2021-03-25T11:38:04Z',
#    'uri': 'http://api.zeit.de/content/5s0zkP0iNOnxucf7UryTns',
#    'snippet': 'Kurz vor dem WM-Qualifikationsspiel gegen Island hat es bei der deutschen Fußballnationalmannschaft einen positiven <em>Corona</em>-Test gegeben, wie der Deutsche Fußball-Bund (DFB) bestätigte.\nDer Spieler',
#    'supertitle': 'DFB',
#    'teaser_text': 'Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.',
#    'teaser_title': 'Positiver Corona-Test in der Fußballnationalmannschaft'},
#   {'subtitle': 'Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.',
#    'uuid': 'V5mg2tY0jnP32xpzwXw1l',
#    'title': 'Streit um Impfstoffverteilung und Exportkontrollen',
#    'href': 'http://www.zeit.de/politik/2021-03/eu-gipfel-corona-impfung-impfstoff-astrazeneca-verteilung',
#    'release_date': '2021-03-25T11:24:43Z',
#    'uri': 'http://api.zeit.de/content/V5mg2tY0jnP32xpzwXw1l',
#    'snippet': ' der in der EU produzierten <em>Corona</em>-Impfstoffe exportiert wird. Größter Abnehmer ist Großbritannien. Zurück kommt von dort aber so gut wie nichts.\nAm Mittwoch beschloss die Kommission deshalb eine',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.',
#    'teaser_title': 'Streit um Impfstoffverteilung und Exportkontrollen'},
#   {'subtitle': 'Die Mitbegründerin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht über die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.',
#    'uuid': '4ZD2UDcxIgF3PbnmZasUTK',
#    'title': 'Maja Göpel, wie können wir die Welt neu denken?',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/maja-goepel-interviewpodcast-alles-gesagt',
#    'release_date': '2021-03-25T10:28:02Z',
#    'uri': 'http://api.zeit.de/content/4ZD2UDcxIgF3PbnmZasUTK',
#    'snippet': 'Sie gilt als Wissenschaftlerin der Stunde, als eine der prägenden Stimmen unserer Zeit – und das, obwohl sie kein Buch über die <em>Corona</em>-Pandemie geschrieben hat: Maja Göpel ist zu Gast bei Alles',
#    'supertitle': 'Maja Göpel',
#    'teaser_text': 'Die Mitbegründerin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht über die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.',
#    'teaser_title': 'Maja Göpel, wie können wir die Welt neu denken?'},
#   {'subtitle': 'Das Unternehmen bemüht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie veröffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.',
#    'uuid': '538zqBwwLdW8oVWlZ2q9Jp',
#    'title': 'AstraZeneca korrigiert Wirksamkeit seines Impfstoffes nach unten',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/astrazeneca-corona-impfstoff-wirksamkeit-studien-daten-korrektur',
#    'release_date': '2021-03-25T10:03:01Z',
#    'uri': 'http://api.zeit.de/content/538zqBwwLdW8oVWlZ2q9Jp',
#    'snippet': 'Nach Zweifeln an einer großangelegten US-Studie zur Wirksamkeit des <em>Corona</em>-Impfstoffs von AstraZeneca hat das Pharmaunternehmen seine Angaben nach unten korrigiert. Der Impfstoff schützt demnach zu',
#    'supertitle': 'Corona-Impfstoff',
#    'teaser_text': 'Das Unternehmen bemüht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie veröffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.',
#    'teaser_title': 'AstraZeneca korrigiert Wirksamkeit seines Impfstoffes nach unten'},
#   {'subtitle': 'Ein Ländervergleich aus gegebenem Anlass\u2002',
#    'uuid': '6I0o9cccMpkBBK1Liio5rw',
#    'title': 'Bayern oder NRW, was ist besser?',
#    'href': 'http://www.zeit.de/2021/13/bundesland-vergleich-nordrhein-westfalen-bayern-statistik',
#    'release_date': '2021-03-25T10:00:54Z',
#    'uri': 'http://api.zeit.de/content/6I0o9cccMpkBBK1Liio5rw',
#    'snippet': 'Wenn in den vergangenen Monaten die Bundesländer Bayern und NRW verglichen wurden, ging es meist \xaddarum, wer die bessere <em>Corona</em>-Strategie hat: die lässigen Rheinländer oder die strengen Bayern, bei',
#    'supertitle': 'Bundesländer im Vergleich',
#    'teaser_text': 'Ein Ländervergleich aus gegebenem Anlass\u2002',
#    'teaser_title': 'Bayern oder NRW, was ist besser?'},
#   {'subtitle': 'Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept "Housing first".',
#    'uuid': '1B144cBunBxUKdPmq26LKz',
#    'title': '"Wir haben zu lange geglaubt, der Markt werde das Problem lösen"',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/nicolas-schmit-eu-kommission-obdachlosigkeit-europa-sozialpolitik',
#    'release_date': '2021-03-25T09:57:20Z',
#    'uri': 'http://api.zeit.de/content/1B144cBunBxUKdPmq26LKz',
#    'snippet': ' Zahl der Obdachlosen gestiegen. Und jetzt schlägt die <em>Corona</em>-Krise stark auf den Arbeitsmarkt durch. Dazu kommt das Thema Migration: Viele Flüchtlinge haben keinen Wohnsitz. Auf der Suche nach Arbeit',
#    'supertitle': 'Nicolas Schmit',
#    'teaser_text': 'Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept Housing first.',
#    'teaser_title': '"Wir haben zu lange geglaubt, der Markt werde das Problem lösen"'},
#   {'subtitle': 'Schlepper und Bagger versuchen den im Sueskanal havarierten Frachter "Ever Given" zu befreien. Industrie und Logistikexperten warnen vor einer Störung der Lieferketten.',
#    'uuid': '4VpGMYrhZwnfDxhyO4SgJV',
#    'title': 'Mindestens 150 Schiffe durch feststeckenden Frachter blockiert',
#    'href': 'http://www.zeit.de/wirtschaft/2021-03/suezkanal-ever-given-containerschiff-oelpreis-welthandel-blockade',
#    'release_date': '2021-03-25T09:07:37Z',
#    'uri': 'http://api.zeit.de/content/4VpGMYrhZwnfDxhyO4SgJV',
#    'snippet': ' Handelspartner China dürfte leiden. Das hatte zuletzt merklich angezogen und der exportabhängigen Industrie aus der <em>Corona</em>-Rezession geholfen. Doch ein Großteil der Lieferungen kommt durch den Sueskanal. Zudem ist',
#    'supertitle': 'Sueskanal',
#    'teaser_text': 'Schlepper und Bagger versuchen den im Sueskanal havarierten Frachter "Ever Given" zu befreien. Industrie und Logistikexperten warnen vor einer Störung der Lieferketten.',
#    'teaser_title': 'Mindestens 150 Schiffe durch feststeckenden Frachter blockiert'},
#   {'subtitle': 'Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.',
#    'uuid': '7JWDt7dkFr3PF73wf6y0zP',
#    'title': '"Wir werden dieses Virus besiegen"',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-regierungserklaerung-bundestag-corona',
#    'release_date': '2021-03-25T08:23:22Z',
#    'uri': 'http://api.zeit.de/content/7JWDt7dkFr3PF73wf6y0zP',
#    'snippet': '-, 60- und 70-Jährige sein. Und das sind Menschen mit sehr vielen Jahren Lebenserwartung." Zehn Prozent von ihnen würden laut Experteneinschätzung <em>Corona</em>-Langzeitfolgen davontragen. "Es lohnt sich, um',
#    'supertitle': 'Regierungserklärung',
#    'teaser_text': 'Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.',
#    'teaser_title': '"Wir werden dieses Virus besiegen"'},
#   {'subtitle': 'Einen Tag nach Absage der angekündigten Osterruhe tritt die Bundeskanzlerin erneut vor den Bundestag. Verfolgen Sie Merkels Regierungserklärung im Livestream',
#    'uuid': '77yvBt2KPs8v2usBduTId6',
#    'title': 'Jetzt live: Angela Merkel gibt Regierungserklärung ab',
#    'href': 'http://www.zeit.de/politik/2021-03/angela-merkel-corona-lockdown-ostern-regierungserklaerung-livestream',
#    'release_date': '2021-03-25T07:59:38Z',
#    'uri': 'http://api.zeit.de/content/77yvBt2KPs8v2usBduTId6',
#    'snippet': 'Die wichtigsten Neuigkeiten zur <em>Corona</em>-Lage in Deutschland lesen Sie in unserem Liveblog.',
#    'supertitle': 'Lockdown über Ostern',
#    'teaser_text': 'Einen Tag nach Absage der angekündigten Osterruhe tritt die Bundeskanzlerin erneut vor den Bundestag. Verfolgen Sie Merkels Regierungserklärung im Livestream',
#    'teaser_title': 'Jetzt live: Angela Merkel gibt Regierungserklärung ab'},
#   {'subtitle': 'Die gelieferten Impfstoffmengen steigen, aber viele Bundesländer kommen nur langsam voran mit der Verabreichung. Ab April sollen deutlich mehr Impfdosen verfügbar sein.',
#    'uuid': '227unSuNGUZpBq55bUzit8',
#    'title': 'Impftempo stagniert bei deutlich unter 300.000 Impfungen pro Tag',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/impfkampagne-impftempo-deutschland-bundeslaender-ostern',
#    'release_date': '2021-03-25T07:27:57Z',
#    'uri': 'http://api.zeit.de/content/227unSuNGUZpBq55bUzit8',
#    'snippet': '. In welchem Umfang die Hochbetagten geschützt sind, ist zwischen den Ländern ebenfalls unterschiedlich, wie das Robert Koch-Institut in seinen Berichten zeigt.\nMit erwarteten 70,5 bis 73,5 Millionen <em>Corona</em>',
#    'supertitle': 'Impfkampagne',
#    'teaser_text': 'Die gelieferten Impfstoffmengen steigen, aber viele Bundesländer kommen nur langsam voran mit der Verabreichung. Ab April sollen deutlich mehr Impfdosen verfügbar sein.',
#    'teaser_title': 'Impftempo stagniert bei deutlich unter 300.000 Impfungen pro Tag'},
#   {'subtitle': 'Die Bundeskanzlerin gesteht Fehler ein, die Corona-Infektionen nehmen zu, die EU ringt um Impfstoffe und der Sueskanal bleibt blockiert. Der Überblick am Morgen',
#    'uuid': 'peEdGOLL34XEtSUE8FBrM',
#    'title': 'Angela Merkels Schuld, eine Havarie und steigende Zahlen',
#    'href': 'http://www.zeit.de/newsletter/was-jetzt/2021-03/merkel-suezkanal-corona-2021-03-25',
#    'release_date': '2021-03-25T06:38:23Z',
#    'uri': 'http://api.zeit.de/content/peEdGOLL34XEtSUE8FBrM',
#    'snippet': ' Schuld auf sich, die EU will Impfstoffexporte verbieten, die <em>Corona</em>-Zahlen steigen stark an, der Sueskanal bleibt blockiert und die neue ZEIT ist da.\nEin Fehler, aber keine Ruhe: Angela Merkel hat die',
#    'supertitle': '"Was jetzt?"-Newsletter',
#    'teaser_text': 'Die Bundeskanzlerin gesteht Fehler ein, die Corona-Infektionen nehmen zu, die EU ringt um Impfstoffe und der Sueskanal bleibt blockiert. Der Überblick am Morgen',
#    'teaser_title': 'Angela Merkels Schuld, eine Havarie und steigende Zahlen'},
#   {'subtitle': 'Personalerin Julia Schusser führt bei Audi im Jahr 400 Vorstellungsgespräche. Hier erzählt sie, warum ein chaotischer Hintergrund von Vorteil sein kann.',
#    'uuid': 'Ew0IpzEtO8aY66mzGQtHY',
#    'title': '"Vom Hoodie bis zum Anzug ist alles in Ordnung"',
#    'href': 'http://www.zeit.de/arbeit/2021-03/vorstellungsgespraeche-bewerbung-tipps-tricks-personalerin-audi',
#    'release_date': '2021-03-25T05:10:51Z',
#    'uri': 'http://api.zeit.de/content/Ew0IpzEtO8aY66mzGQtHY',
#    'snippet': '-Gespräch vor <em>Corona</em> sehr nervös wirkten und dann im zweiten Onlinegespräch im Lockdown gelassener und entspannter durch die Kamera kommunizierten. Die Stressfaktoren von einem Vorstellungsgespräch vor Ort',
#    'supertitle': 'Vorstellungsgespräche',
#    'teaser_text': 'Personalerin Julia Schusser führt bei Audi im Jahr 400 Vorstellungsgespräche – derzeit online. Hier erzählt sie, warum ein chaotischer Hintergrund von Vorteil sein kann.',
#    'teaser_title': '"Vom Hoodie bis zum Anzug ist alles in Ordnung"'},
#   {'subtitle': 'Während um die großen Linien in der Coronapolitik gestritten wird, probieren Tübingen, Rostock und Altötting neue Wege im Kampf gegen die Krise aus. Wie funktioniert das?',
#    'uuid': '24Y25YNeZVf4GyuiSJKuQb',
#    'title': 'Es geht auch anders',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/pandemiebekaempfung-kommunen-konzepte-corona-tuebingen-rostock-altoetting',
#    'release_date': '2021-03-25T05:08:41Z',
#    'uri': 'http://api.zeit.de/content/24Y25YNeZVf4GyuiSJKuQb',
#    'snippet': 'Während Ministerpräsidenten und die Kanzlerin über die großen Linien der <em>Corona</em>-Politik streiten, versuchen viele Städte und Gemeinden, vor Ort kleine und praktikable Lösungen zu finden. Wir stellen',
#    'supertitle': 'Pandemiebekämpfung',
#    'teaser_text': 'Während um die großen Linien in der Coronapolitik gestritten wird, probieren Tübingen, Rostock und Altötting neue Wege im Kampf gegen die Krise aus. Wie funktioniert das?',
#    'teaser_title': 'Es geht auch anders'},
#   {'subtitle': 'Beim EU-Gipfel geht es unter anderem um die Impfstoffversorgung – ein besonderer Gast will sich zuschalten. Außerdem: Therapieren deutsche Intensivstationen zu viel?',
#    'uuid': '335BzYQeHGPKRVy2tMKFyB',
#    'title': 'Viel Diskussionsbedarf und ein besonderer Gast',
#    'href': 'http://www.zeit.de/politik/2021-03/eu-gipfel-corona-impfstoff-joe-biden-nachrichtenpodcast',
#    'release_date': '2021-03-25T04:54:21Z',
#    'uri': 'http://api.zeit.de/content/335BzYQeHGPKRVy2tMKFyB',
#    'snippet': ' möglich ist, ist auch sinnvoll.\xa0\nJan Schweitzer, Redakteur im Ressort Wissen der ZEIT, ordnet die Warnung der Fachleute für Intensivmedizin ein. Er setzt sie in Beziehung zur aktuellen <em>Corona</em>-Lage und zeigt',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Beim EU-Gipfel geht es unter anderem um die Impfstoffversorgung – ein besonderer Gast will sich zuschalten. Außerdem: Therapieren deutsche Intensivstationen zu viel?',
#    'teaser_title': 'Viel Diskussionsbedarf und ein besonderer Gast'},
#   {'subtitle': '95 Prozent der Seniorinnen und Senioren in Pflegeheimen haben mindestens eine Impfung erhalten. Die Impfkampagne stagniert, doch Jens Spahn verspricht Besserung.',
#    'uuid': '36itswdSW0JtLGRxwyWXTy',
#    'title': 'Fast alle Pflegeheimbewohner laut RKI geimpft',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/corona-pandemie-impfkampagne-rki-deutschland-pflegeheime',
#    'release_date': '2021-03-25T04:37:29Z',
#    'uri': 'http://api.zeit.de/content/36itswdSW0JtLGRxwyWXTy',
#    'snippet': ' bevorstehenden zweiten Quartal sollen deutlich mehr Menschen in Deutschland geimpft werden können, insgesamt werden 70,5 bis 73,5 Millionen <em>Corona</em>-Impfdosen erwartet. Im ersten Quartal waren es 19,8 Millionen',
#    'supertitle': 'Corona-Pandemie',
#    'teaser_text': '95 Prozent der Seniorinnen und Senioren in Pflegeheimen haben mindestens eine Impfung erhalten. Bundesweit stagniert die Impfkampagne, Jens Spahn verspricht Besserung.',
#    'teaser_title': 'Fast alle Pflegeheimbewohner laut RKI geimpft'},
#   {'subtitle': 'Lothar Wieler hat nach Angela Merkels Kehrtwende empfohlen, das öffentliche Leben herunterzufahren. Laut Epidemiologen reichen fünf Tage Osterruhe nicht einmal aus.',
#    'uuid': '48DikAXNqmJezt4YVLoMhz',
#    'title': 'Dritte Welle laut RKI-Chef nur mit Lockdown zu stoppen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/corona-politik-rki-chef-lothar-wieler-lockdown-dritte-welle',
#    'release_date': '2021-03-25T04:01:38Z',
#    'uri': 'http://api.zeit.de/content/48DikAXNqmJezt4YVLoMhz',
#    'snippet': 'Die jüngste Zunahme der <em>Corona</em>-Neuinfektionen in Deutschland kann nach Ansicht des Robert Koch-Instituts (RKI) nur mit Hilfe eines Lockdowns gestoppt werden. Bis ein Großteil der Bevölkerung gegen',
#    'supertitle': 'Corona-Politik',
#    'teaser_text': 'Lothar Wieler hat nach Angela Merkels Kehrtwende empfohlen, das öffentliche Leben herunterzufahren. Laut Epidemiologen reichen fünf Tage Osterruhe nicht einmal aus.',
#    'teaser_title': 'Dritte Welle laut RKI-Chef nur mit Lockdown zu stoppen'},
#   {'subtitle': 'Gemeinsam könne die westliche Welt China Paroli bieten, sagte Antony Blinken in Brüssel. Die USA und die EU hatten Sanktionen wegen der Lage der Uiguren verhängt.',
#    'uuid': '7F0QUJDD8rbk7LJM2iIwgn',
#    'title': 'US-Außenminister stellt EU enge Zusammenarbeit in Aussicht',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/usa-aussenminister-antony-blinken-eu-china-beziehung',
#    'release_date': '2021-03-25T00:32:25Z',
#    'uri': 'http://api.zeit.de/content/7F0QUJDD8rbk7LJM2iIwgn',
#    'snippet': ' chinesische Führung ihrerseits Missstände in den USA. Dort sei die <em>Corona</em>-Pandemie außer Kontrolle geraten, es habe politisches Chaos, Konflikte zwischen Menschen unterschiedlicher Hautfarbe und',
#    'supertitle': 'USA',
#    'teaser_text': 'Gemeinsam könne die westliche Welt China Paroli bieten, sagte Antony Blinken in Brüssel. Die USA und die EU hatten Sanktionen wegen der Lage der Uiguren verhängt.',
#    'teaser_title': 'US-Außenminister stellt EU enge Zusammenarbeit in Aussicht'},
#   {'subtitle': 'Die Testpflicht für Flugpassagiere reicht vielen nicht aus – auch der Kanzlerin nicht. Deshalb lässt die Bundesregierung weitere Maßnahmen prüfen.',
#    'uuid': '13vPkzOimFOfvkcLp2bUXK',
#    'title': 'Bundesregierung prüft Verbot von Auslandsreisen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/corona-beschluesse-bundesregierung-urlaubsreisen-ausland-unterbindung',
#    'release_date': '2021-03-25T00:21:09Z',
#    'uri': 'http://api.zeit.de/content/13vPkzOimFOfvkcLp2bUXK',
#    'snippet': 'Angesichts der Diskussion über Mallorca-Urlaub trotz <em>Corona</em> erwägt die Bundesregierung, Reisen in beliebte Urlaubsgebiete im Ausland vorübergehend zu unterbinden. "Das wird jetzt von den zuständigen',
#    'supertitle': 'Corona-Beschlüsse',
#    'teaser_text': 'Die Testpflicht für Flugpassagiere reicht vielen nicht aus – auch der Kanzlerin nicht. Deshalb lässt die Bundesregierung weitere Maßnahmen prüfen.',
#    'teaser_title': 'Bundesregierung prüft Verbot von Auslandsreisen'},
#   {'subtitle': 'Mit 22.657 Corona-Neuinfektionen meldet die Behörde einen rasanten Anstieg der Infektionszahlen. Die Sieben-Tage-Inzidenz stieg auf 113.',
#    'uuid': '6uTeBQX2eYAb9zK40AvRhQ',
#    'title': 'RKI registriert gut 5.000 Neuinfektionen mehr als vor einer Woche',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/coronavirus-neuinfektionen-rki-gesundheitsaemter',
#    'release_date': '2021-03-24T21:25:29Z',
#    'uri': 'http://api.zeit.de/content/6uTeBQX2eYAb9zK40AvRhQ',
#    'snippet': 'Die deutschen Gesundheitsämter haben dem Robert Koch-Institut (RKI) im Laufe des Mittwochs 22.657 <em>Corona</em>-Neuinfektionen gemeldet, gut 5.000 mehr als noch vor einer Woche (17.504). ZEIT ONLINE kommt',
#    'supertitle': 'Coronavirus',
#    'teaser_text': 'Mit 22.657 Corona-Neuinfektionen meldet die Behörde einen rasanten Anstieg der Infektionszahlen. Die Sieben-Tage-Inzidenz stieg auf 113.',
#    'teaser_title': 'RKI registriert gut 5.000 Neuinfektionen mehr als vor einer Woche'},
#   {'subtitle': 'Die Kanzlerin versichert, sie habe die Unterstützung der gesamten Regierung. Forderungen nach weiteren Konsequenzen aus der Absage des Osterlockdowns weist sie zurück.',
#    'uuid': '7xzmc4S70a1FIyWw9rDea5',
#    'title': 'Angela Merkel lehnt Vertrauensfrage ab',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/cdu-angela-merkel-vertrauensfrage-opposition-bundestag',
#    'release_date': '2021-03-24T20:47:54Z',
#    'uri': 'http://api.zeit.de/content/7xzmc4S70a1FIyWw9rDea5',
#    'snippet': ' Opposition. Diese Begegnungen mit den 16 Länderchefs seien wichtig, weil das Infektionsschutzgesetz regele, dass die Länder für die <em>Corona</em>-Maßnahmen zuständig seien. "Damit Deutschland nicht ein vollständiger',
#    'supertitle': 'CDU',
#    'teaser_text': 'Die Kanzlerin versichert, sie habe die Unterstützung der gesamten Regierung. Forderungen nach weiteren Konsequenzen aus der Absage des Osterlockdowns weist sie zurück.',
#    'teaser_title': 'Angela Merkel lehnt Vertrauensfrage ab'},
#   {'subtitle': 'Kinder infizieren sich zwar seltener als Erwachsene und verkraften Covid-19 besser. Doch auch für sie ist die Mutante ansteckender. Was das für Kitas und Schulen heißt.',
#    'uuid': '6NbtygoCmS6eAj1gpwOaIE',
#    'title': 'Warum gerade jetzt mehr Kinder Corona kriegen',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/infektionsrisiko-schulen-kitas-kinder-neuinfektion-corona-pandemie',
#    'release_date': '2021-03-24T19:24:10Z',
#    'uri': 'http://api.zeit.de/content/6NbtygoCmS6eAj1gpwOaIE',
#    'snippet': 'Frust und starke Emotionen prägen die Debatte um Kinder und <em>Corona</em>. Die Frage, wann und wie Kinder in der Pandemie zur Schule oder in die Kita dürfen, birgt Sprengkraft. Einheitliche, klare Regeln',
#    'supertitle': 'Infektionsrisiko in Schulen und Kitas',
#    'teaser_text': 'Kinder infizieren sich zwar seltener als Erwachsene\xa0und verkraften Covid-19 besser. Doch auch für sie ist die Mutante ansteckender. Was das für Kitas und Schulen heißt.',
#    'teaser_title': 'Warum gerade jetzt mehr Kinder Corona kriegen'},
#   {'subtitle': 'Wer entscheidet, wenn man es selbst nicht mehr kann? Eine Vollmacht hilft Angehörigen. Wir erklären, wie man auf einer DIN-A4-Seite Vorkehrungen für den Notfall trifft.',
#    'uuid': '6tPLZI8RIAJPsbv3Rhai5k',
#    'title': 'Darauf kommt es bei einer Vorsorgevollmacht an',
#    'href': 'http://www.zeit.de/wirtschaft/2021-02/vorsorgevollmacht-patientenverfuegung-recht-handlungsfaehigkeit-geschaeftsunfaehigkeit-faq',
#    'release_date': '2021-03-24T19:23:28Z',
#    'uri': 'http://api.zeit.de/content/6tPLZI8RIAJPsbv3Rhai5k',
#    'snippet': 'Sie haben auch noch keine Vorsorgevollmacht und fragen sich: Brauche ich das überhaupt? Wir sagen: Besser ist es. Und helfen Ihnen dabei, sie aufzustellen. Denn in der <em>Corona</em>-Krise bewegt immer mehr',
#    'supertitle': 'Rechtliche Vorsorge',
#    'teaser_text': 'Wer entscheidet, wenn man es selbst nicht mehr kann? Eine Vollmacht hilft Angehörigen. Wir erklären, wie man auf einer DIN-A4-Seite Vorkehrungen für den Notfall trifft.',
#    'teaser_title': 'Darauf kommt es bei einer Vorsorgevollmacht an'},
#   {'subtitle': 'Inzwischen sind fast neun Millionen Menschen in Deutschland gegen Covid geimpft worden. Die Quote für schwere Verdachtsfälle liegt bei 0,3 pro 1.000 Impfdosen.',
#    'uuid': '7ffPlIgNBBgvBtNSIpOL1t',
#    'title': 'Schwere Nebenwirkungen nach Corona-Impfung weiterhin die Ausnahme',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/nebenwirkungen-impfung-coronavirus-paul-ehrlich-institut',
#    'release_date': '2021-03-24T18:47:55Z',
#    'uri': 'http://api.zeit.de/content/7ffPlIgNBBgvBtNSIpOL1t',
#    'snippet': 'Schwerwiegende Nebenwirkungen nach <em>Corona</em>-Impfungen treten weiterhin nur sehr selten auf. Nach fast neun Millionen Impfungen in Deutschland nannte das zuständige Paul-Ehrlich-Institut (PEI) eine',
#    'supertitle': 'Paul-Ehrlich-Institut',
#    'teaser_text': 'Inzwischen sind fast neun Millionen Menschen in Deutschland gegen Covid geimpft worden. Die Quote für schwere Verdachtsfälle liegt bei 0,3 pro 1.000 Impfdosen.',
#    'teaser_title': 'Schwere Nebenwirkungen nach Corona-Impfung weiterhin die Ausnahme'},
#   {'subtitle': 'Das ist neu, nicht nur für die Corona-Politik, sondern auch für fast 16 Jahre Kanzlerschaft. Merkel hat um Verzeihung gebeten – und könnte ihre Position so verbessern.',
#    'uuid': '4cHpUa7ubbZSFb2N0hcfLh',
#    'title': 'Angela Merkels Kalkül könnte aufgehen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/pandmie-politik-corona-angela-merkel-entschuldigung-opposition-bundestag',
#    'release_date': '2021-03-24T17:18:16Z',
#    'uri': 'http://api.zeit.de/content/4cHpUa7ubbZSFb2N0hcfLh',
#    'snippet': ' die dritte Welle der <em>Corona</em>-Pandemie zumindest ein wenig zu brechen. Eine Idee, auf die laut Süddeutscher Zeitung Kanzleramtschef Helge Braun mehr oder weniger spontan gekommen war. ("Helge, hast du',
#    'supertitle': 'Pandemiepolitik',
#    'teaser_text': 'Das ist neu, nicht nur für die Corona-Politik, sondern auch für fast 16 Jahre Kanzlerschaft. Merkel hat um Verzeihung gebeten – und könnte ihre Position so verbessern.',
#    'teaser_title': 'Angela Merkels Kalkül könnte aufgehen'},
#   {'subtitle': 'Für das laufende Jahr braucht das Finanzministerium 60,4 Milliarden Euro mehr und will einen Nachtragshaushalt. Auch 2022 dürfte die Schuldenbremse kaum zu halten sein.',
#    'uuid': '25AF0UIwcGpbDdoZM3qFmb',
#    'title': 'Bundesregierung plant mit 81,5 Milliarden neuen Schulden für 2022',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/staatsverschuldung-bundesregierung-schulden-2022-haushalt-schuldenbremse-finanzpolitik',
#    'release_date': '2021-03-24T17:15:47Z',
#    'uri': 'http://api.zeit.de/content/25AF0UIwcGpbDdoZM3qFmb',
#    'snippet': 'Die Bundesregierung verteidigt die Rekordverschuldung als Reaktion auf die <em>Corona</em>-Pandemie: "Das ist teuer. Aber Nichtstun wäre viel teurer", sagte Bundesfinanzminister Olaf Scholz (SPD) bei der',
#    'supertitle': 'Staatsverschuldung',
#    'teaser_text': 'Für das laufende Jahr braucht das Finanzministerium 60,4 Milliarden Euro mehr und will einen Nachtragshaushalt. Auch 2022 dürfte die Schuldenbremse kaum zu halten sein.',
#    'teaser_title': 'Bundesregierung plant mit 81,5 Milliarden neuen Schulden für 2022'},
#   {'subtitle': 'Im Streit mit AstraZeneca um Impfstofflieferungen hat die Kommission in Brüssel neue Regeln erlassen. Generelle Ausfuhrverbote gibt es zwar nicht – neue Kriterien schon.',
#    'uuid': '69JIVt1W9QZu4g1CzYe42x',
#    'title': 'EU verschärft Kontrolle von Impfstoffexporten',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/eu-kommission-corona-impfstoff-export-kontrolle-exportstopp-europaeische-union',
#    'release_date': '2021-03-24T17:00:43Z',
#    'uri': 'http://api.zeit.de/content/69JIVt1W9QZu4g1CzYe42x',
#    'snippet': 'Der Export der knappen <em>Corona</em>-Impfstoffe aus der Europäischen Union soll nach dem Willen der EU noch schärfer kontrolliert und notfalls häufiger gestoppt werden. Dies beschloss die Kommission',
#    'supertitle': 'Streit mit AstraZeneca',
#    'teaser_text': 'Im Streit mit AstraZeneca um Impfstofflieferungen hat die Kommission in Brüssel neue Regeln erlassen. Generelle Ausfuhrverbote gibt es zwar nicht – neue Kriterien schon.',
#    'teaser_title': 'EU verschärft Kontrolle von Impfstoffexporten'},
#   {'subtitle': 'Die Bundeskanzlerin hat die unlängst beschlossene "Osterruhe" zurückgezogen und einen Fehler eingestanden. Die Opposition im Bundestag fordert eine Vertrauensabstimmung.',
#    'uuid': '6vzg6RO7KZ0V8eVhQtKvjD',
#    'title': 'Angela Merkel übernimmt Verantwortung',
#    'href': 'http://www.zeit.de/politik/2021-03/corona-beschluesse-ruhetage-lockdown-ostern-angela-merkel-nachrichtenpodcast',
#    'release_date': '2021-03-24T16:24:15Z',
#    'uri': 'http://api.zeit.de/content/6vzg6RO7KZ0V8eVhQtKvjD',
#    'snippet': 'Nicht einmal 48 Stunden nach dem Beschluss der Bund-Länder-Runde, zur <em>Corona</em>-Bekämpfung rund um Ostern zusätzliche "Ruhetage" einzurichten, hat Bundeskanzlerin Angela Merkel diese Entscheidung heute',
#    'supertitle': 'Corona-Beschlüsse',
#    'teaser_text': 'Die Bundeskanzlerin hat die unlängst beschlossene "Osterruhe" zurückgezogen und einen Fehler eingestanden. Die Opposition im Bundestag fordert eine Vertrauensabstimmung.',
#    'teaser_title': 'Angela Merkel übernimmt Verantwortung'},
#   {'subtitle': 'Aus dem Gefängnis spricht der türkische Oppositionspolitiker Selahattin Demirtaş über das drohende Verbot seiner Partei\u2002',
#    'uuid': '6lmkoZSiBpG7wWQT11Qybi',
#    'title': '"Kein Grund, hoffnungslos zu sein"',
#    'href': 'http://www.zeit.de/2021/13/selahattin-demirtas-tuerkei-hdp-verbot-erdogan-akp-menschenrechte',
#    'release_date': '2021-03-24T15:52:54Z',
#    'uri': 'http://api.zeit.de/content/6lmkoZSiBpG7wWQT11Qybi',
#    'snippet': ' und sie einem seiner Anwälte bei einem der nächsten Besuche zurückgeben. Aber jetzt ist <em>Corona</em>. Anwalt und Mandant sind derzeit durch eine Glasscheibe getrennt, sie dürfen keine Unterlagen austauschen',
#    'supertitle': 'Selahattin Demirtaş',
#    'teaser_text': 'Aus dem Gefängnis spricht der türkische Oppositionspolitiker Selahattin Demirtaş über das drohende Verbot seiner Partei\u2002',
#    'teaser_title': '"Kein Grund, hoffnungslos zu sein"'},
#   {'subtitle': 'Der Intensivmediziner Uwe Janssens ermahnt seine Kollegen zu mehr Augenmaß in der Therapie. Der Wille der Patientinnen und Patienten müsse im Mittelpunkt stehen',
#    'uuid': '6eYN46kHAUS4Cdg3pPRwGg',
#    'title': '"Mit dem Tod offen umgehen"',
#    'href': 'http://www.zeit.de/2021/13/uwe-janssens-intensivmedizin-ethik-therapie-ueberversorgung-ueberschaetzung',
#    'release_date': '2021-03-24T15:52:50Z',
#    'uri': 'http://api.zeit.de/content/6eYN46kHAUS4Cdg3pPRwGg',
#    'snippet': 'DIE ZEIT: Mitten in der dritten Welle der <em>Corona</em>-Pandemie bringt die Deutsche Interdisziplinäre Vereinigung für Intensiv- und Notfallmedizin (Divi) ein Papier zur Überversorgung in der',
#    'supertitle': 'Uwe Janssens',
#    'teaser_text': 'Der Intensivmediziner Uwe Janssens ermahnt seine Kollegen zu mehr Augenmaß in der Therapie. Der Wille der Patientinnen und Patienten müsse im Mittelpunkt stehen',
#    'teaser_title': '"Intensivbetten sind oft mit den falschen Patienten belegt"'},
#   {'subtitle': 'Gabriele von Arnims erstaunliches Buch über das lange Sterben ihres Mannes.\u2002',
#    'uuid': '7II51zRl4cZJf4LXxIuYlx',
#    'title': 'Schau mich doch an',
#    'href': 'http://www.zeit.de/2021/13/gabriele-von-arnim-das-leben-ist-ein-voruebergehender-zustand',
#    'release_date': '2021-03-24T15:52:42Z',
#    'uri': 'http://api.zeit.de/content/7II51zRl4cZJf4LXxIuYlx',
#    'snippet': ' entziehen.\nDa wäre das Wegducken. 75.000 <em>Corona</em>-Tote. Wie lebhaft sich die Leute gegenseitig versichern, dass sie niemanden kennen, der an Covid gestorben ist.\nNicht selten kommt der Tod schnell, scheint',
#    'supertitle': 'Gabriele von Arnim',
#    'teaser_text': 'Gabriele von Arnims erstaunliches Buch über das lange Sterben ihres Mannes.\u2002',
#    'teaser_title': 'Schau mich doch an'},
#   {'subtitle': 'Wie unser Immunsystem Tag für Tag auf uns aufpasst – eine Reise ins Innere des menschlichen Körpers.\u2002',
#    'uuid': '71FLvZ1wsCfu0s3hGIHsA1',
#    'title': 'Gute Besserung!',
#    'href': 'http://www.zeit.de/2021/13/immunsystem-koerper-zellen-antikoerper-forschung-medizin-coronavirus',
#    'release_date': '2021-03-24T15:52:27Z',
#    'uri': 'http://api.zeit.de/content/71FLvZ1wsCfu0s3hGIHsA1',
#    'snippet': ' of Health in Washington. Ihr Chef ist Anthony Fauci, der <em>Corona</em>-Berater des Präsidenten. Als sie ihren Laptop aufklappt, ist es bei ihr vier Uhr morgens. Sie stehe gerne früh auf, sagt sie.\nMatzinger, Tochter',
#    'supertitle': 'Immunsystem',
#    'teaser_text': 'Wie unser Immunsystem Tag für Tag auf uns aufpasst – eine Reise ins Innere des menschlichen Körpers.\u2002',
#    'teaser_title': 'Gute Besserung!'},
#   {'subtitle': 'Alfred Sauter war einer der einflussreichsten Strategen der CSU. Bis sein Geschäftsmodell aufflog\u2002',
#    'uuid': '6HDekuZjENuKoJKjrsxd5T',
#    'title': 'Anwalt in eigener Sache',
#    'href': 'http://www.zeit.de/2021/13/alfred-sauter-csu-maskenaffaere-lobbyismus-transparenz',
#    'release_date': '2021-03-24T15:52:24Z',
#    'uri': 'http://api.zeit.de/content/6HDekuZjENuKoJKjrsxd5T',
#    'snippet': ' Auskunft über seine Mandanten geben. Lediglich ihre Anzahl veröffentlicht er: Allein im <em>Corona</em>-Jahr hat sie sich im Vergleich zu den beiden Vorjahren verdreifacht. Alfred Sauter selbst weist stets darauf hin',
#    'supertitle': 'Alfred Sauter',
#    'teaser_text': 'Alfred Sauter war einer der einflussreichsten Strategen der CSU. Bis sein Geschäftsmodell aufflog\u2002',
#    'teaser_title': 'Anwalt in eigener Sache'},
#   {'subtitle': 'Fabian Leendertz sucht nach dem Ursprung von Corona. Die Ermittlungen werden noch dauern.',
#    'uuid': '5hN2zPFIyYx4QVDwfK8NOy',
#    'title': 'Der Seuchenfahnder',
#    'href': 'http://www.zeit.de/2021/13/fabian-leendertz-corona-ursprung-suche-rki-epidemiologie-zoonosen',
#    'release_date': '2021-03-24T15:52:14Z',
#    'uri': 'http://api.zeit.de/content/5hN2zPFIyYx4QVDwfK8NOy',
#    'snippet': ' dem Sprung gestoppt werden. Danach sei es extrem schwierig, Viren wie Ebola oder Sars-CoV-2 aufzuhalten, sagt Leendertz, das habe die <em>Corona</em>-Pandemie gezeigt. Einen Ausbruch vorherzusagen oder zu',
#    'supertitle': 'Fabian Leendertz',
#    'teaser_text': 'Fabian Leendertz sucht nach dem Ursprung von Corona. Die Ermittlungen werden noch dauern.',
#    'teaser_title': 'Der Seuchenfahnder'},
#   {'subtitle': 'In der Pandemie ist Manuela Schwesig zur Gegenspielerin von Kanzlerin Merkel und zum Gesicht der SPD geworden. Wenn sie im Herbst die Landtagswahl gewinnt, kann sie in ihrer Partei werden, was sie will.',
#    'uuid': '27g73KZUKIf4sJlbgXHG4T',
#    'title': '"Die Leute wollen Haltung sehen"',
#    'href': 'http://www.zeit.de/2021/13/manuela-schwesig-corona-krise-spd-mecklenburg-vorpommern-karriere',
#    'release_date': '2021-03-24T15:52:11Z',
#    'uri': 'http://api.zeit.de/content/27g73KZUKIf4sJlbgXHG4T',
#    'snippet': 'Als Manuela Schwesig am Sonntagnachmittag, 24 Stunden vor der nächsten <em>Corona</em>-Krisenrunde, zur Videoverabredung auf dem Schirm erscheint, hat sie bereits eine Eiche gepflanzt und einen Schlachtplan',
#    'supertitle': 'Manuela Schwesig',
#    'teaser_text': 'In der Pandemie ist Manuela Schwesig zum Gesicht der SPD geworden. Wenn sie im Herbst die Landtagswahl gewinnt, kann sie in ihrer Partei werden, was sie will.',
#    'teaser_title': '"Die Leute wollen Haltung sehen"'},
#   {'subtitle': 'Bernard Meyer baute jahrelang immer größere Schiffe. Sein Umgang mit Arbeitern ist umstritten. Von Gewerkschaften hält er wenig – das rächt sich in der Krise.\u2002',
#    'uuid': '2A4zMOrKNLt7ohL53DRCpz',
#    'title': 'Kreuzfahrtkönig unter Druck',
#    'href': 'http://www.zeit.de/2021/13/schiffbau-werft-kreuzfahrt-ig-metall-bernhard-meyer',
#    'release_date': '2021-03-24T15:52:06Z',
#    'uri': 'http://api.zeit.de/content/2A4zMOrKNLt7ohL53DRCpz',
#    'snippet': ' Geschäftsführer im Unternehmen tätig und stehen bereit, das Erbe in siebter Generation fortzuführen. Meyers Verhandlungsgeschick ist es zu verdanken, dass seine Kunden im <em>Corona</em>-Krisenjahr 2020 keinen einzigen',
#    'supertitle': 'Schiffbau',
#    'teaser_text': 'Bernard Meyer baute jahrelang immer größere Schiffe. Sein Umgang mit Arbeitern ist umstritten. Von Gewerkschaften hält er wenig – das rächt sich in der Krise.\u2002',
#    'teaser_title': 'Kreuzfahrtkönig unter Druck'},
#   {'subtitle': 'Lernt die Menschheit aus Krisen? Ein Gespräch zwischen Wolfgang Schäuble und dem Autor Rutger Bregman',
#    'uuid': '3BJD02k2SW8maH0XD9isCT',
#    'title': '"Der Mensch kann Fürchterliches anrichten" – "Die meisten sind tief in ihrem Inneren anständig"',
#    'href': 'http://www.zeit.de/2021/13/wolfgang-schaeuble-rutger-bregman-corona-krise-mensch',
#    'release_date': '2021-03-24T15:52:01Z',
#    'uri': 'http://api.zeit.de/content/3BJD02k2SW8maH0XD9isCT',
#    'snippet': ' diese Welt je gesehen hat. Deshalb glaube ich, dass das Momentum der <em>Corona</em>-Krise anders sein kann als 2008. Aber das ist keine Vorhersage, denn es könnte auch sehr viel schlechter kommen.\nSchäuble: Auch',
#    'supertitle': 'Wolfgang Schäuble und Rutger Bregman',
#    'teaser_text': 'Wird sich durch die Krise der Pandemie unsere Gesellschaft dauerhaft verändern? Wolfgang Schäuble und der Autor Rutger Bregman glauben an eine tiefgreifende Zäsur.',
#    'teaser_title': '"Die fortschrittlichste Generation, die diese Welt je gesehen hat"'},
#   {'subtitle': 'Zwei türkische Filme zeigen ein Land zwischen Überlebenskunst und Anarchie.',
#    'uuid': '2uj6T6jf2LBkR2km7ztk7w',
#    'title': 'Für ein paar Lira mehr',
#    'href': 'http://www.zeit.de/2021/13/tuerkische-filme-leben-papier-hey-there-istanbul-netflix-mubi',
#    'release_date': '2021-03-24T15:52:00Z',
#    'uri': 'http://api.zeit.de/content/2uj6T6jf2LBkR2km7ztk7w',
#    'snippet': ', eine virtuelle Reise durch ein Land im Lockdown, eine frühe und sicher nicht die letzte <em>Corona</em>-Komödie.',
#    'supertitle': 'Türkische Filme',
#    'teaser_text': 'Zwei türkische Filme zeigen ein Land zwischen Überlebenskunst und Anarchie.',
#    'teaser_title': 'Für ein paar Lira mehr'},
#   {'subtitle': 'Die männliche Rede klingt staatstragend, die weibliche eher tastend. Diese Konditionierung sitzt zu tief, um sie rasch überwinden zu können.',
#    'uuid': '2FxcePIFNVu9GXsp7rU1c3',
#    'title': 'Das Gewicht der weiblichen Stimme',
#    'href': 'http://www.zeit.de/2021/13/gleichberechtigung-frauen-rede-stimme-vorurteile-politik-maenner',
#    'release_date': '2021-03-24T15:51:54Z',
#    'uri': 'http://api.zeit.de/content/2FxcePIFNVu9GXsp7rU1c3',
#    'snippet': ', wie zu Beginn der <em>Corona</em>-Krise im Frühjahr 2020. Der Schatten des Spahn-Söder-Kretschmann-Laschet-Drosten-Streeck-Kekulé-Elefanten wurde sehr wohl bemerkt. Aber auch mir erschien ein Virus, das',
#    'supertitle': 'Gleichberechtigung',
#    'teaser_text': 'Die männliche Rede klingt staatstragend, die weibliche eher tastend. Diese Konditionierung sitzt zu tief, um sie rasch überwinden zu können.',
#    'teaser_title': 'Das Gewicht der weiblichen Stimme'},
#   {'subtitle': 'Flugtaxis für Städte, Moos gegen Feinstaub: Es gibt so viele gute Ideen, die unser Leben einfacher und lebenswerter machen. Das schlagen unsere Leserinnen und Leser vor.',
#    'uuid': '2BPTdj0HtujeYrDSunQg3N',
#    'title': 'Lern mal deine Nachbarn kennen',
#    'href': 'http://www.zeit.de/2021/13/ideen-innovation-technologie-plattform-start-up-hilfsorganisation',
#    'release_date': '2021-03-24T15:51:48Z',
#    'uri': 'http://api.zeit.de/content/2BPTdj0HtujeYrDSunQg3N',
#    'snippet': ' Plattform nebenan.de etwa bietet einen <em>Corona</em>-Einkaufsservice an. Doch um dies in Anspruch zu nehmen, müssen die Hilfesuchenden mit dem Internet umgehen können. Bei der App aus München ist das anders: Sie',
#    'supertitle': 'Ideen',
#    'teaser_text': 'Flugtaxis für Städte, Moos gegen Feinstaub: Es gibt so viele gute Ideen, die unser Leben einfacher und lebenswerter machen. Das schlagen unsere Leserinnen und Leser vor.',
#    'teaser_title': 'Lern mal deine Nachbarn kennen'},
#   {'subtitle': 'Ist es wichtiger, in der Partei oder bei den Wählern beliebt zu sein, wenn man Kanzlerkandidat werden möchte?',
#    'uuid': '6shnFYASAaQn3Sd7vq977y',
#    'title': 'Überlebensfrage',
#    'href': 'http://www.zeit.de/2021/13/bundestagswahl-kanzleramt-cdu-die-gruenen-markus-soeder',
#    'release_date': '2021-03-24T15:51:46Z',
#    'uri': 'http://api.zeit.de/content/6shnFYASAaQn3Sd7vq977y',
#    'snippet': ' sich aber ändern, wenn sich in den nächsten Wochen ein virologischer und ein politischer Inzidenzwert aufeinander zubewegen sollten: einerseits eine steigende Zahl von <em>Corona</em>-Infizierten, andererseits',
#    'supertitle': 'Bundestagswahl',
#    'teaser_text': 'Ist es wichtiger, in der Partei oder bei den Wählern beliebt zu sein, wenn man Kanzlerkandidat werden möchte?',
#    'teaser_title': 'Überlebensfrage'},
#   {'subtitle': 'Warum benennen die Russen ihren Impfstoff nach einem Satellitenprogramm? Ein Deutungsversuch\u2002',
#    'uuid': 'f62B8Adnt0JYRE1wycOyo',
#    'title': 'Der neue Sputnik-Schock',
#    'href': 'http://www.zeit.de/2021/13/russland-sputnik-corona-impfstoff-raumfahrtprogramm-drohung-symbolik',
#    'release_date': '2021-03-24T15:51:39Z',
#    'uri': 'http://api.zeit.de/content/f62B8Adnt0JYRE1wycOyo',
#    'snippet': ' <em>Corona</em>-Impfstoff diesen Namen, noch dazu versehen mit einem großen V, was für victory, also "Sieg", steht? Es ist als doppelte Botschaft zu verstehen. Die Bürger Russlands sollen von dem Begriff an die',
#    'supertitle': 'Russland',
#    'teaser_text': 'Warum benennen die Russen ihren Impfstoff nach einem Satellitenprogramm? Ein Deutungsversuch\u2002',
#    'teaser_title': 'Der neue Sputnik-Schock'},
#   {'subtitle': 'Intensivmediziner schlagen Alarm. Sie therapieren zu viel. Das ist schädlich, teuer und unmenschlich.',
#    'uuid': 'WbmzC6x1oTGkWZUeTDaFS',
#    'title': 'Wie viel soll man machen?',
#    'href': 'http://www.zeit.de/2021/13/intensivmedizin-gesundheitssystem-ueberversorgung-geld-patienten',
#    'release_date': '2021-03-24T15:51:37Z',
#    'uri': 'http://api.zeit.de/content/WbmzC6x1oTGkWZUeTDaFS',
#    'snippet': 'Es mag zynisch wirken, worüber eine Gruppe von Expertinnen und Experten um den Intensivmediziner Uwe Janssens da schreibt. Kurz bevor die Zahl der belegten Intensivbetten wegen einer neuen <em>Corona</em>',
#    'supertitle': 'Intensivmedizin',
#    'teaser_text': 'In Zeiten von Corona zeigt sich ein altes Problem von Intensivstationen: Es gibt eine Überversorgung. Das ist schädlich, teuer und unmenschlich – sagen Mediziner.',
#    'teaser_title': 'Wenn Intensivmediziner mehr therapieren, als sie sollten'},
#   {'subtitle': 'Die einzigen erhaltenen Salzmumien weltweit wurden in einem Stollen im Iran gefunden. Archäologen haben ihr Schicksal recherchiert.',
#    'uuid': '5z3CgXmtoT5Hubj8jg1SDv',
#    'title': 'Der Junge aus dem Bergwerk',
#    'href': 'http://www.zeit.de/2021/13/archaeologie-mumie-iran-salz-stollen-koerper-junge',
#    'release_date': '2021-03-24T15:51:30Z',
#    'uri': 'http://api.zeit.de/content/5z3CgXmtoT5Hubj8jg1SDv',
#    'snippet': ' Zwischenbilanz aber hat er die bisherigen Befunde in der neuen Sonderausstellung zusammengetragen: Tod im Salz. Virtuell öffnet die Schau in diesen Tagen. Im Museum wird sie wohl erst nach dem Ende des <em>Corona</em>',
#    'supertitle': 'Archäologie',
#    'teaser_text': 'Die einzigen erhaltenen Salzmumien weltweit wurden in einem Stollen im Iran gefunden. Archäologen haben ihr Schicksal recherchiert.',
#    'teaser_title': 'Der Junge aus dem Bergwerk'},
#   {'subtitle': 'Viele Deutsche träumen davon, aus der Stadt wegzuziehen. Wie finden sie in der Provinz das gute Leben? Leserinnen und Leser haben eine Fülle von Ideen dafür eingereicht. Unsere Autorin ist ihnen nachgegangen.',
#    'uuid': '6gzAvAPaKtL9EGI2eOHk3R',
#    'title': 'Frischer Wind vom Land',
#    'href': 'http://www.zeit.de/2021/13/landleben-landwirtschaft-immobilien-einkommen-solidaritaet-zusammenhalt',
#    'release_date': '2021-03-24T15:51:24Z',
#    'uri': 'http://api.zeit.de/content/6gzAvAPaKtL9EGI2eOHk3R',
#    'snippet': ' Zugewinne verzeichnen. Gerade wird das Land von vielen Menschen neu entdeckt.\nWährend der <em>Corona</em>-Pandemie zieht es viele Städter hinaus in die ländlichen Naherholungsgebiete, das hat bei manchen auch den',
#    'supertitle': 'Landleben',
#    'teaser_text': 'Viele Deutsche träumen davon, aus der Stadt wegzuziehen. Wie finden sie in der Provinz das gute Leben? Leserinnen und Leser haben eine Fülle von Ideen dafür eingereicht.',
#    'teaser_title': 'Frischer Wind vom Land'},
#   {'subtitle': 'Die Forschung für die nächste Pandemie muss jetzt beginnen. Wir brauchen Technik gegen Tröpfchen – und vieles mehr.\u2002',
#    'uuid': '6Tu4zX2trHlCu5X5w4C8n4',
# ...
#    'release_date': '2021-03-23T03:06:50Z',
#    'uri': 'http://api.zeit.de/content/jG7SPTTLuG47261DeNwNl',
#    'snippet': ' zwölfstündigen Schaltkonferenz gegen <em>Corona</em>-Lockerungen jeder Art. Einen Großteil der Zeit verbrachte man im Streit um eine Fußnote der Küstenbundesländer, mit der sie ihrer Bevölkerung zumindest Osterurlaub',
#    'supertitle': 'Ministerpräsidentenkonferenz',
#    'teaser_text': 'In einer Rekordsitzung haben sich Bund und Länder auf zusätzliche Schließtage zu Ostern geeinigt. Wo wird verschärft, wo gelockert? Die Beschlüsse im Schnelltest',
#    'teaser_title': 'Zwölf Stunden für zwei Tage Osterlockdown'},
#   {'subtitle': 'Die dritte Welle sei "sehr, sehr ernst", betont Kanzlerin Angela Merkel. Fünf Tage soll das öffentliche Leben stillstehen, Supermärkte sollen nur Karsamstag öffnen.',
#    'uuid': '6h9aYlAqEhbZsL82BqoFAB',
#    'title': 'Bund und Länder beschließen strengeren Lockdown über Ostern',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/lockdown-bund-und-laender-verlaengern-lockdown-bis-mitte-april',
#    'release_date': '2021-03-23T01:40:14Z',
#    'uri': 'http://api.zeit.de/content/6h9aYlAqEhbZsL82BqoFAB',
#    'snippet': 'Angesichts weiter steigender <em>Corona</em>-Infektionszahlen schicken Bund und Länder Deutschland über Ostern in den schärfsten Lockdown seit Beginn der Pandemie vor einem Jahr. Vom 1. bis einschließlich 5',
#    'supertitle': 'Lockdown',
#    'teaser_text': 'Die dritte Welle sei "sehr, sehr ernst", betont Kanzlerin Angela Merkel. Fünf Tage soll das öffentliche Leben stillstehen, Supermärkte sollen nur Karsamstag öffnen.',
#    'teaser_title': 'Bund und Länder beschließen strengeren Lockdown über Ostern'},
#   {'subtitle': 'Der Lockdown wird bis 18. April verlängert und über Ostern verschärft. Die Bundeskanzlerin spricht zu den neuen Bund-Länder-Beschlüssen.',
#    'uuid': '7ffpqCEqAMrby2jSV7SlR',
#    'title': 'Angela Merkel zu den neuen Corona-Beschlüssen',
#    'href': 'http://www.zeit.de/politik/2021-03/bund-laender-treffen-beschluesse-angela-merkel-notbremse-lockdown-livestream',
#    'release_date': '2021-03-23T01:38:21Z',
#    'uri': 'http://api.zeit.de/content/7ffpqCEqAMrby2jSV7SlR',
#    'snippet': 'Die wichtigsten Neuigkeiten zur <em>Corona</em>-Lage in Deutschland lesen Sie in unserem Liveblog.',
#    'supertitle': 'Bund-Länder-Treffen',
#    'teaser_text': 'Der Lockdown wird bis 18. April verlängert und über Ostern verschärft. Die Bundeskanzlerin spricht zu den neuen Bund-Länder-Beschlüssen.',
#    'teaser_title': 'Jetzt live: Angela Merkel zu den neuen Corona-Beschlüssen'},
#   {'subtitle': 'Die Infektionszahlen erhöhen sich weiter: Das Robert Koch-Institut hat 7.485 Neuinfizierte und 250 Todesfälle verzeichnet. Die Sieben-Tage-Inzidenz liegt nun bei 108.',
#    'uuid': '7l5ltsQz3Q5GNt1POR3qa2',
#    'title': 'RKI registriert etwa 2.000 Infizierte mehr als vor einer Woche',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/coonavirus-neuinfektionen-rki-gesundheitsaemter-todesfaelle-bundeslaender',
#    'release_date': '2021-03-23T00:56:21Z',
#    'uri': 'http://api.zeit.de/content/7l5ltsQz3Q5GNt1POR3qa2',
#    'snippet': 'Das Robert Koch-Institut (RKI) meldet 7.485 Neuinfektionen mit dem Coronavirus. Das sind 2.005 Fälle mehr als vor einer Woche. Nach Recherchen von ZEIT ONLINE wurden 8.909 neue <em>Corona</em>-Fälle gemeldet',
#    'supertitle': 'Coronavirus',
#    'teaser_text': 'Die Infektionszahlen erhöhen sich weiter: Das Robert Koch-Institut hat 7.485 Neuinfizierte und 250 Todesfälle verzeichnet. Die Sieben-Tage-Inzidenz liegt nun bei 108.',
#    'teaser_title': 'RKI registriert etwa 2.000 Infizierte mehr als vor einer Woche'},
#   {'subtitle': 'Der slowakische Wirtschaftsminister Richard Sulík ist in einer schweren Regierungskrise zurückgetreten. Er hatte die Corona-Politik des Regierungschefs heftig kritisiert.',
#    'uuid': '6TebNMUVr0wdGufNs2yntt',
#    'title': 'Minister tritt im Streit um Corona-Krisenmanagement zurück',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/slowakei-ruecktritt-wirtschaftsminister-corona-regierungskrise',
#    'release_date': '2021-03-23T00:05:34Z',
#    'uri': 'http://api.zeit.de/content/6TebNMUVr0wdGufNs2yntt',
#    'snippet': ' Rache", kritisierte die Partei auf Facebook. Matovič zeige neuerlich, dass er nicht geeignet ist, die Regierung zu führen.\nSulík war wegen seiner Kritik an der <em>Corona</em>-Politik des Regierungschefs schon',
#    'supertitle': 'Slowakei',
#    'teaser_text': 'Der slowakische Wirtschaftsminister Richard Sulík ist in einer schweren Regierungskrise zurückgetreten. Er hatte die Corona-Politik des Regierungschefs heftig kritisiert.',
#    'teaser_title': 'Minister tritt im Streit um Corona-Krisenmanagement zurück'},
#   {'subtitle': 'Zäher Alltag, unklare Zukunft und Freunde, die zu viel trinken: Die Pandemie führt in ein emotionales Chaos. Sie verunsichert Menschen, die genau jetzt wachsen sollten.',
#    'uuid': '4HcoBIUNHBFntQpPLTIyhj',
#    'title': 'Mein Corona-Kopf macht pff, ahhhhh, mrrrrr',
#    'href': 'http://www.zeit.de/campus/2021-03/gefuehle-lockdown-corona-pandemie-emotionen-stimmung-angst-unsicherheit',
#    'release_date': '2021-03-22T19:49:47Z',
#    'uri': 'http://api.zeit.de/content/4HcoBIUNHBFntQpPLTIyhj',
#    'snippet': ', die meine Freunde und ich machen, wenn jemand mal wieder von <em>Corona</em> anfängt.\xa0\nMeine Bilanz seit Beginn der Pandemie: Ich habe meinen Schulabschluss gemacht, mich für eine Uni im Ausland entschieden. Ich',
#    'supertitle': 'Gefühle im Lockdown',
#    'teaser_text': 'Zäher Alltag, unklare Zukunft und Freunde, die zu viel trinken: Die Pandemie führt in ein emotionales Chaos. Sie verunsichert Menschen, die genau jetzt wachsen sollten.',
#    'teaser_title': 'Mein Corona-Kopf macht pff, ahhhhh, mrrrrr'},
#   {'subtitle': 'In der Pandemie sehnen sich genervte Städter nach der Weite der Provinz. Lars Weisbrod und Ijoma Mangold fragen sich, ob das Phänomen Corona überdauern wird.',
#    'uuid': '4Feru7Zggs4zy72Q3c5jzC',
#    'title': 'Liegt die Zukunft auf dem Land?',
#    'href': 'http://www.zeit.de/kultur/2021-03/leben-land-stadtflucht-mieten-provinz-homeoffice-feuilleton-podcast',
#    'release_date': '2021-03-22T19:07:35Z',
#    'uri': 'http://api.zeit.de/content/4Feru7Zggs4zy72Q3c5jzC',
#    'snippet': 'Spätestens seit der <em>Corona</em>-Pandemie heißt es, die Städte verlören an Attraktivität. Die hohen Mieten machen selbst der Mittelschicht zu schaffen, Familien können sich den Platz, den sie brauchen',
#    'supertitle': 'Leben auf dem Land',
#    'teaser_text': 'In der Pandemie sehnen sich genervte Städter nach der Weite der Provinz. Lars Weisbrod und Ijoma Mangold fragen sich, ob das Phänomen Corona überdauern wird.',
#    'teaser_title': 'Liegt die Zukunft auf dem Land?'},
#   {'subtitle': 'Wegen der Corona-Krise will Bundesfinanzminister Olaf Scholz 2021 und 2022 zusätzliche Schulden aufnehmen. Die Schuldenbremse bleibt weiter ausgesetzt.',
#    'uuid': '6eedQU3OleeCUagAD6WYay',
#    'title': 'Olaf Scholz plant weitere Neuverschuldung',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/bundesfinanzminister-olaf-scholz-spd-neuverschuldung-2022',
#    'release_date': '2021-03-22T18:30:33Z',
#    'uri': 'http://api.zeit.de/content/6eedQU3OleeCUagAD6WYay',
#    'snippet': 'Bundesfinanzminister Olaf Scholz (SPD) plant wegen der <em>Corona</em>-Krise weitere neue Schulden. Wie aus dem Finanzministerium bekannt wurde, ist allein für das kommende Jahr eine Neuverschuldung von 81,5',
#    'supertitle': 'Bundesfinanzminister',
#    'teaser_text': 'Wegen der Corona-Krise will Bundesfinanzminister Olaf Scholz 2021 und 2022 zusätzliche Schulden aufnehmen. Die Schuldenbremse bleibt weiter ausgesetzt.',
#    'teaser_title': 'Olaf Scholz plant weitere Neuverschuldung'},
#   {'subtitle': 'Der Kreis Elbe-Elster ist einer der Corona-Hotspots in Brandenburg, trotzdem verhinderte sein Landrat neue Beschränkungen. Er kann das erklären.',
#    'uuid': '1N0wa3vphubFNjsIKBECA1',
#    'title': 'Tempo 200',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2021-03/corona-politik-brandenburg-elber-elster-lockdown-oeffnungen-massnahmen',
#    'release_date': '2021-03-22T17:33:56Z',
#    'uri': 'http://api.zeit.de/content/1N0wa3vphubFNjsIKBECA1',
#    'snippet': 'Eine der Erstaunlichkeiten der <em>Corona</em>-Pandemie ist, dass sie oft und plötzlich selbst eher periphere Gegenden bekannt macht. Man könnte es das Tirschenreuth-Phänomen nennen – kein Ort kann sicher',
#    'supertitle': 'Corona-Politik in Brandenburg',
#    'teaser_text': 'Der Kreis Elbe-Elster ist einer der Corona-Hotspots in Brandenburg, trotzdem verhinderte sein Landrat neue Beschränkungen. Er kann das erklären.',
#    'teaser_title': 'Tempo 200'},
#   {'subtitle': 'Die EU sanktioniert China wegen des Umgangs mit den Uiguren – die chinesische Regierung reagiert prompt. Außerdem im Podcast-Update: Die Bund-Länder-Runde tagt.',
#    'uuid': '5DfxsDlJ5UEwvv9tV9ZfkF',
#    'title': 'Europas Sanktionen gegen China – historisch, aber harmlos',
#    'href': 'http://www.zeit.de/politik/2021-03/eu-china-sanktionen-uiguren-haftlager-menschenrecht-nachrichtenpodcast',
#    'release_date': '2021-03-22T16:00:56Z',
#    'uri': 'http://api.zeit.de/content/5DfxsDlJ5UEwvv9tV9ZfkF',
#    'snippet': ' eigentlich nur ein "Nadelstich" und doch bemerkenswert sind.\nDie Bund-Länder-Runde diskutiert unterdessen über Beschränkungen und Lockerungen wegen der <em>Corona</em>-Pandemie. Die Beschlussvorlage sieht vor, den',
#    'supertitle': 'EU und China',
#    'teaser_text': 'Die EU sanktioniert China wegen des Umgangs mit den Uiguren – die chinesische Regierung reagiert prompt. Außerdem im Podcast-Update: Die Bund-Länder-Runde tagt.',
#    'teaser_title': 'Europas Sanktionen gegen China – historisch, aber harmlos'},
#   {'subtitle': 'Die eine singt fast so gut wie Alicia Keys, die andere jubelt, als hätte sie täglich einen 6er im Lotto. Wie wir unsere Nachbar*innen in der Pandemie kennenlernen.',
#    'uuid': '78TpiYB3xH6GUaz2cZfrmC',
#    'title': 'Die bekannten Unbekannten',
#    'href': 'http://www.zeit.de/zett/2021-03/nachbarschaft-corona-pandemie-garten-privatkonzerte-sozialer-kontakt',
#    'release_date': '2021-03-22T15:59:31Z',
#    'uri': 'http://api.zeit.de/content/78TpiYB3xH6GUaz2cZfrmC',
#    'snippet': ' uns unser eigenes Bild vom Leben nebenan. Acht Anekdoten über Menschen, von denen wir ohne die Pandemie vielleicht gar nicht so viel mitbekommen hätten.\nBei uns im Haus hat sich während <em>Corona</em> ein',
#    'supertitle': 'Nachbarschaft in Corona-Zeiten',
#    'teaser_text': 'Die eine singt fast so gut wie Alicia Keys, die andere jubelt, als hätte sie täglich einen 6er im Lotto. Wie wir unsere Nachbar*innen in der Pandemie kennenlernen.',
#    'teaser_title': 'Die bekannten Unbekannten'},
#   {'subtitle': 'Die Fraktion hatte dem früheren bayerischen Justizminister wegen der Maskenaffäre den Rauswurf angedroht. Jetzt kommt Alfred Sauter dem mit seinem Schritt offenbar zuvor.',
#    'uuid': '3PM3BmcL7HFbXpigPEIHSJ',
#    'title': 'Alfred Sauter tritt aus CSU-Landtagsfraktion aus',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/alfred-sauter-csu-korruption-verdacht-austritt-landtagsfraktion',
#    'release_date': '2021-03-22T14:52:08Z',
#    'uri': 'http://api.zeit.de/content/3PM3BmcL7HFbXpigPEIHSJ',
#    'snippet': ' stehen in Zusammenhang mit dem Ankauf von <em>Corona</em>-Schutzmasken durch den Staat und mit Korruptionsvorwürfen gegen den mittlerweile aus der CSU ausgetretenen Bundestagsabgeordneten Georg Nüßlein, der wie',
#    'supertitle': 'Korruptionsverdacht',
#    'teaser_text': 'Die Fraktion hatte dem früheren bayerischen Justizminister wegen der Maskenaffäre den Rauswurf angedroht. Jetzt kommt Alfred Sauter dem mit seinem Schritt offenbar zuvor.',
#    'teaser_title': 'Alfred Sauter tritt aus CSU-Landtagsfraktion aus'},
#   {'subtitle': 'Kundenbegrenzungen und Terminbuchungen für manche Geschäfte verstoßen laut Gerichtsurteil gegen die Gleichbehandlung. Als Reaktion weitet NRW die Beschränkungen aus.',
#    'uuid': '4Tx1DEjMpbxqRm9GoQVuRH',
#    'title': 'Gericht kippt Beschränkungen für Einzelhandel in NRW',
#    'href': 'http://www.zeit.de/wirtschaft/2021-03/einzelhandel-lockdown-click-and-meet-termin-gericht-urteil-gleichbehandlung',
#    'release_date': '2021-03-22T14:00:04Z',
#    'uri': 'http://api.zeit.de/content/4Tx1DEjMpbxqRm9GoQVuRH',
#    'snippet': '. Der Beschluss ist unanfechtbar.\nMedia Markt ist nicht das einzige Unternehmen, das gegen die <em>Corona</em>-Verordnungen juristisch vorgeht. Bei immer mehr Einzelhändlern in Deutschland endet nach Monaten des',
#    'supertitle': 'Click and Meet',
#    'teaser_text': 'Kundenbegrenzungen und Terminbuchungen für manche Geschäfte verstoßen laut Gerichtsurteil gegen die Gleichbehandlung. Als Reaktion weitet NRW die Beschränkungen aus.',
#    'teaser_title': 'Gericht kippt Beschränkungen für Einzelhandel in NRW'},
#   {'subtitle': 'Verwandtentreffen mit mehr als zwei Haushalten über Ostern, wieder mehr Normalität in den Pflegeheimen: Über diese Beschlussvorlage beraten Bund und Länder am Nachmittag.',
#    'uuid': '3GQ8mTcTrdMMOO4Rq6mzxl',
#    'title': 'Bund und Länder wollen Familienbesuche an Ostern erlauben',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/corona-gipfel-bund-laender-massnahmen-altenheim-familie-ostern',
#    'release_date': '2021-03-22T11:10:38Z',
#    'uri': 'http://api.zeit.de/content/3GQ8mTcTrdMMOO4Rq6mzxl',
#    'snippet': 'Die <em>Corona</em>-Infektionszahlen steigen wieder stark an, der Lockdown wird aller Voraussicht nach bis mindestens Mitte April verlängert und auch wieder verschärft. Dennoch planen Bund und Länder offenbar',
#    'supertitle': 'Corona-Gipfel',
#    'teaser_text': 'Verwandtentreffen mit mehr als zwei Haushalten über Ostern, wieder mehr Normalität in den Pflegeheimen: Über diese Beschlussvorlage beraten Bund und Länder am Nachmittag.',
#    'teaser_title': 'Bund und Länder wollen Familienbesuche an Ostern erlauben'},
#   {'subtitle': 'Der Carsharer Miles nimmt E-Autos in seine Flotte auf. Wieso nicht früher? Chef Oliver Mackprang sagt, die Politik setze falsche Anreize – vor allem in Berlin.',
#    'uuid': 'nrw0o9n9n3dZF0CVS4yMy',
#    'title': '"Elektromobilität ist jetzt erst für uns praktikabel"',
#    'href': 'http://www.zeit.de/mobilitaet/2021-03/carsharing-miles-elektro-autos-klimaschutz-oliver-mackprang',
#    'release_date': '2021-03-22T09:56:04Z',
#    'uri': 'http://api.zeit.de/content/nrw0o9n9n3dZF0CVS4yMy',
#    'snippet': ' Kooperation mit Volkswagen dahinter?\nMackprang: Nein, VW ist mit WeShare ja ein direkter Konkurrent. Wir sind konzernunabhängig.\nZEIT ONLINE: Wie wirkt sich die <em>Corona</em>-Krise auf Ihr Geschäft aus?\nMackprang: Im',
#    'supertitle': 'Carsharing',
#    'teaser_text': 'Der Carsharer Miles nimmt E-Autos in seine Flotte auf. Wieso nicht früher? Chef Oliver Mackprang sagt, die Politik setze falsche Anreize – vor allem in Berlin.',
#    'teaser_title': '"Elektromobilität ist jetzt erst für uns praktikabel"'},
#   {'subtitle': 'Um Korruption bei Mandatsträgern entgegenzuwirken, dringt ein Teil der CDU auf eindeutige Transparenzregeln. CSU-Chef Markus Söder hatte diese bereits angekündigt.',
#    'uuid': '19zKJH7PqQ1EKXWzUNPVLH',
#    'title': 'CDU-Sozialflügel fordert Verhaltenskodex für Abgeordnete',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/maskenaffaere-cdu-korruption-lobbyismus-verhaltenskodex-markus-soeder',
#    'release_date': '2021-03-22T07:43:07Z',
#    'uri': 'http://api.zeit.de/content/19zKJH7PqQ1EKXWzUNPVLH',
#    'snippet': 'Mehrere Unionsabgeordnete waren an Geschäften mit <em>Corona</em>-Schutzausrüstung beteiligt. Damit so etwas nicht wieder passiert, hat der CDU-Sozialflügel die eigene Partei aufgefordert, dem Beispiel der',
#    'supertitle': 'Maskenaffäre',
#    'teaser_text': 'Um Korruption bei Mandatsträgern entgegenzuwirken, dringt ein Teil der CDU auf eindeutige Transparenzregeln. CSU-Chef Markus Söder hatte diese bereits angekündigt.',
#    'teaser_title': 'CDU-Sozialflügel fordert Verhaltenskodex für Abgeordnete'}],
#  'found': 9707,
#  'limit': 100,
#  'offset': 0}

# %%
keys=list(test2["matches"][0].keys())
#keys

# %%
from datetime import datetime
from datetime import date, timedelta

dates=pd.date_range('2020-03-09','2021-03-24',freq='W').strftime('%m/%d/%y %H:%M:%S').tolist()

dates_new=[]
for date in dates:
    dates_new.append(datetime.strptime(date, '%m/%d/%y %H:%M:%S'))

# %%
i=0
tuple((dates_new[i],dates_new[i+1]))
# Out:
# (datetime.datetime(2020, 3, 15, 0, 0), datetime.datetime(2020, 3, 22, 0, 0))

# %%
dates_zeit=[]
for i in range(len(dates_new)):
    try:
        d=tuple((dates_new[i],dates_new[i+1]))
        dates_zeit.append(d)
    except:
        continue

# %%
type(dates_zeit[0])
# Out:
# tuple

# %%
type(dates[0])
# Out:
# str

# %%
#time_range: expects a time_range in the form of a tuple of two datetime or pandas.Timestamp Instances

# %%
#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "corona")

# %%
request
# Out:
# {'matches': [{'subtitle': 'Laut der Berliner Staatsanwaltschaft hat der Verschwörungserzähler Deutschland verlassen. Somit könne ein Haftbefehl gegen ihn auch absehbar nicht durchgesetzt werden.',
#    'uuid': '7h5zDtpa2OCcRfDxg7HgG6',
#    'title': 'Atilla Hildmann soll sich in die Türkei abgesetzt haben',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2021-03/attila-hildmann-verschwoerungstheorien-verdacht-volksverletzung-haftbefehl',
#    'release_date': '2021-03-25T15:48:01Z',
#    'uri': 'http://api.zeit.de/content/7h5zDtpa2OCcRfDxg7HgG6',
#    'snippet': 'Der Verschwörungserzähler und Leugner der <em>Corona</em>-Pandemie Attila Hildmann hält sich nach Erkenntnissen der Berliner Staatsanwaltschaft derzeit in der Türkei auf. Wie die Behörde mitteilte, kann ein',
#    'supertitle': 'Verdacht der Volksverhetzung',
#    'teaser_text': 'Laut der Berliner Staatsanwaltschaft hat der Verschwörungserzähler Deutschland verlassen. Somit könne ein Haftbefehl gegen ihn auch absehbar nicht durchgesetzt werden.',
#    'teaser_title': 'Atilla Hildmann soll sich in die Türkei abgesetzt haben'},
#   {'subtitle': 'Die EU verschärft die Regeln für ihre Impfstoffexporte, damit andere Länder wie Großbritannien nicht bevorzugt werden. Aber nicht alle Europäer unterstützen die Maßnahme.',
#    'uuid': '6IbgVmBGmRXN3p9tLn6Jco',
#    'title': 'Plötzlich protektionistisch',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/impfstoffexporte-coronavirus-eu-bevorzugung-regeln-pandemie',
#    'release_date': '2021-03-25T15:24:06Z',
#    'uri': 'http://api.zeit.de/content/6IbgVmBGmRXN3p9tLn6Jco',
#    'snippet': 'Ob in Deutschland, Belgien, oder Italien: In der EU wird reichlich <em>Corona</em>-Impfstoff hergestellt. Das heißt aber nicht, dass er ihr auch zur Verfügung steht. Die Europäische Union ist einer der',
#    'supertitle': 'Impfstoffexporte',
#    'teaser_text': 'Die EU verschärft die Regeln für ihre Impfstoffexporte, damit andere Länder wie Großbritannien nicht bevorzugt werden. Aber nicht alle Europäer unterstützen die Maßnahme.',
#    'teaser_title': 'Plötzlich protektionistisch'},
#   {'subtitle': 'Noch vor 50 Jahren lebten 1,5 Millionen Elefanten in Afrika. Inzwischen sind es nur noch etwa 400.oo0. Schuld sind laut Naturschützern unter anderem Elfenbein-Wilderer.',
#    'uuid': '74vTbWj1jOpA10BdlBjdUY',
#    'title': 'Afrikanischer Waldelefant akut vom Aussterben bedroht',
#    'href': 'http://www.zeit.de/wissen/umwelt/2021-03/rote-liste-tierschutz-afrikanischer-waldelefant-aussterben',
#    'release_date': '2021-03-25T15:21:37Z',
#    'uri': 'http://api.zeit.de/content/74vTbWj1jOpA10BdlBjdUY',
#    'snippet': ', dass dieser deutlich weniger Kohlenstoff speichern kann."\nDer Tier- und Naturschutz leidet zudem unter dem Einfluss der <em>Corona</em>-Pandemie. Wie die IUCN kürzlich berichtete, mussten mehr als die Hälfte der',
#    'supertitle': 'Tierschutz',
#    'teaser_text': 'Noch vor 50 Jahren lebten 1,5 Millionen Elefanten in Afrika. Inzwischen sind es nur noch etwa 400.oo0. Schuld sind laut Naturschützern unter anderem Elfenbein-Wilderer.',
#    'teaser_title': 'Afrikanischer Waldelefant akut vom Aussterben bedroht'},
#   {'subtitle': 'Der Prozess um den größten bekannten Steuerskandal der deutschen Geschichte hat begonnen. Einer der Angeklagten lebt in der Schweiz und tauchte zum Auftakt nicht auf.',
#    'uuid': '3s3YhJKy2dehj9xoGrDpM9',
#    'title': 'Prozess um milliardenschwere Cum-Ex-Aktiendeals hat begonnen',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/cum-ex-skandal-steuerbetrug-aktiendeal-hanno-berger-prozess',
#    'release_date': '2021-03-25T14:25:38Z',
#    'uri': 'http://api.zeit.de/content/3s3YhJKy2dehj9xoGrDpM9',
#    'snippet': ' Frankfurt hatte schon im Mai 2018 ihre Anklage öffentlich gemacht. Sie wurde aber lange geprüft und der Prozess wegen <em>Corona</em>-Pandemie mehrfach vertagt.\nUrsprünglich waren sechs Menschen angeklagt. Das',
#    'supertitle': 'Steuerbetrug',
#    'teaser_text': 'Der Prozess um den größten bekannten Steuerskandal der deutschen Geschichte hat begonnen. Einer der Angeklagten lebt in der Schweiz und tauchte zum Auftakt nicht auf.',
#    'teaser_title': 'Prozess um milliardenschwere Cum-Ex-Aktiendeals hat begonnen'},
#   {'subtitle': 'Noch drei, vier schwere Monate? Nur noch ein bisschen zusammenreißen? Schluss damit! Hier können Sie Ihren Frust rauslassen, schreien Sie uns an!',
#    'uuid': '6YyGGlsBHt9mTl8QkVnrr6',
#    'title': 'Coronaaaaaaaaaargghhh!',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2021-03/corona-krise-lockdown-wut-frust-verzweiflung-angst-leseraufruf',
#    'release_date': '2021-03-25T14:12:53Z',
#    'uri': 'http://api.zeit.de/content/6YyGGlsBHt9mTl8QkVnrr6',
#    'snippet': ',\nschimpfen,\nweinen,\nsingen,\nerzählen, was Ihnen zum Thema <em>Corona</em> auf der Seele liegt.\nSenden Sie uns eine Sprachnachricht an 0157 57551398 und machen Sie sich Luft. Sie können WhatsApp, Signal oder Telegram',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Noch drei, vier schwere Monate? Nur noch ein bisschen zusammenreißen? Schluss damit! Hier können Sie Ihren Frust rauslassen, schreien Sie uns an!',
#    'teaser_title': 'Coronaaaaaaaaaargghhh!'},
#   {'subtitle': 'Nach ihrer öffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.',
#    'uuid': '6Ux163KMzgplMUcaejSUIQ',
#    'title': 'Erst Selbstkritik, dann Selbstverteidigung',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-corona-lockdown-ostern-eu-gipfel-intensivstationen',
#    'release_date': '2021-03-25T12:53:01Z',
#    'uri': 'http://api.zeit.de/content/6Ux163KMzgplMUcaejSUIQ',
#    'snippet': ' berichtet sie dem Parlament über die Themen des anstehenden Europäischen Rates. Sie lobt den europäischen Resilienzfonds, der helfen soll, die schwere Wirtschaftskrise infolge der <em>Corona</em>-Pandemie zu',
#    'supertitle': 'Angela Merkel',
#    'teaser_text': 'Nach ihrer öffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.',
#    'teaser_title': 'Erst Selbstkritik, dann Selbstverteidigung'},
#   {'subtitle': 'Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.',
#    'uuid': '31Dsx9ZRJZ2atPIMsvZla9',
#    'title': 'Die Last der Erwartung',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/europa-eu-von-der-leyen-corona-gipfel',
#    'release_date': '2021-03-25T12:14:24Z',
#    'uri': 'http://api.zeit.de/content/31Dsx9ZRJZ2atPIMsvZla9',
#    'snippet': ' erneut eines der bestimmenden Themen sein wird. Im internationalen Kampf gegen <em>Corona</em> scheint die EU tatsächlich keine allzu gute Figur zu machen: Die Impfquote in ihren Mitgliedstaaten liegt deutlich',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.',
#    'teaser_title': 'Die Last der Erwartung'},
#   {'subtitle': 'Die Münchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaffäre in der Union festnehmen lassen. In Thüringer CDU-Büros gab es Durchsuchungen.',
#    'uuid': '1AoHRPchEPrODNj4J7HIzp',
#    'title': 'Haftbefehl und eine Festnahme in der Maskenaffäre',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/haftbefehl-in-der-maskenaffaere-erlassen',
#    'release_date': '2021-03-25T11:40:50Z',
#    'uri': 'http://api.zeit.de/content/1AoHRPchEPrODNj4J7HIzp',
#    'snippet': 'In der Affäre um Korruptionsvorwürfe beim Kauf von <em>Corona</em>-Schutzmasken hat es nach Angaben der Münchener Generalstaatsanwaltschaft eine Festnahme gegeben. Ein Haftbefehl sei erlassen worden, teilte',
#    'supertitle': 'München',
#    'teaser_text': 'Die Münchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaffäre in der Union festnehmen lassen. In Thüringer CDU-Büros gab es Durchsuchungen.',
#    'teaser_title': 'Haftbefehl und Festnahme in der Maskenaffäre'},
#   {'subtitle': 'Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.',
#    'uuid': '5s0zkP0iNOnxucf7UryTns',
#    'title': 'Positiver Corona-Test in der Fußballnationalmannschaft',
#    'href': 'http://www.zeit.de/sport/2021-03/dfb-corona-test-nationalmannschaft-wm-qualifikationsspiel',
#    'release_date': '2021-03-25T11:38:04Z',
#    'uri': 'http://api.zeit.de/content/5s0zkP0iNOnxucf7UryTns',
#    'snippet': 'Kurz vor dem WM-Qualifikationsspiel gegen Island hat es bei der deutschen Fußballnationalmannschaft einen positiven <em>Corona</em>-Test gegeben, wie der Deutsche Fußball-Bund (DFB) bestätigte.\nDer Spieler',
#    'supertitle': 'DFB',
#    'teaser_text': 'Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.',
#    'teaser_title': 'Positiver Corona-Test in der Fußballnationalmannschaft'},
#   {'subtitle': 'Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.',
#    'uuid': 'V5mg2tY0jnP32xpzwXw1l',
#    'title': 'Streit um Impfstoffverteilung und Exportkontrollen',
#    'href': 'http://www.zeit.de/politik/2021-03/eu-gipfel-corona-impfung-impfstoff-astrazeneca-verteilung',
#    'release_date': '2021-03-25T11:24:43Z',
#    'uri': 'http://api.zeit.de/content/V5mg2tY0jnP32xpzwXw1l',
#    'snippet': ' der in der EU produzierten <em>Corona</em>-Impfstoffe exportiert wird. Größter Abnehmer ist Großbritannien. Zurück kommt von dort aber so gut wie nichts.\nAm Mittwoch beschloss die Kommission deshalb eine',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.',
#    'teaser_title': 'Streit um Impfstoffverteilung und Exportkontrollen'},
#   {'subtitle': 'Die Mitbegründerin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht über die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.',
#    'uuid': '4ZD2UDcxIgF3PbnmZasUTK',
#    'title': 'Maja Göpel, wie können wir die Welt neu denken?',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/maja-goepel-interviewpodcast-alles-gesagt',
#    'release_date': '2021-03-25T10:28:02Z',
#    'uri': 'http://api.zeit.de/content/4ZD2UDcxIgF3PbnmZasUTK',
#    'snippet': 'Sie gilt als Wissenschaftlerin der Stunde, als eine der prägenden Stimmen unserer Zeit – und das, obwohl sie kein Buch über die <em>Corona</em>-Pandemie geschrieben hat: Maja Göpel ist zu Gast bei Alles',
#    'supertitle': 'Maja Göpel',
#    'teaser_text': 'Die Mitbegründerin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht über die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.',
#    'teaser_title': 'Maja Göpel, wie können wir die Welt neu denken?'},
#   {'subtitle': 'Das Unternehmen bemüht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie veröffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.',
#    'uuid': '538zqBwwLdW8oVWlZ2q9Jp',
#    'title': 'AstraZeneca korrigiert Wirksamkeit seines Impfstoffs leicht',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/astrazeneca-corona-impfstoff-wirksamkeit-studien-daten-korrektur',
#    'release_date': '2021-03-25T10:03:01Z',
#    'uri': 'http://api.zeit.de/content/538zqBwwLdW8oVWlZ2q9Jp',
#    'snippet': 'Nach Zweifeln an einer großangelegten US-Studie zur Wirksamkeit des <em>Corona</em>-Impfstoffs von AstraZeneca hat das Pharmaunternehmen seine Angaben leicht nach unten korrigiert. Der Impfstoff schützt',
#    'supertitle': 'Corona-Impfstoff',
#    'teaser_text': 'Das Unternehmen bemüht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie veröffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.',
#    'teaser_title': 'AstraZeneca korrigiert Wirksamkeit seines Impfstoffes leicht'},
#   {'subtitle': 'Ein Ländervergleich aus gegebenem Anlass',
#    'uuid': '6I0o9cccMpkBBK1Liio5rw',
#    'title': 'Bayern oder NRW, was ist besser?',
#    'href': 'http://www.zeit.de/2021/13/bundesland-vergleich-nordrhein-westfalen-bayern-statistik',
#    'release_date': '2021-03-25T10:00:54Z',
#    'uri': 'http://api.zeit.de/content/6I0o9cccMpkBBK1Liio5rw',
#    'snippet': 'Wenn in den vergangenen Monaten die Bundesländer Bayern und NRW verglichen wurden, ging es meist \xaddarum, wer die bessere <em>Corona</em>-Strategie hat: die lässigen Rheinländer oder die strengen Bayern, bei',
#    'supertitle': 'Bundesländer im Vergleich',
#    'teaser_text': 'In beiden Ländern findet man ein gewisses Überlegenheitsgefühl. Man ist ja der Größte, hier nach Fläche, dort nach Bürgern. Ein Ländervergleich aus gegebenem Anlass\u2002',
#    'teaser_title': 'Bayern oder NRW, was ist besser?'},
#   {'subtitle': 'Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept Housing first.',
#    'uuid': '1B144cBunBxUKdPmq26LKz',
#    'title': '"Wir haben zu lange geglaubt, der Markt werde das Problem lösen"',
#    'href': 'http://www.zeit.de/gesellschaft/2021-03/nicolas-schmit-eu-kommission-obdachlosigkeit-europa-sozialpolitik',
#    'release_date': '2021-03-25T09:57:20Z',
#    'uri': 'http://api.zeit.de/content/1B144cBunBxUKdPmq26LKz',
#    'snippet': ' Zahl der Obdachlosen gestiegen. Und jetzt schlägt die <em>Corona</em>-Krise stark auf den Arbeitsmarkt durch. Dazu kommt das Thema Migration: Viele Flüchtlinge haben keinen Wohnsitz. Auf der Suche nach Arbeit',
#    'supertitle': 'Nicolas Schmit',
#    'teaser_text': 'Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept Housing first.',
#    'teaser_title': '"Wir haben zu lange geglaubt, der Markt werde das Problem lösen"'},
#   {'subtitle': 'Schlepper und Bagger versuchen den im Sueskanal havarierten Frachter "Ever Given" zu befreien. Industrie und Logistikexperten warnen vor einer Störung der Lieferketten.',
#    'uuid': '4VpGMYrhZwnfDxhyO4SgJV',
#    'title': 'Mindestens 150 Schiffe durch feststeckenden Frachter blockiert',
#    'href': 'http://www.zeit.de/wirtschaft/2021-03/suezkanal-ever-given-containerschiff-oelpreis-welthandel-blockade',
#    'release_date': '2021-03-25T09:07:37Z',
#    'uri': 'http://api.zeit.de/content/4VpGMYrhZwnfDxhyO4SgJV',
#    'snippet': ' Handelspartner China dürfte leiden. Das hatte zuletzt merklich angezogen und der exportabhängigen Industrie aus der <em>Corona</em>-Rezession geholfen. Doch ein Großteil der Lieferungen kommt durch den Sueskanal. Zudem ist',
#    'supertitle': 'Sueskanal',
#    'teaser_text': 'Schlepper und Bagger versuchen den im Sueskanal havarierten Frachter "Ever Given" zu befreien. Industrie und Logistikexperten warnen vor einer Störung der Lieferketten.',
#    'teaser_title': 'Mindestens 150 Schiffe durch feststeckenden Frachter blockiert'},
#   {'subtitle': 'Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.',
#    'uuid': '7JWDt7dkFr3PF73wf6y0zP',
#    'title': '"Wir werden dieses Virus besiegen"',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-regierungserklaerung-bundestag-corona',
#    'release_date': '2021-03-25T08:23:22Z',
#    'uri': 'http://api.zeit.de/content/7JWDt7dkFr3PF73wf6y0zP',
#    'snippet': '-, 60- und 70-Jährige sein. Und das sind Menschen mit sehr vielen Jahren Lebenserwartung." Zehn Prozent von ihnen würden laut Experteneinschätzung <em>Corona</em>-Langzeitfolgen davontragen. "Es lohnt sich, um',
#    'supertitle': 'Regierungserklärung',
#    'teaser_text': 'Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.',
#    'teaser_title': '"Wir werden dieses Virus besiegen"'},
#   {'subtitle': 'Einen Tag nach Absage der angekündigten Osterruhe tritt die Bundeskanzlerin erneut vor den Bundestag. Verfolgen Sie Merkels Regierungserklärung im Livestream',
#    'uuid': '77yvBt2KPs8v2usBduTId6',
#    'title': 'Jetzt live: Angela Merkel gibt Regierungserklärung ab',
#    'href': 'http://www.zeit.de/politik/2021-03/angela-merkel-corona-lockdown-ostern-regierungserklaerung-livestream',
#    'release_date': '2021-03-25T07:59:38Z',
#    'uri': 'http://api.zeit.de/content/77yvBt2KPs8v2usBduTId6',
#    'snippet': 'Die wichtigsten Neuigkeiten zur <em>Corona</em>-Lage in Deutschland lesen Sie in unserem Liveblog.',
#    'supertitle': 'Lockdown über Ostern',
#    'teaser_text': 'Einen Tag nach Absage der angekündigten Osterruhe tritt die Bundeskanzlerin erneut vor den Bundestag. Verfolgen Sie Merkels Regierungserklärung im Livestream',
#    'teaser_title': 'Jetzt live: Angela Merkel gibt Regierungserklärung ab'},
#   {'subtitle': 'Die gelieferten Impfstoffmengen steigen, aber viele Bundesländer kommen nur langsam voran mit der Verabreichung. Ab April sollen deutlich mehr Impfdosen verfügbar sein.',
#    'uuid': '227unSuNGUZpBq55bUzit8',
#    'title': 'Impftempo stagniert bei deutlich unter 300.000 Impfungen pro Tag',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/impfkampagne-impftempo-deutschland-bundeslaender-ostern',
#    'release_date': '2021-03-25T07:27:57Z',
#    'uri': 'http://api.zeit.de/content/227unSuNGUZpBq55bUzit8',
#    'snippet': '. In welchem Umfang die Hochbetagten geschützt sind, ist zwischen den Ländern ebenfalls unterschiedlich, wie das Robert Koch-Institut in seinen Berichten zeigt.\nMit erwarteten 70,5 bis 73,5 Millionen <em>Corona</em>',
#    'supertitle': 'Impfkampagne',
#    'teaser_text': 'Die gelieferten Impfstoffmengen steigen, aber viele Bundesländer kommen nur langsam voran mit der Verabreichung. Ab April sollen deutlich mehr Impfdosen verfügbar sein.',
#    'teaser_title': 'Impftempo stagniert bei deutlich unter 300.000 Impfungen pro Tag'},
#   {'subtitle': 'Die Bundeskanzlerin gesteht Fehler ein, die Corona-Infektionen nehmen zu, die EU ringt um Impfstoffe und der Sueskanal bleibt blockiert. Der Überblick am Morgen',
#    'uuid': 'peEdGOLL34XEtSUE8FBrM',
#    'title': 'Angela Merkels Schuld, eine Havarie und steigende Zahlen',
#    'href': 'http://www.zeit.de/newsletter/was-jetzt/2021-03/merkel-suezkanal-corona-2021-03-25',
#    'release_date': '2021-03-25T06:38:23Z',
#    'uri': 'http://api.zeit.de/content/peEdGOLL34XEtSUE8FBrM',
#    'snippet': ' Schuld auf sich, die EU will Impfstoffexporte verbieten, die <em>Corona</em>-Zahlen steigen stark an, der Sueskanal bleibt blockiert und die neue ZEIT ist da.\nEin Fehler, aber keine Ruhe: Angela Merkel hat die',
#    'supertitle': '"Was jetzt?"-Newsletter',
#    'teaser_text': 'Die Bundeskanzlerin gesteht Fehler ein, die Corona-Infektionen nehmen zu, die EU ringt um Impfstoffe und der Sueskanal bleibt blockiert. Der Überblick am Morgen',
#    'teaser_title': 'Angela Merkels Schuld, eine Havarie und steigende Zahlen'},
#   {'subtitle': 'Personalerin Julia Schusser führt bei Audi im Jahr 400 Vorstellungsgespräche. Hier erzählt sie, warum ein chaotischer Hintergrund von Vorteil sein kann.',
#    'uuid': 'Ew0IpzEtO8aY66mzGQtHY',
#    'title': '"Vom Hoodie bis zum Anzug ist alles in Ordnung"',
#    'href': 'http://www.zeit.de/arbeit/2021-03/vorstellungsgespraeche-bewerbung-tipps-tricks-personalerin-audi',
#    'release_date': '2021-03-25T05:10:51Z',
#    'uri': 'http://api.zeit.de/content/Ew0IpzEtO8aY66mzGQtHY',
#    'snippet': '-Gespräch vor <em>Corona</em> sehr nervös wirkten und dann im zweiten Onlinegespräch im Lockdown gelassener und entspannter durch die Kamera kommunizierten. Die Stressfaktoren von einem Vorstellungsgespräch vor Ort',
#    'supertitle': 'Vorstellungsgespräche',
#    'teaser_text': 'Personalerin Julia Schusser führt bei Audi im Jahr 400 Vorstellungsgespräche – derzeit online. Hier erzählt sie, warum ein chaotischer Hintergrund von Vorteil sein kann.',
#    'teaser_title': '"Vom Hoodie bis zum Anzug ist alles in Ordnung"'},
#   {'subtitle': 'Während um die großen Linien in der Coronapolitik gestritten wird, probieren Tübingen, Rostock und Altötting neue Wege im Kampf gegen die Krise aus. Wie funktioniert das?',
#    'uuid': '24Y25YNeZVf4GyuiSJKuQb',
#    'title': 'Es geht auch anders',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/pandemiebekaempfung-kommunen-konzepte-corona-tuebingen-rostock-altoetting',
#    'release_date': '2021-03-25T05:08:41Z',
#    'uri': 'http://api.zeit.de/content/24Y25YNeZVf4GyuiSJKuQb',
#    'snippet': 'Während Ministerpräsidenten und die Kanzlerin über die großen Linien der <em>Corona</em>-Politik streiten, versuchen viele Städte und Gemeinden, vor Ort kleine und praktikable Lösungen zu finden. Wir stellen',
#    'supertitle': 'Pandemiebekämpfung',
#    'teaser_text': 'Während um die großen Linien in der Coronapolitik gestritten wird, probieren Tübingen, Rostock und Altötting neue Wege im Kampf gegen die Krise aus. Wie funktioniert das?',
#    'teaser_title': 'Es geht auch anders'},
#   {'subtitle': 'Beim EU-Gipfel geht es unter anderem um die Impfstoffversorgung – ein besonderer Gast will sich zuschalten. Außerdem: Therapieren deutsche Intensivstationen zu viel?',
#    'uuid': '335BzYQeHGPKRVy2tMKFyB',
#    'title': 'Viel Diskussionsbedarf und ein besonderer Gast',
#    'href': 'http://www.zeit.de/politik/2021-03/eu-gipfel-corona-impfstoff-joe-biden-nachrichtenpodcast',
#    'release_date': '2021-03-25T04:54:21Z',
#    'uri': 'http://api.zeit.de/content/335BzYQeHGPKRVy2tMKFyB',
#    'snippet': ' möglich ist, ist auch sinnvoll.\xa0\nJan Schweitzer, Redakteur im Ressort Wissen der ZEIT, ordnet die Warnung der Fachleute für Intensivmedizin ein. Er setzt sie in Beziehung zur aktuellen <em>Corona</em>-Lage und zeigt',
#    'supertitle': 'EU-Gipfel',
#    'teaser_text': 'Beim EU-Gipfel geht es unter anderem um die Impfstoffversorgung – ein besonderer Gast will sich zuschalten. Außerdem: Therapieren deutsche Intensivstationen zu viel?',
#    'teaser_title': 'Viel Diskussionsbedarf und ein besonderer Gast'},
#   {'subtitle': '95 Prozent der Seniorinnen und Senioren in Pflegeheimen haben mindestens eine Impfung erhalten. Die Impfkampagne stagniert, doch Jens Spahn verspricht Besserung.',
#    'uuid': '36itswdSW0JtLGRxwyWXTy',
#    'title': 'Fast alle Pflegeheimbewohner laut RKI geimpft',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/corona-pandemie-impfkampagne-rki-deutschland-pflegeheime',
#    'release_date': '2021-03-25T04:37:29Z',
#    'uri': 'http://api.zeit.de/content/36itswdSW0JtLGRxwyWXTy',
#    'snippet': ' bevorstehenden zweiten Quartal sollen deutlich mehr Menschen in Deutschland geimpft werden können, insgesamt werden 70,5 bis 73,5 Millionen <em>Corona</em>-Impfdosen erwartet. Im ersten Quartal waren es 19,8 Millionen',
#    'supertitle': 'Corona-Pandemie',
#    'teaser_text': '95 Prozent der Seniorinnen und Senioren in Pflegeheimen haben mindestens eine Impfung erhalten. Bundesweit stagniert die Impfkampagne, Jens Spahn verspricht Besserung.',
#    'teaser_title': 'Fast alle Pflegeheimbewohner laut RKI geimpft'},
#   {'subtitle': 'Lothar Wieler hat nach Angela Merkels Kehrtwende empfohlen, das öffentliche Leben herunterzufahren. Laut Epidemiologen reichen fünf Tage Osterruhe nicht einmal aus.',
#    'uuid': '48DikAXNqmJezt4YVLoMhz',
#    'title': 'Dritte Welle laut RKI-Chef nur mit Lockdown zu stoppen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/corona-politik-rki-chef-lothar-wieler-lockdown-dritte-welle',
#    'release_date': '2021-03-25T04:01:38Z',
#    'uri': 'http://api.zeit.de/content/48DikAXNqmJezt4YVLoMhz',
#    'snippet': 'Die jüngste Zunahme der <em>Corona</em>-Neuinfektionen in Deutschland kann nach Ansicht des Robert Koch-Instituts (RKI) nur mit Hilfe eines Lockdowns gestoppt werden. Bis ein Großteil der Bevölkerung gegen',
#    'supertitle': 'Corona-Politik',
#    'teaser_text': 'Lothar Wieler hat nach Angela Merkels Kehrtwende empfohlen, das öffentliche Leben herunterzufahren. Laut Epidemiologen reichen fünf Tage Osterruhe nicht einmal aus.',
#    'teaser_title': 'Dritte Welle laut RKI-Chef nur mit Lockdown zu stoppen'},
#   {'subtitle': 'Gemeinsam könne die westliche Welt China Paroli bieten, sagte Antony Blinken in Brüssel. Die USA und die EU hatten Sanktionen wegen der Lage der Uiguren verhängt.',
#    'uuid': '7F0QUJDD8rbk7LJM2iIwgn',
#    'title': 'US-Außenminister stellt EU enge Zusammenarbeit in Aussicht',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/usa-aussenminister-antony-blinken-eu-china-beziehung',
#    'release_date': '2021-03-25T00:32:25Z',
#    'uri': 'http://api.zeit.de/content/7F0QUJDD8rbk7LJM2iIwgn',
#    'snippet': ' chinesische Führung ihrerseits Missstände in den USA. Dort sei die <em>Corona</em>-Pandemie außer Kontrolle geraten, es habe politisches Chaos, Konflikte zwischen Menschen unterschiedlicher Hautfarbe und',
#    'supertitle': 'USA',
#    'teaser_text': 'Gemeinsam könne die westliche Welt China Paroli bieten, sagte Antony Blinken in Brüssel. Die USA und die EU hatten Sanktionen wegen der Lage der Uiguren verhängt.',
#    'teaser_title': 'US-Außenminister stellt EU enge Zusammenarbeit in Aussicht'},
#   {'subtitle': 'Die Testpflicht für Flugpassagiere reicht vielen nicht aus – auch der Kanzlerin nicht. Deshalb lässt die Bundesregierung weitere Maßnahmen prüfen.',
#    'uuid': '13vPkzOimFOfvkcLp2bUXK',
#    'title': 'Bundesregierung prüft Verbot von Auslandsreisen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/corona-beschluesse-bundesregierung-urlaubsreisen-ausland-unterbindung',
#    'release_date': '2021-03-25T00:21:09Z',
#    'uri': 'http://api.zeit.de/content/13vPkzOimFOfvkcLp2bUXK',
#    'snippet': 'Angesichts der Diskussion über Mallorca-Urlaub trotz <em>Corona</em> erwägt die Bundesregierung, Reisen in beliebte Urlaubsgebiete im Ausland vorübergehend zu unterbinden. "Das wird jetzt von den zuständigen',
#    'supertitle': 'Corona-Beschlüsse',
#    'teaser_text': 'Die Testpflicht für Flugpassagiere reicht vielen nicht aus – auch der Kanzlerin nicht. Deshalb lässt die Bundesregierung weitere Maßnahmen prüfen.',
#    'teaser_title': 'Bundesregierung prüft Verbot von Auslandsreisen'},
#   {'subtitle': 'Mit 22.657 Corona-Neuinfektionen meldet die Behörde einen rasanten Anstieg der Infektionszahlen. Die Sieben-Tage-Inzidenz stieg auf 113.',
#    'uuid': '6uTeBQX2eYAb9zK40AvRhQ',
#    'title': 'RKI registriert gut 5.000 Neuinfektionen mehr als vor einer Woche',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/coronavirus-neuinfektionen-rki-gesundheitsaemter',
#    'release_date': '2021-03-24T21:25:29Z',
#    'uri': 'http://api.zeit.de/content/6uTeBQX2eYAb9zK40AvRhQ',
#    'snippet': 'Die deutschen Gesundheitsämter haben dem Robert Koch-Institut (RKI) im Laufe des Mittwochs 22.657 <em>Corona</em>-Neuinfektionen gemeldet, gut 5.000 mehr als noch vor einer Woche (17.504). ZEIT ONLINE kommt',
#    'supertitle': 'Coronavirus',
#    'teaser_text': 'Mit 22.657 Corona-Neuinfektionen meldet die Behörde einen rasanten Anstieg der Infektionszahlen. Die Sieben-Tage-Inzidenz stieg auf 113.',
#    'teaser_title': 'RKI registriert gut 5.000 Neuinfektionen mehr als vor einer Woche'},
#   {'subtitle': 'Die Kanzlerin versichert, sie habe die Unterstützung der gesamten Regierung. Forderungen nach weiteren Konsequenzen aus der Absage des Osterlockdowns weist sie zurück.',
#    'uuid': '7xzmc4S70a1FIyWw9rDea5',
#    'title': 'Angela Merkel lehnt Vertrauensfrage ab',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/cdu-angela-merkel-vertrauensfrage-opposition-bundestag',
#    'release_date': '2021-03-24T20:47:54Z',
#    'uri': 'http://api.zeit.de/content/7xzmc4S70a1FIyWw9rDea5',
#    'snippet': ' Opposition. Diese Begegnungen mit den 16 Länderchefs seien wichtig, weil das Infektionsschutzgesetz regele, dass die Länder für die <em>Corona</em>-Maßnahmen zuständig seien. "Damit Deutschland nicht ein vollständiger',
#    'supertitle': 'CDU',
#    'teaser_text': 'Die Kanzlerin versichert, sie habe die Unterstützung der gesamten Regierung. Forderungen nach weiteren Konsequenzen aus der Absage des Osterlockdowns weist sie zurück.',
#    'teaser_title': 'Angela Merkel lehnt Vertrauensfrage ab'},
#   {'subtitle': 'Kinder infizieren sich zwar seltener als Erwachsene und verkraften Covid-19 besser. Doch auch für sie ist die Mutante ansteckender. Was das für Kitas und Schulen heißt.',
#    'uuid': '6NbtygoCmS6eAj1gpwOaIE',
#    'title': 'Warum gerade jetzt mehr Kinder Corona kriegen',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/infektionsrisiko-schulen-kitas-kinder-neuinfektion-corona-pandemie',
#    'release_date': '2021-03-24T19:24:10Z',
#    'uri': 'http://api.zeit.de/content/6NbtygoCmS6eAj1gpwOaIE',
#    'snippet': 'Frust und starke Emotionen prägen die Debatte um Kinder und <em>Corona</em>. Die Frage, wann und wie Kinder in der Pandemie zur Schule oder in die Kita dürfen, birgt Sprengkraft. Einheitliche, klare Regeln',
#    'supertitle': 'Infektionsrisiko in Schulen und Kitas',
#    'teaser_text': 'Kinder infizieren sich zwar seltener als Erwachsene\xa0und verkraften Covid-19 besser. Doch auch für sie ist die Mutante ansteckender. Was das für Kitas und Schulen heißt.',
#    'teaser_title': 'Warum gerade jetzt mehr Kinder Corona kriegen'},
#   {'subtitle': 'Wer entscheidet, wenn man es selbst nicht mehr kann? Eine Vollmacht hilft Angehörigen. Wir erklären, wie man auf einer DIN-A4-Seite Vorkehrungen für den Notfall trifft.',
#    'uuid': '6tPLZI8RIAJPsbv3Rhai5k',
#    'title': 'Darauf kommt es bei einer Vorsorgevollmacht an',
#    'href': 'http://www.zeit.de/wirtschaft/2021-02/vorsorgevollmacht-patientenverfuegung-recht-handlungsfaehigkeit-geschaeftsunfaehigkeit-faq',
#    'release_date': '2021-03-24T19:23:28Z',
#    'uri': 'http://api.zeit.de/content/6tPLZI8RIAJPsbv3Rhai5k',
#    'snippet': 'Sie haben auch noch keine Vorsorgevollmacht und fragen sich: Brauche ich das überhaupt? Wir sagen: Besser ist es. Und helfen Ihnen dabei, sie aufzustellen. Denn in der <em>Corona</em>-Krise bewegt immer mehr',
#    'supertitle': 'Rechtliche Vorsorge',
#    'teaser_text': 'Wer entscheidet, wenn man es selbst nicht mehr kann? Eine Vollmacht hilft Angehörigen. Wir erklären, wie man auf einer DIN-A4-Seite Vorkehrungen für den Notfall trifft.',
#    'teaser_title': 'Darauf kommt es bei einer Vorsorgevollmacht an'},
#   {'subtitle': 'Inzwischen sind fast neun Millionen Menschen in Deutschland gegen Covid geimpft worden. Die Quote für schwere Verdachtsfälle liegt bei 0,3 pro 1.000 Impfdosen.',
#    'uuid': '7ffPlIgNBBgvBtNSIpOL1t',
#    'title': 'Schwere Nebenwirkungen nach Corona-Impfung weiterhin die Ausnahme',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-03/nebenwirkungen-impfung-coronavirus-paul-ehrlich-institut',
#    'release_date': '2021-03-24T18:47:55Z',
#    'uri': 'http://api.zeit.de/content/7ffPlIgNBBgvBtNSIpOL1t',
#    'snippet': 'Schwerwiegende Nebenwirkungen nach <em>Corona</em>-Impfungen treten weiterhin nur sehr selten auf. Nach fast neun Millionen Impfungen in Deutschland nannte das zuständige Paul-Ehrlich-Institut (PEI) eine',
#    'supertitle': 'Paul-Ehrlich-Institut',
#    'teaser_text': 'Inzwischen sind fast neun Millionen Menschen in Deutschland gegen Covid geimpft worden. Die Quote für schwere Verdachtsfälle liegt bei 0,3 pro 1.000 Impfdosen.',
#    'teaser_title': 'Schwere Nebenwirkungen nach Corona-Impfung weiterhin die Ausnahme'},
#   {'subtitle': 'Das ist neu, nicht nur für die Corona-Politik, sondern auch für fast 16 Jahre Kanzlerschaft. Merkel hat um Verzeihung gebeten – und könnte ihre Position so verbessern.',
#    'uuid': '4cHpUa7ubbZSFb2N0hcfLh',
#    'title': 'Angela Merkels Kalkül könnte aufgehen',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/pandmie-politik-corona-angela-merkel-entschuldigung-opposition-bundestag',
#    'release_date': '2021-03-24T17:18:16Z',
#    'uri': 'http://api.zeit.de/content/4cHpUa7ubbZSFb2N0hcfLh',
#    'snippet': ' die dritte Welle der <em>Corona</em>-Pandemie zumindest ein wenig zu brechen. Eine Idee, auf die laut Süddeutscher Zeitung Kanzleramtschef Helge Braun mehr oder weniger spontan gekommen war. ("Helge, hast du',
#    'supertitle': 'Pandemiepolitik',
#    'teaser_text': 'Das ist neu, nicht nur für die Corona-Politik, sondern auch für fast 16 Jahre Kanzlerschaft. Merkel hat um Verzeihung gebeten – und könnte ihre Position so verbessern.',
#    'teaser_title': 'Angela Merkels Kalkül könnte aufgehen'},
#   {'subtitle': 'Für das laufende Jahr braucht das Finanzministerium 60,4 Milliarden Euro mehr und will einen Nachtragshaushalt. Auch 2022 dürfte die Schuldenbremse kaum zu halten sein.',
#    'uuid': '25AF0UIwcGpbDdoZM3qFmb',
#    'title': 'Bundesregierung plant mit 81,5 Milliarden neuen Schulden für 2022',
#    'href': 'http://www.zeit.de/politik/deutschland/2021-03/staatsverschuldung-bundesregierung-schulden-2022-haushalt-schuldenbremse-finanzpolitik',
#    'release_date': '2021-03-24T17:15:47Z',
#    'uri': 'http://api.zeit.de/content/25AF0UIwcGpbDdoZM3qFmb',
#    'snippet': 'Die Bundesregierung verteidigt die Rekordverschuldung als Reaktion auf die <em>Corona</em>-Pandemie: "Das ist teuer. Aber Nichtstun wäre viel teurer", sagte Bundesfinanzminister Olaf Scholz (SPD) bei der',
#    'supertitle': 'Staatsverschuldung',
#    'teaser_text': 'Für das laufende Jahr braucht das Finanzministerium 60,4 Milliarden Euro mehr und will einen Nachtragshaushalt. Auch 2022 dürfte die Schuldenbremse kaum zu halten sein.',
#    'teaser_title': 'Bundesregierung plant mit 81,5 Milliarden neuen Schulden für 2022'},
#   {'subtitle': 'Im Streit mit AstraZeneca um Impfstofflieferungen hat die Kommission in Brüssel neue Regeln erlassen. Generelle Ausfuhrverbote gibt es zwar nicht – neue Kriterien schon.',
#    'uuid': '69JIVt1W9QZu4g1CzYe42x',
#    'title': 'EU verschärft Kontrolle von Impfstoffexporten',
#    'href': 'http://www.zeit.de/politik/ausland/2021-03/eu-kommission-corona-impfstoff-export-kontrolle-exportstopp-europaeische-union',
#    'release_date': '2021-03-24T17:00:43Z',
#    'uri': 'http://api.zeit.de/content/69JIVt1W9QZu4g1CzYe42x',
#    'snippet': 'Der Export der knappen <em>Corona</em>-Impfstoffe aus der Europäischen Union soll nach dem Willen der EU noch schärfer kontrolliert und notfalls häufiger gestoppt werden. Dies beschloss die Kommission',
#    'supertitle': 'Streit mit AstraZeneca',
#    'teaser_text': 'Im Streit mit AstraZeneca um Impfstofflieferungen hat die Kommission in Brüssel neue Regeln erlassen. Generelle Ausfuhrverbote gibt es zwar nicht – neue Kriterien schon.',
#    'teaser_title': 'EU verschärft Kontrolle von Impfstoffexporten'},
#   {'subtitle': 'Die Bundeskanzlerin hat die unlängst beschlossene "Osterruhe" zurückgezogen und einen Fehler eingestanden. Die Opposition im Bundestag fordert eine Vertrauensabstimmung.',
#    'uuid': '6vzg6RO7KZ0V8eVhQtKvjD',
#    'title': 'Angela Merkel übernimmt Verantwortung',
#    'href': 'http://www.zeit.de/politik/2021-03/corona-beschluesse-ruhetage-lockdown-ostern-angela-merkel-nachrichtenpodcast',
#    'release_date': '2021-03-24T16:24:15Z',
#    'uri': 'http://api.zeit.de/content/6vzg6RO7KZ0V8eVhQtKvjD',
#    'snippet': 'Nicht einmal 48 Stunden nach dem Beschluss der Bund-Länder-Runde, zur <em>Corona</em>-Bekämpfung rund um Ostern zusätzliche "Ruhetage" einzurichten, hat Bundeskanzlerin Angela Merkel diese Entscheidung heute',
#    'supertitle': 'Corona-Beschlüsse',
#    'teaser_text': 'Die Bundeskanzlerin hat die unlängst beschlossene "Osterruhe" zurückgezogen und einen Fehler eingestanden. Die Opposition im Bundestag fordert eine Vertrauensabstimmung.',
#    'teaser_title': 'Angela Merkel übernimmt Verantwortung'},
#   {'subtitle': 'Aus dem Gefängnis spricht der türkische Oppositionspolitiker Selahattin Demirtaş über das drohende Verbot seiner Partei\u2002',
#    'uuid': '6lmkoZSiBpG7wWQT11Qybi',
#    'title': '"Kein Grund, hoffnungslos zu sein"',
#    'href': 'http://www.zeit.de/2021/13/selahattin-demirtas-tuerkei-hdp-verbot-erdogan-akp-menschenrechte',
#    'release_date': '2021-03-24T15:52:54Z',
#    'uri': 'http://api.zeit.de/content/6lmkoZSiBpG7wWQT11Qybi',
#    'snippet': ' und sie einem seiner Anwälte bei einem der nächsten Besuche zurückgeben. Aber jetzt ist <em>Corona</em>. Anwalt und Mandant sind derzeit durch eine Glasscheibe getrennt, sie dürfen keine Unterlagen austauschen',
#    'supertitle': 'Selahattin Demirtaş',
#    'teaser_text': 'Aus dem Gefängnis spricht der türkische Oppositionspolitiker Selahattin Demirtaş über das drohende Verbot seiner Partei\u2002',
#    'teaser_title': '"Kein Grund, hoffnungslos zu sein"'},
#   {'subtitle': 'Der Intensivmediziner Uwe Janssens ermahnt seine Kollegen zu mehr Augenmaß in der Therapie. Der Wille der Patientinnen und Patienten müsse im Mittelpunkt stehen',
#    'uuid': '6eYN46kHAUS4Cdg3pPRwGg',
#    'title': '"Mit dem Tod offen umgehen"',
#    'href': 'http://www.zeit.de/2021/13/uwe-janssens-intensivmedizin-ethik-therapie-ueberversorgung-ueberschaetzung',
#    'release_date': '2021-03-24T15:52:50Z',
#    'uri': 'http://api.zeit.de/content/6eYN46kHAUS4Cdg3pPRwGg',
#    'snippet': 'DIE ZEIT: Mitten in der dritten Welle der <em>Corona</em>-Pandemie bringt die Deutsche Interdisziplinäre Vereinigung für Intensiv- und Notfallmedizin (Divi) ein Papier zur Überversorgung in der',
#    'supertitle': 'Uwe Janssens',
#    'teaser_text': 'Der Intensivmediziner Uwe Janssens ermahnt seine Kollegen zu mehr Augenmaß in der Therapie. Der Wille der Patientinnen und Patienten müsse im Mittelpunkt stehen',
#    'teaser_title': '"Intensivbetten sind oft mit den falschen Patienten belegt"'},
#   {'subtitle': 'Gabriele von Arnims erstaunliches Buch über das lange Sterben ihres Mannes.\u2002',
#    'uuid': '7II51zRl4cZJf4LXxIuYlx',
#    'title': 'Schau mich doch an',
#    'href': 'http://www.zeit.de/2021/13/gabriele-von-arnim-das-leben-ist-ein-voruebergehender-zustand',
#    'release_date': '2021-03-24T15:52:42Z',
#    'uri': 'http://api.zeit.de/content/7II51zRl4cZJf4LXxIuYlx',
#    'snippet': ' entziehen.\nDa wäre das Wegducken. 75.000 <em>Corona</em>-Tote. Wie lebhaft sich die Leute gegenseitig versichern, dass sie niemanden kennen, der an Covid gestorben ist.\nNicht selten kommt der Tod schnell, scheint',
#    'supertitle': 'Gabriele von Arnim',
#    'teaser_text': 'Gabriele von Arnims erstaunliches Buch über das lange Sterben ihres Mannes.\u2002',
#    'teaser_title': 'Schau mich doch an'},
#   {'subtitle': 'Wie unser Immunsystem Tag für Tag auf uns aufpasst – eine Reise ins Innere des menschlichen Körpers.\u2002',
#    'uuid': '71FLvZ1wsCfu0s3hGIHsA1',
#    'title': 'Gute Besserung!',
#    'href': 'http://www.zeit.de/2021/13/immunsystem-koerper-zellen-antikoerper-forschung-medizin-coronavirus',
#    'release_date': '2021-03-24T15:52:27Z',
#    'uri': 'http://api.zeit.de/content/71FLvZ1wsCfu0s3hGIHsA1',
#    'snippet': ' of Health in Washington. Ihr Chef ist Anthony Fauci, der <em>Corona</em>-Berater des Präsidenten. Als sie ihren Laptop aufklappt, ist es bei ihr vier Uhr morgens. Sie stehe gerne früh auf, sagt sie.\nMatzinger, Tochter',
#    'supertitle': 'Immunsystem',
#    'teaser_text': 'Wie unser Immunsystem Tag für Tag auf uns aufpasst – eine Reise ins Innere des menschlichen Körpers.\u2002',
#    'teaser_title': 'Gute Besserung!'},
#   {'subtitle': 'Alfred Sauter war einer der einflussreichsten Strategen der CSU. Bis sein Geschäftsmodell aufflog\u2002',
#    'uuid': '6HDekuZjENuKoJKjrsxd5T',
#    'title': 'Anwalt in eigener Sache',
#    'href': 'http://www.zeit.de/2021/13/alfred-sauter-csu-maskenaffaere-lobbyismus-transparenz',
#    'release_date': '2021-03-24T15:52:24Z',
#    'uri': 'http://api.zeit.de/content/6HDekuZjENuKoJKjrsxd5T',
#    'snippet': ' Auskunft über seine Mandanten geben. Lediglich ihre Anzahl veröffentlicht er: Allein im <em>Corona</em>-Jahr hat sie sich im Vergleich zu den beiden Vorjahren verdreifacht. Alfred Sauter selbst weist stets darauf hin',
#    'supertitle': 'Alfred Sauter',
#    'teaser_text': 'Alfred Sauter war einer der einflussreichsten Strategen der CSU. Bis sein Geschäftsmodell aufflog\u2002',
#    'teaser_title': 'Anwalt in eigener Sache'},
#   {'subtitle': 'Fabian Leendertz sucht nach dem Ursprung von Corona. Die Ermittlungen werden noch dauern.',
#    'uuid': '5hN2zPFIyYx4QVDwfK8NOy',
#    'title': 'Der Seuchenfahnder',
#    'href': 'http://www.zeit.de/2021/13/fabian-leendertz-corona-ursprung-suche-rki-epidemiologie-zoonosen',
#    'release_date': '2021-03-24T15:52:14Z',
#    'uri': 'http://api.zeit.de/content/5hN2zPFIyYx4QVDwfK8NOy',
#    'snippet': ' dem Sprung gestoppt werden. Danach sei es extrem schwierig, Viren wie Ebola oder Sars-CoV-2 aufzuhalten, sagt Leendertz, das habe die <em>Corona</em>-Pandemie gezeigt. Einen Ausbruch vorherzusagen oder zu',
#    'supertitle': 'Fabian Leendertz',
#    'teaser_text': 'Fabian Leendertz sucht nach dem Ursprung von Corona. Die Ermittlungen werden noch dauern.',
#    'teaser_title': 'Der Seuchenfahnder'},
#   {'subtitle': 'In der Pandemie ist Manuela Schwesig zur Gegenspielerin von Kanzlerin Merkel und zum Gesicht der SPD geworden. Wenn sie im Herbst die Landtagswahl gewinnt, kann sie in ihrer Partei werden, was sie will.',
#    'uuid': '27g73KZUKIf4sJlbgXHG4T',
#    'title': '"Die Leute wollen Haltung sehen"',
#    'href': 'http://www.zeit.de/2021/13/manuela-schwesig-corona-krise-spd-mecklenburg-vorpommern-karriere',
#    'release_date': '2021-03-24T15:52:11Z',
#    'uri': 'http://api.zeit.de/content/27g73KZUKIf4sJlbgXHG4T',
#    'snippet': 'Als Manuela Schwesig am Sonntagnachmittag, 24 Stunden vor der nächsten <em>Corona</em>-Krisenrunde, zur Videoverabredung auf dem Schirm erscheint, hat sie bereits eine Eiche gepflanzt und einen Schlachtplan',
#    'supertitle': 'Manuela Schwesig',
#    'teaser_text': 'In der Pandemie ist Manuela Schwesig zum Gesicht der SPD geworden. Wenn sie im Herbst die Landtagswahl gewinnt, kann sie in ihrer Partei werden, was sie will.',
#    'teaser_title': '"Die Leute wollen Haltung sehen"'},
#   {'subtitle': 'Bernard Meyer baute jahrelang immer größere Schiffe. Sein Umgang mit Arbeitern ist umstritten. Von Gewerkschaften hält er wenig – das rächt sich in der Krise.\u2002',
#    'uuid': '2A4zMOrKNLt7ohL53DRCpz',
#    'title': 'Kreuzfahrtkönig unter Druck',
#    'href': 'http://www.zeit.de/2021/13/schiffbau-werft-kreuzfahrt-ig-metall-bernhard-meyer',
#    'release_date': '2021-03-24T15:52:06Z',
#    'uri': 'http://api.zeit.de/content/2A4zMOrKNLt7ohL53DRCpz',
#    'snippet': ' Geschäftsführer im Unternehmen tätig und stehen bereit, das Erbe in siebter Generation fortzuführen. Meyers Verhandlungsgeschick ist es zu verdanken, dass seine Kunden im <em>Corona</em>-Krisenjahr 2020 keinen einzigen',
#    'supertitle': 'Schiffbau',
#    'teaser_text': 'Bernard Meyer baute jahrelang immer größere Schiffe. Sein Umgang mit Arbeitern ist umstritten. Von Gewerkschaften hält er wenig – das rächt sich in der Krise.\u2002',
#    'teaser_title': 'Kreuzfahrtkönig unter Druck'},
#   {'subtitle': 'Lernt die Menschheit aus Krisen? Ein Gespräch zwischen Wolfgang Schäuble und dem Autor Rutger Bregman',
#    'uuid': '3BJD02k2SW8maH0XD9isCT',
#    'title': '"Der Mensch kann Fürchterliches anrichten" – "Die meisten sind tief in ihrem Inneren anständig"',
#    'href': 'http://www.zeit.de/2021/13/wolfgang-schaeuble-rutger-bregman-corona-krise-mensch',
#    'release_date': '2021-03-24T15:52:01Z',
#    'uri': 'http://api.zeit.de/content/3BJD02k2SW8maH0XD9isCT',
#    'snippet': ' diese Welt je gesehen hat. Deshalb glaube ich, dass das Momentum der <em>Corona</em>-Krise anders sein kann als 2008. Aber das ist keine Vorhersage, denn es könnte auch sehr viel schlechter kommen.\nSchäuble: Auch',
#    'supertitle': 'Wolfgang Schäuble und Rutger Bregman',
#    'teaser_text': 'Wird sich durch die Krise der Pandemie unsere Gesellschaft dauerhaft verändern? Wolfgang Schäuble und der Autor Rutger Bregman glauben an eine tiefgreifende Zäsur.',
#    'teaser_title': '"Die fortschrittlichste Generation, die diese Welt je gesehen hat"'},
#   {'subtitle': 'Zwei türkische Filme zeigen ein Land zwischen Überlebenskunst und Anarchie.',
#    'uuid': '2uj6T6jf2LBkR2km7ztk7w',
#    'title': 'Für ein paar Lira mehr',
#    'href': 'http://www.zeit.de/2021/13/tuerkische-filme-leben-papier-hey-there-istanbul-netflix-mubi',
#    'release_date': '2021-03-24T15:52:00Z',
#    'uri': 'http://api.zeit.de/content/2uj6T6jf2LBkR2km7ztk7w',
#    'snippet': ', eine virtuelle Reise durch ein Land im Lockdown, eine frühe und sicher nicht die letzte <em>Corona</em>-Komödie.',
#    'supertitle': 'Türkische Filme',
#    'teaser_text': 'Zwei türkische Filme zeigen ein Land zwischen Überlebenskunst und Anarchie.',
#    'teaser_title': 'Für ein paar Lira mehr'},
#   {'subtitle': 'Die männliche Rede klingt staatstragend, die weibliche eher tastend. Diese Konditionierung sitzt zu tief, um sie rasch überwinden zu können.',
#    'uuid': '2FxcePIFNVu9GXsp7rU1c3',
#    'title': 'Das Gewicht der weiblichen Stimme',
#    'href': 'http://www.zeit.de/2021/13/gleichberechtigung-frauen-rede-stimme-vorurteile-politik-maenner',
#    'release_date': '2021-03-24T15:51:54Z',
#    'uri': 'http://api.zeit.de/content/2FxcePIFNVu9GXsp7rU1c3',
#    'snippet': ', wie zu Beginn der <em>Corona</em>-Krise im Frühjahr 2020. Der Schatten des Spahn-Söder-Kretschmann-Laschet-Drosten-Streeck-Kekulé-Elefanten wurde sehr wohl bemerkt. Aber auch mir erschien ein Virus, das',
#    'supertitle': 'Gleichberechtigung',
#    'teaser_text': 'Die männliche Rede klingt staatstragend, die weibliche eher tastend. Diese Konditionierung sitzt zu tief, um sie rasch überwinden zu können.',
#    'teaser_title': 'Das Gewicht der weiblichen Stimme'},
#   {'subtitle': 'Flugtaxis für Städte, Moos gegen Feinstaub: Es gibt so viele gute Ideen, die unser Leben einfacher und lebenswerter machen. Das schlagen unsere Leserinnen und Leser vor.',
#    'uuid': '2BPTdj0HtujeYrDSunQg3N',
#    'title': 'Lern mal deine Nachbarn kennen',
#    'href': 'http://www.zeit.de/2021/13/ideen-innovation-technologie-plattform-start-up-hilfsorganisation',
#    'release_date': '2021-03-24T15:51:48Z',
#    'uri': 'http://api.zeit.de/content/2BPTdj0HtujeYrDSunQg3N',
#    'snippet': ' Plattform nebenan.de etwa bietet einen <em>Corona</em>-Einkaufsservice an. Doch um dies in Anspruch zu nehmen, müssen die Hilfesuchenden mit dem Internet umgehen können. Bei der App aus München ist das anders: Sie',
#    'supertitle': 'Ideen',
#    'teaser_text': 'Flugtaxis für Städte, Moos gegen Feinstaub: Es gibt so viele gute Ideen, die unser Leben einfacher und lebenswerter machen. Das schlagen unsere Leserinnen und Leser vor.',
#    'teaser_title': 'Lern mal deine Nachbarn kennen'},
#   {'subtitle': 'Ist es wichtiger, in der Partei oder bei den Wählern beliebt zu sein, wenn man Kanzlerkandidat werden möchte?',
#    'uuid': '6shnFYASAaQn3Sd7vq977y',
#    'title': 'Überlebensfrage',
#    'href': 'http://www.zeit.de/2021/13/bundestagswahl-kanzleramt-cdu-die-gruenen-markus-soeder',
#    'release_date': '2021-03-24T15:51:46Z',
#    'uri': 'http://api.zeit.de/content/6shnFYASAaQn3Sd7vq977y',
#    'snippet': ' sich aber ändern, wenn sich in den nächsten Wochen ein virologischer und ein politischer Inzidenzwert aufeinander zubewegen sollten: einerseits eine steigende Zahl von <em>Corona</em>-Infizierten, andererseits',
#    'supertitle': 'Bundestagswahl',
#    'teaser_text': 'Ist es wichtiger, in der Partei oder bei den Wählern beliebt zu sein, wenn man Kanzlerkandidat werden möchte?',
#    'teaser_title': 'Überlebensfrage'},
#   {'subtitle': 'Warum benennen die Russen ihren Impfstoff nach einem Satellitenprogramm? Ein Deutungsversuch\u2002',
#    'uuid': 'f62B8Adnt0JYRE1wycOyo',
#    'title': 'Der neue Sputnik-Schock',
#    'href': 'http://www.zeit.de/2021/13/russland-sputnik-corona-impfstoff-raumfahrtprogramm-drohung-symbolik',
#    'release_date': '2021-03-24T15:51:39Z',
#    'uri': 'http://api.zeit.de/content/f62B8Adnt0JYRE1wycOyo',
#    'snippet': ' <em>Corona</em>-Impfstoff diesen Namen, noch dazu versehen mit einem großen V, was für victory, also "Sieg", steht? Es ist als doppelte Botschaft zu verstehen. Die Bürger Russlands sollen von dem Begriff an die',
#    'supertitle': 'Russland',
# ...
#    'teaser_title': 'Wohin nur mit all dem Geld?'},
#   {'subtitle': 'Nach Protesten gegen den Putsch hat die Militärregierung in Myanmar den Notstand verhängt. Größere Versammlungen sind verboten, nachts gilt eine Ausgangssperre.',
#    'uuid': 'wlOqGqhDWBXE3pIWF52kz',
#    'title': 'Militärregierung verhängt Kriegsrecht in Teilen des Landes',
#    'href': 'http://www.zeit.de/politik/ausland/2021-02/myanmar-militaerputsch-ausgangssperre-versammlungsverbote-militaerregierung-proteste-rangun-mandalay',
#    'release_date': '2021-02-08T19:22:34Z',
#    'uri': 'http://api.zeit.de/content/wlOqGqhDWBXE3pIWF52kz',
#    'snippet': '. Er kündigte eine Aufhebung der <em>Corona</em>-Maßnahmen an.\nDas Militär rechtfertigt den Staatsstreich mit Vorwürfen des Wahlbetrugs gegen Suu Kyis Partei NDL. Sie widersprach damit der staatlichen',
#    'supertitle': 'Myanmar',
#    'teaser_text': 'Nach Protesten gegen den Putsch hat die Militärregierung in Myanmar den Notstand verhängt. Größere Versammlungen sind verboten, nachts gilt eine Ausgangssperre.',
#    'teaser_title': 'Militärregierung verhängt Kriegsrecht in Teilen des Landes'},
#   {'subtitle': 'Die Kommission hatte es Anfang Januar angekündigt, jetzt hat sie dem Vertrag zugestimmt: BioNTech/Pfizer liefern weitere Dosen. 75 Millionen sollen bis Ende März kommen.',
#    'uuid': '6VzYdDMgcM3Q3hEzXMBJr1',
#    'title': 'EU ordert 300 Millionen weitere Impfdosen von BioNTech/Pfizer',
#    'href': 'http://www.zeit.de/politik/ausland/2021-02/eu-ordert-300-millionen-weitere-impfdosen-von-biontech-pfizer',
#    'release_date': '2021-02-08T18:31:39Z',
#    'uri': 'http://api.zeit.de/content/6VzYdDMgcM3Q3hEzXMBJr1',
#    'snippet': 'Die EU-Kommission hat bei BioNTtech/Pfizer eine Bestellung über weitere 300 Millionen Dosen <em>Corona</em>-Impfstoff aufgegeben. Die Brüsseler Behörde habe am Montag eine entsprechende zweite Abmachung mit',
#    'supertitle': 'Corona-Impfstoff',
#    'teaser_text': 'Die Kommission hatte es Anfang Januar angekündigt, jetzt hat sie dem Vertrag zugestimmt: BioNTech/Pfizer liefern weitere Dosen. 75 Millionen sollen bis Ende März kommen.',
#    'teaser_title': 'EU ordert 300 Millionen weitere Impfdosen von BioNTech/Pfizer'},
#   {'subtitle': 'Mancher erhält Gutscheine für FFP2-Masken und weiß nicht warum. Andere gehen irrtümlich leer aus. Wie die Zuteilung der Virenfilter funktioniert – oder eben nicht.',
#    'uuid': '5zh1s7DXekdWOGKIFMDDwK',
#    'title': 'Verwirrung um die Gratismaske',
#    'href': 'http://www.zeit.de/gesellschaft/2021-02/corona-schutz-ffp2-masken-gutscheine-verteilung-buerger-mundschutz',
#    'release_date': '2021-02-08T18:21:57Z',
#    'uri': 'http://api.zeit.de/content/5zh1s7DXekdWOGKIFMDDwK',
#    'snippet': ' bevorstehende <em>Corona</em>-Impfungen. In Niedersachsen bat das Sozialministerium um Entschuldigung für solche Pannen: Der Grund: Die Briefe hatte das Landessozialministerium verschickt. Es nutzte dafür nicht die',
#    'supertitle': 'Corona-Schutz',
#    'teaser_text': 'Mancher erhält Gutscheine für FFP2-Masken und weiß nicht warum. Andere gehen irrtümlich leer aus. Wie die Zuteilung der Virenfilter funktioniert – oder eben nicht.',
#    'teaser_title': 'Verwirrung um die Gratismaske'},
#   {'subtitle': 'Die Hamburger Abschlussprüfungen finden statt, fast wie immer. "Abi 2021" wird das Gütesiegel für einen Jahrgang werden, der mehr geleistet hat als die meisten vor ihm.',
#    'uuid': '7wO6v2VOFh7KzGtxBTptXI',
#    'title': 'Keine Angst vor dem Corona-Abi!',
#    'href': 'http://www.zeit.de/hamburg/2021-02/abitur-2021-corona-schulabschluss-pandemie-abschlusspruefung-jahrgang-notabitur',
#    'release_date': '2021-02-08T17:57:04Z',
#    'uri': 'http://api.zeit.de/content/7wO6v2VOFh7KzGtxBTptXI',
#    'snippet': 'Vor den Abiturklausuren werden die offenen Briefe geschrieben, so ist es inzwischen Tradition in der <em>Corona</em>-Zeit. Bereits im vergangenen März hatten Hamburger Gymnasiasten gefordert, die Prüfungen',
#    'supertitle': 'Abitur 2021',
#    'teaser_text': 'Die Hamburger Abschlussprüfungen finden statt, fast wie immer. "Abi 2021" wird das Gütesiegel für einen Jahrgang werden, der mehr geleistet hat als die meisten vor ihm.',
#    'teaser_title': 'Keine Angst vor dem Corona-Abi!'},
#   {'subtitle': 'Coronavirus, Artensterben und Klimawandel – alle drei hängen zusammen. Die Virologin Sandra Junglen erforscht, was der Mensch tun muss, um künftige Krisen zu verhindern.',
#    'uuid': '7MzqWTQFmjiEtbcSH1tsfE',
#    'title': '"Wer Pandemien verhindern will, muss den Regenwald erhalten"',
#    'href': 'http://www.zeit.de/wissen/umwelt/2021-02/virologie-pandemie-regenwald-abholzung-sandra-junglen',
#    'release_date': '2021-02-08T17:29:34Z',
#    'uri': 'http://api.zeit.de/content/7MzqWTQFmjiEtbcSH1tsfE',
#    'snippet': ' Ausbreitung eines Virus auf diese Art im Nachhinein nachzuvollziehen?\nJunglen: Das Ziel muss natürlich sein, die Ausbreitung solcher Viren in Zukunft zu verhindern. Wir sehen ja gerade in der <em>Corona</em>-Pandemie',
#    'supertitle': 'Virologie',
#    'teaser_text': 'Coronavirus, Artensterben und Klimawandel – alle drei hängen zusammen. Die Virologin Sandra Junglen erforscht, was der Mensch tun muss, um künftige Krisen zu verhindern.',
#    'teaser_title': '"Wer Pandemien verhindern will, muss den Regenwald erhalten"'},
#   {'subtitle': 'Mit GameStop haben Robinhood-Nerds die Wallstreet zum Schwitzen gebracht. Lars Weisbrod und Ijoma Mangold über die Gamification der Börsenspekulation',
#    'uuid': '1Y5Rfd33f7pK7RWqnmWMzZ',
#    'title': 'Den Kapitalismus mit seinen eigenen Mitteln schlagen',
#    'href': 'http://www.zeit.de/kultur/2021-02/gamestop-kapitalismus-boerse-feuilleton-podcast',
#    'release_date': '2021-02-08T17:23:43Z',
#    'uri': 'http://api.zeit.de/content/1Y5Rfd33f7pK7RWqnmWMzZ',
#    'snippet': 'Es war eine junge Generation von Nerds, die in der <em>Corona</em>-Zeit eine neue Beschäftigung für sich entdeckte: Im Lockdown kann man ja nicht nur Netflix bingen, sondern auch mit Aktien zocken. Und zwar',
#    'supertitle': 'GameStop',
#    'teaser_text': 'Mit GameStop haben Robinhood-Nerds die Wallstreet zum Schwitzen gebracht. Lars Weisbrod und Ijoma Mangold über die Gamification der Börsenspekulation',
#    'teaser_title': 'Den Kapitalismus mit seinen eigenen Mitteln schlagen'},
#   {'subtitle': 'Handelsverbände fordern, Geschäfte bald wieder zu öffnen; die Politik mahnt und bremst. Laut einem Bericht soll der Lockdown wohl bis Ende Februar verlängert werden.',
#    'uuid': '7izLuqN4w3tK3AMPDLAnlq',
#    'title': 'Bund und Länder offenbar weitgehend einig über Lockdown-Verlängerung',
#    'href': 'http://www.zeit.de/wirtschaft/2021-02/corona-wirtschaftskrise-lockdown-handelsverbaende-geschaefte-oeffnung-bund-laender-gipfel',
#    'release_date': '2021-02-08T16:32:13Z',
#    'uri': 'http://api.zeit.de/content/7izLuqN4w3tK3AMPDLAnlq',
#    'snippet': ' -präsidenten der Bundesländer erneut mit Bundeskanzlerin Angela Merkel über das weitere Vorgehen. Merkel soll angesichts sinkender <em>Corona</em>-Infektionszahlen eine längerfristige Strategie für Schulen und Kitas',
#    'supertitle': 'Corona-Wirtschaftskrise',
#    'teaser_text': 'Handelsverbände fordern, Geschäfte bald wieder zu öffnen; die Politik mahnt und bremst. Laut einem Bericht soll der Lockdown wohl bis Ende Februar verlängert werden.',
#    'teaser_title': 'Bund und Länder offenbar weitgehend einig über Lockdown-Verlängerung'},
#   {'subtitle': 'Er arbeitet in den Wohnungen fremder Menschen und hat zurzeit so viel zu tun wie nie: Ein Heizungsinstallateur berichtet, warum er mit ungutem Gefühl zu den Kunden fährt.',
#    'uuid': '25DLK4AfQQ3U64XsJHf4Cf',
#    'title': '"Viele Kollegen fürchten, sich bei der Arbeit anzustecken, ich auch"',
#    'href': 'http://www.zeit.de/hamburg/2021-02/heizungsinstallateur-handwerker-coronavirus-pandemie-infektion-hamburg',
#    'release_date': '2021-02-08T16:07:09Z',
#    'uri': 'http://api.zeit.de/content/25DLK4AfQQ3U64XsJHf4Cf',
#    'snippet': ' gesagt: "<em>Corona</em> kommt mir nicht ins Haus – aber Sie auch nicht, wenn Sie Maske tragen!" Also habe ich eine Ausnahme gemacht, mit viel Abstand und einem schlechten Gefühl.\nUnser Chef hat gesagt, in solchen',
#    'supertitle': 'Heizungsinstallateur',
#    'teaser_text': 'Er arbeitet in den Wohnungen fremder Menschen und hat zurzeit so viel zu tun wie nie: Ein Heizungsinstallateur berichtet, warum er mit ungutem Gefühl zu den Kunden fährt.',
#    'teaser_title': '"Viele Kollegen fürchten, sich bei der Arbeit anzustecken, ich auch"'},
#   {'subtitle': 'Sendungen in die EU werden teuer, Tourneen brauchen nun Jahre Vorlauf. Im Freihandelsabkommen wurden ganze Wirtschaftszweige übersehen – und zwar ziemlich bedeutende.',
#    'uuid': '3j7keIS9tNblisdo5HwDsA',
#    'title': 'Übersehen im Kleingedruckten',
#    'href': 'http://www.zeit.de/politik/ausland/2021-02/brexit-zoll-bestellungen-online-zollgebuehren-freihandelsabkommen',
#    'release_date': '2021-02-08T14:52:56Z',
#    'uri': 'http://api.zeit.de/content/3j7keIS9tNblisdo5HwDsA',
#    'snippet': '.\n"Wir können nur froh sein, dass wir durch <em>Corona</em> leere Theater und Musikhallen haben, so schrecklich es für die Branche ist", sagt Bird. "Wäre alles ausgebucht, wäre es eine Katastrophe gewesen, das',
#    'supertitle': 'Brexit und Zoll',
#    'teaser_text': 'Sendungen in die EU werden teuer, Tourneen brauchen nun Jahre Vorlauf. Im Freihandelsabkommen wurden ganze Wirtschaftszweige übersehen – und zwar ziemlich bedeutende.',
#    'teaser_title': 'Übersehen im Kleingedruckten'},
#   {'subtitle': 'Wegen mehr Krankheitsfällen oder Quarantänezeiten gehen zahlreiche Arbeitstage verloren. Besonders viel Arbeitszeit kosten im Lockdown geschlossene Kitas und Schulen.',
#    'uuid': '77XwUMKNTSPCRrJBHnYcqi',
#    'title': 'Zweite Infektionswelle kostet laut Studie 59 Millionen Arbeitstage',
#    'href': 'http://www.zeit.de/arbeit/2021-02/corona-lockdown-iab-zweite-infektionswelle-arbeitstage-kitas-schulen-kosten',
#    'release_date': '2021-02-08T14:38:25Z',
#    'uri': 'http://api.zeit.de/content/77XwUMKNTSPCRrJBHnYcqi',
#    'snippet': 'Wegen der zweiten <em>Corona</em>-Infektionswelle sind in Deutschland rund 59 Millionen Arbeitstage ausgefallen. Zu diesem Ergebnis kommt eine Studie des Nürnberger Instituts für Arbeitsmarkt- und',
#    'supertitle': 'Corona-Lockdown',
#    'teaser_text': 'Wegen mehr Krankheitsfällen oder Quarantänezeiten gehen zahlreiche Arbeitstage verloren. Besonders viel Arbeitszeit kosten im Lockdown geschlossene Kitas und Schulen.',
#    'teaser_title': 'Zweite Infektionswelle kostet laut Studie 59 Millionen Arbeitstage'},
#   {'subtitle': 'Mit strengen Schutzmaßnahmen soll Präsenzunterricht bald wieder möglich sein. Ab welchem Zeitpunkt, will aber auch die Bundesbildungsministerin nicht sagen.',
#    'uuid': '7jy6eIQUxDdN3UrMrhq9Ym',
#    'title': 'Lüften, Maske tragen, Klassen teilen – Experten stellen Leitfaden vor',
#    'href': 'http://www.zeit.de/gesellschaft/schule/2021-02/schuloeffnung-corona-leitfaden-infektionsschutz-schulbetrieb-unterricht-pandemie',
#    'release_date': '2021-02-08T14:04:02Z',
#    'uri': 'http://api.zeit.de/content/7jy6eIQUxDdN3UrMrhq9Ym',
#    'snippet': 'Masken, regelmäßiges Lüften, Wechselunterricht und die Bildung fester Gruppen, ein entzerrter Schulverkehr und andere Infektionsschutzmaßnahmen können einen Schulbetrieb unter <em>Corona</em>-Bedingungen',
#    'supertitle': 'Schulöffnungen',
#    'teaser_text': 'Mit strengen Schutzmaßnahmen soll Präsenzunterricht bald wieder möglich sein. Ab welchem Zeitpunkt, will aber auch die Bundesbildungsministerin nicht sagen.',
#    'teaser_title': 'Lüften, Maske tragen, Klassen teilen – Experten stellen Leitfaden vor'},
#   {'subtitle': 'Auch externe Experten kommen zum Schluss: Die Vakzine von BioNTech und Pfizer hilft gegen Laborviren, die die Schlüsselmutationen aus Südafrika und Großbritannien tragen.',
#    'uuid': 'kSGsRDl233kETXphWk8Z7',
#    'title': 'Wirksamkeit des BioNTech-Impfstoffs gegen Mutationen bestätigt',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-02/biontech-impfstoff-corona-varianten-grossbritannien-suedafrika-wirksamkeit',
#    'release_date': '2021-02-08T13:31:09Z',
#    'uri': 'http://api.zeit.de/content/kSGsRDl233kETXphWk8Z7',
#    'snippet': 'Externe Experten haben die Wirkung des Impfstoffs von BioNTech und Pfizer gegen im Labor erzeugte Viren, die die Schlüsselmutationen der <em>Corona</em>-Varianten aus Südafrika und Großbritannien tragen',
#    'supertitle': 'Corona-Varianten',
#    'teaser_text': 'Auch externe Experten kommen zum Schluss: Die Vakzine von BioNTech und Pfizer hilft gegen Laborviren, die die Schlüsselmutationen aus Südafrika und Großbritannien tragen.',
#    'teaser_title': 'Wirksamkeit des BioNTech-Impfstoffs gegen Mutationen bestätigt'},
#   {'subtitle': 'Erstmals machen Experten gemeinsam in einem Papier Vorschläge, wie Schule in der Pandemie funktionieren kann. Mitverfasserin Eva Rehfuess erklärt die Leitlinie.',
#    'uuid': '1vIYM9kYmTMhklrc38RfQP',
#    'title': '"Ansteckungen unter Schülern kann die Leitlinie nicht ganz verhindern"',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2021-02/corona-massnahmen-eva-rehfuess-leitlinie-schule-schulaemter-bundesregierung',
#    'release_date': '2021-02-08T12:01:04Z',
#    'uri': 'http://api.zeit.de/content/1vIYM9kYmTMhklrc38RfQP',
#    'snippet': ' Kurzfassung vorliegt. Sie nennen darin <em>Corona</em>-Maßnahmen, mit denen ein sicherer Unterricht an Schulen möglich ist. An diesem Mittwoch beraten zudem die Bundeskanzlerin und die Ministerpräsidentinnen erneut über',
#    'supertitle': 'Eva Rehfuess',
#    'teaser_text': 'Erstmals machen Experten gemeinsam in einem Papier Vorschläge, wie Schule in der Pandemie funktionieren kann. Mitverfasserin Eva Rehfuess erklärt die Leitlinie.',
#    'teaser_title': '"Ansteckungen unter Schülern kann die Leitlinie nicht ganz verhindern"'},
#   {'subtitle': 'Der neue Bußgeldkatalog soll Raser härter bestrafen – ist aber seit Monaten ausgesetzt. Die grüne Bremer Verkehrssenatorin Maike Schaefer über den Streit mit der Union',
#    'uuid': '5zj5bjmfjmM3sXXZEQUodl',
#    'title': '"Es passieren so viele Unfälle wegen überhöhter Geschwindigkeit"',
#    'href': 'http://www.zeit.de/mobilitaet/2021-02/bussgeldkatalog-verkehrsregeln-strafen-maike-schaefer-konflikt-union',
#    'release_date': '2021-02-08T11:47:22Z',
#    'uri': 'http://api.zeit.de/content/5zj5bjmfjmM3sXXZEQUodl',
#    'snippet': ' etwas Positivem an: Der Rettungsschirm für den ÖPNV in der <em>Corona</em>-Krise war ein gutes Signal. Ich hatte auch den Eindruck, dass das Thema Verkehrswende angekommen ist, Radverkehr und Schienenverkehr',
#    'supertitle': 'Bußgeldkatalog',
#    'teaser_text': 'Der neue Bußgeldkatalog soll Raser härter bestrafen – ist aber seit Monaten ausgesetzt. Die grüne Bremer Verkehrssenatorin Maike Schaefer über den Streit mit der Union',
#    'teaser_title': '"Es passieren so viele Unfälle wegen überhöhter Geschwindigkeit"'},
#   {'subtitle': 'Seit 1990 wurden in Europa nicht mehr so wenige Autos verkauft wie im vergangenen Januar. Nur Fahrzeuge mit elektrischem Antrieb sind deutlich stärker gefragt als bisher.',
#    'uuid': '5d3N0pq2vKVf3KCFlxTA5S',
#    'title': 'Autoverkäufe in Westeuropa auf Tiefpunkt',
#    'href': 'http://www.zeit.de/mobilitaet/2021-02/autoindustrie-zulassungsdaten-corona-krise-autoverkaeufe-einbruch-westeuropa',
#    'release_date': '2021-02-08T11:15:41Z',
#    'uri': 'http://api.zeit.de/content/5d3N0pq2vKVf3KCFlxTA5S',
#    'snippet': ' Grundlage nationaler Zulassungsdaten. Im Vergleich zum Januar 2020, der noch nicht von der <em>Corona</em>-Krise geprägt war, ging die Zahl der Neuwagen um 25,6 Prozent zurück. Die größten Einbrüche erlebten die',
#    'supertitle': 'Autoindustrie',
#    'teaser_text': 'Seit 1990 wurden in Europa nicht mehr so wenige Autos verkauft wie im vergangenen Januar. Nur Fahrzeuge mit elektrischem Antrieb sind deutlich stärker gefragt als bisher.',
#    'teaser_title': 'Autoverkäufe in Westeuropa auf Tiefpunkt'}],
#  'found': 9710,
#  'limit': 1000,
#  'offset': 0}

# %%
len(request["matches"])
# Out:
# 1000

# %%
test=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "corona", time_range=dates_zeit[0])
test
# Out:
# {'matches': [{'subtitle': 'Spätestens nach einem Tag Homeoffice und Homeschooling haben sich alle eine Partie Spaß verdient. Die Gesellschaftsspiele-Tipps der ZEIT ONLINE-Redaktion',
#    'uuid': 'ai01aXlbpWDKG6KQ8SoNT',
#    'title': "Noch 'ne Runde!",
#    'href': 'http://www.zeit.de/kultur/2020-03/gesellschaftsspiele-ruesselbande-mikado-ligretto-uno',
#    'release_date': '2020-03-21T19:29:55Z',
#    'uri': 'http://api.zeit.de/content/ai01aXlbpWDKG6KQ8SoNT',
#    'snippet': ' tatsächlich auch für Erwachsene nicht langweilig. (Für 2 bis 7 Spieler, ab 4 Jahren)Simone Gaul\nEine Krise braucht Bilder, muss begreifbar werden durch Metaphern. Die derzeitige <em>Corona</em>-Krise sickert nur',
#    'supertitle': 'Spiele',
#    'teaser_text': 'Spätestens nach einem Tag Homeoffice und Homeschooling haben sich alle eine Partie Spaß verdient. Die Gesellschaftsspiele-Tipps der ZEIT ONLINE-Redaktion',
#    'teaser_title': "Noch 'ne Runde!"},
#   {'subtitle': 'Klar ist: Wir sollen zu Hause bleiben. Dort haben wir Zeit für Gesellschaftsspiele, sagen die einen. Ach was, Zeitverschwendung, sagen die anderen. Ein Contra und Pro',
#    'uuid': '3TC9Ji5DdFRFrwqJKZC7sf',
#    'title': 'Gewinnen ist was für Verlierer?',
#    'href': 'http://www.zeit.de/kultur/2020-03/corona-quarantaene-zeit-gesellschaftsspiele-pro-contra',
#    'release_date': '2020-03-21T19:28:56Z',
#    'uri': 'http://api.zeit.de/content/3TC9Ji5DdFRFrwqJKZC7sf',
#    'snippet': ' mir schweigend Möglichkeiten aus, ein besserer Mensch zu werden (okay, vielleicht erst einmal nur für die Zeit, bis das mit <em>Corona</em> irgendwann vorbei ist). Oder höre am liebsten Menschen zu, statt sie',
#    'supertitle': 'Gesellschaftsspiele',
#    'teaser_text': 'Klar ist: Wir sollen zu Hause bleiben. Dort haben wir Zeit für Gesellschaftsspiele, sagen die einen. Ach was, Zeitverschwendung, sagen die anderen. Ein Contra und Pro',
#    'teaser_title': 'Gewinnen ist was für Verlierer?'},
#   {'subtitle': 'Die Regierenden testen in der Coronakrise gesetzliche Grenzen. Entfesselt ist der deutsche Staat zwar nicht. Dennoch ist Kritik an dessen Handeln unabdingbar.',
#    'uuid': '2Ild1ehYFQJ6nYBjzTydJO',
#    'title': 'Corona und der Staat',
#    'href': 'http://www.zeit.de/kultur/2020-03/staat-ausnahmezustand-notstandsgesetze-coronavirus-deutschland-infektionsschutzgesetz-recht',
#    'release_date': '2020-03-21T19:24:03Z',
#    'uri': 'http://api.zeit.de/content/2Ild1ehYFQJ6nYBjzTydJO',
#    'snippet': ' dennoch nicht allzu vorsichtig sein. Denn wer nicht rechtzeitig handelt, siehe <em>Corona</em>, der gerät in noch schwerere Wasser.\nAllzu weit zwar sollte die Politik sich nicht von der Volksmeinung entfernen, aber',
#    'supertitle': 'Demokratie',
#    'teaser_text': 'Die Regierenden testen in der Coronakrise gesetzliche Grenzen. Entfesselt ist der deutsche Staat zwar nicht. Dennoch ist Kritik an dessen Handeln unabdingbar.',
#    'teaser_title': 'Corona und der Staat'},
#   {'subtitle': 'Du Mingjun lebt in Wuhan, dem Ursprungsort der Coronavirus-Pandemie. Sie hat die "Psychologische Hotline Hubei" gegründet, um zu helfen. Wer ruft nachts bei ihr an?',
#    'uuid': '2CPo4kOgyXiFtwWQBi27ka',
#    'title': '"Kleine Änderungen im Alltag können viel bewirken"',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/wuhan-coronavirus-quarantaene-ausgangssperre-depressionen-angst-psychische-belastung',
#    'release_date': '2020-03-21T19:08:31Z',
#    'uri': 'http://api.zeit.de/content/2CPo4kOgyXiFtwWQBi27ka',
#    'snippet': ' provisorischen <em>Corona</em>-Krankenhäusern und Quarantäne-Lagern in Ihrer Stadt erging?\nDu Mingjun:\xa0Einige COVID-19-Patienten habe ich durch den gesamten Krankheitsverlauf begleitet, von den ersten Tagen an, an denen',
#    'supertitle': 'Wuhan',
#    'teaser_text': 'Du Mingjun lebt in Wuhan, dem Ursprungsort der Coronavirus-Pandemie. Sie hat die "Psychologische Hotline Hubei" gegründet, um zu helfen. Wer ruft nachts bei ihr an?',
#    'teaser_title': '"Kleine Änderungen im Alltag können viel bewirken"'},
#   {'subtitle': 'Ausgangssperren, die Unis sind zu, die Flüge gestrichen: Die Corona-Krise stellt Studierende im Auslandssemester vor die Frage: gehen oder bleiben?',
#    'uuid': '4hmNfUCoLb5qwMhYmtb4Nr',
#    'title': '"Eigentlich wäre ich jetzt gerne bei meiner Familie"',
#    'href': 'http://www.zeit.de/campus/2020-03/auslandssemester-coronavirus-italien-spanien-slowenien-studierende-ausland',
#    'release_date': '2020-03-21T18:07:50Z',
#    'uri': 'http://api.zeit.de/content/4hmNfUCoLb5qwMhYmtb4Nr',
#    'snippet': 'Eigentlich wollten sie den Sommer in Italien, Spanien und Slowenien verbringen. Doch aufgrund der <em>Corona</em>-Krise kam alles anders. Drei gestrandete Erasmus-Studierende berichten.\nMatti Helmrich, 24',
#    'supertitle': 'Auslandssemester',
#    'teaser_text': 'Ausgangssperren, die Unis sind zu, die Flüge gestrichen: Die Corona-Krise stellt Studierende im Auslandssemester vor die Frage: gehen oder bleiben?',
#    'teaser_title': '"Eigentlich wäre ich jetzt gerne bei meiner Familie"'},
#   {'subtitle': 'Corona führt zur Isolation, der Alltag bricht weg: Für psychisch kranke Menschen wie unsere Autorin ist das besonders hart. Was sie belastet – und was ihr hilft.',
#    'uuid': '1LMK2JAGHpuptmYkBJ9wdc',
#    'title': 'Ich bin nicht allein zu Hause, ich habe ja meine Depression',
#    'href': 'http://www.zeit.de/zeit-magazin/leben/2020-03/isolation-coronavirus-quarantaene-depressionen-psychische-krankheiten-social-distancing-ausgangssperre',
#    'release_date': '2020-03-21T17:11:10Z',
#    'uri': 'http://api.zeit.de/content/1LMK2JAGHpuptmYkBJ9wdc',
#    'snippet': 'Schon morgens fünf neue Eilmeldungen auf dem Telefon. <em>Corona</em>, <em>Corona</em>, <em>Corona</em>, <em>Corona</em>, <em>Corona</em>. Tote, Krise, Panik, noch mehr Tote, Ausgangssperre. Am liebsten würde ich einfach liegen bleiben und',
#    'supertitle': 'Isolation',
#    'teaser_text': 'Corona bedeutet immer noch Isolation: Für psychisch kranke Menschen wie unsere Autorin ist das besonders hart. Was ihr hilft, hat viele Leser interessiert.',
#    'teaser_title': 'Ich bin nicht allein zu Hause, ich habe ja meine Depression'},
#   {'subtitle': 'In Italien und Frankreich müssen die Menschen zu Hause bleiben. Andere Länder haben es ohne Lockdown geschafft. Das sagt die Wissenschaft zu den Maßnahmen.',
#    'uuid': '3DnIHEmiARhDgBaBXsyQUO',
#    'title': 'Kann eine Ausgangssperre die Pandemie stoppen?',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2020-03/quarantaene-ausgangssperre-coronavirus-bayern-psyche-isolation-wirtschaft-folgen',
#    'release_date': '2020-03-21T16:38:34Z',
#    'uri': 'http://api.zeit.de/content/3DnIHEmiARhDgBaBXsyQUO',
#    'snippet': ', in Italien bei fünf bis sechs Tagen, sagt der Mathematiker Thomas Götz. In Deutschland hingegen verdopple sich die Zahl der <em>Corona</em>-Positiven derzeit innerhalb von nur drei Tagen.\nTrotzdem erwägt die',
#    'supertitle': 'Quarantäne',
#    'teaser_text': 'In Italien und Frankreich müssen die Menschen zu Hause bleiben. Andere Länder haben es ohne Lockdown geschafft. Das sagt die Wissenschaft zu den Maßnahmen.',
#    'teaser_title': 'Kann eine Ausgangssperre die Pandemie stoppen?'},
#   {'subtitle': 'Mit einem Nachtragshaushalt will die Koalition schnelle Hilfszahlungen an Unternehmen und Selbständige ermöglichen. Außerdem übernimmt der Staat hohe Kreditgarantien.',
#    'uuid': '4xqca4fYz2qR5FdMantEyD',
#    'title': 'Bundesregierung plant Mehrausgaben von 150 Milliarden Euro',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/rettungspaket-nachtragshaushalt-coronoavirus-pandemie-folgen-olaf-scholz',
#    'release_date': '2020-03-21T16:20:29Z',
#    'uri': 'http://api.zeit.de/content/4xqca4fYz2qR5FdMantEyD',
#    'snippet': ' Entwicklung eines Impfstoffs, für Unterstützungen der Bundeswehr wie auch für Hilfen für Deutsche im Ausland sind rund 3,5 Milliarden Euro vorgesehen.\nAuch die von den <em>Corona</em>-Auswirkungen betroffenen Mieter und',
#    'supertitle': 'Rettungspaket',
#    'teaser_text': 'Mit einem Nachtragshaushalt will die Koalition schnelle Hilfszahlungen an Unternehmen und Selbständige ermöglichen. Außerdem übernimmt der Staat hohe Kreditgarantien.',
#    'teaser_title': 'Bundesregierung plant Mehrausgaben von 150 Milliarden Euro'},
#   {'subtitle': 'Der ägyptische Diktator Abdel Fattah al-Sissi nutzt die Corona-Krise, um noch härter gegen seine Kritiker vorzugehen. Politische Gefangene müssen um ihr Leben fürchten.',
#    'uuid': '6rcOsRdJ0qGXsRuOYrXIeY',
#    'title': 'Wie in einem Horrorfilm',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/aegypten-coronavirus-abdel-fattah-al-sissi-politische-gefangene',
#    'release_date': '2020-03-21T16:03:30Z',
#    'uri': 'http://api.zeit.de/content/6rcOsRdJ0qGXsRuOYrXIeY',
#    'snippet': ' ohnehin sind die Inhaftierten in Zeiten von <em>Corona</em> von jeder sozialen Interaktion abgeschnitten. Und ihre Angehörigen fürchten nun, mehr als sonst ohnehin, um deren Leben. Doch darüber öffentlich zu',
#    'supertitle': 'Ägypten',
#    'teaser_text': 'Der ägyptische Diktator Abdel Fattah al-Sissi nutzt die Corona-Krise, um noch härter gegen seine Kritiker vorzugehen. Politische Gefangene müssen um ihr Leben fürchten.',
#    'teaser_title': 'Wie in einem Horrorfilm'},
#   {'subtitle': 'Der Soziologe Heinz Bude beobachtet Corona-Deutschland aus seiner Wohnung in Berlin-Pankow. Was er sieht? Eine Gesellschaft, die Schutz sucht. Und Ignoranten.',
#    'uuid': '4REIH0K3uq1Cu9KjAdjsbG',
#    'title': '"Als hätten viele noch nicht kapiert, worum es geht"',
#    'href': 'http://www.zeit.de/gesellschaft/schule/2020-03/corona-krise-folgen-neoliberalismus-gerechtigkeit-solidaritaet-heinz-bude',
#    'release_date': '2020-03-21T14:53:06Z',
#    'uri': 'http://api.zeit.de/content/4REIH0K3uq1Cu9KjAdjsbG',
#    'snippet': ': Was noch?\nBude: Das Pathos der Zivilgesellschaft – dass sich die Dinge am besten in Selbstorganisation regeln – hat einen ziemlichen Knacks bekommen. Zwar hat das <em>Corona</em>-Virus erstaunliche Praktiken des',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Der Soziologe Heinz Bude beobachtet Corona-Deutschland aus seiner Wohnung in Berlin-Pankow. Was er sieht? Eine Gesellschaft, die Schutz sucht. Und einige Ignoranten.',
#    'teaser_title': '"Als hätten viele noch nicht kapiert, worum es geht"'},
#   {'subtitle': 'Der Hamburger Tafel macht Corona große Probleme: Viele Ehrenamtliche bleiben weg, Ausgabestellen machen zu. Unterwegs mit denen, die den Laden noch am Laufen halten',
#    'uuid': '4jJgFIAAmyWZTw0Uj23Fav',
#    'title': 'Die letzte Fahrt',
#    'href': 'http://www.zeit.de/hamburg/2020-03/hamburger-tafel-coronavirus-epidemie-lebensmittel-ausgabestellen-lebensmittelspenden',
#    'release_date': '2020-03-21T14:38:06Z',
#    'uri': 'http://api.zeit.de/content/4jJgFIAAmyWZTw0Uj23Fav',
#    'snippet': '. Er macht die Langstrecke, 500 bis 600 Kilometer pro Woche seien da nicht ungewöhnlich. "Ich fahre gern!", sagt er. Dennoch soll Streeck bald aufhören. Er ist 72 Jahre alt, <em>Corona</em>-Risikogruppe, deshalb',
#    'supertitle': 'Hamburger Tafel',
#    'teaser_text': 'Der Hamburger Tafel macht Corona große Probleme: Viele Ehrenamtliche bleiben weg, Ausgabestellen machen zu. Unterwegs mit denen, die den Laden noch am Laufen halten',
#    'teaser_title': 'Die letzte Fahrt'},
#   {'subtitle': 'Virologist Christian Drosten is guiding Germany through the current pandemic. He spoke to ZEIT ONLINE about the length of the crisis – and how it will change our lives.',
#    'uuid': '2SGZf1oYa0hX3fVC2r1xmp',
#    'title': '"We Have To Bring Down the Number of Cases Now. Otherwise We Won\'t Be Able To Handle It"',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2020-03/christian-drosten-coronavirus-pandemic-germany-virologist-charite',
#    'release_date': '2020-03-21T14:15:23Z',
#    'uri': 'http://api.zeit.de/content/2SGZf1oYa0hX3fVC2r1xmp',
#    'snippet': '.\nZEIT ONLINE: So, given the <em>corona</em> parties that have been taking place, you wouldn\'t say: "From now on, no one is allowed to go outside?"\nDrosten: Who am I to say such a thing? I can say',
#    'supertitle': 'Christian Drosten',
#    'teaser_text': 'Virologist Christian Drosten is guiding Germany through the current pandemic. He spoke to ZEIT ONLINE about the length of the crisis – and how it will change our lives.',
#    'teaser_title': '"We Have To Bring Down the Number of Cases Now"'},
#   {'subtitle': 'Unser Autor dokumentiert, wie Corona das Land verändert. An einem Rasthof bei Rostock trifft er zwei Lkw-Fahrer, unterwegs in zwei Richtungen, aber mit ähnlichen Sorgen.',
#    'uuid': '11WdtdctJ7ZpOk543myf9H',
#    'title': 'Angst vor der letzten Ausfahrt',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/coronavirus-pandemie-lkw-fahrer-rostock-familie-jobverlust',
#    'release_date': '2020-03-21T12:19:13Z',
#    'uri': 'http://api.zeit.de/content/11WdtdctJ7ZpOk543myf9H',
#    'snippet': 'Wie verändert der <em>Corona</em>-Ausbruch Deutschland? Unser Reporter Henning Sußebach beschreibt das\xa0in der Serie "Aus einem anderen Land". An welche Orte er noch gelangt,\xa0mit welchen Menschen er (bei',
#    'supertitle': 'Coronavirus-Pandemie',
#    'teaser_text': 'Unser Autor dokumentiert, wie Corona das Land verändert. An einem Rasthof bei Rostock trifft er zwei Lkw-Fahrer, unterwegs in zwei Richtungen, aber mit ähnlichen Sorgen.',
#    'teaser_title': 'Angst vor der letzten Ausfahrt'},
#   {'subtitle': 'Wer unten steht, leidet mehr: Die Corona-Krise verdeutlicht und verschärft die soziale Ungleichheit. Es geht jetzt auch um die gesellschaftlichen Abwehrkräfte.',
#    'uuid': '5vnQGfp2LaroxbOS4FltwL',
#    'title': 'Hierarchie der Not',
#    'href': 'http://www.zeit.de/wirtschaft/2020-03/soziale-ungleichheit-coronavirus-pandemie-versorgung-covid-19',
#    'release_date': '2020-03-21T11:52:57Z',
#    'uri': 'http://api.zeit.de/content/5vnQGfp2LaroxbOS4FltwL',
#    'snippet': ', die jenen drohen, die ihre Miete und ihre Rechnungen nicht zahlen. Aber was ist, wenn sie die wegen <em>Corona</em> nicht mehr zahlen können? Sell sagt: "Wenn man eine Gesellschaft einfriert, dann muss man auch',
#    'supertitle': 'Soziale Ungleichheit',
#    'teaser_text': 'Wer unten steht, leidet mehr: Die Corona-Krise verdeutlicht und verschärft die soziale Ungleichheit. Es geht jetzt auch um die gesellschaftlichen Abwehrkräfte.',
#    'teaser_title': 'Hierarchie der Not'},
#   {'subtitle': 'Kulturschaffende trifft die Corona-Krise besonders hart, die Politik scheint das begriffen zu haben. Nur eine Verantwortliche schweigt bisher: die Kulturstaatsministerin.',
#    'uuid': '4MvXu81CS7h4iWry8CF6GH',
#    'title': 'Das Erwachen der Macht',
#    'href': 'http://www.zeit.de/kultur/2020-03/kulturpolitik-coronavirus-kunst-kuenstler-einnahmen-kulturfoerderung',
#    'release_date': '2020-03-21T11:40:22Z',
#    'uri': 'http://api.zeit.de/content/4MvXu81CS7h4iWry8CF6GH',
#    'snippet': 'Die erste Strophe ist nun gesungen nach einigen Tagen <em>Corona</em>-Krise, die Appelle, Aufrufe und Absichtserklärungen der Politik sind in der Welt, auch der Kulturpolitik, die in Deutschland sehr komplex',
#    'supertitle': 'Kulturpolitik',
#    'teaser_text': 'Kulturschaffende trifft die Corona-Krise besonders hart, die Politik scheint das begriffen zu haben. Nur eine Verantwortliche schweigt bisher: die Kulturstaatsministerin.',
#    'teaser_title': 'Das Erwachen der Macht'},
#   {'subtitle': 'Nach dem Ausbruch des Coronavirus in Wuhan stand Chinas Führung in der Bevölkerung plötzlich unter Druck. Doch inzwischen hat sie die öffentliche Meinung wieder im Griff.',
#    'uuid': '1oqaqWylApdOM0H8BKH7vL',
#    'title': '"Das wäre in China nicht passiert"',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/propaganda-china-infektionen-einreise-quarantaene',
#    'release_date': '2020-03-21T11:24:43Z',
#    'uri': 'http://api.zeit.de/content/1oqaqWylApdOM0H8BKH7vL',
#    'snippet': ' nicht unbedingt Ausländer – häufig sind es Chinesinnen und Chinesen, die wieder in die Heimat wollen. Angesichts der weltweiten <em>Corona</em>-Lage sehen sie China als den für sie sichersten Ort. "Schaut euch die',
#    'supertitle': 'Propaganda',
#    'teaser_text': 'Nach dem Ausbruch des Coronavirus in Wuhan stand Chinas Führung in der Bevölkerung plötzlich unter Druck. Doch inzwischen hat sie die öffentliche Meinung wieder im Griff.',
#    'teaser_title': '"Das wäre in China nicht passiert"'},
#   {'subtitle': 'In Kliniken werden Schutzmasken knapp. Bundeswehr und Zoll schaffen heran, was sie bekommen können. Doch bislang weiß keiner genau, wie viele eigentlich benötigt werden.',
#    'uuid': '5Q39R5aWHhGrXwv6xZ9kUU',
#    'title': 'Warten auf die Masken',
#    'href': 'http://www.zeit.de/wirtschaft/2020-03/schutzausruestung-coronavirus-atemmasken-schutzanzuege-krankenhaeuser-knappheit-hersteller',
#    'release_date': '2020-03-21T10:11:02Z',
#    'uri': 'http://api.zeit.de/content/5Q39R5aWHhGrXwv6xZ9kUU',
#    'snippet': ' an einer simplen Bronchitis oder einer durch andere Erkrankungen verursachten Lungenentzündung leiden, müssen wir erst einmal so behandeln, als hätten sie <em>Corona</em>", sagt Pott. Für eine Intensivstation wie',
#    'supertitle': 'Schutzausrüstung',
#    'teaser_text': 'In Kliniken werden Schutzmasken knapp. Bundeswehr und Zoll schaffen heran, was sie bekommen können. Doch bislang weiß keiner genau, wie viele eigentlich benötigt werden.',
#    'teaser_title': 'Warten auf die Masken'},
#   {'subtitle': 'Ein Hamburger Anästhesist über seine Vorbereitungen auf die Flut der schweren Fälle. Und: Restaurants in Hamburg müssen schließen',
#    'uuid': '4GtPOdIruBmaz0ptZSqsgu',
#    'title': '"Was, wenn wir Entscheidungen über Tod und Leben treffen müssen?"',
#    'href': 'http://www.zeit.de/hamburg/2020-03/elbvertiefung-21-03-2020',
#    'release_date': '2020-03-21T09:00:55Z',
#    'uri': 'http://api.zeit.de/content/4GtPOdIruBmaz0ptZSqsgu',
#    'snippet': ' gegen die <em>Corona</em>-Pandemie abstimmen und über eine Ausgangssperre beraten.\nJugendliche sollen in Rellingen und anderen Orten im Kreis Pinneberg in der Nacht zum Donnerstag sogenannte <em>Corona</em>-Partys unter',
#    'supertitle': 'Christian Drosten',
#    'teaser_text': 'Ein Hamburger Anästhesist über seine Vorbereitungen auf die Flut der schweren Fälle. Und: Restaurants in Hamburg müssen schließen',
#    'teaser_title': '"Was, wenn wir Entscheidungen über Tod und Leben treffen müssen?"'},
#   {'subtitle': 'Der Libanon ist bankrott, das öffentliche Gesundheitswesen marode. Die Menschen helfen sich selbst: mit selbst gebauten Beatmungsgeräten, Anis und dem Roten Kreuz.',
#    'uuid': '1IVr4apl5IduyWp1ogST2U',
#    'title': 'Corona und der Pleitegeier',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/libanon-beirut-coronavirus-covid-19-social-distancing',
#    'release_date': '2020-03-21T08:49:20Z',
#    'uri': 'http://api.zeit.de/content/1IVr4apl5IduyWp1ogST2U',
#    'snippet': ' oft aus wie gewohnt.\nSeit hier im Februar der erste <em>Corona</em>-Infizierte entdeckt wurde, hat die Regierung das öffentliche Leben schrittweise lahmgelegt. In Deutschland war das Virus noch nicht recht Thema',
#    'supertitle': 'Libanon',
#    'teaser_text': 'Der Libanon ist bankrott, das öffentliche Gesundheitswesen marode. Die Menschen helfen sich selbst: mit selbst gebauten Beatmungsgeräten, Anis und dem Roten Kreuz.',
#    'teaser_title': 'Corona und der Pleitegeier'},
#   {'subtitle': 'Der eine scheint als Krisenmanager die Rolle seines Lebens gefunden zu haben, am anderen wird täglich rumgenörgelt. Was genau macht den Unterschied?',
#    'uuid': '3bpa7Ea8oXVNRDMUA61c6G',
#    'title': 'Super-Söder versus Machtlos-Müller',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/krisenmanagement-markus-soeder-michael-mueller-csu-spd',
#    'release_date': '2020-03-21T06:21:32Z',
#    'uri': 'http://api.zeit.de/content/3bpa7Ea8oXVNRDMUA61c6G',
#    'snippet': ' auch die Wahl.\nAuch Söder gilt spätestens seit der <em>Corona</em>-Krise als Kanzleranwärter. Laut einer aktuellen Umfrage ist er erstmals der beliebteste Politiker der Republik. In fünf Aspekten unterscheidet er',
#    'supertitle': 'Politiker in der Corona-Krise',
#    'teaser_text': 'Der eine scheint als Krisenmanager die Rolle seines Lebens gefunden zu haben, am anderen wird täglich rumgenörgelt. Was genau macht den Unterschied?',
#    'teaser_title': 'Super-Söder versus Machtlos-Müller'},
#   {'subtitle': 'Laut offizieller Statistik sind in Hamburg 768 Menschen mit dem Coronavirus infiziert. Die wahre Zahl liegt wohl weit höher. Haben die Behörden den Anschluss verloren?',
#    'uuid': '7xqI1qUfKOTE44ehskEcig',
#    'title': 'Wie hoch liegt die Dunkelziffer?',
#    'href': 'http://www.zeit.de/hamburg/2020-03/corona-test-ergebnisse-hamburg-covid-19',
#    'release_date': '2020-03-20T23:29:07Z',
#    'uri': 'http://api.zeit.de/content/7xqI1qUfKOTE44ehskEcig',
#    'snippet': ' es diesmal geschafft hat, viel ansteckender zu sein als bei dem Sars-Ausbruch im Jahr 2002. In den ersten Wochen der <em>Corona</em>-Epidemie wurde das in Europa unterschätzt.\nIm Moment ist die Lage auf den',
#    'supertitle': 'Corona-Test',
#    'teaser_text': 'Laut offizieller Statistik sind in Hamburg 768 Menschen mit dem Coronavirus infiziert. Die wahre Zahl liegt wohl weit höher. Haben die Behörden den Anschluss verloren?',
#    'teaser_title': 'Wie hoch liegt die Dunkelziffer?'},
#   {'subtitle': 'Nach dem rechtsextremen Anschlag machten Politiker mit ihren Reden Hoffnung. Zeit, dass den Worten Taten folgen, fordert die Vorsitzende des Ausländerbeirats von Hanau.',
#    'uuid': '3oC3zbg02mlJRdwDxCYEWN',
#    'title': 'Der Hass hat nicht aufgehört',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/hanau-selma-yilmaz-ilkhan-auslaenderbeirat-rassismus',
#    'release_date': '2020-03-20T19:50:19Z',
#    'uri': 'http://api.zeit.de/content/3oC3zbg02mlJRdwDxCYEWN',
#    'snippet': ' beruhigen wird. Sie wissen nicht, ob sie je Antworten auf viele ihrer Fragen bekommen werden.\nDie <em>Corona</em>-Pandemie hat innerhalb weniger Tage fast alle Aufmerksamkeit auf sich gezogen. Das ist nachvollziehbar',
#    'supertitle': 'Hanau',
#    'teaser_text': 'Nach dem rechtsextremen Anschlag machten Politiker mit ihren Reden Hoffnung. Zeit, dass den Worten Taten folgen, fordert die Vorsitzende des Ausländerbeirats von Hanau.',
#    'teaser_title': 'Der Hass hat nicht aufgehört'},
#   {'subtitle': 'China schickt Masken, Ärzte und Krankenhauspersonal nach Italien und in viele andere Länder – und macht nebenbei ein bisschen Werbung für die Seidenstraße.',
#    'uuid': '5ghhPadkKQxFwV3FcdrqFX',
#    'title': 'Maskendiplomatie',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/coronakrise-china-hilfsgueter-italien-usa-coronavirus-covid-19',
#    'release_date': '2020-03-20T19:41:50Z',
#    'uri': 'http://api.zeit.de/content/5ghhPadkKQxFwV3FcdrqFX',
#    'snippet': ' treiben. Das Bild soll sich nun aufhellen und vergessen machen, dass die <em>Corona</em>-Krise mit Chinas Untätigkeit und Verschleierungstaktik begonnen hatte.\nDass China gegenwärtig die Massenproduktion von',
#    'supertitle': 'Coronakrise',
#    'teaser_text': 'China schickt Masken, Ärzte und Krankenhauspersonal nach Italien und in viele andere Länder – und macht nebenbei ein bisschen Werbung für die Seidenstraße.',
#    'teaser_title': 'Maskendiplomatie'},
#   {'subtitle': '"Das wurde noch nie zuvor gemacht": Im Kampf gegen die Corona-Krise will Kommissionspräsidentin Ursula von der Leyen eine höhere Neuverschuldung der EU-Länder erlauben.',
#    'uuid': '5kXfQdhWYltIdRq0SlXn4P',
#    'title': 'EU-Kommission will Stabilitätspakt aussetzen',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/europaeische-union-haushaltsdefizite-mitgliedstaaten-eu-kommission-corona-krise',
#    'release_date': '2020-03-20T19:00:00Z',
#    'uri': 'http://api.zeit.de/content/5kXfQdhWYltIdRq0SlXn4P',
#    'snippet': 'Wegen der <em>Corona</em>-Pandemie will die EU-Kommission in einem nie dagewesenen Schritt die Regeln für Haushaltsdefizite der Mitgliedstaaten bis auf Weiteres aussetzen. Erstmalig aktiviere die Behörde "die',
#    'supertitle': 'Europäische Union',
#    'teaser_text': '"Das wurde noch nie zuvor gemacht": Im Kampf gegen die Corona-Krise will Kommissionspräsidentin Ursula von der Leyen eine höhere Neuverschuldung der EU-Länder erlauben.',
#    'teaser_title': 'EU-Kommission will Stabilitätspakt aussetzen'},
#   {'subtitle': 'Unser Autor dokumentiert, wie Corona das Land verändert. In Schleswig-Holstein steht ein Bauer vor einer Entscheidung mit Symbolwert: Erdbeeren pflanzen oder nicht?',
#    'uuid': '3Y5c1tB1ye8BN2CAi710zo',
#    'title': 'Die Wette seines Lebens',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/landwirtschaft-coronavirus-coronakrise-felder-anbau-erntehelfer-saison-erdbeeren',
#    'release_date': '2020-03-20T18:56:05Z',
#    'uri': 'http://api.zeit.de/content/3Y5c1tB1ye8BN2CAi710zo',
#    'snippet': 'Wie verändert der <em>Corona</em>-Ausbruch Deutschland? Unser Reporter Henning Sußebach beschreibt das\xa0in der Serie "Aus einem anderen Land". An welche Orte er noch gelangt,\xa0mit welchen Menschen er (bei',
#    'supertitle': 'Landwirtschaft',
#    'teaser_text': 'Unser Autor dokumentiert, wie Corona das Land verändert. In Schleswig-Holstein steht ein Bauer vor einer Entscheidung mit Symbolwert: Erdbeeren pflanzen oder nicht?',
#    'teaser_title': 'Die Wette seines Lebens'},
#   {'subtitle': 'Der völkische AfD-Flügel soll sich auflösen. So will es der Parteivorstand. Am radikalen Personal der Partei und dessen Positionen ändert das aber nichts.',
#    'uuid': '4eu4Tw1vxTNX89JsdRLRks',
#    'title': 'Ein Fall von strategischer Kosmetik',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/afd-fluegel-aufloesung-bjoern-hoecke-personal-positionen',
#    'release_date': '2020-03-20T18:09:42Z',
#    'uri': 'http://api.zeit.de/content/4eu4Tw1vxTNX89JsdRLRks',
#    'snippet': 'Seit 11 Uhr morgens saßen die Chefs der AfD in der Bundesgeschäftsstelle nahe dem Berliner Zoo zusammen. Einige Mitglieder des Bundesvorstands hatten sich per Video zugeschaltet, wegen der <em>Corona</em>',
#    'supertitle': 'AfD-Flügel-Auflösung',
#    'teaser_text': 'Der völkische AfD-Flügel soll sich auflösen. So will es der Parteivorstand. Am radikalen Personal der Partei und dessen Positionen ändert das aber nichts.',
#    'teaser_title': 'Ein Fall von strategischer Kosmetik'},
#   {'subtitle': 'Die Beatmung von Covid-19-Patienten ist in den Kliniken Sache der Anästhesisten. Die rüsten sich akribisch für eine Flut der schweren Fälle –\xa0und hoffen auf Glück.',
#    'uuid': '19ze4ofXwXKUOOSAxRtZiJ',
#    'title': '"Was, wenn wir Entscheidungen über Tod und Leben treffen müssen?"',
#    'href': 'http://www.zeit.de/hamburg/2020-03/beatmungsplaetze-covid-19-patienten-thoralf-kerner',
#    'release_date': '2020-03-20T18:08:55Z',
#    'uri': 'http://api.zeit.de/content/19ze4ofXwXKUOOSAxRtZiJ',
#    'snippet': ': Was meinen Sie damit?\nKerner: Pandemiepatienten dürfen nicht in Kontakt zu anderen Patienten kommen, das Virus ist zu ansteckend. Aus Italien wird empfohlen, schwerkranke <em>Corona</em>-Patienten auf speziellen',
#    'supertitle': 'Beatmungsplätze für Covid-19-Patienten',
#    'teaser_text': 'Die Beatmung von Covid-19-Patienten ist in den Kliniken Sache der Anästhesisten. Die rüsten sich akribisch für eine Flut der schweren Fälle. Das hat viele interessiert.',
#    'teaser_title': '"Was, wenn wir Entscheidungen über Tod und Leben treffen müssen?"'},
#   {'subtitle': 'Bund und Länder haben beschlossen, dass das Kontaktverbot bis zum Ende der Osterferien gilt. Was heißt das für das Fest? Die wichtigsten Fragen und Antworten im Überblick',
#    'uuid': '4MR0GiSd8j6vprnGLwv1HW',
#    'title': 'Können wir zu Ostern einen Ausflug machen?',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/ausgangssperren-coronavirus-deutschland-social-distancing-quarantaene-ansteckung-faq',
#    'release_date': '2020-03-20T17:23:21Z',
#    'uri': 'http://api.zeit.de/content/4MR0GiSd8j6vprnGLwv1HW',
#    'snippet': ' und begründbar. Die rechtliche Grundlage dafür bietet im Fall der <em>Corona</em>-Pandemie das Infektionsschutzgesetz.\nEin Kontaktverbot ist kein Hausarrest: Bürgerinnen und Bürger in Deutschland dürfen',
#    'supertitle': 'Ausgangsbeschränkungen',
#    'teaser_text': 'Bund und Länder haben beschlossen, dass das Kontaktverbot bis zum Ende der Osterferien gilt. Was heißt das für das Fest? Die wichtigsten Fragen und Antworten im Überblick',
#    'teaser_title': 'Können wir zu Ostern einen Ausflug machen?'},
#   {'subtitle': 'Wo gelten Ausgangsbeschränkungen, und wo dürfen nur noch zwei Menschen auf öffentlichen Plätzen zusammenstehen? Ein Überblick über die Bundesländer und ihre Regelungen',
#    'uuid': '1UwG2EFBUsyoNvz6C1XjzI',
#    'title': 'Diese Einschränkungen gelten in den Bundesländern',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/coronavirus-pandemie-bundeslaender-ausgangssperre-quarantaene-einschraenkungen-social-distancing',
#    'release_date': '2020-03-20T17:18:50Z',
#    'uri': 'http://api.zeit.de/content/1UwG2EFBUsyoNvz6C1XjzI',
#    'snippet': ' ankündigte. Das Mitnehmen von Speisen sei weiterhin möglich. Der Grenzverkehr mit <em>Corona</em>-Risikogebieten wird nun streng kontrolliert. Pendlerinnen und Pendlern sei weiter die Fahrt über die Grenze zur Arbeit',
#    'supertitle': 'Coronavirus-Pandemie',
#    'teaser_text': 'Wo gelten Ausgangsbeschränkungen, und wo dürfen nur noch zwei Menschen auf öffentlichen Plätzen zusammenstehen? Ein Überblick über die Bundesländer und ihre Regelungen',
#    'teaser_title': 'Diese Einschränkungen gelten in den Bundesländern'},
#   {'subtitle': 'Wie würde es sein, wenn es plötzlich verboten wäre, das Haus zu verlassen? In dem Moment, da einem die Freiheit genommen werden soll, spürt man das Glück dieser Freiheit.',
#    'uuid': '5jkpDpEesqTE6d8dFzYyQP',
#    'title': 'Wenn wir unsere Freiheit lieben, müssen wir jetzt auf sie verzichten',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/ausgangssperre-coronavirus-covid-19-freiheit-angela-merkel-ddr',
#    'release_date': '2020-03-20T15:56:07Z',
#    'uri': 'http://api.zeit.de/content/5jkpDpEesqTE6d8dFzYyQP',
#    'snippet': 'Angela Merkel hat in ihrer Fernsehansprache gesagt, dass sie wegen ihrer Herkunft aus der DDR umso mehr weiß, wie schwer die nun in der <em>Corona</em>-Krise beschlossenen Einschränkungen für uns alle sind',
#    'supertitle': 'Ausgangssperre',
#    'teaser_text': 'Wie würde es sein, wenn es plötzlich verboten wäre, das Haus zu verlassen? In dem Moment, da einem die Freiheit genommen werden soll, spürt man das Glück dieser Freiheit.',
#    'teaser_title': 'Wenn wir unsere Freiheit lieben, müssen wir jetzt auf sie verzichten'},
#   {'subtitle': 'Am Sonntag will sich die Kanzlerin mit den Ministerpräsidenten beraten, Markus Söder hat für Bayern bereits eine Ausgehsperre verhängt. Erste Länder ziehen schon nach.',
#    'uuid': '2sAzbGqaPErsqS4fhUMrOE',
#    'title': 'Update: Rückt die bundesweite Ausgangssperre näher?',
#    'href': 'http://www.zeit.de/politik/2020-03/covid-19-bayern-obdachlosigkeit-markus-soeder-coronavirus',
#    'release_date': '2020-03-20T15:47:39Z',
#    'uri': 'http://api.zeit.de/content/2sAzbGqaPErsqS4fhUMrOE',
#    'snippet': ' Möglichkeit, uns Fragen zu stellen. Wir versuchen, diese zu beantworten. Heute geht es um die Frage, wie es Obdachlosen in Zeiten der <em>Corona</em>-Krise geht. Die freie Autorin Annabel Trautwein hat sich die',
#    'supertitle': 'Covid-19',
#    'teaser_text': 'Am Sonntag will sich die Kanzlerin mit den Ministerpräsidenten beraten, Markus Söder hat für Bayern bereits eine Ausgehsperre verhängt. Erste Länder ziehen schon nach.',
#    'teaser_title': 'Update: Rückt die bundesweite Ausgangssperre näher?'},
#   {'subtitle': 'Sie spielen Klavier, backen Brot oder nehmen an Klopapierjonglierwettbewerben teil. Viele Profifußballer sitzen wegen Corona zu Hause, die Stimmung aber ist meist gut.',
#    'uuid': '2J9wgxrxGExtBpd0pIEfz2',
#    'title': 'Quarantäne United',
#    'href': 'http://www.zeit.de/sport/2020-03/fussballer-quarantaene-klopapier-instagram',
#    'release_date': '2020-03-20T15:40:23Z',
#    'uri': 'http://api.zeit.de/content/2J9wgxrxGExtBpd0pIEfz2',
#    'snippet': ' <em>Corona</em>-Patient Hübers berichtet, dass ihm Pakete und Essenslieferungen auf die Fensterbank gestellt werden.\nMittlerweile stecken neben Hannover 96 weitere Teams in Quarantäne: der 1. FC Nürnberg, der SC',
#    'supertitle': 'Fußball und Corona',
#    'teaser_text': 'Sie spielen Klavier, backen Brot oder nehmen an Klopapierjonglierwettbewerben teil. Viele Profifußballer sitzen wegen Corona zu Hause, die Stimmung aber ist meist gut.',
#    'teaser_title': 'Quarantäne United'},
#   {'subtitle': 'Restaurants schließen, Veranstaltungen werden abgesagt, Kunden brechen weg. Was bedeutet das für berufliche Existenzen? 30 Stimmen aus unserer Community',
#    'uuid': '1h9cvLf5WFVAvuePvE77H7',
#    'title': '"Ich weiß nicht, wie ich meine Familie jetzt ernähren kann"',
#    'href': 'http://www.zeit.de/arbeit/2020-03/corona-krise-pandemie-deutschland-existenzen-wirtschaft-leserstimmen',
#    'release_date': '2020-03-20T15:07:57Z',
#    'uri': 'http://api.zeit.de/content/1h9cvLf5WFVAvuePvE77H7',
#    'snippet': 'Vor dem Virus sind nicht alle gleich. Die <em>Corona</em>-Krise stellt die soziale Frage. Wer kann sich in der Vierzimmerwohnung auf gemütliches Homeoffice einstellen und weiß sich in einem entfristeten',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Restaurants schließen, Veranstaltungen werden abgesagt, Kunden brechen weg. Was bedeutet das für berufliche Existenzen? 30 Stimmen aus unserer Community',
#    'teaser_title': '"Ich weiß nicht, wie ich meine Familie jetzt ernähren kann"'},
#   {'subtitle': 'Die Corona-Pandemie belastet die Infrastruktur: Der Datenverkehr nimmt zu, in manchen Ländern gab es Netzausfälle. Die deutschen Provider sind vorbereitet, sagen sie.',
#    'uuid': '51l9MwwxcyKeStR4MBzel5',
#    'title': 'Wie stabil ist das Internet in Zeiten von Corona?',
#    'href': 'http://www.zeit.de/digital/internet/2020-03/deutsche-internetprovider-infrastruktur-coronavirus-homeoffice',
#    'release_date': '2020-03-20T14:44:38Z',
#    'uri': 'http://api.zeit.de/content/51l9MwwxcyKeStR4MBzel5',
#    'snippet': 'Die gute Nachricht: Am weltgrößten Internetknoten De-Cix in Frankfurt am Main ist man angesichts der <em>Corona</em>-Pandemie und dem damit zunehmenden Datenverkehr im Internet noch vergleichsweise entspannt',
#    'supertitle': 'Deutsche Internetprovider',
#    'teaser_text': 'Die Corona-Pandemie belastet die Infrastruktur: Der Datenverkehr nimmt zu, in manchen Ländern gab es Netzausfälle. Die deutschen Provider sind vorbereitet, sagen sie.',
#    'teaser_title': 'Wie stabil ist das Internet in Zeiten von Corona?'},
#   {'subtitle': 'Am Sonntag gibt es neue Beratungen der Bundeskanzlerin mit den Landesregierungen. Dann wird auch darüber entschieden: Müssen in Deutschland bald alle zu Hause bleiben?',
#    'uuid': '43wLTFzN4H1nkXFsOASeAO',
#    'title': 'Das Verhalten der Bevölkerung am Wochenende soll entscheidend sein',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/ausgangssperren-deutschland-coronavirus-helge-braun',
#    'release_date': '2020-03-20T14:13:58Z',
#    'uri': 'http://api.zeit.de/content/43wLTFzN4H1nkXFsOASeAO',
#    'snippet': ' vermeidet." Es gebe aber immer noch Menschen, "die eng zusammenstehen, feiern, die zu <em>Corona</em>-Partys einladen".\nEine Ausgangssperre sei kein "Allheilmittel", sie löse nicht jedes Problem, sagte Müller und',
#    'supertitle': 'Ausgangssperren in Deutschland',
#    'teaser_text': 'Am Sonntag gibt es neue Beratungen der Bundeskanzlerin mit den Landesregierungen. Dann wird auch darüber entschieden: Müssen in Deutschland bald alle zu Hause bleiben?',
#    'teaser_title': '"Wir werden uns das Verhalten an diesem Wochenende anschauen"'},
#   {'subtitle': 'Wie gewichtet man die Freiheit, etwas zu tun, gegenüber der Freiheit, vor etwas bewahrt zu werden? Die Frage bleibt auch in Zeiten der antizipierten Katastrophe wichtig.',
#    'uuid': '6tMUBbcP1JTppY4RssvCoI',
#    'title': 'Wir müssen wach bleiben und diskutieren',
#    'href': 'http://www.zeit.de/kultur/2020-03/persoenliche-freiheit-coronavirus-ausnahmezustand-krisensituation',
#    'release_date': '2020-03-20T13:18:42Z',
#    'uri': 'http://api.zeit.de/content/6tMUBbcP1JTppY4RssvCoI',
#    'snippet': ' zu können. Manchmal schießt er dabei über das Ziel hinaus, und das ist derzeit sowohl höchst problematisch wie dennoch debattenrelevant.\nSo war sich Agamben zu Beginn der italienischen <em>Corona</em>-Epidemie',
#    'supertitle': 'Persönliche Freiheit',
#    'teaser_text': 'Wie gewichtet man die Freiheit, etwas zu tun, gegenüber der Freiheit, vor etwas bewahrt zu werden? Die Frage bleibt auch in Zeiten der antizipierten Katastrophe wichtig.',
#    'teaser_title': 'Wir müssen wach bleiben und diskutieren'},
#   {'subtitle': 'Die Rentenunterschiede zwischen Ost- und Westdeutschland schwinden weiter. Von Sommer an bekommen Rentnerinnen und Rentner deutlich mehr Geld.',
#    'uuid': '3hQEMi2VJ8rzosSz1q1grW',
#    'title': 'Rente steigt stärker',
#    'href': 'http://www.zeit.de/wirtschaft/2020-03/alterssicherung-rente-rentenunterschiede-osten-westen-ausgleich',
#    'release_date': '2020-03-20T13:05:53Z',
#    'uri': 'http://api.zeit.de/content/3hQEMi2VJ8rzosSz1q1grW',
#    'snippet': ' in ungewissen Zeiten steht die\xa0Rentenversicherung für Verlässlichkeit." Die neue Rentensteigerung folge der guten wirtschaftlichen Entwicklung im Jahr 2019. Die erwarteten Auswirkungen der <em>Corona</em>-Krise auf die',
#    'supertitle': 'Alterssicherung',
#    'teaser_text': 'Die Rentenunterschiede zwischen Ost- und Westdeutschland schwinden weiter. Von Sommer an bekommen Rentnerinnen und Rentner deutlich mehr Geld.',
#    'teaser_title': 'Rente steigt stärker'},
#   {'subtitle': 'Das Coronavirus betrifft auch die Gerichte. Einige sagen Verhandlungen ab, andere reduzieren die Sitzplätze. Scheidungen werden am Telefon verhandelt.',
#    'uuid': '7PLFrAUn0oJYB9K9rZIeg',
#    'title': 'Richter als Seuchenbekämpfer',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/corona-krise-deutschland-richter-gerichte-kirchenaustritte-scheidungen-coronavirus',
#    'release_date': '2020-03-20T12:58:30Z',
#    'uri': 'http://api.zeit.de/content/7PLFrAUn0oJYB9K9rZIeg',
#    'snippet': ' Aufwand, die gesamte Beweisaufnahme wiederholen zu müssen.\xa0\nBundeskanzlerin Angela Merkel hatte in ihrer Rede an die Nation von der <em>Corona</em>-Krise als "größten Herausforderung seit dem Zweiten Weltkrieg',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Das Coronavirus betrifft auch die Gerichte. Einige sagen Verhandlungen ab, andere reduzieren die Sitzplätze. Scheidungen werden am Telefon verhandelt.',
#    'teaser_title': 'Richter als Seuchenbekämpfer'},
#   {'subtitle': 'Noch ist er Bezirksverordneter in Tempelhof-Schöneberg: Künftig will der Juso-Chef in den Bundestag. So wolle er Veränderungen vorantreiben, sagt er in einem Interview.',
#    'uuid': '48lmqVjquBVLuXpKUSh6Rf',
#    'title': 'Kevin Kühnert will bei Bundestagswahl antreten',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/kevin-kuehnert-spd-vorsitz-bundestagswahl',
#    'release_date': '2020-03-20T12:35:53Z',
#    'uri': 'http://api.zeit.de/content/48lmqVjquBVLuXpKUSh6Rf',
#    'snippet': ' Scholz, den er bei der Wahl für den Parteivorsitz nicht unterstützt hatte. Scholz mache seinen Job in der <em>Corona</em>-Krise "einfach verdammt gut", sagte Kühnert in dem Interview. "Wir alle können froh sein',
#    'supertitle': 'SPD',
#    'teaser_text': 'Noch ist er Bezirksverordneter in Tempelhof-Schöneberg: Künftig will der Juso-Chef in den Bundestag. So wolle er Veränderungen vorantreiben, sagt er in einem Interview.',
#    'teaser_title': 'Kevin Kühnert will bei Bundestagswahl antreten'},
#   {'subtitle': 'Wer in Italien auf der Intensivstation liegt, muss allein kämpfen. Auch in die Leichenschauräume dürfen die Angehörigen nicht. Und vom Beerdigungsbesuch wird abgeraten.',
#    'uuid': '3oVusTUkr7HWrSlCRZCPQO',
#    'title': 'Stilles Sterben',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/krankenversorgung-italien-totenversorgung-bestattung-mailand-lombardei',
#    'release_date': '2020-03-20T12:17:44Z',
#    'uri': 'http://api.zeit.de/content/3oVusTUkr7HWrSlCRZCPQO',
#    'snippet': ' zerrissen wird und von den Propellergeräuschen der Rettungshubschrauber. Dabei ist Mailand mit seinen 1,2 Millionen Einwohnern bis jetzt noch relativ glimpflich davongekommen: Rund 1.400 <em>Corona</em>-Infizierte',
#    'supertitle': 'Krankenversorgung in Italien',
#    'teaser_text': 'Wer in Italien auf der Intensivstation liegt, muss allein kämpfen. Auch in die Leichenschauräume dürfen die Angehörigen nicht. Und vom Beerdigungsbesuch wird abgeraten.',
#    'teaser_title': 'Stilles Sterben'},
#   {'subtitle': 'Friseursalons in Bayern schließen. In anderen Bundesländern noch nicht. Kunden sagen trotzdem ab. Hier erzählt ein Friseur, wie er sich und die Gäste vor Corona schützt.',
#    'uuid': '23DtYZwJAzgpUunxfHibUG',
#    'title': '"Es ist ein Kraftakt, durch den Tag zu kommen"',
#    'href': 'http://www.zeit.de/arbeit/2020-03/infektionsschutz-friseursalon-abstand-coronavirus-alltag',
#    'release_date': '2020-03-20T12:14:52Z',
#    'uri': 'http://api.zeit.de/content/23DtYZwJAzgpUunxfHibUG',
#    'snippet': 'Friseurinnen und Friseure kommen ihren Gästen beim Haareschneiden nah – zu nah für <em>Corona</em>. In Bayern müssen die Salons deshalb jetzt schließen, kündigte Bayerns Ministerpräsident Markus Söder heute',
#    'supertitle': 'Infektionsschutz im Friseursalon',
#    'teaser_text': 'Friseursalons in Bayern schließen. In anderen Bundesländern noch nicht. Kunden sagen trotzdem ab. Hier erzählt ein Friseur, wie er sich und die Gäste vor Corona schützt.',
#    'teaser_title': '"Es ist ein Kraftakt, durch den Tag zu kommen"'},
#   {'subtitle': 'Die Restaurantkette steckt seit Langem in finanziellen Schwierigkeiten. Nun ist Vapiano zahlungsunfähig. Der Vorstand hofft auf die Corona-Hilfen der Bundesregierung.',
#    'uuid': '5Cuknsf7x2nNVQ5H5FOkGz',
#    'title': 'Vapiano muss Insolvenzantrag stellen',
#    'href': 'http://www.zeit.de/wirtschaft/unternehmen/2020-03/vapiano-restaurantkette-insolvenz-corona-krise',
#    'release_date': '2020-03-20T11:24:02Z',
#    'uri': 'http://api.zeit.de/content/5Cuknsf7x2nNVQ5H5FOkGz',
#    'snippet': 'Die <em>Corona</em>-Krise hat die ohnehin angeschlagene Restaurantkette Vapiano in die Insolvenz getrieben. Wie das Unternehmen selbst mitteilte, sei man wegen des drastischen Umsatzrückgangs zahlungsunfähig',
#    'supertitle': 'Restaurantkette',
#    'teaser_text': 'Die Restaurantkette steckt seit Langem in finanziellen Schwierigkeiten. Nun ist Vapiano zahlungsunfähig. Der Vorstand hofft auf die Corona-Hilfen der Bundesregierung.',
#    'teaser_title': 'Vapiano muss Insolvenzantrag stellen'},
#   {'subtitle': 'Selten lag die Schönheit, die Großartigkeit und Bedeutsamkeit von Friedrich Hölderlin so auf der Hand wie heute: in Corona-Zeiten. Zum 250. Geburtstag des Dichters',
#    'uuid': '55DP0FKdIeDJz5boEEsUEb',
#    'title': 'Mit ihm sind wir modern',
#    'href': 'http://www.zeit.de/kultur/literatur/2020-03/friedrich-hoelderlin-dichter-geburtstag-corona-zeiten',
#    'release_date': '2020-03-20T11:05:51Z',
#    'uri': 'http://api.zeit.de/content/55DP0FKdIeDJz5boEEsUEb',
#    'snippet': ' und die Großartigkeit und Bedeutsamkeit von Hölderlin so auf der Hand wie heute: in <em>Corona</em>-Zeiten. Die elaborierten Argumentationsketten, warum uns der schwäbische Dichter vergangener Zeiten auch im 21',
#    'supertitle': 'Friedrich Hölderlin',
#    'teaser_text': 'Selten lag die Schönheit, die Großartigkeit und Bedeutsamkeit von Friedrich Hölderlin so auf der Hand wie heute: in Corona-Zeiten. Zum 250. Geburtstag des Dichters',
#    'teaser_title': 'Mit ihm sind wir modern'},
#   {'subtitle': 'Wie es den Ärmsten der Stadt geht. Auch: Covid-19-Fälle in Hamburg steigen weiter, Mangel an Schutzmasken vorerst behoben, Hilfspaket für Künstler und Kleinunternehmer.',
#    'uuid': '3PIaQkbvkKqWQb9qfOu4Xm',
#    'title': 'Eine Recherche unter Hamburgs Obdachlosen in Zeiten von Corona',
#    'href': 'http://www.zeit.de/hamburg/2020-03/elbvertiefung-20-03-2020',
#    'release_date': '2020-03-20T10:55:04Z',
#    'uri': 'http://api.zeit.de/content/3PIaQkbvkKqWQb9qfOu4Xm',
#    'snippet': ' ziehen.\nUm Selbstständige und Kleinunternehmer in Hamburg vor der sofortigen\xa0Insolvenz in Folge der <em>Corona</em>-Krise zu bewahren, legt der Senat für sie ein eigenes Hilfsprogramm auf. Das Paket beinhaltet',
#    'supertitle': 'Corona-Welle',
#    'teaser_text': 'Wie es den Ärmsten der Stadt geht. Auch: Covid-19-Fälle in Hamburg steigen weiter, Mangel an Schutzmasken vorerst behoben, Hilfspaket für Künstler und Kleinunternehmer.',
#    'teaser_title': 'Eine Recherche unter Hamburgs Obdachlosen in Zeiten von Corona'},
#   {'subtitle': 'Bislang galt die schwarze Null als Dogma jedes Bundesfinanzministers. Olaf Scholz will in der Corona-Krise aber mit Milliarden helfen und notfalls Schulden aufnehmen.',
#    'uuid': '45xbJPbr21e7oeRn0uqqKJ',
#    'title': 'Bundesregierung will Schuldenbremse lockern',
#    'href': 'http://www.zeit.de/wirtschaft/2020-03/corona-krise-bundesregierung-will-schuldenbremse-lockern',
#    'release_date': '2020-03-20T10:32:56Z',
#    'uri': 'http://api.zeit.de/content/45xbJPbr21e7oeRn0uqqKJ',
#    'snippet': 'Die Bundesregierung will die Schuldenbremse wegen der <em>Corona</em>-Krise aufweichen, damit sich der Bund höher verschulden kann. Das berichten die Süddeutsche Zeitung und die Deutsche Presse-Agentur (dpa',
#    'supertitle': 'Corona-Krise',
#    'teaser_text': 'Bislang galt die schwarze Null als Dogma jedes Bundesfinanzministers. Olaf Scholz will in der Corona-Krise aber mit Milliarden helfen und notfalls Schulden aufnehmen.',
#    'teaser_title': 'Bundesregierung will Schuldenbremse lockern'},
#   {'subtitle': 'Heimarbeit, Heimunterricht und Enge – für viele Menschen verändert Corona den Alltag. Eine Familie, ein Single, ein Rentner und eine Kommune berichten.',
#    'uuid': '6JE9QYoWiy33s2LhCTgjkF',
#    'title': '"Man muss sich eine harte Struktur geben"',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/familienalltag-coronavirus-ausgangsperre-homeoffice-quarantaene',
#    'release_date': '2020-03-20T10:31:22Z',
#    'uri': 'http://api.zeit.de/content/6JE9QYoWiy33s2LhCTgjkF',
#    'snippet': ' Kinder ganz gut betreuen. Trotzdem waren wir abends einfach nur durch.\nSeit Wochen sprechen wir in der Familie über <em>Corona</em>. Wir hören auch die Nachrichten zusammen. Ich habe meinen Kindern erklärt, dass',
#    'supertitle': 'Familienalltag',
#    'teaser_text': 'Heimarbeit, Heimunterricht und Enge – für viele Menschen verändert Corona den Alltag. Eine Familie, ein Single, ein Rentner und eine Kommune berichten.',
#    'teaser_title': '"Man muss sich eine harte Struktur geben"'},
#   {'subtitle': 'Der Virologe Christian Drosten leitet Deutschland durch die Pandemie. Ein Gespräch über Ausgangssperren, die Dauer der Krise – und wie sie unser Leben verändert.',
#    'uuid': '5nAMbZjmKlEQ049kVuE3lT',
#    'title': '"Wir müssen jetzt die Fälle senken. Sonst schaffen wir es nicht"',
#    'href': 'http://www.zeit.de/wissen/gesundheit/2020-03/christian-drosten-coronavirus-pandemie-deutschland-virologe-charite',
#    'release_date': '2020-03-20T08:18:38Z',
#    'uri': 'http://api.zeit.de/content/5nAMbZjmKlEQ049kVuE3lT',
#    'snippet': 'Read this interview in English.\nWas vor einer Woche noch unmöglich schien, ist jetzt Realität: Die <em>Corona</em>-Pandemie verändert das Leben in Deutschland grundlegend. Erstmals in der Geschichte der',
#    'supertitle': 'Christian Drosten',
#    'teaser_text': 'Der Virologe Christian Drosten leitet Deutschland durch die Pandemie. Ein Gespräch über Ausgangssperren, die Dauer der Krise – und wie sie unser Leben verändert.',
#    'teaser_title': '"Wir müssen jetzt die Fälle senken. Sonst schaffen wir es nicht"'},
#   {'subtitle': 'Läden, Cafés, Kinos: die Pandemie bringt alles zum Stillstand – und könnte Deutschland in die schwerste Krise der Nachkriegsgeschichte stürzen. Aber es gibt einen Ausweg.',
#    'uuid': '4tzMIiwxZobDEL5c0NOUXl',
#    'title': 'Keine Frage, das wird teuer',
#    'href': 'http://www.zeit.de/wirtschaft/2020-03/corona-covid-19-deutschland-wirtschaft-konjunktur-prognose-5vor8',
# ...
#    'release_date': '2020-03-16T08:25:29Z',
#    'uri': 'http://api.zeit.de/content/2KVqEQ3hPNFH4D2ncjZsxC',
#    'snippet': 'Die Eingangstüren der Grundschule im Ingolstädter Ortsteil Ringsee öffnen sich automatisch, sobald jemand auf sie zugeht. Das ist perfekt für ein Wahllokal in Zeiten der <em>Corona</em>-Krise: Niemand, der',
#    'supertitle': 'Kommunalwahl in Bayern',
#    'teaser_text': 'Bayerns Wähler trotzen dem Virus, die Beteiligung bei den Kommunalwahlen steigt sogar. Die CSU atmet auf – die Grünen müssen ein paar Hoffnungen begraben.',
#    'teaser_title': 'Siegen in Zeiten von Corona'},
#   {'subtitle': "In der Corona-Krise schlägt Bernie Sanders' große Stunde. Das zeigte das erbitterte TV-Duell gegen Joe Biden. Aber sein Erfolg bleibt nur ein symbolischer.",
#    'uuid': '38zH5WqPLQRWBlXERZLBE9',
#    'title': '"Das hier ist Krieg"',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/bernie-sanders-corona-joe-biden-tv-duell',
#    'release_date': '2020-03-16T06:36:54Z',
#    'uri': 'http://api.zeit.de/content/38zH5WqPLQRWBlXERZLBE9',
#    'snippet': ' <em>Corona</em>-Krise eine Steilvorlage für sein wichtigstes Thema bekommen: die Gesundheitsversorgung in den USA. Millionen Amerikanerinnen und Amerikaner sind nicht oder nur unzureichend krankenversichert. In den',
#    'supertitle': 'Corona',
#    'teaser_text': "In der Corona-Krise schlägt Bernie Sanders' große Stunde. Das zeigte das erbitterte TV-Duell gegen Joe Biden. Aber sein Erfolg bleibt nur ein symbolischer.",
#    'teaser_title': '"Das hier ist Krieg"'},
#   {'subtitle': 'Die Corona-Krise zeigt, wie abhängig wir von China sind. Doch auch wegen der menschenverachtenden Politik muss sich der Westen Chinas Machthunger entgegenstellen.',
#    'uuid': '2q5naJp9edOxC1YcccbS41',
#    'title': 'Wir müssen über China reden',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/coronavirus-china-krise-abhaengigkeit-menschenrechte-ueberwachung-westen-konkurrenz-5vor8',
#    'release_date': '2020-03-16T06:24:39Z',
#    'uri': 'http://api.zeit.de/content/2q5naJp9edOxC1YcccbS41',
#    'snippet': ' Mitte ihren Ursprung hatten. Sie hätten auch anderswo entstehen können.\nDas <em>Corona</em>-Virus und seine Folgen führen uns drastisch vor Augen, wie abhängig wir von China geworden sind, vor allem wirtschaftlich',
#    'supertitle': 'Kampf gegen Covid-19',
#    'teaser_text': 'Die Corona-Krise zeigt, wie abhängig wir von China sind. Doch auch wegen der menschenverachtenden Politik muss sich der Westen Chinas Machthunger entgegenstellen.',
#    'teaser_title': 'Wir müssen über China reden'},
#   {'subtitle': 'Im Kampf gegen die Coronavirus-Pandemie lassen EU-Länder die Schlagbäume herunter. Dabei könnte eine europäische Antwort viel effektiver sein als diese Kleinstaaterei.',
#    'uuid': '5wHls2MLrrkAmPaytECvYS',
#    'title': 'Wo ist das Europa, das schützt?',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/grenzschliessungen-coronavirus-pandemie-deutschland-eu',
#    'release_date': '2020-03-16T05:51:24Z',
#    'uri': 'http://api.zeit.de/content/5wHls2MLrrkAmPaytECvYS',
#    'snippet': ', und es schützt nicht Europa, sondern der Nationalstaat – das wird jedenfalls mit den Grenzschließungen jedenfalls suggeriert. Wie erfolgreich wird diese praktizierte Kleinstaaterei im Kampf gegen <em>Corona</em>',
#    'supertitle': 'Grenzschließungen',
#    'teaser_text': 'Im Kampf gegen die Coronavirus-Pandemie lassen EU-Länder die Schlagbäume herunter. Dabei könnte eine europäische Antwort viel effektiver sein als diese Kleinstaaterei.',
#    'teaser_title': 'Wo ist das Europa, das schützt?'},
#   {'subtitle': 'Innerhalb weniger Tage hat Covid-19 das öffentliche Leben zum Erliegen gebracht. Wie lange dauert der Shutdown? Und: warum in Brandenburg gegen Tesla protestiert wird.',
#    'uuid': '6uyKyihN6SCGdXslK0PIzz',
#    'title': 'Was wir jetzt machen, entscheidet',
#    'href': 'http://www.zeit.de/politik/2020-03/pandemie-coronavirus-alltag-stillstand-nachrichtenpodcast',
#    'release_date': '2020-03-16T04:58:41Z',
#    'uri': 'http://api.zeit.de/content/6uyKyihN6SCGdXslK0PIzz',
#    'snippet': ' gerechtfertigt sind, erklärt ZEIT-ONLINE-Wissensredakteur Jakob Simmank.\xa0 Er geht auch darauf ein, wie lange die Schulschließungen anhalten könnten und wie man schwere <em>Corona</em>-Fälle künftig behandeln könnte.\nEs war',
#    'supertitle': 'Pandemie',
#    'teaser_text': 'Innerhalb weniger Tage hat Covid-19 das öffentliche Leben zum Erliegen gebracht. Wie lange dauert der Shutdown? Und: warum in Brandenburg gegen Tesla protestiert wird.',
#    'teaser_title': 'Was wir jetzt machen, entscheidet'},
#   {'subtitle': 'Die Fed hat den Leitzins um einen vollen Prozentpunkt auf zwischen 0 und 0,25 Prozent gesenkt. Dadurch soll die durch Corona angeschlagene Wirtschaft angekurbelt werden.',
#    'uuid': '6InGi6IqW76cMWzcXwKbph',
#    'title': 'US-Notenbank senkt Leitzins wegen Corona-Krise auf Nullniveau',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/fed-leitzins-senkung-us-notenbank-coronavirus-nullniveau',
#    'release_date': '2020-03-16T04:56:56Z',
#    'uri': 'http://api.zeit.de/content/6InGi6IqW76cMWzcXwKbph',
#    'snippet': ' beizubehalten, bis die Wirtschaft die Folgen der <em>Corona</em>-Krise bewältigt habe. Mit der Zinssenkung werden Kredite billiger, was die Wirtschaftsaktivität und den Konsum fördern soll. Die\xa0Fed\xa0hatte den Leitzins',
#    'supertitle': 'Corona-Pandemie',
#    'teaser_text': 'Die Fed hat den Leitzins um einen vollen Prozentpunkt auf zwischen 0 und 0,25 Prozent gesenkt. Dadurch soll die durch Corona angeschlagene Wirtschaft angekurbelt werden.',
#    'teaser_title': 'US-Notenbank senkt Leitzins wegen Corona-Krise auf Nullniveau'},
#   {'subtitle': 'Die britische Regierung gibt ihre Strategie im Kampf gegen Covid-19 auf. Statt eine Erkrankung von Millionen Menschen in Kauf zu nehmen, setzt sie nun auf Isolation.',
#    'uuid': '6LFbTc6BdRNNITfd3jbPXk',
#    'title': 'Massenisolation statt Herdenimmunität',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/covid-19-grossbritannien-herdenimmunitaet-virusbekaempfung',
#    'release_date': '2020-03-15T19:39:58Z',
#    'uri': 'http://api.zeit.de/content/6LFbTc6BdRNNITfd3jbPXk',
#    'snippet': ' Fieber erkrankte und praktisch acht Tage von dem ärztlichen Notruf hingehalten wurde. Immer wieder wurde ihm ein <em>Corona</em>-Test versprochen, der dann wieder abgeblasen wurde, dann Rückrufe angekündigt, die',
#    'supertitle': 'Covid-19',
#    'teaser_text': 'Die britische Regierung gibt ihre Strategie im Kampf gegen Covid-19 auf. Statt eine Erkrankung von Millionen Menschen in Kauf zu nehmen, setzt sie nun auf Isolation.',
#    'teaser_title': 'Massenisolation statt Herdenimmunität'},
#   {'subtitle': 'Die Corona-Krise treibt einen typischen Familienkonflikt auf die Spitze: Wer darf für wen Entscheidungen treffen? Über die Grenze zwischen Fürsorge und Bevormundung.',
#    'uuid': '66KPQ13IAR8uavX6nG1W68',
#    'title': 'Opa, du kriegst jetzt Besuchsverbot',
#    'href': 'http://www.zeit.de/zeit-magazin/leben/2020-03/risikogruppen-besuchsverbote-grosseltern-coronavirus-generationenbeziehung',
#    'release_date': '2020-03-15T19:37:41Z',
#    'uri': 'http://api.zeit.de/content/66KPQ13IAR8uavX6nG1W68',
#    'snippet': ' Krankenhaus. Als die <em>Corona</em>-Warnungen immer eindringlicher werden und der Virologe Christian Drosten dazu aufruft, ältere Menschen nicht zu gefährden, postet mein Großvater ein Foto in den Familienchat. Zu',
#    'supertitle': 'Risikogruppen',
#    'teaser_text': 'Die Corona-Krise treibt einen typischen Familienkonflikt auf die Spitze: Wer darf für wen Entscheidungen treffen? Das hat viele Leser interessiert.',
#    'teaser_title': 'Opa, du kriegst jetzt Besuchsverbot'},
#   {'subtitle': 'Die Krise der Gesundheitsversorgung in den USA spitzt sich durch die Pandemie weiter zu. Die 1,5 Millionen Obdachlosen des Landes leiden darunter besonders.',
#    'uuid': '3WcVIuJ07JGn0cqVmM1xwz',
#    'title': '"Eine soziale Krise mit einer Gesundheitskrise obendrauf"',
#    'href': 'http://www.zeit.de/politik/ausland/2020-03/coronavirus-usa-gesundheitssystem-unversicherte-obdachlose-bobby-watts',
#    'release_date': '2020-03-15T16:39:39Z',
#    'uri': 'http://api.zeit.de/content/3WcVIuJ07JGn0cqVmM1xwz',
#    'snippet': ' in Obdachlosigkeit leben ? Bobby Watts und Barbara DiPietro vom National Healthcare for the Homeless Council (NHCHC) befürchten, dass <em>Corona</em> vor allem zulasten der Ärmsten gehen wird – und sich die Krise der',
#    'supertitle': 'Coronavirus in den USA',
#    'teaser_text': 'Die Krise der Gesundheitsversorgung in den USA spitzt sich durch die Pandemie weiter zu. Die 1,5 Millionen Obdachlosen des Landes leiden darunter besonders.',
#    'teaser_title': '"Eine soziale Krise mit einer Gesundheitskrise obendrauf"'},
#   {'subtitle': 'Angesichts der Lage im Land sei es unbedeutend, wann ihr Nachfolger feststehe, sagte die CDU-Chefin. Indirekt stellte sie auch die Kanzlerfähigkeit der Bewerber infrage.',
#    'uuid': 'ItEGJm4MZJPELCtW7SzRJ',
#    'title': 'Kramp-Karrenbauer wirft Merz und Röttgen falsche Prioritäten vor',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/cdu-vorsitz-annegret-kramp-karrenbauer-friedrich-merz-corona-pandemie',
#    'release_date': '2020-03-15T16:26:11Z',
#    'uri': 'http://api.zeit.de/content/ItEGJm4MZJPELCtW7SzRJ',
#    'snippet': ' Wahl ihres Nachfolgers stattfinde, sei gegenwärtig von geringer Bedeutung. "Angesichts der <em>Corona</em>-Lage ist das eine Frage, die die Menschen nicht interessiert. Ich führe meine Partei als Vorsitzende mit',
#    'supertitle': 'CDU-Vorsitz',
#    'teaser_text': 'Angesichts der Lage im Land sei es unbedeutend, wann ihr Nachfolger feststehe, sagte die CDU-Chefin. Indirekt stellte sie auch die Kanzlerfähigkeit der Bewerber infrage.',
#    'teaser_title': 'Kramp-Karrenbauer wirft Merz und Röttgen falsche Prioritäten vor'},
#   {'subtitle': 'Die Angst vor dem Coronavirus lähmt das soziale Leben? Nicht ganz. In dieser schwierigen Zeit entdecken viele Menschen ihre Hilfsbereitschaft wieder.',
#    'uuid': '2vjZufzFYNXQdFehqSKUSd',
#    'title': '"In der Krise gewinnt Nachbarschaft neue Bedeutung"',
#    'href': 'http://www.zeit.de/gesellschaft/2020-03/nachbarschaftshilfe-nebenan-de-coronavirus-sozialleben-ina-remmers',
#    'release_date': '2020-03-15T15:56:00Z',
#    'uri': 'http://api.zeit.de/content/2vjZufzFYNXQdFehqSKUSd',
#    'snippet': 'Eine Fotografin, die kostenlose Kinderbetreuung anbietet, weil sie gerade ohnehin keine Aufträge hat. Eine Studentin, die für Risikogruppen einkaufen gehen will – die <em>Corona</em>-Epidemie hat eine neue',
#    'supertitle': 'Nachbarschaftshilfe',
#    'teaser_text': 'Die Angst vor dem Coronavirus lähmt das soziale Leben? Nicht ganz. In dieser schwierigen Zeit entdecken viele Menschen ihre Hilfsbereitschaft wieder.',
#    'teaser_title': '"In der Krise gewinnt Nachbarschaft neue Bedeutung"'},
#   {'subtitle': 'Zweitweiser Unterricht für alle Schüler ab 25. Mai, mehr als 190 Menschen gestorben: die Lage in Hamburg im Überblick',
#    'uuid': '2Oof1pyzdjuxkFHSrN57qa',
#    'title': 'Kitas sollen stufenweise wieder öffnen',
#    'href': 'http://www.zeit.de/hamburg/2020-03/coronavirus-hamburg-schulschliessungen-massnahmen-veranstaltungen-faq',
#    'release_date': '2020-03-15T15:15:53Z',
#    'uri': 'http://api.zeit.de/content/2Oof1pyzdjuxkFHSrN57qa',
#    'snippet': ' in Hamburg 204 Menschen mit einer <em>Corona</em>-Infektion gestorben. Laut dem Institut für Rechtsmedizin wurde bei 195 Menschen die Infektion als todesursächlich festgestellt. Der Altersschnitt der Gestorbenen lag',
#    'supertitle': 'Coronavirus in Hamburg',
#    'teaser_text': 'Zeitweiser Unterricht für alle Schüler ab 25. Mai, mehr als 190 Menschen gestorben: die Lage in Hamburg im Überblick',
#    'teaser_title': 'Kitas sollen stufenweise wieder öffnen'},
#   {'subtitle': 'Wer aus Österreich, Frankreich, Luxemburg, Dänemark oder der Schweiz nach Deutschland einreisen will, braucht ab Montag einen "triftigen Grund". Pendler sind ausgenommen.',
#    'uuid': '3rHDlJrvTZDV1kH2P45k0u',
#    'title': 'Deutschland riegelt Grenzen zu fünf Ländern teilweise ab',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/coronavirus-deutsche-grenzen-ab-montag-geschlossen',
#    'release_date': '2020-03-15T14:22:16Z',
#    'uri': 'http://api.zeit.de/content/3rHDlJrvTZDV1kH2P45k0u',
#    'snippet': ' von Kanzlerin Angela Merkel (CDU) beraten.\nPolizeikräfte seien bereits unterwegs zu den Grenzabschnitten, sagte der Präsident der Bundespolizei, Dieter Romann. Von <em>Corona</em>-Infektionen sei auch die',
#    'supertitle': 'Coronavirus',
#    'teaser_text': 'Wer aus Österreich, Frankreich, Luxemburg, Dänemark oder der Schweiz nach Deutschland einreisen will, braucht ab Montag einen "triftigen Grund". Pendler sind ausgenommen.',
#    'teaser_title': 'Deutschland riegelt Grenzen zu fünf Ländern teilweise ab'},
#   {'subtitle': 'Corona verweist uns zurück in eine behagliche Welt aus Familie, engen Freunden und Nachbarinnen. Einige hoffen schon auf bleibende Solidarität. Die wird es nicht geben.',
#    'uuid': '1RHnfbQXQjM9sAkUWwEnTQ',
#    'title': 'Willkommen in Retrotopia',
#    'href': 'http://www.zeit.de/gesellschaft/zeitgeschehen/2020-03/coronavirus-gemeinschaft-wir-retrotopia-solidaritaet-zusammenhalt-digitalisierung',
#    'release_date': '2020-03-15T13:43:32Z',
#    'uri': 'http://api.zeit.de/content/1RHnfbQXQjM9sAkUWwEnTQ',
#    'snippet': 'Wie werden sie also aussehen, unsere <em>Corona</em>-Tage? Vielleicht bestenfalls so: Morgens lassen wir uns per Podcast vom Virologen auf Krisenstand bringen, auf dem Frühstückstisch aufgetautes Brot, H',
#    'supertitle': 'Coronavirus',
#    'teaser_text': 'Corona verweist uns zurück in eine behagliche Welt aus Familie, engen Freunden und Nachbarinnen. Einige hoffen schon auf bleibende Solidarität. Die wird es nicht geben.',
#    'teaser_title': 'Willkommen in Retrotopia'},
#   {'subtitle': 'Die deutsche Firma CureVac hat Berichte über eine mögliche Übernahme durch die US-Regierung zurückgewiesen. Man wolle einen Impfstoff für "die ganze Welt" entwicklen.',
#    'uuid': '2p0oMqzfVoRO8ovlzO15DG',
#    'title': 'Tübinger Impfstofffirma dementiert mögliche US-Übernahme',
#    'href': 'http://www.zeit.de/wirtschaft/unternehmen/2020-03/coronavirus-impfstoff-curevac-deutsche-firma-usa-rechte',
#    'release_date': '2020-03-15T12:12:58Z',
#    'uri': 'http://api.zeit.de/content/2p0oMqzfVoRO8ovlzO15DG',
#    'snippet': ' Übernahme gibt es nicht", sagte er. Zwar bestehe durchaus Interesse aus den USA an der Arbeit von CureVac, aber "<em>Corona</em> ist ein weltweites Problem, dafür arbeiten wir", sagte Haas.\nBundeswirtschaftsminister',
#    'supertitle': 'Coronavirus-Impfstoff',
#    'teaser_text': 'Die deutsche Firma CureVac hat Berichte über eine mögliche Übernahme durch die US-Regierung zurückgewiesen. Man wolle einen Impfstoff für "die ganze Welt" entwicklen.',
#    'teaser_title': 'Tübinger Impfstofffirma dementiert mögliche US-Übernahme'},
#   {'subtitle': 'Sie fordern Grenzschließungen, horten Lebensmittel und träumen vom Ende der Demokratie: Wie Rechtsradikale versuchen, die Corona-Pandemie für ihre Ziele zu nutzen.',
#    'uuid': '4wWRRbLLzWzbSj755dXmt6',
#    'title': '"Der ultimative Niedergangsbeschleuniger"',
#    'href': 'http://www.zeit.de/politik/deutschland/2020-03/afd-rechtsradikale-coronavirus-verfassungsschutz-gefahr',
#    'release_date': '2020-03-15T06:05:51Z',
#    'uri': 'http://api.zeit.de/content/4wWRRbLLzWzbSj755dXmt6',
#    'snippet': '. In seinem Gastbeitrag analysiert er die Zusammenhänge zwischen Rechtsradikalismus und der <em>Corona</em>-Pandemie.\nAm Dienstagabend wurde in München eine 45-jährige Münchnerin mit chinesischen Wurzeln von einem',
#    'supertitle': 'AfD',
#    'teaser_text': 'Sie fordern Grenzschließungen, horten Lebensmittel und träumen vom Ende der Demokratie: Wie Rechtsradikale versuchen, die Corona-Pandemie für ihre Ziele zu nutzen.',
#    'teaser_title': '"Der ultimative Niedergangsbeschleuniger"'}],
#  'found': 200,
#  'limit': 1000,
#  'offset': 0}

# %%
test["matches"][0]["subtitle"]
# Out:
# 'Spätestens nach einem Tag Homeoffice und Homeschooling haben sich alle eine Partie Spaß verdient. Die Gesellschaftsspiele-Tipps der ZEIT ONLINE-Redaktion'

# %% [markdown]
# ### Keyword = "corona"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "corona", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  200
# date:  200
# snippet:  200
# teaser_text:  200
# teaser_title:  200
# href:  200
# -----
#
# loop:  1
#
# title:  425
# date:  425
# snippet:  425
# teaser_text:  425
# teaser_title:  425
# href:  425
# -----
#
# loop:  2
#
# title:  652
# date:  652
# snippet:  652
# teaser_text:  652
# teaser_title:  652
# href:  652
# -----
#
# loop:  3
#
# title:  862
# date:  862
# snippet:  862
# teaser_text:  862
# teaser_title:  862
# href:  862
# -----
#
# loop:  4
#
# title:  1054
# date:  1054
# snippet:  1054
# teaser_text:  1054
# teaser_title:  1054
# href:  1054
# -----
#
# loop:  5
#
# title:  1287
# date:  1287
# snippet:  1287
# teaser_text:  1287
# teaser_title:  1287
# href:  1287
# -----
#
# loop:  6
#
# title:  1483
# date:  1483
# snippet:  1483
# teaser_text:  1483
# teaser_title:  1483
# href:  1483
# -----
#
# loop:  7
#
# title:  1695
# date:  1695
# snippet:  1695
# teaser_text:  1695
# teaser_title:  1695
# href:  1695
# -----
#
# loop:  8
#
# title:  1907
# date:  1907
# snippet:  1907
# teaser_text:  1907
# teaser_title:  1907
# href:  1907
# -----
#
# loop:  9
#
# title:  2082
# date:  2082
# snippet:  2082
# teaser_text:  2082
# teaser_title:  2082
# href:  2082
# -----
#
# loop:  10
#
# title:  2313
# date:  2313
# snippet:  2313
# teaser_text:  2313
# teaser_title:  2313
# href:  2313
# -----
#
# loop:  11
#
# title:  2510
# date:  2510
# snippet:  2510
# teaser_text:  2510
# teaser_title:  2510
# href:  2510
# -----
#
# loop:  12
#
# title:  2719
# date:  2719
# snippet:  2719
# teaser_text:  2719
# teaser_title:  2719
# href:  2719
# -----
#
# loop:  13
#
# title:  2928
# date:  2928
# snippet:  2928
# teaser_text:  2928
# teaser_title:  2928
# href:  2928
# -----
#
# loop:  14
#
# title:  3156
# date:  3156
# snippet:  3156
# teaser_text:  3156
# teaser_title:  3156
# href:  3156
# -----
#
# loop:  15
#
# title:  3351
# date:  3351
# snippet:  3351
# teaser_text:  3351
# teaser_title:  3351
# href:  3351
# -----
#
# loop:  16
#
# title:  3526
# date:  3526
# snippet:  3526
# teaser_text:  3526
# teaser_title:  3526
# href:  3526
# -----
#
# loop:  17
#
# title:  3699
# date:  3699
# snippet:  3699
# teaser_text:  3699
# teaser_title:  3699
# href:  3699
# -----
#
# loop:  18
#
# title:  3881
# date:  3881
# snippet:  3881
# teaser_text:  3881
# teaser_title:  3881
# href:  3881
# -----
#
# loop:  19
#
# title:  4042
# date:  4042
# snippet:  4042
# teaser_text:  4042
# teaser_title:  4042
# href:  4042
# -----
#
# loop:  20
#
# title:  4210
# date:  4210
# snippet:  4210
# teaser_text:  4210
# teaser_title:  4210
# href:  4210
# -----
#
# loop:  21
#
# title:  4386
# date:  4386
# snippet:  4386
# teaser_text:  4386
# teaser_title:  4386
# href:  4386
# -----
#
# loop:  22
#
# title:  4558
# date:  4558
# snippet:  4558
# teaser_text:  4558
# teaser_title:  4558
# href:  4558
# -----
#
# loop:  23
#
# title:  4735
# date:  4735
# snippet:  4735
# teaser_text:  4735
# teaser_title:  4735
# href:  4735
# -----
#
# loop:  24
#
# title:  4917
# date:  4917
# snippet:  4917
# teaser_text:  4917
# teaser_title:  4917
# href:  4917
# -----
#
# loop:  25
#
# title:  5068
# date:  5068
# snippet:  5068
# teaser_text:  5068
# teaser_title:  5068
# href:  5068
# -----
#
# loop:  26
#
# title:  5223
# date:  5223
# snippet:  5223
# teaser_text:  5223
# teaser_title:  5223
# href:  5223
# -----
#
# loop:  27
#
# title:  5374
# date:  5374
# snippet:  5374
# teaser_text:  5374
# teaser_title:  5374
# href:  5374
# -----
#
# loop:  28
#
# title:  5543
# date:  5543
# snippet:  5543
# teaser_text:  5543
# teaser_title:  5543
# href:  5543
# -----
#
# loop:  29
#
# title:  5725
# date:  5725
# snippet:  5725
# teaser_text:  5725
# teaser_title:  5725
# href:  5725
# -----
#
# loop:  30
#
# title:  5907
# date:  5907
# snippet:  5907
# teaser_text:  5907
# teaser_title:  5907
# href:  5907
# -----
#
# loop:  31
#
# title:  6053
# date:  6053
# snippet:  6053
# teaser_text:  6053
# teaser_title:  6053
# href:  6053
# -----
#
# loop:  32
#
# title:  6259
# date:  6259
# snippet:  6259
# teaser_text:  6259
# teaser_title:  6259
# href:  6259
# -----
#
# loop:  33
#
# title:  6403
# date:  6403
# snippet:  6403
# teaser_text:  6403
# teaser_title:  6403
# href:  6403
# -----
#
# loop:  34
#
# title:  6567
# date:  6567
# snippet:  6567
# teaser_text:  6567
# teaser_title:  6567
# href:  6567
# -----
#
# loop:  35
#
# title:  6739
# date:  6739
# snippet:  6739
# teaser_text:  6739
# teaser_title:  6739
# href:  6739
# -----
#
# loop:  36
#
# title:  6887
# date:  6887
# snippet:  6887
# teaser_text:  6887
# teaser_title:  6887
# href:  6887
# -----
#
# loop:  37
#
# title:  7044
# date:  7044
# snippet:  7044
# teaser_text:  7044
# teaser_title:  7044
# href:  7044
# -----
#
# loop:  38
#
# title:  7227
# date:  7227
# snippet:  7227
# teaser_text:  7227
# teaser_title:  7227
# href:  7227
# -----
#
# loop:  39
#
# title:  7359
# date:  7359
# snippet:  7359
# teaser_text:  7359
# teaser_title:  7359
# href:  7359
# -----
#
# loop:  40
#
# title:  7493
# date:  7493
# snippet:  7493
# teaser_text:  7493
# teaser_title:  7493
# href:  7493
# -----
#
# loop:  41
#
# title:  7624
# date:  7624
# snippet:  7624
# teaser_text:  7624
# teaser_title:  7624
# href:  7624
# -----
#
# loop:  42
#
# title:  7762
# date:  7762
# snippet:  7762
# teaser_text:  7762
# teaser_title:  7762
# href:  7762
# -----
#
# loop:  43
#
# title:  7911
# date:  7911
# snippet:  7911
# teaser_text:  7911
# teaser_title:  7911
# href:  7911
# -----
#
# loop:  44
#
# title:  8065
# date:  8065
# snippet:  8065
# teaser_text:  8065
# teaser_title:  8065
# href:  8065
# -----
#
# loop:  45
#
# title:  8224
# date:  8224
# snippet:  8224
# teaser_text:  8224
# teaser_title:  8224
# href:  8224
# -----
#
# loop:  46
#
# title:  8367
# date:  8367
# snippet:  8367
# teaser_text:  8367
# teaser_title:  8367
# href:  8367
# -----
#
# loop:  47
#
# title:  8530
# date:  8530
# snippet:  8530
# teaser_text:  8530
# teaser_title:  8530
# href:  8530
# -----
#
# loop:  48
#
# title:  8678
# date:  8678
# snippet:  8678
# teaser_text:  8678
# teaser_title:  8678
# href:  8678
# -----
#
# loop:  49
#
# title:  8808
# date:  8808
# snippet:  8808
# teaser_text:  8808
# teaser_title:  8808
# href:  8808
# -----
#
# loop:  50
#
# title:  8954
# date:  8954
# snippet:  8954
# teaser_text:  8954
# teaser_title:  8954
# href:  8954
# -----
#
# loop:  51
#
# title:  9100
# date:  9100
# snippet:  9100
# teaser_text:  9100
# teaser_title:  9100
# href:  9100
# -----
#
# loop:  52
#
# title:  9266
# date:  9266
# snippet:  9266
# teaser_text:  9266
# teaser_title:  9266
# href:  9266
# -----

# %%
test=[]
test.append(request["matches"][0]["title"])
test
# Out:
# ["Noch 'ne Runde!"]

# %%
zeit_df = pd.DataFrame()

zeit_df['title'] = [h for h in title]
zeit_df['release_date'] = [s for s in release_date]
zeit_df['snippet'] = [data for data in snippet]
zeit_df['teaser_text'] = [data for data in teaser_text]
zeit_df['teaser_title'] = [data for data in teaser_title]
zeit_df['href'] = [h for h in href]

zeit_df
# Out:
#                                                   title          release_date  \
# 0                                       Noch 'ne Runde!  2020-03-21T19:29:55Z
# 1                       Gewinnen ist was für Verlierer?  2020-03-21T19:28:56Z
# 2                                  Corona und der Staat  2020-03-21T19:24:03Z
# 3     "Kleine Änderungen im Alltag können viel bewir...  2020-03-21T19:08:31Z
# 4     "Eigentlich wäre ich jetzt gerne bei meiner Fa...  2020-03-21T18:07:50Z
# ...                                                 ...                   ...
# 9261  Bischof Georg Bätzing kritisiert Konservative ...  2021-03-14T12:13:13Z
# 9262  Kritik an Polizei nach hartem Vorgehen bei Mah...  2021-03-14T08:55:01Z
# 9263                           Kiffen lernen von Mexiko  2021-03-14T08:54:44Z
# 9264        Zehn Antworten zum ersten Superwahltag 2021  2021-03-14T05:53:16Z
# 9265                      Lieber lügen statt meditieren  2021-03-14T05:50:54Z
#
#                                                 snippet  \
# 0      tatsächlich auch für Erwachsene nicht langwei...
# 1      mir schweigend Möglichkeiten aus, ein bessere...
# 2      dennoch nicht allzu vorsichtig sein. Denn wer...
# 3      provisorischen <em>Corona</em>-Krankenhäusern...
# 4     Eigentlich wollten sie den Sommer in Italien, ...
# ...                                                 ...
# 9261   sei sich bewusst, dass jetzt "getan oder auch...
# 9262   landesweiten Protest. Die geplante Kundgebung...
# 9263   libertäre Kraft geriert, etwa in der <em>Coro...
# 9264   Bundesländer. Ist Baden-Württemberg unter Kre...
# 9265   Kleinigkeiten, die vielleicht absurd erschein...
#
#                                             teaser_text  \
# 0     Spätestens nach einem Tag Homeoffice und Homes...
# 1     Klar ist: Wir sollen zu Hause bleiben. Dort ha...
# 2     Die Regierenden testen in der Coronakrise gese...
# 3     Du Mingjun lebt in Wuhan, dem Ursprungsort der...
# 4     Ausgangssperren, die Unis sind zu, die Flüge g...
# ...                                                 ...
# 9261  Georg Bätzing spricht sich für "dringend notwe...
# 9262  Die Mahnwache für die ermordete Sarah E. war o...
# 9263  Cannabis legalisieren, nicht nur medizinisch, ...
# 9264  In Baden-Württemberg und Rheinland-Pfalz wird ...
# 9265  Selfcare ist wichtig in dieser Pandemie, aber ...
#
#                                            teaser_title  \
# 0                                       Noch 'ne Runde!
# 1                       Gewinnen ist was für Verlierer?
# 2                                  Corona und der Staat
# 3     "Kleine Änderungen im Alltag können viel bewir...
# 4     "Eigentlich wäre ich jetzt gerne bei meiner Fa...
# ...                                                 ...
# 9261  Limburger Bischof kritisiert Konservative in k...
# 9262  Kritik an Polizei nach hartem Vorgehen bei Mah...
# 9263                           Kiffen lernen von Mexiko
# 9264        Zehn Antworten zum ersten Superwahltag 2021
# 9265                      Lieber lügen statt meditieren
#
#                                                    href
# 0     http://www.zeit.de/kultur/2020-03/gesellschaft...
# 1     http://www.zeit.de/kultur/2020-03/corona-quara...
# 2     http://www.zeit.de/kultur/2020-03/staat-ausnah...
# 3     http://www.zeit.de/gesellschaft/zeitgeschehen/...
# 4     http://www.zeit.de/campus/2020-03/auslandsseme...
# ...                                                 ...
# 9261  http://www.zeit.de/gesellschaft/2021-03/zdf-fe...
# 9262  http://www.zeit.de/gesellschaft/zeitgeschehen/...
# 9263  http://www.zeit.de/politik/deutschland/2021-03...
# 9264  http://www.zeit.de/politik/deutschland/2021-03...
# 9265  http://www.zeit.de/campus/2021-03/self-care-co...
#
# [9266 rows x 6 columns]

# %%
max(zeit_df["release_date"])
# Out:
# '2021-03-20T15:45:48Z'

# %%
zeit_df.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_corona.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "astrazeneca"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "astrazeneca", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  1
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  2
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  3
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  4
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  5
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  6
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  7
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  8
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  9
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  10
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  11
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  12
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  13
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  14
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  15
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  16
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  17
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  18
#
# title:  8
# date:  8
# snippet:  8
# teaser_text:  8
# teaser_title:  8
# href:  8
# -----
#
# loop:  19
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  20
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  21
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  22
#
# title:  15
# date:  15
# snippet:  15
# teaser_text:  15
# teaser_title:  15
# href:  15
# -----
#
# loop:  23
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  24
#
# title:  17
# date:  17
# snippet:  17
# teaser_text:  17
# teaser_title:  17
# href:  17
# -----
#
# loop:  25
#
# title:  22
# date:  22
# snippet:  22
# teaser_text:  22
# teaser_title:  22
# href:  22
# -----
#
# loop:  26
#
# title:  22
# date:  22
# snippet:  22
# teaser_text:  22
# teaser_title:  22
# href:  22
# -----
#
# loop:  27
#
# title:  23
# date:  23
# snippet:  23
# teaser_text:  23
# teaser_title:  23
# href:  23
# -----
#
# loop:  28
#
# title:  23
# date:  23
# snippet:  23
# teaser_text:  23
# teaser_title:  23
# href:  23
# -----
#
# loop:  29
#
# title:  24
# date:  24
# snippet:  24
# teaser_text:  24
# teaser_title:  24
# href:  24
# -----
#
# loop:  30
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  31
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  32
#
# title:  26
# date:  26
# snippet:  26
# teaser_text:  26
# teaser_title:  26
# href:  26
# -----
#
# loop:  33
#
# title:  26
# date:  26
# snippet:  26
# teaser_text:  26
# teaser_title:  26
# href:  26
# -----
#
# loop:  34
#
# title:  28
# date:  28
# snippet:  28
# teaser_text:  28
# teaser_title:  28
# href:  28
# -----
#
# loop:  35
#
# title:  29
# date:  29
# snippet:  29
# teaser_text:  29
# teaser_title:  29
# href:  29
# -----
#
# loop:  36
#
# title:  37
# date:  37
# snippet:  37
# teaser_text:  37
# teaser_title:  37
# href:  37
# -----
#
# loop:  37
#
# title:  40
# date:  40
# snippet:  40
# teaser_text:  40
# teaser_title:  40
# href:  40
# -----
#
# loop:  38
#
# title:  46
# date:  46
# snippet:  46
# teaser_text:  46
# teaser_title:  46
# href:  46
# -----
#
# loop:  39
#
# title:  51
# date:  51
# snippet:  51
# teaser_text:  51
# teaser_title:  51
# href:  51
# -----
#
# loop:  40
#
# title:  52
# date:  52
# snippet:  52
# teaser_text:  52
# teaser_title:  52
# href:  52
# -----
#
# loop:  41
#
# title:  57
# date:  57
# snippet:  57
# teaser_text:  57
# teaser_title:  57
# href:  57
# -----
#
# loop:  42
#
# title:  62
# date:  62
# snippet:  62
# teaser_text:  62
# teaser_title:  62
# href:  62
# -----
#
# loop:  43
#
# title:  69
# date:  69
# snippet:  69
# teaser_text:  69
# teaser_title:  69
# href:  69
# -----
#
# loop:  44
#
# title:  77
# date:  77
# snippet:  77
# teaser_text:  77
# teaser_title:  77
# href:  77
# -----
#
# loop:  45
#
# title:  111
# date:  111
# snippet:  111
# teaser_text:  111
# teaser_title:  111
# href:  111
# -----
#
# loop:  46
#
# title:  130
# date:  130
# snippet:  130
# teaser_text:  130
# teaser_title:  130
# href:  130
# -----
#
# loop:  47
#
# title:  140
# date:  140
# snippet:  140
# teaser_text:  140
# teaser_title:  140
# href:  140
# -----
#
# loop:  48
#
# title:  153
# date:  153
# snippet:  153
# teaser_text:  153
# teaser_title:  153
# href:  153
# -----
#
# loop:  49
#
# title:  166
# date:  166
# snippet:  166
# teaser_text:  166
# teaser_title:  166
# href:  166
# -----
#
# loop:  50
#
# title:  183
# date:  183
# snippet:  183
# teaser_text:  183
# teaser_title:  183
# href:  183
# -----
#
# loop:  51
#
# title:  203
# date:  203
# snippet:  203
# teaser_text:  203
# teaser_title:  203
# href:  203
# -----
#
# loop:  52
#
# title:  244
# date:  244
# snippet:  244
# teaser_text:  244
# teaser_title:  244
# href:  244
# -----

# %%
zeit_df2 = pd.DataFrame()

zeit_df2['title'] = [h for h in title]
zeit_df2['release_date'] = [s for s in release_date]
zeit_df2['snippet'] = [data for data in snippet]
zeit_df2['teaser_text'] = [data for data in teaser_text]
zeit_df2['teaser_title'] = [data for data in teaser_title]
zeit_df2['href'] = [h for h in href]

zeit_df2
# Out:
#                                                  title          release_date  \
# 0    Pfizer rechnet mit Corona-Impfstoff zuerst für...  2020-05-28T17:28:17Z
# 1         EU-Länder sichern sich Impfstoff-Lieferungen  2020-06-13T15:38:35Z
# 2    Pharmakonzern Sanofi soll bei Corona-Impfallia...  2020-06-16T14:40:40Z
# 3    Bundesregierung beteiligt sich an Impfstoffher...  2020-06-15T11:10:19Z
# 4                        Das Testlabor der ganzen Welt  2020-07-22T14:51:29Z
# ..                                                 ...                   ...
# 239  "Manche behaupteten, sie hätten ein Attest geg...  2021-03-15T13:36:29Z
# 240  EU leitet Vertragsverletzungsverfahren gegen G...  2021-03-15T13:24:56Z
# 241  Russischer Corona-Impfstoff soll in Deutschlan...  2021-03-15T11:16:34Z
# 242  Wie eine Mutter eine private Teststrategie in ...  2021-03-15T09:00:03Z
# 243  EU-Politiker droht mit Exportstopp für AstraZe...  2021-03-14T04:20:31Z
#
#                                                snippet  \
# 0     derzeit knapp ein Dutzend Wirkstoffe in klini...
# 1     der Impfstoff einsatzbereit sei, solle der Ko...
# 2     dem Hersteller <em>AstraZeneca</em> einen Ver...
# 3     Bundesgesundheitsministeriums jedoch bereits ...
# 4     Universität Oxford und dem Firmenverbund <em>...
# ..                                                 ...
# 239  Deutschland hat die Impfungen mit dem Impfstof...
# 240   zurück. Dabei geht es vor allem um das Mittel...
# 241  . Bei den bisher von der Ema zugelassenen Coro...
# 242   <em>AstraZeneca</em> stoppt Hamburg die Impft...
# 243  Der Pharmakonzern <em>AstraZeneca</em> hat mit...
#
#                                            teaser_text  \
# 0    Noch gibt es keinen Impfstoff gegen Sars-CoV-2...
# 1    Sobald ein Impfstoff einsatzbereit ist, soll d...
# 2    Frankreich will bei Impfstoffen unabhängig wer...
# 3    Das Tübinger Unternehmen bekommt Unterstützung...
# 4    Nirgendwo sind mehr Impfstoffversuche geplant ...
# ..                                                 ...
# 239  Liam Klages, 20, leitet ein Impfzentrum. Im Ge...
# 240  Im Streit um Nordirland hat die EU-Kommission ...
# 241  Russland hat nach eigenen Angaben Abkommen mit...
# 242  Und scheiterte. Außerdem: Klagen gegen Maskenp...
# 243  Zum zweiten Mal hat der Pharmakonzern die EU-S...
#
#                                           teaser_title  \
# 0    Pfizer rechnet mit Corona-Impfstoff zuerst für...
# 1         EU-Länder sichern sich Impfstoff-Lieferungen
# 2    Pharmakonzern Sanofi soll bei Corona-Impfallia...
# 3    Bundesregierung beteiligt sich an Impfstoffher...
# 4                        Das Testlabor der ganzen Welt
# ..                                                 ...
# 239  "Manche behaupteten, sie hätten ein Attest geg...
# 240  EU startet Vertragsverletzungsverfahren gegen ...
# 241  Russischer Corona-Impfstoff soll in Deutschlan...
# 242  Wie eine Mutter eine private Teststrategie in ...
# 243  EU-Politiker droht mit Exportstopp für AstraZe...
#
#                                                   href
# 0    http://www.zeit.de/wissen/gesundheit/2020-05/p...
# 1    http://www.zeit.de/wissen/gesundheit/2020-06/i...
# 2    http://www.zeit.de/wirtschaft/2020-06/frankrei...
# 3    http://www.zeit.de/wirtschaft/unternehmen/2020...
# 4    http://www.zeit.de/2020/31/coronavirus-brasili...
# ..                                                 ...
# 239  http://www.zeit.de/arbeit/2021-03/astrazeneca-...
# 240  http://www.zeit.de/politik/ausland/2021-03/bre...
# 241  http://www.zeit.de/wissen/2021-03/sputnik-v-ru...
# 242  http://www.zeit.de/hamburg/2021-03/elbvertiefu...
# 243  http://www.zeit.de/wissen/gesundheit/2021-03/a...
#
# [244 rows x 6 columns]

# %%
max(zeit_df2["release_date"])
# Out:
# '2021-03-20T17:19:40Z'

# %%
zeit_df2.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_astrazeneca.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "biontech"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "biontech", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  1
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  2
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  3
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  4
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  5
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  6
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  7
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  8
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  9
#
# title:  6
# date:  6
# snippet:  6
# teaser_text:  6
# teaser_title:  6
# href:  6
# -----
#
# loop:  10
#
# title:  6
# date:  6
# snippet:  6
# teaser_text:  6
# teaser_title:  6
# href:  6
# -----
#
# loop:  11
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  12
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  13
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  14
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  15
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  16
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  17
#
# title:  14
# date:  14
# snippet:  14
# teaser_text:  14
# teaser_title:  14
# href:  14
# -----
#
# loop:  18
#
# title:  18
# date:  18
# snippet:  18
# teaser_text:  18
# teaser_title:  18
# href:  18
# -----
#
# loop:  19
#
# title:  19
# date:  19
# snippet:  19
# teaser_text:  19
# teaser_title:  19
# href:  19
# -----
#
# loop:  20
#
# title:  19
# date:  19
# snippet:  19
# teaser_text:  19
# teaser_title:  19
# href:  19
# -----
#
# loop:  21
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  22
#
# title:  23
# date:  23
# snippet:  23
# teaser_text:  23
# teaser_title:  23
# href:  23
# -----
#
# loop:  23
#
# title:  24
# date:  24
# snippet:  24
# teaser_text:  24
# teaser_title:  24
# href:  24
# -----
#
# loop:  24
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  25
#
# title:  30
# date:  30
# snippet:  30
# teaser_text:  30
# teaser_title:  30
# href:  30
# -----
#
# loop:  26
#
# title:  33
# date:  33
# snippet:  33
# teaser_text:  33
# teaser_title:  33
# href:  33
# -----
#
# loop:  27
#
# title:  33
# date:  33
# snippet:  33
# teaser_text:  33
# teaser_title:  33
# href:  33
# -----
#
# loop:  28
#
# title:  34
# date:  34
# snippet:  34
# teaser_text:  34
# teaser_title:  34
# href:  34
# -----
#
# loop:  29
#
# title:  36
# date:  36
# snippet:  36
# teaser_text:  36
# teaser_title:  36
# href:  36
# -----
#
# loop:  30
#
# title:  36
# date:  36
# snippet:  36
# teaser_text:  36
# teaser_title:  36
# href:  36
# -----
#
# loop:  31
#
# title:  39
# date:  39
# snippet:  39
# teaser_text:  39
# teaser_title:  39
# href:  39
# -----
#
# loop:  32
#
# title:  40
# date:  40
# snippet:  40
# teaser_text:  40
# teaser_title:  40
# href:  40
# -----
#
# loop:  33
#
# title:  40
# date:  40
# snippet:  40
# teaser_text:  40
# teaser_title:  40
# href:  40
# -----
#
# loop:  34
#
# title:  56
# date:  56
# snippet:  56
# teaser_text:  56
# teaser_title:  56
# href:  56
# -----
#
# loop:  35
#
# title:  64
# date:  64
# snippet:  64
# teaser_text:  64
# teaser_title:  64
# href:  64
# -----
#
# loop:  36
#
# title:  71
# date:  71
# snippet:  71
# teaser_text:  71
# teaser_title:  71
# href:  71
# -----
#
# loop:  37
#
# title:  82
# date:  82
# snippet:  82
# teaser_text:  82
# teaser_title:  82
# href:  82
# -----
#
# loop:  38
#
# title:  98
# date:  98
# snippet:  98
# teaser_text:  98
# teaser_title:  98
# href:  98
# -----
#
# loop:  39
#
# title:  116
# date:  116
# snippet:  116
# teaser_text:  116
# teaser_title:  116
# href:  116
# -----
#
# loop:  40
#
# title:  129
# date:  129
# snippet:  129
# teaser_text:  129
# teaser_title:  129
# href:  129
# -----
#
# loop:  41
#
# title:  149
# date:  149
# snippet:  149
# teaser_text:  149
# teaser_title:  149
# href:  149
# -----
#
# loop:  42
#
# title:  175
# date:  175
# snippet:  175
# teaser_text:  175
# teaser_title:  175
# href:  175
# -----
#
# loop:  43
#
# title:  189
# date:  189
# snippet:  189
# teaser_text:  189
# teaser_title:  189
# href:  189
# -----
#
# loop:  44
#
# title:  208
# date:  208
# snippet:  208
# teaser_text:  208
# teaser_title:  208
# href:  208
# -----
#
# loop:  45
#
# title:  238
# date:  238
# snippet:  238
# teaser_text:  238
# teaser_title:  238
# href:  238
# -----
#
# loop:  46
#
# title:  258
# date:  258
# snippet:  258
# teaser_text:  258
# teaser_title:  258
# href:  258
# -----
#
# loop:  47
#
# title:  276
# date:  276
# snippet:  276
# teaser_text:  276
# teaser_title:  276
# href:  276
# -----
#
# loop:  48
#
# title:  288
# date:  288
# snippet:  288
# teaser_text:  288
# teaser_title:  288
# href:  288
# -----
#
# loop:  49
#
# title:  302
# date:  302
# snippet:  302
# teaser_text:  302
# teaser_title:  302
# href:  302
# -----
#
# loop:  50
#
# title:  313
# date:  313
# snippet:  313
# teaser_text:  313
# teaser_title:  313
# href:  313
# -----
#
# loop:  51
#
# title:  328
# date:  328
# snippet:  328
# teaser_text:  328
# teaser_title:  328
# href:  328
# -----
#
# loop:  52
#
# title:  346
# date:  346
# snippet:  346
# teaser_text:  346
# teaser_title:  346
# href:  346
# -----

# %%
zeit_df3 = pd.DataFrame()

zeit_df3['title'] = [h for h in title]
zeit_df3['release_date'] = [s for s in release_date]
zeit_df3['snippet'] = [data for data in snippet]
zeit_df3['teaser_text'] = [data for data in teaser_text]
zeit_df3['teaser_title'] = [data for data in teaser_title]
zeit_df3['href'] = [h for h in href]

zeit_df3
# Out:
#                                                  title          release_date  \
# 0                                   Warten auf Heilung  2020-03-18T16:01:00Z
# 1                                     Die Weltenretter  2020-03-25T15:53:04Z
# 2      Die wichtigsten Corona-Nachrichten vom Mittwoch  2020-04-22T15:17:50Z
# 3    Update: Ein großer Schritt auf der Suche nach ...  2020-04-22T14:50:04Z
# 4    Erste klinische Studie zu Corona-Impfstoff zug...  2020-04-22T12:46:27Z
# ..                                                 ...                   ...
# 341  Impfgipfel von Bund und Ländern auf Freitag ve...  2021-03-16T10:45:04Z
# 342  "Manche behaupteten, sie hätten ein Attest geg...  2021-03-15T13:36:29Z
# 343  Russischer Corona-Impfstoff soll in Deutschlan...  2021-03-15T11:16:34Z
# 344                            Der Sieg der Superstars  2021-03-14T20:11:27Z
# 345  EU-Politiker droht mit Exportstopp für AstraZe...  2021-03-14T04:20:31Z
#
#                                                snippet  \
# 0     Impfstoff Versäumtes nachzuholen. <em>BioNTec...
# 1     Medikamenten-Entwicklers <em>Biontech</em> su...
# 2    -Institut, mitteilte, erhält das Mainzer Unter...
# 3     <em>Biontech</em> darf ab April an Menschen g...
# 4    Erstmals darf in Deutschland ein Impfstoff geg...
# ..                                                 ...
# 341   zugelassenen Mittel von <em>BioNTech</em>/Pfi...
# 342  ?\nKlages: Erst seit etwa zwei Wochen. Wir ver...
# 343  . Bei den bisher von der Ema zugelassenen Coro...
# 344  , Heimat von <em>BioNTech</em>), führte dazu, ...
# 345  , sagte Ministerpräsidentin Manuela Schwesig (...
#
#                                            teaser_text  \
# 0    Während Covid-19 wütet, suchen Forschende welt...
# 1    Überall arbeiten Pharmafirmen an einem Mittel ...
# 2    In Deutschland ist die erste Zulassung für ein...
# 3    Das Paul-Ehrlich-Institut hat die erste zugela...
# 4    In Deutschland ist zum ersten Mal eine klinisc...
# ..                                                 ...
# 341  Wie geht es weiter mit AstraZeneca, wann impfe...
# 342  Liam Klages, 20, leitet ein Impfzentrum. Im Ge...
# 343  Russland hat nach eigenen Angaben Abkommen mit...
# 344  Sie haben die Wahlen in ihren Bundesländern fa...
# 345  Zum zweiten Mal hat der Pharmakonzern die EU-S...
#
#                                           teaser_title  \
# 0                        Kein Mittel und doch Hoffnung
# 1                                     Die Weltenretter
# 2      Die wichtigsten Corona-Nachrichten vom Mittwoch
# 3    Update: Ein großer Schritt auf der Suche nach ...
# 4    Erste klinische Studie zu Corona-Impfstoff zug...
# ..                                                 ...
# 341  Impfgipfel von Bund und Ländern auf Freitag ve...
# 342  "Manche behaupteten, sie hätten ein Attest geg...
# 343  Russischer Corona-Impfstoff soll in Deutschlan...
# 344                            Der Sieg der Superstars
# 345  EU-Politiker droht mit Exportstopp für AstraZe...
#
#                                                   href
# 0    http://www.zeit.de/2020/13/coronavirus-covid-1...
# 1    http://www.zeit.de/2020/14/impfstoff-sars-cov-...
# 2    http://www.zeit.de/gesellschaft/zeitgeschehen/...
# 3    http://www.zeit.de/politik/2020-04/corona-kris...
# 4    http://www.zeit.de/wissen/gesundheit/2020-04/c...
# ..                                                 ...
# 341  http://www.zeit.de/politik/deutschland/2021-03...
# 342  http://www.zeit.de/arbeit/2021-03/astrazeneca-...
# 343  http://www.zeit.de/wissen/2021-03/sputnik-v-ru...
# 344  http://www.zeit.de/politik/deutschland/2021-03...
# 345  http://www.zeit.de/wissen/gesundheit/2021-03/a...
#
# [346 rows x 6 columns]

# %%
max(zeit_df3["release_date"])
# Out:
# '2021-03-20T17:19:40Z'

# %%
zeit_df3.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_biontech.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "curevac"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "curevac", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  3
# date:  3
# snippet:  3
# teaser_text:  3
# teaser_title:  3
# href:  3
# -----
#
# loop:  1
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  2
#
# title:  6
# date:  6
# snippet:  6
# teaser_text:  6
# teaser_title:  6
# href:  6
# -----
#
# loop:  3
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  4
#
# title:  8
# date:  8
# snippet:  8
# teaser_text:  8
# teaser_title:  8
# href:  8
# -----
#
# loop:  5
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  6
#
# title:  10
# date:  10
# snippet:  10
# teaser_text:  10
# teaser_title:  10
# href:  10
# -----
#
# loop:  7
#
# title:  10
# date:  10
# snippet:  10
# teaser_text:  10
# teaser_title:  10
# href:  10
# -----
#
# loop:  8
#
# title:  11
# date:  11
# snippet:  11
# teaser_text:  11
# teaser_title:  11
# href:  11
# -----
#
# loop:  9
#
# title:  12
# date:  12
# snippet:  12
# teaser_text:  12
# teaser_title:  12
# href:  12
# -----
#
# loop:  10
#
# title:  12
# date:  12
# snippet:  12
# teaser_text:  12
# teaser_title:  12
# href:  12
# -----
#
# loop:  11
#
# title:  12
# date:  12
# snippet:  12
# teaser_text:  12
# teaser_title:  12
# href:  12
# -----
#
# loop:  12
#
# title:  12
# date:  12
# snippet:  12
# teaser_text:  12
# teaser_title:  12
# href:  12
# -----
#
# loop:  13
#
# title:  14
# date:  14
# snippet:  14
# teaser_text:  14
# teaser_title:  14
# href:  14
# -----
#
# loop:  14
#
# title:  15
# date:  15
# snippet:  15
# teaser_text:  15
# teaser_title:  15
# href:  15
# -----
#
# loop:  15
#
# title:  15
# date:  15
# snippet:  15
# teaser_text:  15
# teaser_title:  15
# href:  15
# -----
#
# loop:  16
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  17
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  18
#
# title:  24
# date:  24
# snippet:  24
# teaser_text:  24
# teaser_title:  24
# href:  24
# -----
#
# loop:  19
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  20
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  21
#
# title:  28
# date:  28
# snippet:  28
# teaser_text:  28
# teaser_title:  28
# href:  28
# -----
#
# loop:  22
#
# title:  30
# date:  30
# snippet:  30
# teaser_text:  30
# teaser_title:  30
# href:  30
# -----
#
# loop:  23
#
# title:  31
# date:  31
# snippet:  31
# teaser_text:  31
# teaser_title:  31
# href:  31
# -----
#
# loop:  24
#
# title:  34
# date:  34
# snippet:  34
# teaser_text:  34
# teaser_title:  34
# href:  34
# -----
#
# loop:  25
#
# title:  36
# date:  36
# snippet:  36
# teaser_text:  36
# teaser_title:  36
# href:  36
# -----
#
# loop:  26
#
# title:  38
# date:  38
# snippet:  38
# teaser_text:  38
# teaser_title:  38
# href:  38
# -----
#
# loop:  27
#
# title:  38
# date:  38
# snippet:  38
# teaser_text:  38
# teaser_title:  38
# href:  38
# -----
#
# loop:  28
#
# title:  39
# date:  39
# snippet:  39
# teaser_text:  39
# teaser_title:  39
# href:  39
# -----
#
# loop:  29
#
# title:  40
# date:  40
# snippet:  40
# teaser_text:  40
# teaser_title:  40
# href:  40
# -----
#
# loop:  30
#
# title:  40
# date:  40
# snippet:  40
# teaser_text:  40
# teaser_title:  40
# href:  40
# -----
#
# loop:  31
#
# title:  41
# date:  41
# snippet:  41
# teaser_text:  41
# teaser_title:  41
# href:  41
# -----
#
# loop:  32
#
# title:  41
# date:  41
# snippet:  41
# teaser_text:  41
# teaser_title:  41
# href:  41
# -----
#
# loop:  33
#
# title:  41
# date:  41
# snippet:  41
# teaser_text:  41
# teaser_title:  41
# href:  41
# -----
#
# loop:  34
#
# title:  45
# date:  45
# snippet:  45
# teaser_text:  45
# teaser_title:  45
# href:  45
# -----
#
# loop:  35
#
# title:  45
# date:  45
# snippet:  45
# teaser_text:  45
# teaser_title:  45
# href:  45
# -----
#
# loop:  36
#
# title:  51
# date:  51
# snippet:  51
# teaser_text:  51
# teaser_title:  51
# href:  51
# -----
#
# loop:  37
#
# title:  52
# date:  52
# snippet:  52
# teaser_text:  52
# teaser_title:  52
# href:  52
# -----
#
# loop:  38
#
# title:  55
# date:  55
# snippet:  55
# teaser_text:  55
# teaser_title:  55
# href:  55
# -----
#
# loop:  39
#
# title:  57
# date:  57
# snippet:  57
# teaser_text:  57
# teaser_title:  57
# href:  57
# -----
#
# loop:  40
#
# title:  57
# date:  57
# snippet:  57
# teaser_text:  57
# teaser_title:  57
# href:  57
# -----
#
# loop:  41
#
# title:  59
# date:  59
# snippet:  59
# teaser_text:  59
# teaser_title:  59
# href:  59
# -----
#
# loop:  42
#
# title:  61
# date:  61
# snippet:  61
# teaser_text:  61
# teaser_title:  61
# href:  61
# -----
#
# loop:  43
#
# title:  62
# date:  62
# snippet:  62
# teaser_text:  62
# teaser_title:  62
# href:  62
# -----
#
# loop:  44
#
# title:  66
# date:  66
# snippet:  66
# teaser_text:  66
# teaser_title:  66
# href:  66
# -----
#
# loop:  45
#
# title:  71
# date:  71
# snippet:  71
# teaser_text:  71
# teaser_title:  71
# href:  71
# -----
#
# loop:  46
#
# title:  77
# date:  77
# snippet:  77
# teaser_text:  77
# teaser_title:  77
# href:  77
# -----
#
# loop:  47
#
# title:  78
# date:  78
# snippet:  78
# teaser_text:  78
# teaser_title:  78
# href:  78
# -----
#
# loop:  48
#
# title:  79
# date:  79
# snippet:  79
# teaser_text:  79
# teaser_title:  79
# href:  79
# -----
#
# loop:  49
#
# title:  80
# date:  80
# snippet:  80
# teaser_text:  80
# teaser_title:  80
# href:  80
# -----
#
# loop:  50
#
# title:  80
# date:  80
# snippet:  80
# teaser_text:  80
# teaser_title:  80
# href:  80
# -----
#
# loop:  51
#
# title:  80
# date:  80
# snippet:  80
# teaser_text:  80
# teaser_title:  80
# href:  80
# -----
#
# loop:  52
#
# title:  82
# date:  82
# snippet:  82
# teaser_text:  82
# teaser_title:  82
# href:  82
# -----

# %%
zeit_df4 = pd.DataFrame()

zeit_df4['title'] = [h for h in title]
zeit_df4['release_date'] = [s for s in release_date]
zeit_df4['snippet'] = [data for data in snippet]
zeit_df4['teaser_text'] = [data for data in teaser_text]
zeit_df4['teaser_title'] = [data for data in teaser_title]
zeit_df4['href'] = [h for h in href]

zeit_df4
# Out:
#                                                 title          release_date  \
# 0                                  Warten auf Heilung  2020-03-18T16:01:00Z
# 1                                      Unsere Quellen  2020-03-18T15:50:03Z
# 2   Tübinger Impfstofffirma dementiert mögliche US...  2020-03-15T12:12:58Z
# 3                               Wege aus dem Lockdown  2020-03-26T17:00:31Z
# 4                                    Die Weltenretter  2020-03-25T15:53:04Z
# ..                                                ...                   ...
# 77  EU ordert 300 Millionen weitere Impfdosen von ...  2021-02-08T18:31:39Z
# 78  Spahn erwartet schnellere Impfung von Erzieher...  2021-02-20T19:40:02Z
# 79                             Lockern oder Lockdown?  2021-02-24T15:57:49Z
# 80               So soll das Impfchaos beendet werden  2021-03-19T20:18:48Z
# 81                  Die Odyssee des Oxford-Impfstoffs  2021-03-17T16:02:29Z
#
#                                               snippet  \
# 0    auf, die WHO listet 41 Vakzin-Kandidaten. An ...
# 1    des Verbandes forschender Arzneimittelherstel...
# 2   Das Tübinger Unternehmen <em>CureVac</em> hat ...
# 3    Ministerpräsidenten Winfried Kretschmann, in ...
# 4    Impfstoffentwicklern gehören neben Sahins Bio...
# ..                                                ...
# 77   im zweiten Quartal 2021 geliefert werden, der...
# 78  . Bei dem Präparat von Johnson & Johnson sei d...
# 79   sicher gegen die britische Variante. Der Zula...
# 80   auch die Vakzine des durch Staatsbeteiligung ...
# 81   Menschen zugelassen.\nDas verhieß dem Oxford-...
#
#                                           teaser_text  \
# 0   Während Covid-19 wütet, suchen Forschende welt...
# 1   Hier haben wir recherchiert. Dies sind die zen...
# 2   Die deutsche Firma CureVac hat Berichte über e...
# 3   Risikogruppen stärker schützen, genug OP-Maske...
# 4   Überall arbeiten Pharmafirmen an einem Mittel ...
# ..                                                ...
# 77  Die Kommission hatte es Anfang Januar angekünd...
# 78  Der Bundesgesundheitsminister rechnet damit, d...
# 79  Seit Monaten sind weite Teile des öffentlichen...
# 80  Hausärzte impfen schon nach Ostern mit, die Gr...
# 81  Probleme begleiteten AstraZeneca schon durch E...
#
#                                          teaser_title  \
# 0                       Kein Mittel und doch Hoffnung
# 1                                      Unsere Quellen
# 2   Tübinger Impfstofffirma dementiert mögliche US...
# 3                               Wege aus dem Lockdown
# 4                                    Die Weltenretter
# ..                                                ...
# 77  EU ordert 300 Millionen weitere Impfdosen von ...
# 78  Spahn erwartet schnellere Impfung von Erzieher...
# 79                             Lockern oder Lockdown?
# 80               So soll das Impfchaos beendet werden
# 81                  Die Odyssee des Oxford-Impfstoffs
#
#                                                  href
# 0   http://www.zeit.de/2020/13/coronavirus-covid-1...
# 1                       http://www.zeit.de/wq/2020-13
# 2   http://www.zeit.de/wirtschaft/unternehmen/2020...
# 3   http://www.zeit.de/wissen/gesundheit/2020-03/c...
# 4   http://www.zeit.de/2020/14/impfstoff-sars-cov-...
# ..                                                ...
# 77  http://www.zeit.de/politik/ausland/2021-02/eu-...
# 78  http://www.zeit.de/politik/deutschland/2021-02...
# 79  http://www.zeit.de/2021/09/corona-massnahmen-d...
# 80  http://www.zeit.de/politik/deutschland/2021-03...
# 81  http://www.zeit.de/2021/12/astrazeneca-impfsto...
#
# [82 rows x 6 columns]

# %%
max(zeit_df4["release_date"])
# Out:
# '2021-03-19T20:18:48Z'

# %%
zeit_df4.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_curevac.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "moderna"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "moderna", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  1
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  2
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  3
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  4
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  5
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  6
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  7
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  8
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  9
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  10
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  11
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  12
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  13
#
# title:  3
# date:  3
# snippet:  3
# teaser_text:  3
# teaser_title:  3
# href:  3
# -----
#
# loop:  14
#
# title:  3
# date:  3
# snippet:  3
# teaser_text:  3
# teaser_title:  3
# href:  3
# -----
#
# loop:  15
#
# title:  3
# date:  3
# snippet:  3
# teaser_text:  3
# teaser_title:  3
# href:  3
# -----
#
# loop:  16
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  17
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  18
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  19
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  20
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  21
#
# title:  11
# date:  11
# snippet:  11
# teaser_text:  11
# teaser_title:  11
# href:  11
# -----
#
# loop:  22
#
# title:  12
# date:  12
# snippet:  12
# teaser_text:  12
# teaser_title:  12
# href:  12
# -----
#
# loop:  23
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  24
#
# title:  14
# date:  14
# snippet:  14
# teaser_text:  14
# teaser_title:  14
# href:  14
# -----
#
# loop:  25
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  26
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  27
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  28
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  29
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  30
#
# title:  16
# date:  16
# snippet:  16
# teaser_text:  16
# teaser_title:  16
# href:  16
# -----
#
# loop:  31
#
# title:  17
# date:  17
# snippet:  17
# teaser_text:  17
# teaser_title:  17
# href:  17
# -----
#
# loop:  32
#
# title:  17
# date:  17
# snippet:  17
# teaser_text:  17
# teaser_title:  17
# href:  17
# -----
#
# loop:  33
#
# title:  17
# date:  17
# snippet:  17
# teaser_text:  17
# teaser_title:  17
# href:  17
# -----
#
# loop:  34
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  35
#
# title:  27
# date:  27
# snippet:  27
# teaser_text:  27
# teaser_title:  27
# href:  27
# -----
#
# loop:  36
#
# title:  33
# date:  33
# snippet:  33
# teaser_text:  33
# teaser_title:  33
# href:  33
# -----
#
# loop:  37
#
# title:  43
# date:  43
# snippet:  43
# teaser_text:  43
# teaser_title:  43
# href:  43
# -----
#
# loop:  38
#
# title:  53
# date:  53
# snippet:  53
# teaser_text:  53
# teaser_title:  53
# href:  53
# -----
#
# loop:  39
#
# title:  61
# date:  61
# snippet:  61
# teaser_text:  61
# teaser_title:  61
# href:  61
# -----
#
# loop:  40
#
# title:  68
# date:  68
# snippet:  68
# teaser_text:  68
# teaser_title:  68
# href:  68
# -----
#
# loop:  41
#
# title:  73
# date:  73
# snippet:  73
# teaser_text:  73
# teaser_title:  73
# href:  73
# -----
#
# loop:  42
#
# title:  86
# date:  86
# snippet:  86
# teaser_text:  86
# teaser_title:  86
# href:  86
# -----
#
# loop:  43
#
# title:  93
# date:  93
# snippet:  93
# teaser_text:  93
# teaser_title:  93
# href:  93
# -----
#
# loop:  44
#
# title:  102
# date:  102
# snippet:  102
# teaser_text:  102
# teaser_title:  102
# href:  102
# -----
#
# loop:  45
#
# title:  119
# date:  119
# snippet:  119
# teaser_text:  119
# teaser_title:  119
# href:  119
# -----
#
# loop:  46
#
# title:  128
# date:  128
# snippet:  128
# teaser_text:  128
# teaser_title:  128
# href:  128
# -----
#
# loop:  47
#
# title:  133
# date:  133
# snippet:  133
# teaser_text:  133
# teaser_title:  133
# href:  133
# -----
#
# loop:  48
#
# title:  140
# date:  140
# snippet:  140
# teaser_text:  140
# teaser_title:  140
# href:  140
# -----
#
# loop:  49
#
# title:  145
# date:  145
# snippet:  145
# teaser_text:  145
# teaser_title:  145
# href:  145
# -----
#
# loop:  50
#
# title:  151
# date:  151
# snippet:  151
# teaser_text:  151
# teaser_title:  151
# href:  151
# -----
#
# loop:  51
#
# title:  160
# date:  160
# snippet:  160
# teaser_text:  160
# teaser_title:  160
# href:  160
# -----
#
# loop:  52
#
# title:  171
# date:  171
# snippet:  171
# teaser_text:  171
# teaser_title:  171
# href:  171
# -----

# %%
zeit_df5 = pd.DataFrame()

zeit_df5['title'] = [h for h in title]
zeit_df5['release_date'] = [s for s in release_date]
zeit_df5['snippet'] = [data for data in snippet]
zeit_df5['teaser_text'] = [data for data in teaser_text]
zeit_df5['teaser_title'] = [data for data in teaser_title]
zeit_df5['href'] = [h for h in href]

zeit_df5
# Out:
#                                                  title          release_date  \
# 0                                     Die Weltenretter  2020-03-25T15:53:04Z
# 1                              Wann kommt die Impfung?  2020-04-09T11:53:18Z
# 2    Bundesregierung beteiligt sich an Impfstoffher...  2020-06-15T11:10:19Z
# 3                       Kleine Spritze, große Hoffnung  2020-07-11T14:13:55Z
# 4      US-Firma Moderna meldet ersten Impfstoff-Erfolg  2020-07-15T06:29:50Z
# ..                                                 ...                   ...
# 166                               Jetzt sind wir dran!  2021-03-17T16:01:50Z
# 167  Impfgipfel von Bund und Ländern auf Freitag ve...  2021-03-16T10:45:04Z
# 168  "Manche behaupteten, sie hätten ein Attest geg...  2021-03-15T13:36:29Z
# 169  Russischer Corona-Impfstoff soll in Deutschlan...  2021-03-15T11:16:34Z
# 170  EU-Politiker droht mit Exportstopp für AstraZe...  2021-03-14T04:20:31Z
#
#                                                snippet  \
# 0     Impfstoffentwicklern gehören neben Sahins Bio...
# 1     trägt den Namen mRNA-1273 und stammt vom US-I...
# 2     auch BioNTech und der US-Biotechkonzern <em>M...
# 3     <em>Moderna</em> will laut der New York Times...
# 4    Ein experimenteller Coronavirus-Impfstoff der ...
# ..                                                 ...
# 166   Fernsehbilder aus Europa und den USA. Auf die...
# 167   zugelassenen Mittel von BioNTech/Pfizer, <em>...
# 168  ?\nKlages: Erst seit etwa zwei Wochen. Wir ver...
# 169  . Bei den bisher von der Ema zugelassenen Coro...
# 170  , sagte Ministerpräsidentin Manuela Schwesig (...
#
#                                            teaser_text  \
# 0    Überall arbeiten Pharmafirmen an einem Mittel ...
# 1    Eine oder zwei Spritzen und man wäre immun: Di...
# 2    Das Tübinger Unternehmen bekommt Unterstützung...
# 3    In Tübingen läuft eine der ersten klinischen C...
# 4    Die Biotechfirma will einen experimentellen Co...
# ..                                                 ...
# 166  In vielen ärmeren Ländern haben die Impfungen ...
# 167  Wie geht es weiter mit AstraZeneca, wann impfe...
# 168  Liam Klages, 20, leitet ein Impfzentrum. Im Ge...
# 169  Russland hat nach eigenen Angaben Abkommen mit...
# 170  Zum zweiten Mal hat der Pharmakonzern die EU-S...
#
#                                           teaser_title  \
# 0                                     Die Weltenretter
# 1                              Wann kommt die Impfung?
# 2    Bundesregierung beteiligt sich an Impfstoffher...
# 3                       Kleine Spritze, große Hoffnung
# 4      US-Firma Moderna meldet ersten Impfstoff-Erfolg
# ..                                                 ...
# 166                               Jetzt sind wir dran!
# 167  Impfgipfel von Bund und Ländern auf Freitag ve...
# 168  "Manche behaupteten, sie hätten ein Attest geg...
# 169  Russischer Corona-Impfstoff soll in Deutschlan...
# 170  EU-Politiker droht mit Exportstopp für AstraZe...
#
#                                                   href
# 0    http://www.zeit.de/2020/14/impfstoff-sars-cov-...
# 1    http://www.zeit.de/wissen/gesundheit/2020-04/s...
# 2    http://www.zeit.de/wirtschaft/unternehmen/2020...
# 3    http://www.zeit.de/wissen/gesundheit/2020-07/c...
# 4    http://www.zeit.de/wissen/gesundheit/2020-07/c...
# ..                                                 ...
# 166  http://www.zeit.de/2021/12/globale-impfstoffve...
# 167  http://www.zeit.de/politik/deutschland/2021-03...
# 168  http://www.zeit.de/arbeit/2021-03/astrazeneca-...
# 169  http://www.zeit.de/wissen/2021-03/sputnik-v-ru...
# 170  http://www.zeit.de/wissen/gesundheit/2021-03/a...
#
# [171 rows x 6 columns]

# %%
max(zeit_df5["release_date"])
# Out:
# '2021-03-19T20:18:48Z'

# %%
zeit_df5.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_moderna.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "Johnson&johnson"

# %%
#automating request

#uuid=[]
title=[]
href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

#keys=list(request["matches"][0].keys())

#automating request

api = zeit.API()
api.set_token(KEY) #put your key in here

for t in range(len(dates_zeit)):
    
    random_i = randint(5, 10)
    time.sleep(random_i)
    print("loop: ", t)
    print()
    
    request=api.get(url = "http://api.zeit.de/content", limit = 1000, search = "Johnson&johnson", time_range=dates_zeit[t])
    
    #title += [request["matches"][i]["title"] for i in range(len(request["matches"]))]
    for i in range(len(request["matches"])):
        try:
            title.append(request["matches"][i]["title"])
        except:
            title.append("no title")
            continue
    print("title: ",len(title))

    #release_date += [request["matches"][i]["release_date"] for i in range(len(request["matches"]))]
    for j in range(len(request["matches"])):
        try:
            release_date.append(request["matches"][j]["release_date"])
        except:
            release_date.append("no date")
            continue
    print("date: ",len(release_date))
    
    #snippet += [request["matches"][i]["snippet"] for i in range(len(request["matches"]))]
    for k in range(len(request["matches"])):
        try:
            snippet.append(request["matches"][k]["snippet"])
        except:
            snippet.append("no snippet")
            continue
    print("snippet: ",len(snippet))
    
    #teaser_text += [request["matches"][i]["teaser_text"] for i in range(len(request["matches"]))]
    for l in range(len(request["matches"])):
        try:
            teaser_text.append(request["matches"][l]["teaser_text"])
        except:
            teaser_text.append("no teaser text")
            continue
    print("teaser_text: ",len(teaser_text))
    
    
    #teaser_title += [request["matches"][i]["teaser_title"] for i in range(len(request["matches"]))]
    for m in range(len(request["matches"])):
        try:
            teaser_title.append(request["matches"][m]["teaser_title"])
        except:
            teaser_title.append("no teaser title")
            continue
    print("teaser_title: ", len(teaser_title))
    
    for n in range(len(request["matches"])):
        try:
            href.append(request["matches"][n]["href"])
        except:
            href.append("no href")
            continue
    print("href: ", len(href))
    
    print("-----")
    print()
# Out:
# loop:  0
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  1
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  2
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  3
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  4
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  5
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  6
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  7
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  8
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  9
#
# title:  0
# date:  0
# snippet:  0
# teaser_text:  0
# teaser_title:  0
# href:  0
# -----
#
# loop:  10
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  11
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  12
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  13
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  14
#
# title:  1
# date:  1
# snippet:  1
# teaser_text:  1
# teaser_title:  1
# href:  1
# -----
#
# loop:  15
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  16
#
# title:  2
# date:  2
# snippet:  2
# teaser_text:  2
# teaser_title:  2
# href:  2
# -----
#
# loop:  17
#
# title:  3
# date:  3
# snippet:  3
# teaser_text:  3
# teaser_title:  3
# href:  3
# -----
#
# loop:  18
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  19
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  20
#
# title:  4
# date:  4
# snippet:  4
# teaser_text:  4
# teaser_title:  4
# href:  4
# -----
#
# loop:  21
#
# title:  5
# date:  5
# snippet:  5
# teaser_text:  5
# teaser_title:  5
# href:  5
# -----
#
# loop:  22
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  23
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  24
#
# title:  7
# date:  7
# snippet:  7
# teaser_text:  7
# teaser_title:  7
# href:  7
# -----
#
# loop:  25
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  26
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  27
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  28
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  29
#
# title:  9
# date:  9
# snippet:  9
# teaser_text:  9
# teaser_title:  9
# href:  9
# -----
#
# loop:  30
#
# title:  10
# date:  10
# snippet:  10
# teaser_text:  10
# teaser_title:  10
# href:  10
# -----
#
# loop:  31
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  32
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  33
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  34
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  35
#
# title:  13
# date:  13
# snippet:  13
# teaser_text:  13
# teaser_title:  13
# href:  13
# -----
#
# loop:  36
#
# title:  15
# date:  15
# snippet:  15
# teaser_text:  15
# teaser_title:  15
# href:  15
# -----
#
# loop:  37
#
# title:  17
# date:  17
# snippet:  17
# teaser_text:  17
# teaser_title:  17
# href:  17
# -----
#
# loop:  38
#
# title:  20
# date:  20
# snippet:  20
# teaser_text:  20
# teaser_title:  20
# href:  20
# -----
#
# loop:  39
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  40
#
# title:  21
# date:  21
# snippet:  21
# teaser_text:  21
# teaser_title:  21
# href:  21
# -----
#
# loop:  41
#
# title:  22
# date:  22
# snippet:  22
# teaser_text:  22
# teaser_title:  22
# href:  22
# -----
#
# loop:  42
#
# title:  23
# date:  23
# snippet:  23
# teaser_text:  23
# teaser_title:  23
# href:  23
# -----
#
# loop:  43
#
# title:  24
# date:  24
# snippet:  24
# teaser_text:  24
# teaser_title:  24
# href:  24
# -----
#
# loop:  44
#
# title:  25
# date:  25
# snippet:  25
# teaser_text:  25
# teaser_title:  25
# href:  25
# -----
#
# loop:  45
#
# title:  28
# date:  28
# snippet:  28
# teaser_text:  28
# teaser_title:  28
# href:  28
# -----
#
# loop:  46
#
# title:  35
# date:  35
# snippet:  35
# teaser_text:  35
# teaser_title:  35
# href:  35
# -----
#
# loop:  47
#
# title:  39
# date:  39
# snippet:  39
# teaser_text:  39
# teaser_title:  39
# href:  39
# -----
#
# loop:  48
#
# title:  44
# date:  44
# snippet:  44
# teaser_text:  44
# teaser_title:  44
# href:  44
# -----
#
# loop:  49
#
# title:  46
# date:  46
# snippet:  46
# teaser_text:  46
# teaser_title:  46
# href:  46
# -----
#
# loop:  50
#
# title:  50
# date:  50
# snippet:  50
# teaser_text:  50
# teaser_title:  50
# href:  50
# -----
#
# loop:  51
#
# title:  63
# date:  63
# snippet:  63
# teaser_text:  63
# teaser_title:  63
# href:  63
# -----
#
# loop:  52
#
# title:  70
# date:  70
# snippet:  70
# teaser_text:  70
# teaser_title:  70
# href:  70
# -----

# %%
zeit_df6 = pd.DataFrame()

zeit_df6['title'] = [h for h in title]
zeit_df6['release_date'] = [s for s in release_date]
zeit_df6['snippet'] = [data for data in snippet]
zeit_df6['teaser_text'] = [data for data in teaser_text]
zeit_df6['teaser_title'] = [data for data in teaser_title]
zeit_df6['href'] = [h for h in href]

zeit_df6
# Out:
#                                                 title          release_date  \
# 0   Pfizer rechnet mit Corona-Impfstoff zuerst für...  2020-05-28T17:28:17Z
# 1    L'Oréal verzichtet auf Werbung für Hautaufheller  2020-06-28T13:46:48Z
# 2                             Die Natur schaut nur zu  2020-07-15T14:58:57Z
# 3                                    Die Welt-Impfung  2020-07-22T14:51:10Z
# 4   US-Behörde bereitet Protokoll für Infektionsst...  2020-08-15T13:01:15Z
# ..                                                ...                   ...
# 65   Warum Weiterimpfen trotz des Risikos richtig ist  2021-03-19T10:21:38Z
# 66  Bund und Länder wollen Impfungen mit AstraZene...  2021-03-18T19:09:44Z
# 67                  Der schöne Schein des Impferfolgs  2021-03-18T04:28:38Z
# 68  Impfgipfel von Bund und Ländern auf Freitag ve...  2021-03-16T10:45:04Z
# 69  EU-Politiker droht mit Exportstopp für AstraZe...  2021-03-14T04:20:31Z
#
#                                               snippet  \
# 0   , Forschungschef des Gesundheitskonzerns <em>J...
# 1   Nach Unilever und <em>Johnson</em> & <em>Johns...
# 2    aber selbst dort, wo die Motive kippen. Denn ...
# 3    Ugur Sahins BioNTech kooperiert), <em>Johnson...
# 4    1DaySooner, die sich für Human Challenge Tria...
# ..                                                ...
# 65   als denkbare Nebenwirkung der Impfung unter V...
# 66   Dosen von Moderna eingeplant. Zudem wird wohl...
# 67   nicht. Die Konkurrenten <em>Johnson</em> & <e...
# 68   zugelassenen Mittel von BioNTech/Pfizer, Mode...
# 69  , sagte Ministerpräsidentin Manuela Schwesig (...
#
#                                           teaser_text  \
# 0   Noch gibt es keinen Impfstoff gegen Sars-CoV-2...
# 1   Jahrzehntelang verdiente der Kosmetikkonzern i...
# 2   Unbeirrt eigensinnig, sprachlich beeindruckend...
# 3   Weltweit erproben Forscher Impfstoffkandidaten...
# 4   Das staatliche Institut für Infektionskrankhei...
# ..                                                ...
# 65  Die Impfung mit AstraZeneca kann seltene Blutg...
# 66  Bundesgesundheitsminister Jens Spahn gibt den ...
# 67  Impfungen im Supermarkt und bald öffnet Disney...
# 68  Wie geht es weiter mit AstraZeneca, wann impfe...
# 69  Zum zweiten Mal hat der Pharmakonzern die EU-S...
#
#                                          teaser_title  \
# 0   Pfizer rechnet mit Corona-Impfstoff zuerst für...
# 1    L'Oréal verzichtet auf Werbung für Hautaufheller
# 2                                 Abgründiges Staunen
# 3                 Das Warten auf die rettende Impfung
# 4   US-Behörde bereitet Protokoll für Infektionsst...
# ..                                                ...
# 65   Warum Weiterimpfen trotz des Risikos richtig ist
# 66  Bund und Länder wollen Impfungen mit AstraZene...
# 67                  Der schöne Schein des Impferfolgs
# 68  Impfgipfel von Bund und Ländern auf Freitag ve...
# 69  EU-Politiker droht mit Exportstopp für AstraZe...
#
#                                                  href
# 0   http://www.zeit.de/wissen/gesundheit/2020-05/p...
# 1   http://www.zeit.de/gesellschaft/2020-06/rassis...
# 2   http://www.zeit.de/2020/30/herzklappen-von-joh...
# 3   http://www.zeit.de/2020/31/coronavirus-impstof...
# 4   http://www.zeit.de/wissen/gesundheit/2020-08/c...
# ..                                                ...
# 65  http://www.zeit.de/wissen/2021-03/astrazeneca-...
# 66  http://www.zeit.de/wissen/gesundheit/2021-03/e...
# 67  http://www.zeit.de/politik/ausland/2021-03/cor...
# 68  http://www.zeit.de/politik/deutschland/2021-03...
# 69  http://www.zeit.de/wissen/gesundheit/2021-03/a...
#
# [70 rows x 6 columns]

# %%
max(zeit_df6["release_date"])
# Out:
# '2021-03-20T17:19:40Z'

# %%
zeit_df6.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/zeit_johnson.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %%
#zeit_df=zeit
#zeit_df

# %%
title=[]
#href=[]
release_date=[]
#uri=[]
snippet=[]
#supertitle=[]
teaser_text=[]
teaser_title=[]

# %%
request["matches"][0]["subtitle"]
# Out:
# 'Spätestens nach einem Tag Homeoffice und Homeschooling haben sich alle eine Partie Spaß verdient. Die Gesellschaftsspiele-Tipps der ZEIT ONLINE-Redaktion'

# %%
import requests
import json

params = {'q' : 'keyword/corona','limit' : '10','fields' : 'subtitle, title, href, release_date, supertitle, teaser_title, teaser_text'}

url = 'http://api.zeit.de/content?'
headers = {'X-Authorization': '91b085bd0328b937cedf331bb2ac9a0bf47d6076c36fb804816f'}

r = requests.get(url, params=params, headers=headers)

json = r.json

soup = BeautifulSoup(r.content, "html.parser")
soup
# Out:
# {
#   "matches": [
#     {
#       "subtitle": "Nach ihrer \u00f6ffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.",
#       "title": "Erst Selbstkritik, dann Selbstverteidigung",
#       "href": "http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-corona-lockdown-ostern-eu-gipfel-intensivstationen",
#       "release_date": "2021-03-25T12:53:01Z",
#       "supertitle": "Angela Merkel",
#       "teaser_text": "Nach ihrer \u00f6ffentlichen Entschuldigung hat Bundeskanzlerin Angela Merkel im Bundestag wieder Tritt gefasst. Sie erinnert daran, dass auch andere Verantwortung tragen.",
#       "teaser_title": "Erst Selbstkritik, dann Selbstverteidigung"
#     },
#     {
#       "subtitle": "Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.",
#       "title": "Die Last der Erwartung",
#       "href": "http://www.zeit.de/politik/ausland/2021-03/europa-eu-von-der-leyen-corona-gipfel",
#       "release_date": "2021-03-25T12:14:24Z",
#       "supertitle": "EU-Gipfel",
#       "teaser_text": "Europapolitik gleicht einer endlosen Actionserie: Finanzkrise, Migration, Brexit, Populismus und jetzt Corona. Dass die Erfolge dabei untergehen, hat einen simplen Grund.",
#       "teaser_title": "Die Last der Erwartung"
#     },
#     {
#       "subtitle": "Die M\u00fcnchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaff\u00e4re in der Union festnehmen lassen. In Th\u00fcringer CDU-B\u00fcros gab es Durchsuchungen.",
#       "title": "Haftbefehl und eine Festnahme in der Maskenaff\u00e4re",
#       "href": "http://www.zeit.de/politik/deutschland/2021-03/haftbefehl-in-der-maskenaffaere-erlassen",
#       "release_date": "2021-03-25T11:40:50Z",
#       "supertitle": "M\u00fcnchen",
#       "teaser_text": "Die M\u00fcnchener Staatsanwaltschaft hat eine Person im Zusammenhang mit der Maskenaff\u00e4re in der Union festnehmen lassen. In Th\u00fcringer CDU-B\u00fcros gab es Durchsuchungen.",
#       "teaser_title": "Haftbefehl und Festnahme in der Maskenaff\u00e4re"
#     },
#     {
#       "subtitle": "Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.",
#       "title": "Positiver Corona-Test in der Fu\u00dfballnationalmannschaft",
#       "href": "http://www.zeit.de/sport/2021-03/dfb-corona-test-nationalmannschaft-wm-qualifikationsspiel",
#       "release_date": "2021-03-25T11:38:04Z",
#       "supertitle": "DFB",
#       "teaser_text": "Stunden vor dem WM-Qualifikationsspiel gegen Island ist ein Profi des DFB-Teams positiv getestet worden. Das Spiel soll wie geplant stattfinden.",
#       "teaser_title": "Positiver Corona-Test in der Fu\u00dfballnationalmannschaft"
#     },
#     {
#       "subtitle": "Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.",
#       "title": "Streit um Impfstoffverteilung und Exportkontrollen",
#       "href": "http://www.zeit.de/politik/2021-03/eu-gipfel-corona-impfung-impfstoff-astrazeneca-verteilung",
#       "release_date": "2021-03-25T11:24:43Z",
#       "supertitle": "EU-Gipfel",
#       "teaser_text": "Die Impfkampagne und Probleme mit Lieferungen von AstraZeneca stehen im Zentrum des virtuellen EU-Gipfels heute. Bei mehreren Themen zeichnen sich Konflikte ab.",
#       "teaser_title": "Streit um Impfstoffverteilung und Exportkontrollen"
#     },
#     {
#       "subtitle": "Die Mitbegr\u00fcnderin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht \u00fcber die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.",
#       "title": "Maja G\u00f6pel, wie k\u00f6nnen wir die Welt neu denken?",
#       "href": "http://www.zeit.de/gesellschaft/2021-03/maja-goepel-interviewpodcast-alles-gesagt",
#       "release_date": "2021-03-25T10:28:02Z",
#       "supertitle": "Maja G\u00f6pel",
#       "teaser_text": "Die Mitbegr\u00fcnderin von Scientists for Future ist zu Gast im unendlichen Podcast. Sie spricht \u00fcber die Klimakrise, den Pandemiealltag und die Zeit nach Merkel.",
#       "teaser_title": "Maja G\u00f6pel, wie k\u00f6nnen wir die Welt neu denken?"
#     },
#     {
#       "subtitle": "Das Unternehmen bem\u00fcht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie ver\u00f6ffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.",
#       "title": "AstraZeneca korrigiert Wirksamkeit seines Impfstoffes nach unten",
#       "href": "http://www.zeit.de/gesellschaft/2021-03/astrazeneca-corona-impfstoff-wirksamkeit-studien-daten-korrektur",
#       "release_date": "2021-03-25T10:03:01Z",
#       "supertitle": "Corona-Impfstoff",
#       "teaser_text": "Das Unternehmen bem\u00fcht sich in den USA um eine Zulassung und hat nun neue Daten einer Studie ver\u00f6ffentlicht. Der Impfstoff habe eine Wirksamkeit von 76 statt 79 Prozent.",
#       "teaser_title": "AstraZeneca korrigiert Wirksamkeit seines Impfstoffes nach unten"
#     },
#     {
#       "subtitle": "Ein L\u00e4ndervergleich aus gegebenem Anlass\u2002",
#       "title": "Bayern oder NRW, was ist besser?",
#       "href": "http://www.zeit.de/2021/13/bundesland-vergleich-nordrhein-westfalen-bayern-statistik",
#       "release_date": "2021-03-25T10:00:54Z",
#       "supertitle": "Bundesl\u00e4nder im Vergleich",
#       "teaser_text": "Ein L\u00e4ndervergleich aus gegebenem Anlass\u2002",
#       "teaser_title": "Bayern oder NRW, was ist besser?"
#     },
#     {
#       "subtitle": "Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept \"Housing first\".",
#       "title": "\"Wir haben zu lange geglaubt, der Markt werde das Problem l\u00f6sen\"",
#       "href": "http://www.zeit.de/gesellschaft/2021-03/nicolas-schmit-eu-kommission-obdachlosigkeit-europa-sozialpolitik",
#       "release_date": "2021-03-25T09:57:20Z",
#       "supertitle": "Nicolas Schmit",
#       "teaser_text": "Die EU-Kommission arbeitet an einer neuen Wohnungslosen-Strategie und will mehr Geld investieren. Sozialkommissar Nicolas Schmit setzt auf das Konzept Housing first.",
#       "teaser_title": "\"Wir haben zu lange geglaubt, der Markt werde das Problem l\u00f6sen\""
#     },
#     {
#       "subtitle": "Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.",
#       "title": "\"Wir werden dieses Virus besiegen\"",
#       "href": "http://www.zeit.de/politik/deutschland/2021-03/angela-merkel-regierungserklaerung-bundestag-corona",
#       "release_date": "2021-03-25T08:23:22Z",
#       "supertitle": "Regierungserkl\u00e4rung",
#       "teaser_text": "Bundeskanzlerin Angela Merkel hat trotz aller Fehler und Schwierigkeiten das Vorgehen der Regierung in der Pandemie verteidigt. Es helfe nicht, nur das Negative zu sehen.",
#       "teaser_title": "\"Wir werden dieses Virus besiegen\""
#     }
#   ],
#   "found": 9710,
#   "limit": 10,
#   "offset": 0
# }

# %%
import json
data = json.loads(soup.p.text[0])
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-e38e88f8e791> in <module>
#       1 import json
# ----> 2 data = json.loads(soup.p.text[0])
#       3 data
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(json['matches'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-437979d4ab7e> in <module>
# ----> 1 print(json['matches'])
#
# TypeError: 'method' object is not subscriptable

# %%
#lxml
soup2 = BeautifulSoup(r.text, "html.parser")
for row in soup2[0]:
    print(row)
    print("---")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-9b82ebab4777> in <module>
#       1 #lxml
#       2 soup2 = BeautifulSoup(r.text, "html.parser")
# ----> 3 for row in soup2[0]:
#       4     print(row)
#       5     print("---")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __getitem__(self, key)
#    1399         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1400         and throws an exception if it's not there."""
# -> 1401         return self.attrs[key]
#    1402
#    1403     def __iter__(self):
#
# KeyError: 0

# %%
url = 'http://api.zeit.de/keyword?q=*corona*&limit=10'

response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 401

# %%
"Corona" AND release_date:[2020-03-01T00:00:00Z TO 2021-03-24T23:59:59.999Z]

# %%
#Inhalt > section > nav > div > span > span:nth-child(2)

# %%
soup = BeautifulSoup(response.content, "html.parser")
#soup

# %%
#Beautiful Soup
#suchergebnisse > section > article:nth-child(1) > article > div > header > h2 > a > span.block.font-sansUI.font-bold.text-xl.mb-12 > span > span
#suchergebnisse > section > article:nth-child(2) > article > div > header > h2 > a > span > span.hover\:opacity-moderate.focus\:opacity-moderate > span

# %%
#Selenium
#//*[@id="suchergebnisse"]/section/article[1]/article/div/header/h2/a/span[2]/span/span

# %% [markdown]
# # spiegel-scraper
#
# https://pypi.org/project/spiegel-scraper/

# %%
#!pip install spiegel-scraper

# %%
from datetime import date
import spiegel_scraper as spon

# %%
from datetime import datetime

# %% [markdown]
# ### time period

# %%
# 2020-03-09 until 2021-03-24
from datetime import date, timedelta

dates=pd.date_range('2020-03-09','2021-03-24',freq='D').strftime("%Y-%m-%d").tolist()
len(dates)
# Out:
# 381

# %%
print(date(2020, 3, 9))
# Out:
# 2020-03-09

# %%
dates=[datetime.strptime(date, "%Y-%m-%d") for date in dates]
dates
# Out:
# [datetime.datetime(2020, 3, 9, 0, 0),
#  datetime.datetime(2020, 3, 10, 0, 0),
#  datetime.datetime(2020, 3, 11, 0, 0),
#  datetime.datetime(2020, 3, 12, 0, 0),
#  datetime.datetime(2020, 3, 13, 0, 0),
#  datetime.datetime(2020, 3, 14, 0, 0),
#  datetime.datetime(2020, 3, 15, 0, 0),
#  datetime.datetime(2020, 3, 16, 0, 0),
#  datetime.datetime(2020, 3, 17, 0, 0),
#  datetime.datetime(2020, 3, 18, 0, 0),
#  datetime.datetime(2020, 3, 19, 0, 0),
#  datetime.datetime(2020, 3, 20, 0, 0),
#  datetime.datetime(2020, 3, 21, 0, 0),
#  datetime.datetime(2020, 3, 22, 0, 0),
#  datetime.datetime(2020, 3, 23, 0, 0),
#  datetime.datetime(2020, 3, 24, 0, 0),
#  datetime.datetime(2020, 3, 25, 0, 0),
#  datetime.datetime(2020, 3, 26, 0, 0),
#  datetime.datetime(2020, 3, 27, 0, 0),
#  datetime.datetime(2020, 3, 28, 0, 0),
#  datetime.datetime(2020, 3, 29, 0, 0),
#  datetime.datetime(2020, 3, 30, 0, 0),
#  datetime.datetime(2020, 3, 31, 0, 0),
#  datetime.datetime(2020, 4, 1, 0, 0),
#  datetime.datetime(2020, 4, 2, 0, 0),
#  datetime.datetime(2020, 4, 3, 0, 0),
#  datetime.datetime(2020, 4, 4, 0, 0),
#  datetime.datetime(2020, 4, 5, 0, 0),
#  datetime.datetime(2020, 4, 6, 0, 0),
#  datetime.datetime(2020, 4, 7, 0, 0),
#  datetime.datetime(2020, 4, 8, 0, 0),
#  datetime.datetime(2020, 4, 9, 0, 0),
#  datetime.datetime(2020, 4, 10, 0, 0),
#  datetime.datetime(2020, 4, 11, 0, 0),
#  datetime.datetime(2020, 4, 12, 0, 0),
#  datetime.datetime(2020, 4, 13, 0, 0),
#  datetime.datetime(2020, 4, 14, 0, 0),
#  datetime.datetime(2020, 4, 15, 0, 0),
#  datetime.datetime(2020, 4, 16, 0, 0),
#  datetime.datetime(2020, 4, 17, 0, 0),
#  datetime.datetime(2020, 4, 18, 0, 0),
#  datetime.datetime(2020, 4, 19, 0, 0),
#  datetime.datetime(2020, 4, 20, 0, 0),
#  datetime.datetime(2020, 4, 21, 0, 0),
#  datetime.datetime(2020, 4, 22, 0, 0),
#  datetime.datetime(2020, 4, 23, 0, 0),
#  datetime.datetime(2020, 4, 24, 0, 0),
#  datetime.datetime(2020, 4, 25, 0, 0),
#  datetime.datetime(2020, 4, 26, 0, 0),
#  datetime.datetime(2020, 4, 27, 0, 0),
#  datetime.datetime(2020, 4, 28, 0, 0),
#  datetime.datetime(2020, 4, 29, 0, 0),
#  datetime.datetime(2020, 4, 30, 0, 0),
#  datetime.datetime(2020, 5, 1, 0, 0),
#  datetime.datetime(2020, 5, 2, 0, 0),
#  datetime.datetime(2020, 5, 3, 0, 0),
#  datetime.datetime(2020, 5, 4, 0, 0),
#  datetime.datetime(2020, 5, 5, 0, 0),
#  datetime.datetime(2020, 5, 6, 0, 0),
#  datetime.datetime(2020, 5, 7, 0, 0),
#  datetime.datetime(2020, 5, 8, 0, 0),
#  datetime.datetime(2020, 5, 9, 0, 0),
#  datetime.datetime(2020, 5, 10, 0, 0),
#  datetime.datetime(2020, 5, 11, 0, 0),
#  datetime.datetime(2020, 5, 12, 0, 0),
#  datetime.datetime(2020, 5, 13, 0, 0),
#  datetime.datetime(2020, 5, 14, 0, 0),
#  datetime.datetime(2020, 5, 15, 0, 0),
#  datetime.datetime(2020, 5, 16, 0, 0),
#  datetime.datetime(2020, 5, 17, 0, 0),
#  datetime.datetime(2020, 5, 18, 0, 0),
#  datetime.datetime(2020, 5, 19, 0, 0),
#  datetime.datetime(2020, 5, 20, 0, 0),
#  datetime.datetime(2020, 5, 21, 0, 0),
#  datetime.datetime(2020, 5, 22, 0, 0),
#  datetime.datetime(2020, 5, 23, 0, 0),
#  datetime.datetime(2020, 5, 24, 0, 0),
#  datetime.datetime(2020, 5, 25, 0, 0),
#  datetime.datetime(2020, 5, 26, 0, 0),
#  datetime.datetime(2020, 5, 27, 0, 0),
#  datetime.datetime(2020, 5, 28, 0, 0),
#  datetime.datetime(2020, 5, 29, 0, 0),
#  datetime.datetime(2020, 5, 30, 0, 0),
#  datetime.datetime(2020, 5, 31, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2020, 6, 2, 0, 0),
#  datetime.datetime(2020, 6, 3, 0, 0),
#  datetime.datetime(2020, 6, 4, 0, 0),
#  datetime.datetime(2020, 6, 5, 0, 0),
#  datetime.datetime(2020, 6, 6, 0, 0),
#  datetime.datetime(2020, 6, 7, 0, 0),
#  datetime.datetime(2020, 6, 8, 0, 0),
#  datetime.datetime(2020, 6, 9, 0, 0),
#  datetime.datetime(2020, 6, 10, 0, 0),
#  datetime.datetime(2020, 6, 11, 0, 0),
#  datetime.datetime(2020, 6, 12, 0, 0),
#  datetime.datetime(2020, 6, 13, 0, 0),
#  datetime.datetime(2020, 6, 14, 0, 0),
#  datetime.datetime(2020, 6, 15, 0, 0),
#  datetime.datetime(2020, 6, 16, 0, 0),
#  datetime.datetime(2020, 6, 17, 0, 0),
#  datetime.datetime(2020, 6, 18, 0, 0),
#  datetime.datetime(2020, 6, 19, 0, 0),
#  datetime.datetime(2020, 6, 20, 0, 0),
#  datetime.datetime(2020, 6, 21, 0, 0),
#  datetime.datetime(2020, 6, 22, 0, 0),
#  datetime.datetime(2020, 6, 23, 0, 0),
#  datetime.datetime(2020, 6, 24, 0, 0),
#  datetime.datetime(2020, 6, 25, 0, 0),
#  datetime.datetime(2020, 6, 26, 0, 0),
#  datetime.datetime(2020, 6, 27, 0, 0),
#  datetime.datetime(2020, 6, 28, 0, 0),
#  datetime.datetime(2020, 6, 29, 0, 0),
#  datetime.datetime(2020, 6, 30, 0, 0),
#  datetime.datetime(2020, 7, 1, 0, 0),
#  datetime.datetime(2020, 7, 2, 0, 0),
#  datetime.datetime(2020, 7, 3, 0, 0),
#  datetime.datetime(2020, 7, 4, 0, 0),
#  datetime.datetime(2020, 7, 5, 0, 0),
#  datetime.datetime(2020, 7, 6, 0, 0),
#  datetime.datetime(2020, 7, 7, 0, 0),
#  datetime.datetime(2020, 7, 8, 0, 0),
#  datetime.datetime(2020, 7, 9, 0, 0),
#  datetime.datetime(2020, 7, 10, 0, 0),
#  datetime.datetime(2020, 7, 11, 0, 0),
#  datetime.datetime(2020, 7, 12, 0, 0),
#  datetime.datetime(2020, 7, 13, 0, 0),
#  datetime.datetime(2020, 7, 14, 0, 0),
#  datetime.datetime(2020, 7, 15, 0, 0),
#  datetime.datetime(2020, 7, 16, 0, 0),
#  datetime.datetime(2020, 7, 17, 0, 0),
#  datetime.datetime(2020, 7, 18, 0, 0),
#  datetime.datetime(2020, 7, 19, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2020, 7, 22, 0, 0),
#  datetime.datetime(2020, 7, 23, 0, 0),
#  datetime.datetime(2020, 7, 24, 0, 0),
#  datetime.datetime(2020, 7, 25, 0, 0),
#  datetime.datetime(2020, 7, 26, 0, 0),
#  datetime.datetime(2020, 7, 27, 0, 0),
#  datetime.datetime(2020, 7, 28, 0, 0),
#  datetime.datetime(2020, 7, 29, 0, 0),
#  datetime.datetime(2020, 7, 30, 0, 0),
#  datetime.datetime(2020, 7, 31, 0, 0),
#  datetime.datetime(2020, 8, 1, 0, 0),
#  datetime.datetime(2020, 8, 2, 0, 0),
#  datetime.datetime(2020, 8, 3, 0, 0),
#  datetime.datetime(2020, 8, 4, 0, 0),
#  datetime.datetime(2020, 8, 5, 0, 0),
#  datetime.datetime(2020, 8, 6, 0, 0),
#  datetime.datetime(2020, 8, 7, 0, 0),
#  datetime.datetime(2020, 8, 8, 0, 0),
#  datetime.datetime(2020, 8, 9, 0, 0),
#  datetime.datetime(2020, 8, 10, 0, 0),
#  datetime.datetime(2020, 8, 11, 0, 0),
#  datetime.datetime(2020, 8, 12, 0, 0),
#  datetime.datetime(2020, 8, 13, 0, 0),
#  datetime.datetime(2020, 8, 14, 0, 0),
#  datetime.datetime(2020, 8, 15, 0, 0),
#  datetime.datetime(2020, 8, 16, 0, 0),
#  datetime.datetime(2020, 8, 17, 0, 0),
#  datetime.datetime(2020, 8, 18, 0, 0),
#  datetime.datetime(2020, 8, 19, 0, 0),
#  datetime.datetime(2020, 8, 20, 0, 0),
#  datetime.datetime(2020, 8, 21, 0, 0),
#  datetime.datetime(2020, 8, 22, 0, 0),
#  datetime.datetime(2020, 8, 23, 0, 0),
#  datetime.datetime(2020, 8, 24, 0, 0),
#  datetime.datetime(2020, 8, 25, 0, 0),
#  datetime.datetime(2020, 8, 26, 0, 0),
#  datetime.datetime(2020, 8, 27, 0, 0),
#  datetime.datetime(2020, 8, 28, 0, 0),
#  datetime.datetime(2020, 8, 29, 0, 0),
#  datetime.datetime(2020, 8, 30, 0, 0),
#  datetime.datetime(2020, 8, 31, 0, 0),
#  datetime.datetime(2020, 9, 1, 0, 0),
#  datetime.datetime(2020, 9, 2, 0, 0),
#  datetime.datetime(2020, 9, 3, 0, 0),
#  datetime.datetime(2020, 9, 4, 0, 0),
#  datetime.datetime(2020, 9, 5, 0, 0),
#  datetime.datetime(2020, 9, 6, 0, 0),
#  datetime.datetime(2020, 9, 7, 0, 0),
#  datetime.datetime(2020, 9, 8, 0, 0),
#  datetime.datetime(2020, 9, 9, 0, 0),
#  datetime.datetime(2020, 9, 10, 0, 0),
#  datetime.datetime(2020, 9, 11, 0, 0),
#  datetime.datetime(2020, 9, 12, 0, 0),
#  datetime.datetime(2020, 9, 13, 0, 0),
#  datetime.datetime(2020, 9, 14, 0, 0),
#  datetime.datetime(2020, 9, 15, 0, 0),
#  datetime.datetime(2020, 9, 16, 0, 0),
#  datetime.datetime(2020, 9, 17, 0, 0),
#  datetime.datetime(2020, 9, 18, 0, 0),
#  datetime.datetime(2020, 9, 19, 0, 0),
#  datetime.datetime(2020, 9, 20, 0, 0),
#  datetime.datetime(2020, 9, 21, 0, 0),
#  datetime.datetime(2020, 9, 22, 0, 0),
#  datetime.datetime(2020, 9, 23, 0, 0),
#  datetime.datetime(2020, 9, 24, 0, 0),
#  datetime.datetime(2020, 9, 25, 0, 0),
#  datetime.datetime(2020, 9, 26, 0, 0),
#  datetime.datetime(2020, 9, 27, 0, 0),
#  datetime.datetime(2020, 9, 28, 0, 0),
#  datetime.datetime(2020, 9, 29, 0, 0),
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2020, 10, 1, 0, 0),
#  datetime.datetime(2020, 10, 2, 0, 0),
#  datetime.datetime(2020, 10, 3, 0, 0),
#  datetime.datetime(2020, 10, 4, 0, 0),
#  datetime.datetime(2020, 10, 5, 0, 0),
#  datetime.datetime(2020, 10, 6, 0, 0),
#  datetime.datetime(2020, 10, 7, 0, 0),
#  datetime.datetime(2020, 10, 8, 0, 0),
#  datetime.datetime(2020, 10, 9, 0, 0),
#  datetime.datetime(2020, 10, 10, 0, 0),
#  datetime.datetime(2020, 10, 11, 0, 0),
#  datetime.datetime(2020, 10, 12, 0, 0),
#  datetime.datetime(2020, 10, 13, 0, 0),
#  datetime.datetime(2020, 10, 14, 0, 0),
#  datetime.datetime(2020, 10, 15, 0, 0),
#  datetime.datetime(2020, 10, 16, 0, 0),
#  datetime.datetime(2020, 10, 17, 0, 0),
#  datetime.datetime(2020, 10, 18, 0, 0),
#  datetime.datetime(2020, 10, 19, 0, 0),
#  datetime.datetime(2020, 10, 20, 0, 0),
#  datetime.datetime(2020, 10, 21, 0, 0),
#  datetime.datetime(2020, 10, 22, 0, 0),
#  datetime.datetime(2020, 10, 23, 0, 0),
#  datetime.datetime(2020, 10, 24, 0, 0),
#  datetime.datetime(2020, 10, 25, 0, 0),
#  datetime.datetime(2020, 10, 26, 0, 0),
#  datetime.datetime(2020, 10, 27, 0, 0),
#  datetime.datetime(2020, 10, 28, 0, 0),
#  datetime.datetime(2020, 10, 29, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2020, 10, 31, 0, 0),
#  datetime.datetime(2020, 11, 1, 0, 0),
#  datetime.datetime(2020, 11, 2, 0, 0),
#  datetime.datetime(2020, 11, 3, 0, 0),
#  datetime.datetime(2020, 11, 4, 0, 0),
#  datetime.datetime(2020, 11, 5, 0, 0),
#  datetime.datetime(2020, 11, 6, 0, 0),
#  datetime.datetime(2020, 11, 7, 0, 0),
#  datetime.datetime(2020, 11, 8, 0, 0),
#  datetime.datetime(2020, 11, 9, 0, 0),
#  datetime.datetime(2020, 11, 10, 0, 0),
#  datetime.datetime(2020, 11, 11, 0, 0),
#  datetime.datetime(2020, 11, 12, 0, 0),
#  datetime.datetime(2020, 11, 13, 0, 0),
#  datetime.datetime(2020, 11, 14, 0, 0),
#  datetime.datetime(2020, 11, 15, 0, 0),
#  datetime.datetime(2020, 11, 16, 0, 0),
#  datetime.datetime(2020, 11, 17, 0, 0),
#  datetime.datetime(2020, 11, 18, 0, 0),
#  datetime.datetime(2020, 11, 19, 0, 0),
#  datetime.datetime(2020, 11, 20, 0, 0),
#  datetime.datetime(2020, 11, 21, 0, 0),
#  datetime.datetime(2020, 11, 22, 0, 0),
#  datetime.datetime(2020, 11, 23, 0, 0),
#  datetime.datetime(2020, 11, 24, 0, 0),
#  datetime.datetime(2020, 11, 25, 0, 0),
#  datetime.datetime(2020, 11, 26, 0, 0),
#  datetime.datetime(2020, 11, 27, 0, 0),
#  datetime.datetime(2020, 11, 28, 0, 0),
#  datetime.datetime(2020, 11, 29, 0, 0),
#  datetime.datetime(2020, 11, 30, 0, 0),
#  datetime.datetime(2020, 12, 1, 0, 0),
#  datetime.datetime(2020, 12, 2, 0, 0),
#  datetime.datetime(2020, 12, 3, 0, 0),
#  datetime.datetime(2020, 12, 4, 0, 0),
#  datetime.datetime(2020, 12, 5, 0, 0),
#  datetime.datetime(2020, 12, 6, 0, 0),
#  datetime.datetime(2020, 12, 7, 0, 0),
#  datetime.datetime(2020, 12, 8, 0, 0),
#  datetime.datetime(2020, 12, 9, 0, 0),
#  datetime.datetime(2020, 12, 10, 0, 0),
#  datetime.datetime(2020, 12, 11, 0, 0),
#  datetime.datetime(2020, 12, 12, 0, 0),
#  datetime.datetime(2020, 12, 13, 0, 0),
#  datetime.datetime(2020, 12, 14, 0, 0),
#  datetime.datetime(2020, 12, 15, 0, 0),
#  datetime.datetime(2020, 12, 16, 0, 0),
#  datetime.datetime(2020, 12, 17, 0, 0),
#  datetime.datetime(2020, 12, 18, 0, 0),
#  datetime.datetime(2020, 12, 19, 0, 0),
#  datetime.datetime(2020, 12, 20, 0, 0),
#  datetime.datetime(2020, 12, 21, 0, 0),
#  datetime.datetime(2020, 12, 22, 0, 0),
#  datetime.datetime(2020, 12, 23, 0, 0),
#  datetime.datetime(2020, 12, 24, 0, 0),
#  datetime.datetime(2020, 12, 25, 0, 0),
#  datetime.datetime(2020, 12, 26, 0, 0),
#  datetime.datetime(2020, 12, 27, 0, 0),
#  datetime.datetime(2020, 12, 28, 0, 0),
#  datetime.datetime(2020, 12, 29, 0, 0),
#  datetime.datetime(2020, 12, 30, 0, 0),
#  datetime.datetime(2020, 12, 31, 0, 0),
#  datetime.datetime(2021, 1, 1, 0, 0),
#  datetime.datetime(2021, 1, 2, 0, 0),
#  datetime.datetime(2021, 1, 3, 0, 0),
#  datetime.datetime(2021, 1, 4, 0, 0),
#  datetime.datetime(2021, 1, 5, 0, 0),
#  datetime.datetime(2021, 1, 6, 0, 0),
#  datetime.datetime(2021, 1, 7, 0, 0),
#  datetime.datetime(2021, 1, 8, 0, 0),
#  datetime.datetime(2021, 1, 9, 0, 0),
#  datetime.datetime(2021, 1, 10, 0, 0),
#  datetime.datetime(2021, 1, 11, 0, 0),
#  datetime.datetime(2021, 1, 12, 0, 0),
#  datetime.datetime(2021, 1, 13, 0, 0),
#  datetime.datetime(2021, 1, 14, 0, 0),
#  datetime.datetime(2021, 1, 15, 0, 0),
#  datetime.datetime(2021, 1, 16, 0, 0),
#  datetime.datetime(2021, 1, 17, 0, 0),
#  datetime.datetime(2021, 1, 18, 0, 0),
#  datetime.datetime(2021, 1, 19, 0, 0),
#  datetime.datetime(2021, 1, 20, 0, 0),
#  datetime.datetime(2021, 1, 21, 0, 0),
#  datetime.datetime(2021, 1, 22, 0, 0),
#  datetime.datetime(2021, 1, 23, 0, 0),
#  datetime.datetime(2021, 1, 24, 0, 0),
#  datetime.datetime(2021, 1, 25, 0, 0),
#  datetime.datetime(2021, 1, 26, 0, 0),
#  datetime.datetime(2021, 1, 27, 0, 0),
#  datetime.datetime(2021, 1, 28, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2021, 1, 30, 0, 0),
#  datetime.datetime(2021, 1, 31, 0, 0),
#  datetime.datetime(2021, 2, 1, 0, 0),
#  datetime.datetime(2021, 2, 2, 0, 0),
#  datetime.datetime(2021, 2, 3, 0, 0),
#  datetime.datetime(2021, 2, 4, 0, 0),
#  datetime.datetime(2021, 2, 5, 0, 0),
#  datetime.datetime(2021, 2, 6, 0, 0),
#  datetime.datetime(2021, 2, 7, 0, 0),
#  datetime.datetime(2021, 2, 8, 0, 0),
#  datetime.datetime(2021, 2, 9, 0, 0),
#  datetime.datetime(2021, 2, 10, 0, 0),
#  datetime.datetime(2021, 2, 11, 0, 0),
#  datetime.datetime(2021, 2, 12, 0, 0),
#  datetime.datetime(2021, 2, 13, 0, 0),
#  datetime.datetime(2021, 2, 14, 0, 0),
#  datetime.datetime(2021, 2, 15, 0, 0),
#  datetime.datetime(2021, 2, 16, 0, 0),
#  datetime.datetime(2021, 2, 17, 0, 0),
#  datetime.datetime(2021, 2, 18, 0, 0),
#  datetime.datetime(2021, 2, 19, 0, 0),
#  datetime.datetime(2021, 2, 20, 0, 0),
#  datetime.datetime(2021, 2, 21, 0, 0),
#  datetime.datetime(2021, 2, 22, 0, 0),
#  datetime.datetime(2021, 2, 23, 0, 0),
#  datetime.datetime(2021, 2, 24, 0, 0),
#  datetime.datetime(2021, 2, 25, 0, 0),
#  datetime.datetime(2021, 2, 26, 0, 0),
#  datetime.datetime(2021, 2, 27, 0, 0),
#  datetime.datetime(2021, 2, 28, 0, 0),
#  datetime.datetime(2021, 3, 1, 0, 0),
#  datetime.datetime(2021, 3, 2, 0, 0),
#  datetime.datetime(2021, 3, 3, 0, 0),
#  datetime.datetime(2021, 3, 4, 0, 0),
#  datetime.datetime(2021, 3, 5, 0, 0),
#  datetime.datetime(2021, 3, 6, 0, 0),
#  datetime.datetime(2021, 3, 7, 0, 0),
#  datetime.datetime(2021, 3, 8, 0, 0),
#  datetime.datetime(2021, 3, 9, 0, 0),
#  datetime.datetime(2021, 3, 10, 0, 0),
#  datetime.datetime(2021, 3, 11, 0, 0),
#  datetime.datetime(2021, 3, 12, 0, 0),
#  datetime.datetime(2021, 3, 13, 0, 0),
#  datetime.datetime(2021, 3, 14, 0, 0),
#  datetime.datetime(2021, 3, 15, 0, 0),
#  datetime.datetime(2021, 3, 16, 0, 0),
#  datetime.datetime(2021, 3, 17, 0, 0),
#  datetime.datetime(2021, 3, 18, 0, 0),
#  datetime.datetime(2021, 3, 19, 0, 0),
#  datetime.datetime(2021, 3, 20, 0, 0),
#  datetime.datetime(2021, 3, 21, 0, 0),
#  datetime.datetime(2021, 3, 22, 0, 0),
#  datetime.datetime(2021, 3, 23, 0, 0),
#  datetime.datetime(2021, 3, 24, 0, 0)]

# %% [markdown]
# ### Test on 2020-03-09

# %%
#archive_html = spon.archive.html_by_date(date(2020, 3, 9))
archive_entries_from_html = spon.archive.scrape_html(spon.archive.html_by_date(dates[0]))

# %%
spiegel_keys=archive_entries_from_html[0].keys()

# %%
len(archive_entries_from_html)
# Out:
# 114

# %%
#for i in range(len(archive_entries_from_html)):
    #print(archive_entries_from_html[i]["url"])

# %%
url = [archive_entries_from_html[i]["url"] for i in range(len(archive_entries_from_html))]
#print(url)

# %%
date_published = [archive_entries_from_html[i]["date_published"] for i in range(len(archive_entries_from_html))]
date_published
# Out:
# [datetime.datetime(2020, 3, 9, 23, 28),
#  datetime.datetime(2020, 3, 9, 23, 21),
#  datetime.datetime(2020, 3, 9, 22, 54),
#  datetime.datetime(2020, 3, 9, 22, 26),
#  datetime.datetime(2020, 3, 9, 21, 57),
#  datetime.datetime(2020, 3, 9, 21, 54),
#  datetime.datetime(2020, 3, 9, 21, 43),
#  datetime.datetime(2020, 3, 9, 21, 24),
#  datetime.datetime(2020, 3, 9, 20, 53),
#  datetime.datetime(2020, 3, 9, 20, 46),
#  datetime.datetime(2020, 3, 9, 20, 33),
#  datetime.datetime(2020, 3, 9, 20, 28),
#  datetime.datetime(2020, 3, 9, 20, 21),
#  datetime.datetime(2020, 3, 9, 20, 18),
#  datetime.datetime(2020, 3, 9, 20, 14),
#  datetime.datetime(2020, 3, 9, 20, 3),
#  datetime.datetime(2020, 3, 9, 19, 55),
#  datetime.datetime(2020, 3, 9, 19, 39),
#  datetime.datetime(2020, 3, 9, 19, 30),
#  datetime.datetime(2020, 3, 9, 19, 27),
#  datetime.datetime(2020, 3, 9, 19, 11),
#  datetime.datetime(2020, 3, 9, 19, 4),
#  datetime.datetime(2020, 3, 9, 18, 36),
#  datetime.datetime(2020, 3, 9, 18, 17),
#  datetime.datetime(2020, 3, 9, 18, 13),
#  datetime.datetime(2020, 3, 9, 18, 8),
#  datetime.datetime(2020, 3, 9, 17, 58),
#  datetime.datetime(2020, 3, 9, 17, 55),
#  datetime.datetime(2020, 3, 9, 17, 50),
#  datetime.datetime(2020, 3, 9, 17, 46),
#  datetime.datetime(2020, 3, 9, 17, 33),
#  datetime.datetime(2020, 3, 9, 17, 28),
#  datetime.datetime(2020, 3, 9, 17, 16),
#  datetime.datetime(2020, 3, 9, 17, 14),
#  datetime.datetime(2020, 3, 9, 17, 8),
#  datetime.datetime(2020, 3, 9, 17, 2),
#  datetime.datetime(2020, 3, 9, 16, 46),
#  datetime.datetime(2020, 3, 9, 16, 45),
#  datetime.datetime(2020, 3, 9, 16, 39),
#  datetime.datetime(2020, 3, 9, 16, 36),
#  datetime.datetime(2020, 3, 9, 16, 31),
#  datetime.datetime(2020, 3, 9, 16, 13),
#  datetime.datetime(2020, 3, 9, 16, 8),
#  datetime.datetime(2020, 3, 9, 16, 5),
#  datetime.datetime(2020, 3, 9, 15, 48),
#  datetime.datetime(2020, 3, 9, 15, 47),
#  datetime.datetime(2020, 3, 9, 15, 44),
#  datetime.datetime(2020, 3, 9, 15, 36),
#  datetime.datetime(2020, 3, 9, 15, 21),
#  datetime.datetime(2020, 3, 9, 15, 12),
#  datetime.datetime(2020, 3, 9, 15, 10),
#  datetime.datetime(2020, 3, 9, 15, 7),
#  datetime.datetime(2020, 3, 9, 14, 57),
#  datetime.datetime(2020, 3, 9, 14, 56),
#  datetime.datetime(2020, 3, 9, 14, 42),
#  datetime.datetime(2020, 3, 9, 14, 36),
#  datetime.datetime(2020, 3, 9, 14, 29),
#  datetime.datetime(2020, 3, 9, 14, 29),
#  datetime.datetime(2020, 3, 9, 14, 21),
#  datetime.datetime(2020, 3, 9, 14, 9),
#  datetime.datetime(2020, 3, 9, 13, 47),
#  datetime.datetime(2020, 3, 9, 13, 38),
#  datetime.datetime(2020, 3, 9, 13, 36),
#  datetime.datetime(2020, 3, 9, 13, 28),
#  datetime.datetime(2020, 3, 9, 13, 7),
#  datetime.datetime(2020, 3, 9, 13, 1),
#  datetime.datetime(2020, 3, 9, 12, 58),
#  datetime.datetime(2020, 3, 9, 12, 58),
#  datetime.datetime(2020, 3, 9, 12, 47),
#  datetime.datetime(2020, 3, 9, 12, 41),
#  datetime.datetime(2020, 3, 9, 12, 40),
#  datetime.datetime(2020, 3, 9, 12, 37),
#  datetime.datetime(2020, 3, 9, 12, 36),
#  datetime.datetime(2020, 3, 9, 12, 30),
#  datetime.datetime(2020, 3, 9, 12, 29),
#  datetime.datetime(2020, 3, 9, 12, 26),
#  datetime.datetime(2020, 3, 9, 11, 55),
#  datetime.datetime(2020, 3, 9, 11, 49),
#  datetime.datetime(2020, 3, 9, 11, 48),
#  datetime.datetime(2020, 3, 9, 11, 32),
#  datetime.datetime(2020, 3, 9, 11, 19),
#  datetime.datetime(2020, 3, 9, 11, 17),
#  datetime.datetime(2020, 3, 9, 10, 52),
#  datetime.datetime(2020, 3, 9, 10, 51),
#  datetime.datetime(2020, 3, 9, 10, 21),
#  datetime.datetime(2020, 3, 9, 10, 12),
#  datetime.datetime(2020, 3, 9, 10, 9),
#  datetime.datetime(2020, 3, 9, 10, 4),
#  datetime.datetime(2020, 3, 9, 9, 39),
#  datetime.datetime(2020, 3, 9, 9, 38),
#  datetime.datetime(2020, 3, 9, 9, 38),
#  datetime.datetime(2020, 3, 9, 9, 17),
#  datetime.datetime(2020, 3, 9, 8, 26),
#  datetime.datetime(2020, 3, 9, 7, 49),
#  datetime.datetime(2020, 3, 9, 7, 44),
#  datetime.datetime(2020, 3, 9, 7, 23),
#  datetime.datetime(2020, 3, 9, 7, 12),
#  datetime.datetime(2020, 3, 9, 6, 49),
#  datetime.datetime(2020, 3, 9, 6, 44),
#  datetime.datetime(2020, 3, 9, 6, 35),
#  datetime.datetime(2020, 3, 9, 5, 48),
#  datetime.datetime(2020, 3, 9, 5, 37),
#  datetime.datetime(2020, 3, 9, 4, 52),
#  datetime.datetime(2020, 3, 9, 4, 48),
#  datetime.datetime(2020, 3, 9, 3, 13),
#  datetime.datetime(2020, 3, 9, 2, 37),
#  datetime.datetime(2020, 3, 9, 1, 54),
#  datetime.datetime(2020, 3, 9, 0, 28),
#  datetime.datetime(2020, 3, 9, 0, 23),
#  datetime.datetime(2020, 3, 9, 0, 13),
#  datetime.datetime(2020, 3, 9, 0, 11),
#  datetime.datetime(2020, 3, 9, 0, 9),
#  datetime.datetime(2020, 3, 9, 0, 8),
#  datetime.datetime(2020, 3, 9, 0, 6)]

# %%
spiegel = pd.DataFrame()
spiegel['date_published'] = [date.strftime("%Y-%m-%d") for date in date_published]

# %%
date_published[0].strftime("%Y-%m-%d")
# Out:
# '2020-03-09'

# %% [markdown]
# ### Scraping data

# %%
url = []
headline = []
is_paid = []
date_published = []
channel = []

for date in dates:
    random_i = randint(5, 20)
    time.sleep(random_i)
    
    print()
    print(date)
    
    archive_entries_from_html = spon.archive.scrape_html(spon.archive.html_by_date(date))
    print()
    
    url += [archive_entries_from_html[i]["url"] for i in range(len(archive_entries_from_html))]
    headline += [archive_entries_from_html[i]["headline"] for i in range(len(archive_entries_from_html))]
    is_paid += [archive_entries_from_html[i]["is_paid"] for i in range(len(archive_entries_from_html))]
    date_published += [archive_entries_from_html[i]["date_published"] for i in range(len(archive_entries_from_html))]
    channel += [archive_entries_from_html[i]["channel"] for i in range(len(archive_entries_from_html))]
    print(len(channel))
# Out:
# 2020-03-09 00:00:00
#
# 114
#
# 2020-03-10 00:00:00
#
# 228
#
# 2020-03-11 00:00:00
#
# 363
#
# 2020-03-12 00:00:00
#
# 497
#
# 2020-03-13 00:00:00
#
# 670
#
# 2020-03-14 00:00:00
#
# 733
#
# 2020-03-15 00:00:00
#
# 797
#
# 2020-03-16 00:00:00
#
# 912
#
# 2020-03-17 00:00:00
#
# 1050
#
# 2020-03-18 00:00:00
#
# 1186
#
# 2020-03-19 00:00:00
#
# 1323
#
# 2020-03-20 00:00:00
#
# 1470
#
# 2020-03-21 00:00:00
#
# 1534
#
# 2020-03-22 00:00:00
#
# 1590
#
# 2020-03-23 00:00:00
#
# 1716
#
# 2020-03-24 00:00:00
#
# 1848
#
# 2020-03-25 00:00:00
#
# 1974
#
# 2020-03-26 00:00:00
#
# 2103
#
# 2020-03-27 00:00:00
#
# 2275
#
# 2020-03-28 00:00:00
#
# 2343
#
# 2020-03-29 00:00:00
#
# 2400
#
# 2020-03-30 00:00:00
#
# 2503
#
# 2020-03-31 00:00:00
#
# 2601
#
# 2020-04-01 00:00:00
#
# 2717
#
# 2020-04-02 00:00:00
#
# 2840
#
# 2020-04-03 00:00:00
#
# 3019
#
# 2020-04-04 00:00:00
#
# 3088
#
# 2020-04-05 00:00:00
#
# 3154
#
# 2020-04-06 00:00:00
#
# 3257
#
# 2020-04-07 00:00:00
#
# 3386
#
# 2020-04-08 00:00:00
#
# 3509
#
# 2020-04-09 00:00:00
#
# 3635
#
# 2020-04-10 00:00:00
#
# 3754
#
# 2020-04-11 00:00:00
#
# 3826
#
# 2020-04-12 00:00:00
#
# 3887
#
# 2020-04-13 00:00:00
#
# 3950
#
# 2020-04-14 00:00:00
#
# 4061
#
# 2020-04-15 00:00:00
#
# 4161
#
# 2020-04-16 00:00:00
#
# 4285
#
# 2020-04-17 00:00:00
#
# 4456
#
# 2020-04-18 00:00:00
#
# 4527
#
# 2020-04-19 00:00:00
#
# 4596
#
# 2020-04-20 00:00:00
#
# 4700
#
# 2020-04-21 00:00:00
#
# 4829
#
# 2020-04-22 00:00:00
#
# 4942
#
# 2020-04-23 00:00:00
#
# 5081
#
# 2020-04-24 00:00:00
#
# 5274
#
# 2020-04-25 00:00:00
#
# 5338
#
# 2020-04-26 00:00:00
#
# 5405
#
# 2020-04-27 00:00:00
#
# 5526
#
# 2020-04-28 00:00:00
#
# 5646
#
# 2020-04-29 00:00:00
#
# 5785
#
# 2020-04-30 00:00:00
#
# 5928
#
# 2020-05-01 00:00:00
#
# 6039
#
# 2020-05-02 00:00:00
#
# 6107
#
# 2020-05-03 00:00:00
#
# 6169
#
# 2020-05-04 00:00:00
#
# 6288
#
# 2020-05-05 00:00:00
#
# 6410
#
# 2020-05-06 00:00:00
#
# 6533
#
# 2020-05-07 00:00:00
#
# 6670
#
# 2020-05-08 00:00:00
#
# 6822
#
# 2020-05-09 00:00:00
#
# 6891
#
# 2020-05-10 00:00:00
#
# 6956
#
# 2020-05-11 00:00:00
#
# 7064
#
# 2020-05-12 00:00:00
#
# 7184
#
# 2020-05-13 00:00:00
#
# 7313
#
# 2020-05-14 00:00:00
#
# 7449
#
# 2020-05-15 00:00:00
#
# 7618
#
# 2020-05-16 00:00:00
#
# 7681
#
# 2020-05-17 00:00:00
#
# 7753
#
# 2020-05-18 00:00:00
#
# 7868
#
# 2020-05-19 00:00:00
#
# 7985
#
# 2020-05-20 00:00:00
#
# 8106
#
# 2020-05-21 00:00:00
#
# 8183
#
# 2020-05-22 00:00:00
#
# 8338
#
# 2020-05-23 00:00:00
#
# 8417
#
# 2020-05-24 00:00:00
#
# 8484
#
# 2020-05-25 00:00:00
#
# 8590
#
# 2020-05-26 00:00:00
#
# 8701
#
# 2020-05-27 00:00:00
#
# 8824
#
# 2020-05-28 00:00:00
#
# 8949
#
# 2020-05-29 00:00:00
#
# 9103
#
# 2020-05-30 00:00:00
#
# 9183
#
# 2020-05-31 00:00:00
#
# 9266
#
# 2020-06-01 00:00:00
#
# 9324
#
# 2020-06-02 00:00:00
#
# 9423
#
# 2020-06-03 00:00:00
#
# 9530
#
# 2020-06-04 00:00:00
#
# 9644
#
# 2020-06-05 00:00:00
#
# 9809
#
# 2020-06-06 00:00:00
#
# 9877
#
# 2020-06-07 00:00:00
#
# 9955
#
# 2020-06-08 00:00:00
#
# 10059
#
# 2020-06-09 00:00:00
#
# 10167
#
# 2020-06-10 00:00:00
#
# 10295
#
# 2020-06-11 00:00:00
#
# 10413
#
# 2020-06-12 00:00:00
#
# 10569
#
# 2020-06-13 00:00:00
#
# 10642
#
# 2020-06-14 00:00:00
#
# 10714
#
# 2020-06-15 00:00:00
#
# 10816
#
# 2020-06-16 00:00:00
#
# 10949
#
# 2020-06-17 00:00:00
#
# 11073
#
# 2020-06-18 00:00:00
#
# 11201
#
# 2020-06-19 00:00:00
#
# 11359
#
# 2020-06-20 00:00:00
#
# 11431
#
# 2020-06-21 00:00:00
#
# 11508
#
# 2020-06-22 00:00:00
#
# 11612
#
# 2020-06-23 00:00:00
#
# 11729
#
# 2020-06-24 00:00:00
#
# 11833
#
# 2020-06-25 00:00:00
#
# 11961
#
# 2020-06-26 00:00:00
#
# 12111
#
# 2020-06-27 00:00:00
#
# 12173
#
# 2020-06-28 00:00:00
#
# 12244
#
# 2020-06-29 00:00:00
#
# 12346
#
# 2020-06-30 00:00:00
#
# 12464
#
# 2020-07-01 00:00:00
#
# 12571
#
# 2020-07-02 00:00:00
#
# 12693
#
# 2020-07-03 00:00:00
#
# 12840
#
# 2020-07-04 00:00:00
#
# 12910
#
# 2020-07-05 00:00:00
#
# 12971
#
# 2020-07-06 00:00:00
#
# 13075
#
# 2020-07-07 00:00:00
#
# 13192
#
# 2020-07-08 00:00:00
#
# 13294
#
# 2020-07-09 00:00:00
#
# 13399
#
# 2020-07-10 00:00:00
#
# 13548
#
# 2020-07-11 00:00:00
#
# 13618
#
# 2020-07-12 00:00:00
#
# 13683
#
# 2020-07-13 00:00:00
#
# 13780
#
# 2020-07-14 00:00:00
#
# 13887
#
# 2020-07-15 00:00:00
#
# 13991
#
# 2020-07-16 00:00:00
#
# 14089
#
# 2020-07-17 00:00:00
#
# 14235
#
# 2020-07-18 00:00:00
#
# 14294
#
# 2020-07-19 00:00:00
#
# 14363
#
# 2020-07-20 00:00:00
#
# 14466
#
# 2020-07-21 00:00:00
#
# 14579
#
# 2020-07-22 00:00:00
#
# 14681
#
# 2020-07-23 00:00:00
#
# 14798
#
# 2020-07-24 00:00:00
#
# 14935
#
# 2020-07-25 00:00:00
#
# 15005
#
# 2020-07-26 00:00:00
#
# 15091
#
# 2020-07-27 00:00:00
#
# 15194
#
# 2020-07-28 00:00:00
#
# 15309
#
# 2020-07-29 00:00:00
#
# 15410
#
# 2020-07-30 00:00:00
#
# 15511
#
# 2020-07-31 00:00:00
#
# 15660
#
# 2020-08-01 00:00:00
#
# 15732
#
# 2020-08-02 00:00:00
#
# 15804
#
# 2020-08-03 00:00:00
#
# 15900
#
# 2020-08-04 00:00:00
#
# 16002
#
# 2020-08-05 00:00:00
#
# 16112
#
# 2020-08-06 00:00:00
#
# 16218
#
# 2020-08-07 00:00:00
#
# 16390
#
# 2020-08-08 00:00:00
#
# 16460
#
# 2020-08-09 00:00:00
#
# 16521
#
# 2020-08-10 00:00:00
#
# 16623
#
# 2020-08-11 00:00:00
#
# 16718
#
# 2020-08-12 00:00:00
#
# 16832
#
# 2020-08-13 00:00:00
#
# 16967
#
# 2020-08-14 00:00:00
#
# 17076
#
# 2020-08-15 00:00:00
#
# 17151
#
# 2020-08-16 00:00:00
#
# 17223
#
# 2020-08-17 00:00:00
#
# 17325
#
# 2020-08-18 00:00:00
#
# 17437
#
# 2020-08-19 00:00:00
#
# 17557
#
# 2020-08-20 00:00:00
#
# 17681
#
# 2020-08-21 00:00:00
#
# 17834
#
# 2020-08-22 00:00:00
#
# 17893
#
# 2020-08-23 00:00:00
#
# 17959
#
# 2020-08-24 00:00:00
#
# 18066
#
# 2020-08-25 00:00:00
#
# 18180
#
# 2020-08-26 00:00:00
#
# 18289
#
# 2020-08-27 00:00:00
#
# 18412
#
# 2020-08-28 00:00:00
#
# 18568
#
# 2020-08-29 00:00:00
#
# 18643
#
# 2020-08-30 00:00:00
#
# 18708
#
# 2020-08-31 00:00:00
#
# 18818
#
# 2020-09-01 00:00:00
#
# 18939
#
# 2020-09-02 00:00:00
#
# 19057
#
# 2020-09-03 00:00:00
#
# 19179
#
# 2020-09-04 00:00:00
#
# 19334
#
# 2020-09-05 00:00:00
#
# 19398
#
# 2020-09-06 00:00:00
#
# 19466
#
# 2020-09-07 00:00:00
#
# 19568
#
# 2020-09-08 00:00:00
#
# 19694
#
# 2020-09-09 00:00:00
#
# 19822
#
# 2020-09-10 00:00:00
#
# 19941
#
# 2020-09-11 00:00:00
#
# 20103
#
# 2020-09-12 00:00:00
#
# 20187
#
# 2020-09-13 00:00:00
#
# 20268
#
# 2020-09-14 00:00:00
#
# 20377
#
# 2020-09-15 00:00:00
#
# 20491
#
# 2020-09-16 00:00:00
#
# 20600
#
# 2020-09-17 00:00:00
#
# 20703
#
# 2020-09-18 00:00:00
#
# 20868
#
# 2020-09-19 00:00:00
#
# 20948
#
# 2020-09-20 00:00:00
#
# 21027
#
# 2020-09-21 00:00:00
#
# 21123
#
# 2020-09-22 00:00:00
#
# 21231
#
# 2020-09-23 00:00:00
#
# 21360
#
# 2020-09-24 00:00:00
#
# 21476
#
# 2020-09-25 00:00:00
#
# 21636
#
# 2020-09-26 00:00:00
#
# 21713
#
# 2020-09-27 00:00:00
#
# 21796
#
# 2020-09-28 00:00:00
#
# 21913
#
# 2020-09-29 00:00:00
#
# 22048
#
# 2020-09-30 00:00:00
#
# 22179
#
# 2020-10-01 00:00:00
#
# 22333
#
# 2020-10-02 00:00:00
#
# 22448
#
# 2020-10-03 00:00:00
#
# 22522
#
# 2020-10-04 00:00:00
#
# 22592
#
# 2020-10-05 00:00:00
#
# 22690
#
# 2020-10-06 00:00:00
#
# 22801
#
# 2020-10-07 00:00:00
#
# 22926
#
# 2020-10-08 00:00:00
#
# 23038
#
# 2020-10-09 00:00:00
#
# 23191
#
# 2020-10-10 00:00:00
#
# 23252
#
# 2020-10-11 00:00:00
#
# 23316
#
# 2020-10-12 00:00:00
#
# 23425
#
# 2020-10-13 00:00:00
#
# 23533
#
# 2020-10-14 00:00:00
#
# 23626
#
# 2020-10-15 00:00:00
#
# 23734
#
# 2020-10-16 00:00:00
#
# 23888
#
# 2020-10-17 00:00:00
#
# 23963
#
# 2020-10-18 00:00:00
#
# 24028
#
# 2020-10-19 00:00:00
#
# 24124
#
# 2020-10-20 00:00:00
#
# 24224
#
# 2020-10-21 00:00:00
#
# 24340
#
# 2020-10-22 00:00:00
#
# 24469
#
# 2020-10-23 00:00:00
#
# 24631
#
# 2020-10-24 00:00:00
#
# 24699
#
# 2020-10-25 00:00:00
#
# 24775
#
# 2020-10-26 00:00:00
#
# 24883
#
# 2020-10-27 00:00:00
#
# 25006
#
# 2020-10-28 00:00:00
#
# 25141
#
# 2020-10-29 00:00:00
#
# 25295
#
# 2020-10-30 00:00:00
#
# 25419
#
# 2020-10-31 00:00:00
#
# 25508
#
# 2020-11-01 00:00:00
#
# 25571
#
# 2020-11-02 00:00:00
#
# 25682
#
# 2020-11-03 00:00:00
#
# 25832
#
# 2020-11-04 00:00:00
#
# 25977
#
# 2020-11-05 00:00:00
#
# 26095
#
# 2020-11-06 00:00:00
#
# 26242
#
# 2020-11-07 00:00:00
#
# 26332
#
# 2020-11-08 00:00:00
#
# 26419
#
# 2020-11-09 00:00:00
#
# 26541
#
# 2020-11-10 00:00:00
#
# 26660
#
# 2020-11-11 00:00:00
#
# 26786
#
# 2020-11-12 00:00:00
#
# 26917
#
# 2020-11-13 00:00:00
#
# 27068
#
# 2020-11-14 00:00:00
#
# 27144
#
# 2020-11-15 00:00:00
#
# 27219
#
# 2020-11-16 00:00:00
#
# 27319
#
# 2020-11-17 00:00:00
#
# 27430
#
# 2020-11-18 00:00:00
#
# 27550
#
# 2020-11-19 00:00:00
#
# 27664
#
# 2020-11-20 00:00:00
#
# 27805
#
# 2020-11-21 00:00:00
#
# 27882
#
# 2020-11-22 00:00:00
#
# 27941
#
# 2020-11-23 00:00:00
#
# 28059
#
# 2020-11-24 00:00:00
#
# 28180
#
# 2020-11-25 00:00:00
#
# 28288
#
# 2020-11-26 00:00:00
#
# 28400
#
# 2020-11-27 00:00:00
#
# 28545
#
# 2020-11-28 00:00:00
#
# 28640
#
# 2020-11-29 00:00:00
#
# 28730
#
# 2020-11-30 00:00:00
#
# 28833
#
# 2020-12-01 00:00:00
#
# 28943
#
# 2020-12-02 00:00:00
#
# 29065
#
# 2020-12-03 00:00:00
#
# 29198
#
# 2020-12-04 00:00:00
#
# 29355
#
# 2020-12-05 00:00:00
#
# 29430
#
# 2020-12-06 00:00:00
#
# 29505
#
# 2020-12-07 00:00:00
#
# 29616
#
# 2020-12-08 00:00:00
#
# 29747
#
# 2020-12-09 00:00:00
#
# 29858
#
# 2020-12-10 00:00:00
#
# 29986
#
# 2020-12-11 00:00:00
#
# 30134
#
# 2020-12-12 00:00:00
#
# 30216
#
# 2020-12-13 00:00:00
#
# 30287
#
# 2020-12-14 00:00:00
#
# 30407
#
# 2020-12-15 00:00:00
#
# 30539
#
# 2020-12-16 00:00:00
#
# 30657
#
# 2020-12-17 00:00:00
#
# 30782
#
# 2020-12-18 00:00:00
#
# 30934
#
# 2020-12-19 00:00:00
#
# 31007
#
# 2020-12-20 00:00:00
#
# 31075
#
# 2020-12-21 00:00:00
#
# 31172
#
# 2020-12-22 00:00:00
#
# 31288
#
# 2020-12-23 00:00:00
#
# 31429
#
# 2020-12-24 00:00:00
#
# 31482
#
# 2020-12-25 00:00:00
#
# 31533
#
# 2020-12-26 00:00:00
#
# 31600
#
# 2020-12-27 00:00:00
#
# 31664
#
# 2020-12-28 00:00:00
#
# 31767
#
# 2020-12-29 00:00:00
#
# 31876
#
# 2020-12-30 00:00:00
# 31965
#
# 2020-12-31 00:00:00
#
# 32077
#
# 2021-01-01 00:00:00
#
# 32133
#
# 2021-01-02 00:00:00
#
# 32199
#
# 2021-01-03 00:00:00
#
# 32260
#
# 2021-01-04 00:00:00
#
# 32359
#
# 2021-01-05 00:00:00
#
# 32463
#
# 2021-01-06 00:00:00
#
# 32588
#
# 2021-01-07 00:00:00
#
# 32720
#
# 2021-01-08 00:00:00
#
# 32860
#
# 2021-01-09 00:00:00
#
# 32933
#
# 2021-01-10 00:00:00
#
# 33004
#
# 2021-01-11 00:00:00
#
# 33113
#
# 2021-01-12 00:00:00
#
# 33242
#
# 2021-01-13 00:00:00
#
# 33367
#
# 2021-01-14 00:00:00
#
# 33505
#
# 2021-01-15 00:00:00
#
# 33669
#
# 2021-01-16 00:00:00
#
# 33749
#
# 2021-01-17 00:00:00
#
# 33838
#
# 2021-01-18 00:00:00
#
# 33962
#
# 2021-01-19 00:00:00
#
# 34077
#
# 2021-01-20 00:00:00
#
# 34188
#
# 2021-01-21 00:00:00
#
# 34310
#
# 2021-01-22 00:00:00
#
# 34480
#
# 2021-01-23 00:00:00
#
# 34559
#
# 2021-01-24 00:00:00
#
# 34633
#
# 2021-01-25 00:00:00
#
# 34743
#
# 2021-01-26 00:00:00
#
# 34864
#
# 2021-01-27 00:00:00
#
# 35013
#
# 2021-01-28 00:00:00
#
# 35155
#
# 2021-01-29 00:00:00
#
# 35316
#
# 2021-01-30 00:00:00
#
# 35399
#
# 2021-01-31 00:00:00
#
# 35486
#
# 2021-02-01 00:00:00
#
# 35614
#
# 2021-02-02 00:00:00
#
# 35730
#
# 2021-02-03 00:00:00
#
# 35843
#
# 2021-02-04 00:00:00
#
# 35946
#
# 2021-02-05 00:00:00
#
# 36112
#
# 2021-02-06 00:00:00
#
# 36187
#
# 2021-02-07 00:00:00
#
# 36273
#
# 2021-02-08 00:00:00
#
# 36384
#
# 2021-02-09 00:00:00
#
# 36512
#
# 2021-02-10 00:00:00
#
# 36642
#
# 2021-02-11 00:00:00
#
# 36775
#
# 2021-02-12 00:00:00
#
# 36932
#
# 2021-02-13 00:00:00
#
# 37010
#
# 2021-02-14 00:00:00
#
# 37089
#
# 2021-02-15 00:00:00
#
# 37199
#
# 2021-02-16 00:00:00
#
# 37326
#
# 2021-02-17 00:00:00
#
# 37444
#
# 2021-02-18 00:00:00
#
# 37566
#
# 2021-02-19 00:00:00
#
# 37726
#
# 2021-02-20 00:00:00
#
# 37812
#
# 2021-02-21 00:00:00
#
# 37900
#
# 2021-02-22 00:00:00
#
# 38013
#
# 2021-02-23 00:00:00
#
# 38136
#
# 2021-02-24 00:00:00
#
# 38273
#
# 2021-02-25 00:00:00
#
# 38407
#
# 2021-02-26 00:00:00
#
# 38557
#
# 2021-02-27 00:00:00
#
# 38649
#
# 2021-02-28 00:00:00
#
# 38728
#
# 2021-03-01 00:00:00
#
# 38845
#
# 2021-03-02 00:00:00
#
# 38976
#
# 2021-03-03 00:00:00
#
# 39103
#
# 2021-03-04 00:00:00
#
# 39225
#
# 2021-03-05 00:00:00
#
# 39376
#
# 2021-03-06 00:00:00
#
# 39451
#
# 2021-03-07 00:00:00
#
# 39510
#
# 2021-03-08 00:00:00
#
# 39635
#
# 2021-03-09 00:00:00
#
# 39762
#
# 2021-03-10 00:00:00
#
# 39886
#
# 2021-03-11 00:00:00
#
# 40017
#
# 2021-03-12 00:00:00
#
# 40184
#
# 2021-03-13 00:00:00
#
# 40255
#
# 2021-03-14 00:00:00
#
# 40343
#
# 2021-03-15 00:00:00
#
# 40485
#
# 2021-03-16 00:00:00
#
# 40617
#
# 2021-03-17 00:00:00
#
# 40743
#
# 2021-03-18 00:00:00
#
# 40875
#
# 2021-03-19 00:00:00
#
# 41048
#
# 2021-03-20 00:00:00
#
# 41114
#
# 2021-03-21 00:00:00
#
# 41190
#
# 2021-03-22 00:00:00
#
# 41310
#
# 2021-03-23 00:00:00
#
# 41445
#
# 2021-03-24 00:00:00
#
# 41528

# %%
spiegel = pd.DataFrame()

spiegel['url'] = [u for u in url]
spiegel['headline'] = [h for h in headline]
spiegel['is_paid'] = [p for p in is_paid]
spiegel['date_published'] = [date for date in date_published]
spiegel['channel'] = [c for c in channel]

# %%
spiegel.shape
# Out:
# (41528, 5)

# %%
spiegel
# Out:
#                                                      url  \
# 0      https://www.spiegel.de/panorama/chile-raeuber-...
# 1      https://www.spiegel.de/sport/coronavirus-serie...
# 2      https://www.spiegel.de/panorama/justiz/harvey-...
# 3      https://www.spiegel.de/sport/fussball/arminia-...
# 4      https://www.spiegel.de/panorama/italien-weitet...
# ...                                                  ...
# 41523  https://www.spiegel.de/wirtschaft/norwegischer...
# 41524  https://www.spiegel.de/reise/luxustourismus-tr...
# 41525  https://www.spiegel.de/netzwelt/web/twitter-er...
# 41526  https://www.spiegel.de/netzwelt/web/digitale-k...
# 41527  https://www.spiegel.de/wirtschaft/unternehmen/...
#
#                                                 headline  is_paid  \
# 0      Chile: Räuber erbeuten 15 Millionen Dollar in bar    False
# 1      Coronavirus: Italien sagt alle Sportveranstalt...    False
# 2      Nach Herz-OP: Weinstein verletzt sich bei Stur...    False
# 3      Topspiel der 2. Bundesliga: Bielefeld wehrt de...    False
# 4      Coronavirus: Italien weitet "rote Zone" auf da...    False
# ...                                                  ...      ...
# 41523  Chef des Norwegischen Staatsfonds: Was Sie vom...    False
# 41524  Luxustourismus trotz Corona: Der Tegernsee wir...    False
# 41525  24 Zeichen: Erster Tweet der Welt bringt bei A...    False
# 41526  Digitale Kopie: GMX und Web.de verraten jetzt ...    False
# 41527  US-Videospielhändler: Umsatz von GameStop sink...    False
#
#            date_published     channel
# 0     2020-03-09 23:28:00    Panorama
# 1     2020-03-09 23:21:00       Sport
# 2     2020-03-09 22:54:00    Panorama
# 3     2020-03-09 22:26:00       Sport
# 4     2020-03-09 21:57:00    Panorama
# ...                   ...         ...
# 41523 2021-03-24 00:43:00  Wirtschaft
# 41524 2021-03-24 00:43:00       Reise
# 41525 2021-03-24 00:43:00    Netzwelt
# 41526 2021-03-24 00:39:00    Netzwelt
# 41527 2021-03-24 00:34:00  Wirtschaft
#
# [41528 rows x 5 columns]

# %%
#df_temp_1=df_temp
spiegel.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/spiegel.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved
