# %%
#!pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#browser = webdriver.Chrome(executable_path = '/Users/carolinvogt/Becoming_Data_Analyst/chromedriver')
#browser.get('https://www.waterqualitydata.us/portal/')

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from time import sleep
import re

# %%
import time
from random import randint
from datetime import datetime
from datetime import date, timedelta

# %%
#listPagination

# %% [markdown]
# ### Test href

# %%
url="https://www.faz.net/suche/?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination"

response = requests.get(url)
print(response.status_code)
soup = BeautifulSoup(response.content, "html.parser")

href=[]
is_paid=[]

test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
href+=[t['href'] for t in test]
is_paid+=[t['data-is-premium'] for t in test]
print("base_headline: ",len(href))
# Out:
# 200
# base_headline:  20

# %%
is_paid
# Out:
# ['false',
#  'false',
#  'false',
#  'false',
#  'true',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'true',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'true']

# %% [markdown]
# ### keyword = "corona"

# %%
urls=[]

for i in range(1301):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
#  'https://www.faz.net/suche/s6.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls[:500]:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))


    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  80
# subtitle:  80
# ...

# %%
'date_published', 'url', 'newspaper', 'headline'

# %%
FA = pd.DataFrame()


FA['title'] = [h for h in base_headline]
FA['subtitle'] = [s for s in subtitle]
FA['date_published'] = [data for data in date]
FA['url'] = [data for data in href]
FA['is_paid'] = [data for data in is_paid]

FA
# Out:
#                                                   title  \
# 0     \n\t\t\t\t\t\t\tSo wenige Insolvenzen wie seit...
# 1     \n\t\t\t\t\t\t\tJunge Wissenschaftler stehen u...
# 2     \n\t\t\t\t\t\t\tZahl der Arbeitslosen sinkt de...
# 3     \n\t\t\t\t\t\t\tKehren die goldenen Zeiten zur...
# 4     \n\t\t\t\t\t\t\tMessebauer findet neue Kunden ...
# ...                                                 ...
# 9994  \n\t\t\t\t\t\t\tDeutsches Geldvermögen auf Rek...
# 9995  \n\t\t\t\t\t\t\tSeid nicht so verletzlich, Gen...
# 9996  \n\t\t\t\t\t\t\tNicht bloß Elitenförderung\n\t...
# 9997  \n\t\t\t\t\t\t\tKurzarbeit in Hessen leicht un...
# 9998  \n\t\t\t\t\t\t\tBayern-Trainer Flick macht ein...
#
#                                                subtitle  \
# 0     \n\t\t\t\t\t\tIn der Corona-Krise wurden viele...
# 1     \n\t\t\t\t\t\tDas Virus stellt den Arbeitsallt...
# 2     \n\t\t\t\t\t\tTrotz des Lockdowns und steigend...
# 3     \n\t\t\t\t\t\tDer Goldpreis hat seit August de...
# ...

# %%
FA.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_part1.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls[500:1000]:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s501.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s502.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s503.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s504.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  80
# ...

# %%
FA2 = pd.DataFrame()

FA2['title'] = [h for h in base_headline]
FA2['subtitle'] = [s for s in subtitle]
FA2['date_published'] = [data for data in date]
FA2['url'] = [data for data in href]
FA2['is_paid'] = [data for data in is_paid]

FA2
# Out:
#                                                   title  \
# 0     \n\t\t\t\t\t\t\tBayern-Trainer Flick macht ein...
# 1     \n\t\t\t\t\t\t\tWer steigt in den Euro Stoxx 5...
# 2     \n\t\t\t\t\t\t\t„Menschen benutzen Teams anste...
# 3     \n\t\t\t\t\t\t\tCorona-Politik vor Gericht\n\t...
# 4     \n\t\t\t\t\t\t\tKampf gegen Pandemie nutzt auc...
# ...                                                 ...
# 9994  \n\t\t\t\t\t\t\tDie Angst im Rücken\n\t\t\t   ...
# 9995  \n\t\t\t\t\t\t\tDie große Angst vor der zweite...
# 9996  \n\t\t\t\t\t\t\tDas Tier ist nur die Fußnote\n...
# 9997  \n\t\t\t\t\t\t\tTesla und Kalifornien einigen ...
# 9998  \n\t\t\t\t\t\t\tEuGH stuft ungarische Transitz...
#
#                                                subtitle  \
# 0     \n\t\t\t\t\t\tNach dem Pflichtsieg im DFB-Poka...
# 1     \n\t\t\t\t\t\tInfineon und RWE haben Chancen, ...
# 2     \n\t\t\t\t\t\tSlack und Microsoft Teams wettei...
# 3     \n\t\t\t\t\t\tIn Berlin erklärt ein Gericht di...
# ...

# %%
FA2.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_part2.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls[1000:]:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1001.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s1002.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s1003.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s1004.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=corona#listPagination
#
# base_headline:  80
# ...

# %%
FA25 = pd.DataFrame()

FA25['title'] = [h for h in base_headline]
FA25['subtitle'] = [s for s in subtitle]
FA25['date_published'] = [data for data in date]
FA25['url'] = [data for data in href]
FA25['is_paid'] = [data for data in is_paid]

FA25
# Out:
#                                                   title  \
# 0     \n\t\t\t\t\t\t\tEuGH stuft ungarische Transitz...
# 1     \n\t\t\t\t\t\t\tTrump fordert Öffnung der Schu...
# 2     \n\t\t\t\t\t\t\tEndlich wieder Schule\n\t\t\t ...
# 3     \n\t\t\t\t\t\t\tGesundheitsämter mit Kontaktve...
# 4     \n\t\t\t\t\t\t\tBundestag berät über weitere C...
# ...                                                 ...
# 5995  \n\t\t\t\t\t\t\t„Die Lage ist ernst“\n\t\t\t  ...
# 5996  \n\t\t\t\t\t\t\tTrump kündigt Maßnahmen gegen ...
# 5997  \n\t\t\t\t\t\t\tDie Härte der Schweiz\n\t\t\t ...
# 5998  \n\t\t\t\t\t\t\tFraport macht’s wie Merck, Bio...
# 5999  \n\t\t\t\t\t\t\tDie Gründe für den Ölpreiskrie...
#
#                                                subtitle  \
# 0     \n\t\t\t\t\t\tDie Bedingungen im Container-Lag...
# 1     \n\t\t\t\t\t\tDer amerikanische Präsident geht...
# 2     \n\t\t\t\t\t\tDie Schulen in Hessen öffnen, te...
# 3     \n\t\t\t\t\t\tZahlreiche Gesundheitsämter habe...
# ...

# %%
FA25.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_part3.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ## keyword = "biontech"

# %%
urls=[]

for i in range(42):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
#  'https://www.faz.net/suche/s6.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("date: ",len(date))
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination
#
# base_headline:  20
# subtitle:  20
# href:  20
# is_paid:  20
# date:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination
#
# base_headline:  40
# subtitle:  40
# href:  40
# is_paid:  40
# date:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination
#
# base_headline:  60
# subtitle:  60
# href:  60
# is_paid:  60
# date:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=biontech#listPagination
#
# base_headline:  80
# ...

# %%
FA3 = pd.DataFrame()

FA3['title'] = [h for h in base_headline]
FA3['subtitle'] = [s for s in subtitle]
FA3['date_published'] = [data for data in date]
FA3['url'] = [data for data in href]
FA3['is_paid'] = [data for data in is_paid]

FA3
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\tVerkündet Macron härtere Coron...
# 1    \n\t\t\t\t\t\t\tHessen setzt Impfungen mit Ast...
# 2    \n\t\t\t\t\t\t\tBiontech-Impfstoff hat hohe Wi...
# 3    \n\t\t\t\t\t\t\tCorona-Kennziffer in Hessen ör...
# 4    \n\t\t\t\t\t\t\tSo entsteht der Corona-Impfsto...
# ..                                                 ...
# 815  \n\t\t\t\t\t\t\tVorzeigeunternehmen\n\t\t\t   ...
# 816  \n\t\t\t\t\t\t\tMehr Platz für große Träume im...
# 817  \n\t\t\t\t\t\t\tImpfen gegen den Krebs\n\t\t\t...
# 818  \n\t\t\t\t\t\t\tDas bringt der Dienstag\n\t\t\...
# 819  \n\t\t\t\t\t\t\tBrüssel setzt Türkei-Gespräche...
#
#                                               subtitle  \
# 0    \n\t\t\t\t\t\tBiontech-Impfstoff zeigt hohe Wi...
# 1    \n\t\t\t\t\t\tWer unter 60 ist, soll in Hessen...
# 2    \n\t\t\t\t\t\tEine Nachricht, die Mut macht: D...
# 3    \n\t\t\t\t\t\tAlsfeld kann es kaum abwarten, d...
# ...

# %%
FA3.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_biontech.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ## keyword = "astrazeneca"

# %%
urls=[]

for i in range(35):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
#  'https://www.faz.net/suche/s6.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=astrazeneca#listPagination
#
# ...

# %%
FA4 = pd.DataFrame()

FA4['title'] = [h for h in base_headline]
FA4['subtitle'] = [s for s in subtitle]
FA4['date_published'] = [data for data in date]
FA4['url'] = [data for data in href]
FA4['is_paid'] = [data for data in is_paid]

FA4
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\t„Überwachung bei Impfstoffen f...
# 1    \n\t\t\t\t\t\t\tVerkündet Macron härtere Coron...
# 2    \n\t\t\t\t\t\t\tHessen setzt Impfungen mit Ast...
# 3    \n\t\t\t\t\t\t\tÖsterreich erwägt Beschaffung ...
# 4    \n\t\t\t\t\t\t\tCorona-Kennziffer in Hessen ör...
# ..                                                 ...
# 675  \n\t\t\t\t\t\t\tAnlehnungsbedarf in der Pharma...
# 676  \n\t\t\t\t\t\t\tMit Leerverkäufen lässt sich g...
# 677  \n\t\t\t\t\t\t\tGlaxo und Biogen erfahren Sege...
# 678  \n\t\t\t\t\t\t\tFusionsfantasie lebt neu auf\n...
# 679  \n\t\t\t\t\t\t\tNovartis-Aktie hängt Konkurren...
#
#                                               subtitle  \
# 0    \n\t\t\t\t\t\tDie Frankfurter Virologin Ciesek...
# 1    \n\t\t\t\t\t\tBiontech-Impfstoff zeigt hohe Wi...
# 2    \n\t\t\t\t\t\tWer unter 60 ist, soll in Hessen...
# 3    \n\t\t\t\t\t\tWien erwägt eine Million Dosen S...
# ...

# %%
FA4.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_astrazeneca.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ## keyword = "moderna"

# %%
urls=[]

for i in range(22):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
#  'https://www.faz.net/suche/s6.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("date: ",len(date))
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination
#
# base_headline:  20
# subtitle:  20
# href:  20
# is_paid:  20
# date:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination
#
# base_headline:  40
# subtitle:  40
# href:  40
# is_paid:  40
# date:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination
#
# base_headline:  60
# subtitle:  60
# href:  60
# is_paid:  60
# date:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=moderna#listPagination
#
# base_headline:  80
# ...

# %%
FA5 = pd.DataFrame()

FA5['title'] = [h for h in base_headline]
FA5['subtitle'] = [s for s in subtitle]
FA5['date_published'] = [data for data in date]
FA5['url'] = [data for data in href]
FA5['is_paid'] = [data for data in is_paid]

FA5
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\tHessen setzt Impfungen mit Ast...
# 1    \n\t\t\t\t\t\t\tAmerika und Deutschland invest...
# 2    \n\t\t\t\t\t\t\tAstra-Zeneca in der Regel nur ...
# 3    \n\t\t\t\t\t\t\tCDC-Chefin: „Im Moment habe ic...
# 4    \n\t\t\t\t\t\t\tStudie bekräftigt geringes Inf...
# ..                                                 ...
# 402  \n\t\t\t\t\t\t\tSehr beruhigend, daß man eine ...
# 403  \n\t\t\t\t\t\t\tHart auf hart, das bringt Heil...
# 404  \n\t\t\t\t\t\t\tDas Absolute verzehrt sich nac...
# 405  \n\t\t\t\t\t\t\tErasmus' kleiner Bruder\n\t\t\...
# 406  \n\t\t\t\t\t\t\tErinnerung an das Denken\n\t\t...
#
#                                               subtitle  \
# 0    \n\t\t\t\t\t\tWer unter 60 ist, soll in Hessen...
# 1    \n\t\t\t\t\t\tIn Deutschland kommt die Impfkam...
# 2    \n\t\t\t\t\t\tDer Impfstoff soll von Mittwoch ...
# 3    \n\t\t\t\t\t\tTrotz des hohen Impftempos in Am...
# ...

# %%
FA5.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_moderna.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "johnson&johnson"
#
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination

# %%
urls=[]

for i in range(22):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=johnson&johnson#listPagination
#
# ...

# %%
FA6 = pd.DataFrame()

FA6['title'] = [h for h in base_headline]
FA6['subtitle'] = [s for s in subtitle]
FA6['date_published'] = [data for data in date]
FA6['url'] = [data for data in href]
FA6['is_paid'] = [data for data in is_paid]

FA6
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\tAmerika und Deutschland invest...
# 1    \n\t\t\t\t\t\t\tWenn sich das Universum verwäh...
# 2    \n\t\t\t\t\t\t\tAstra-Zeneca in der Regel nur ...
# 3    \n\t\t\t\t\t\t\tEs war einmal eine Sehnsucht\n...
# 4    \n\t\t\t\t\t\t\tEin großer Vertrag zur Bekämpf...
# ..                                                 ...
# 415  \n\t\t\t\t\t\t\tTrump bekommt die Quittung von...
# 416  \n\t\t\t\t\t\t\tEin ermächtigendes Gefühl\n\t\...
# 417  \n\t\t\t\t\t\t\tKampf für die Freiheit\n\t\t\t...
# 418  \n\t\t\t\t\t\t\tLondons U-Bahn in Not\n\t\t\t ...
# 419  \n\t\t\t\t\t\t\tAm bitteren Ende einer langen ...
#
#                                               subtitle  \
# 0    \n\t\t\t\t\t\tIn Deutschland kommt die Impfkam...
# 1    \n\t\t\t\t\t\tGeschichten erzählen mit dem Tel...
# 2    \n\t\t\t\t\t\tDer Impfstoff soll von Mittwoch ...
# 3    \n\t\t\t\t\t\tWie wird es nach der Pandemie in...
# ...

# %%
FA6.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_johnson.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %% [markdown]
# ### keyword = "curevac"

# %%
urls=[]

for i in range(13):
    url="https://www.faz.net/suche/s"+str(i)+".html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination"
    urls.append(url)
    
urls=urls[1:(len(urls))]
urls
# Out:
# ['https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
#  'https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
#  'https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
#  'https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
#  'https://www.faz.net/suche/s5.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
#  'https://www.faz.net/suche/s6.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination',
# ...

# %%
base_headline=[]
subtitle=[]
date=[]
href=[]
is_paid=[]

i=1

for url in urls:
    response = requests.get(url)
    print(response.status_code)
    soup = BeautifulSoup(response.content, "html.parser")
    
    random_i = randint(5, 15)
    time.sleep(random_i)
    print("loop: ", i)
    print(url)
    print()

    test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})
    #base_headline=[]
    #for row in test:
        #base_headline.append(row.get_text())
        #leerzeichen entfernen
    base_headline+=[row.get_text() for row in test]
    print("base_headline: ",len(base_headline))

    test=soup.find_all("div",attrs={"class":"tsr-Base_Content"})
    #subtitle=[]
    #for row in test:
        #subtitle.append(row.get_text())
        #leerzeichen entfernen
    subtitle+=[row.get_text() for row in test]
    print("subtitle: ",len(subtitle))

    test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
    #date=[]
    #for row in test:
        #date.append(row["datetime"])
        #leerzeichen entfernen
    date+=[row["datetime"] for row in test]
    print("date: ",len(date))
    
    test=soup.find_all("a",attrs={"class":"js-hlp-LinkSwap js-tsr-Base_ContentLink tsr-Base_ContentLink"})
    href+=[t['href'] for t in test]
    print("href: ",len(href))
    is_paid+=[t['data-is-premium'] for t in test]
    print("is_paid: ",len(is_paid))
    
    print("------")
    print()
    
    i+=1
# Out:
# 200
# loop:  1
# https://www.faz.net/suche/s1.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination
#
# base_headline:  20
# subtitle:  20
# date:  20
# href:  20
# is_paid:  20
# ------
#
# 200
# loop:  2
# https://www.faz.net/suche/s2.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination
#
# base_headline:  40
# subtitle:  40
# date:  40
# href:  40
# is_paid:  40
# ------
#
# 200
# loop:  3
# https://www.faz.net/suche/s3.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination
#
# base_headline:  60
# subtitle:  60
# date:  60
# href:  60
# is_paid:  60
# ------
#
# 200
# loop:  4
# https://www.faz.net/suche/s4.html?ct=article&ct=audio&ct=blog&ct=gallery&ct=infografik&ct=storytelling&ct=video&type=content&&query=curevac#listPagination
#
# base_headline:  80
# ...

# %%
FA7 = pd.DataFrame()

FA7['title'] = [h for h in base_headline]
FA7['subtitle'] = [s for s in subtitle]
FA7['date_published'] = [data for data in date]
FA7['url'] = [data for data in href]
FA7['is_paid'] = [data for data in is_paid]

FA7
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\tAmerika und Deutschland invest...
# 1    \n\t\t\t\t\t\t\tMerkel drängt Länderchefs zum ...
# 2    \n\t\t\t\t\t\t\tWas taugt die Biontech-Aktie?\...
# 3    \n\t\t\t\t\t\t\t„Wir werden die komplette Prod...
# 4    \n\t\t\t\t\t\t\tEU-Gipfel für bessere Kontroll...
# ..                                                 ...
# 222  \n\t\t\t\t\t\t\tGates steigt in deutsche Arzne...
# 223  \n\t\t\t\t\t\t\tDr. Oetker schluckt Coppenrath...
# 224  \n\t\t\t\t\t\t\tWettlauf gegen den Krebs\n\t\t...
# 225  \n\t\t\t\t\t\t\tHopp-Firma will in das Frankfu...
# 226  \n\t\t\t\t\t\t\t„Wir werden bei Leonardo noch ...
#
#                                               subtitle  \
# 0    \n\t\t\t\t\t\tIn Deutschland kommt die Impfkam...
# 1    \n\t\t\t\t\t\tDie Kanzlerin nennt den jüngsten...
# 2    \n\t\t\t\t\t\tAuf Unternehmen wie Biontech und...
# 3    \n\t\t\t\t\t\tDer Chemieriese BASF will den ge...
# ...

# %%
FA7.to_csv("/Users/carolinvogt/Becoming_Data_Analyst/vaccine_confidence/FA_curevac.csv")

print("Sucessfully saved")
# Out:
# Sucessfully saved

# %%
test_df=FA

test_df.date_published.apply(lambda x: x.split("T")[0])
#if this is working: save!!!

# %%
test=date
test_df=pd.DataFrame()

# %%
test_df["time"]=[date for date in test]
test_df

# %%
test_df.time.apply(lambda x: x.split("T")[0])

# %%
type(test[0])#.strftime("%Y-%m-%d")

# %%
testi=datetime.strptime(test[0], "%Y-%m-%d")
testi

# %% [markdown]
# ### Headline

# %%
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(1) > article > div.tsr-Base_TextWrapper > div > div > a > header > h2 > span.tsr-Base_HeadlineText
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(7) > article > div.tsr-Base_TextWrapper > div > div > a > header > h2 > span.tsr-Base_HeadlineText

# %%
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(i) > article > div.tsr-Base_TextWrapper > div > div > a > header > h2 > span.tsr-Base_HeadlineText

# %%
response = requests.get(urls[0])
response.status_code # 200 status code means OK!

# %%
document.querySelector("#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div")

# %%
soup = BeautifulSoup(response.content, "html.parser")
    
soup

# %%
soup2=soup.select("div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap")

# %%
soup2

# %%
response = requests.get(urls[0])
soup = BeautifulSoup(response.content, "html.parser")

test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
date=[]

date+=[row["datetime"] for row in test]

response = requests.get(urls[1])
soup = BeautifulSoup(response.content, "html.parser")

test=soup.find_all("time",attrs={"class":"tsr-Base_ContentMetaTime"})
#date=[]

date+=[row["datetime"] for row in test]

print(len(date))
date

# %%
subtitle

# %%
soup.select("#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(7) > article > div.tsr-Base_TextWrapper > div > div > a > header > h2 > span.tsr-Base_HeadlineText")

# %%
test=soup.find_all("span",attrs={"class":"tsr-Base_HeadlineText"})

# %%
for row in test:
    print(row.get_text())
    #leerzeichen entfernen

# %%
soup.find("span",{"class":"tsr-Base_HeadlineEmphasisText"})

# %%
soup.find("span",{"class":"tsr-Base_Content"})

# %%
soup.find("span",{"class":"tsr-Base_ContentMetaTime"})

# %%
headline=[]
artist=[]


headline.append(top_2000[i].find("div",{"class":"tsr-Base_HeadlineText"}).get_text())

# %%
headline

# %% [markdown]
# ### Subtitle

# %%
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(8) > article > div.tsr-Base_TextWrapper > div > div > div

#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(1) > article > div.tsr-Base_TextWrapper > div > div > div

# %%
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(i) > article > div.tsr-Base_TextWrapper > div > div > div

# %% [markdown]
# ### date

# %%
#TOP > div.Suche > div.o-ModuleWrapper.o-ModuleWrapper-has-less-bottom-gap > div > div > div.o-Grid_Col.o-Grid_Col-12.o-Grid-has-min-height > ul > li:nth-child(i) > article > div.tsr-Base_TextWrapper > div > div > footer > ul > li.tsr-Base_ContentMetaItem.tsr-Base_ContentMetaItem-time-of-publication > time

# %%
response.json()

# %%
soup = BeautifulSoup(response.content, "html.parser")
#soup

# %%
#Beautiful Soup
#suchergebnisse > section > article:nth-child(1) > article > div > header > h2 > a > span.block.font-sansUI.font-bold.text-xl.mb-12 > span > span
#suchergebnisse > section > article:nth-child(2) > article > div > header > h2 > a > span > span.hover\:opacity-moderate.focus\:opacity-moderate > span

# %%
#Selenium
#//*[@id="suchergebnisse"]/section/article[1]/article/div/header/h2/a/span[2]/span/span

# %% [markdown]
# # spiegel-scraper
#
# https://pypi.org/project/spiegel-scraper/

# %%
#!pip install spiegel-scraper

# %%
from datetime import date
import spiegel_scraper as spon

# %%
from datetime import datetime

# %% [markdown]
# ### time period

# %%
# 2020-03-09 until 2021-03-24
from datetime import date, timedelta

dates=pd.date_range('2020-03-09','2021-03-24',freq='D').strftime("%Y-%m-%d").tolist()
len(dates)

# %%
print(date(2020, 3, 9))

# %%
dates=[datetime.strptime(date, "%Y-%m-%d") for date in dates]
dates

# %% [markdown]
# ### Test on 2020-03-09

# %%
#archive_html = spon.archive.html_by_date(date(2020, 3, 9))
archive_entries_from_html = spon.archive.scrape_html(spon.archive.html_by_date(dates[0]))

# %%
spiegel_keys=archive_entries_from_html[0].keys()

# %%
len(archive_entries_from_html)

# %%
#for i in range(len(archive_entries_from_html)):
    #print(archive_entries_from_html[i]["url"])

# %%
url = [archive_entries_from_html[i]["url"] for i in range(len(archive_entries_from_html))]
#print(url)

# %%
date_published = [archive_entries_from_html[i]["date_published"] for i in range(len(archive_entries_from_html))]
date_published

# %%
spiegel = pd.DataFrame()
spiegel['date_published'] = [date.strftime("%Y-%m-%d") for date in date_published]

# %%
date_published[0].strftime("%Y-%m-%d")

# %% [markdown]
# ### Scraping data

# %%
url = []
headline = []
is_paid = []
date_published = []
channel = []

for date in dates:
    random_i = randint(5, 20)
    time.sleep(random_i)
    
    print()
    print(date)
    
    archive_entries_from_html = spon.archive.scrape_html(spon.archive.html_by_date(date))
    print()
    
    url += [archive_entries_from_html[i]["url"] for i in range(len(archive_entries_from_html))]
    headline += [archive_entries_from_html[i]["headline"] for i in range(len(archive_entries_from_html))]
    is_paid += [archive_entries_from_html[i]["is_paid"] for i in range(len(archive_entries_from_html))]
    date_published += [archive_entries_from_html[i]["date_published"] for i in range(len(archive_entries_from_html))]
    channel += [archive_entries_from_html[i]["channel"] for i in range(len(archive_entries_from_html))]
    print(len(channel))

# %%
spiegel = pd.DataFrame()

spiegel['url'] = [u for u in url]
spiegel['headline'] = [h for h in headline]
spiegel['is_paid'] = [p for p in is_paid]
spiegel['date_published'] = [date.strftime("%Y-%m-%d") for date in date_published]
spiegel['channel'] = [c for c in channel]
