# %%
import pandas as pd

# %%
all_headlines = pd.DataFrame

# %%
telegraph = pd.read_csv("C:/Users/jw156/Ironhack/vaccine/telegraph.csv", index_col=0)
guardian = pd.read_csv("C:/Users/jw156/Ironhack/vaccine/guardian.csv", index_col=0)
independent = pd.read_csv("C:/Users/jw156/Ironhack/vaccine/independent.csv", index_col=0)

# %%
telegraph
# Out:
#                                                    title  \
# 0      \nCoronavirus latest news: Joint EU-UK stateme...
# 1      \nEurope tightens Covid restrictions as 'third...
# 2      \nPubs may demand Covid passport before they w...
# 3      \nBoris Johnson warns EU that vaccine ban targ...
# 4      \nLateral flow Covid testing too inaccurate to...
# ...                                                  ...
# 22390  \nChina's coronavirus outbreak proves we must ...
# 22391  \nCoronavirus tests come back negative on 14 p...
# 22392  \nThe best of The Telegraph in audio: The batt...
# 22393  \nCoronavirus: China hastily builds new 1,000-...
# 22394  \nChina locks down 14 cities as Wuhan coronavi...
#
#                                                    hrefs                 times
# 0      https://www.telegraph.co.uk/global-health/scie...   24 Mar 2021, 7:00pm
# 1      https://www.telegraph.co.uk/politics/2021/03/2...   24 Mar 2021, 4:30pm
# 2      https://www.telegraph.co.uk/politics/2021/03/2...   24 Mar 2021, 6:36pm
# 3      https://www.telegraph.co.uk/news/2021/03/24/eu...   24 Mar 2021, 7:26pm
# 4      https://www.telegraph.co.uk/news/2021/03/24/la...   24 Mar 2021, 6:34pm
# ...                                                  ...                   ...
# 22390  https://www.telegraph.co.uk/global-health/scie...   24 Jan 2020, 2:33pm
# 22391  https://www.telegraph.co.uk/news/2020/01/24/co...   24 Jan 2020, 1:37pm
# 22392  https://www.telegraph.co.uk/news/2020/01/24/be...  24 Jan 2020, 12:04pm
# 22393  https://www.telegraph.co.uk/news/2020/01/24/wa...  24 Jan 2020, 10:59am
# 22394  https://www.telegraph.co.uk/news/2020/01/24/ch...   24 Jan 2020, 9:05am
#
# [22395 rows x 3 columns]

# %%
import re

def cleaned_headline(sentence):
    new_sent = re.sub("\n", "", sentence)
    return new_sent

def cleaned_headline_2(sentence):
    new_sent = re.sub("\xa0", " ", sentence)
    return new_sent

def make_sentence(sentence):
    sent = sentence.split(' ')
    word = [word.lower() for word in sent]
    return word

# %%
telegraph['new_title'] = telegraph['title'].apply(cleaned_headline)

# %%
telegraph['new_title'] = telegraph['new_title'].apply(cleaned_headline_2)

# %%
telegraph['no_punc_title'] = telegraph.new_title.apply(lambda x: re.sub(r'[^\w\s]', '',x))

# %%
telegraph['new_title'] = telegraph['new_title'].apply(make_sentence)

# %%
telegraph['no_punc_title']
# Out:
# 0        Coronavirus latest news Joint EUUK statement i...
# 1        Europe tightens Covid restrictions as third wa...
# 2        Pubs may demand Covid passport before they wil...
# 3        Boris Johnson warns EU that vaccine ban target...
# 4        Lateral flow Covid testing too inaccurate to b...
#                                ...
# 22390    Chinas coronavirus outbreak proves we must pay...
# 22391    Coronavirus tests come back negative on 14 peo...
# 22392    The best of The Telegraph in audio The battle ...
# 22393    Coronavirus China hastily builds new 1000bed h...
# 22394    China locks down 14 cities as Wuhan coronaviru...
# Name: no_punc_title, Length: 22395, dtype: object

# %%
words_list = telegraph['no_punc_title'].tolist()

# %%
stop_words=["a", '',"about","above","after","again","against","ain","all","am","an","and","any","are","aren","aren't","as","at","be","because","been","before","being","below","between","both","but","by","can","couldn","couldn't","d","did","didn","didn't","do","does","doesn","doesn't","doing","don","don't","down","during","each","few","for","from","further","had","hadn","hadn't","has","hasn","hasn't","have","haven","haven't","having","he","her","here","hers","herself","him","himself","his","how","i","if","in","into","is","isn","isn't","it","it's","its","itself","just","ll","m","ma","me","mightn","mightn't","more","most","mustn","mustn't","my","myself","needn","needn't","no","nor","not","now","o","of","off","on","once","only","or","other","our","ours","ourselves","out","over","own","re","s","same","shan","shan't","she","she's","should","should've","shouldn","shouldn't","so","some","such","t","than","that","that'll","the","their","theirs","them","themselves","then","there","these","they","this","those","through","to","too","under","until","up","ve","very","was","wasn","wasn't","we","were","weren","weren't","what","when","where","which","while","who","whom","why","will","with","won","won't","wouldn","wouldn't","y","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves","could","he'd","he'll","he's","here's","how's","i'd","i'll","i'm","i've","let's","ought","she'd","she'll","that's","there's","they'd","they'll","they're","they've","we'd","we'll","we're","we've","what's","when's","where's","who's","why's","would","able","abst","accordance","according","accordingly","across","act","actually","added","adj","affected","affecting","affects","afterwards","ah","almost","alone","along","already","also","although","always","among","amongst","announce","another","anybody","anyhow","anymore","anyone","anything","anyway","anyways","anywhere","apparently","approximately","arent","arise","around","aside","ask","asking","auth","available","away","awfully","b","back","became","become","becomes","becoming","beforehand","begin","beginning","beginnings","begins","behind","believe","beside","besides","beyond","biol","brief","briefly","c","ca","came","cannot","can't","cause","causes","certain","certainly","co","com","come","comes","contain","containing","contains","couldnt","date","different","done","downwards","due","e","ed","edu","effect","eg","eight","eighty","either","else","elsewhere","end","ending","enough","especially","et","etc","even","ever","every","everybody","everyone","everything","everywhere","ex","except","f","far","ff","fifth","first","five","fix","followed","following","follows","former","formerly","forth","found","four","furthermore","g","gave","get","gets","getting","give","given","gives","giving","go","goes","gone","got","gotten","h","happens","hardly","hed","hence","hereafter","hereby","herein","heres","hereupon","hes","hi","hid","hither","home","howbeit","however","hundred","id","ie","im","immediate","immediately","importance","important","inc","indeed","index","information","instead","invention","inward","itd","it'll","j","k","keep","keeps","kept","kg","km","know","known","knows","l","largely","last","lately","later","latter","latterly","least","less","lest","let","lets","like","liked","likely","line","little","'ll","look","looking","looks","ltd","made","mainly","make","makes","many","may","maybe","mean","means","meantime","meanwhile","merely","mg","might","million","miss","ml","moreover","mostly","mr","mrs","much","mug","must","n","na","name","namely","nay","nd","near","nearly","necessarily","necessary","need","needs","neither","never","nevertheless","new","next","nine","ninety","nobody","non","none","nonetheless","noone","normally","nos","noted","nothing","nowhere","obtain","obtained","obviously","often","oh","ok","okay","old","omitted","one","ones","onto","ord","others","otherwise","outside","overall","owing","p","page","pages","part","particular","particularly","past","per","perhaps","placed","please","plus","poorly","possible","possibly","potentially","pp","predominantly","present","previously","primarily","probably","promptly","proud","provides","put","q","que","quickly","quite","qv","r","ran","rather","rd","readily","really","recent","recently","ref","refs","regarding","regardless","regards","related","relatively","research","respectively","resulted","resulting","results","right","run","said","saw","say","saying","says","sec","section","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sent","seven","several","shall","shed","shes","show","showed","shown","showns","shows","significant","significantly","similar","similarly","since","six","slightly","somebody","somehow","someone","somethan","something","sometime","sometimes","somewhat","somewhere","soon","sorry","specifically","specified","specify","specifying","still","stop","strongly","sub","substantially","successfully","sufficiently","suggest","sup","sure","take","taken","taking","tell","tends","th","thank","thanks","thanx","thats","that've","thence","thereafter","thereby","thered","therefore","therein","there'll","thereof","therere","theres","thereto","thereupon","there've","theyd","theyre","think","thou","though","thoughh","thousand","throug","throughout","thru","thus","til","tip","together","took","toward","towards","tried","tries","truly","try","trying","ts","twice","two","u","un","unfortunately","unless","unlike","unlikely","unto","upon","ups","us","use","used","useful","usefully","usefulness","uses","using","usually","v","value","various","'ve","via","viz","vol","vols","vs","w","want","wants","wasnt","way","wed","welcome","went","werent","whatever","what'll","whats","whence","whenever","whereafter","whereas","whereby","wherein","wheres","whereupon","wherever","whether","whim","whither","whod","whoever","whole","who'll","whomever","whos","whose","widely","willing","wish","within","without","wont","words","world","wouldnt","www","x","yes","yet","youd","youre","z","zero","a's","ain't","allow","allows","apart","appear","appreciate","appropriate","associated","best","better","c'mon","c's","cant","changes","clearly","concerning","consequently","consider","considering","corresponding","course","currently","definitely","described","despite","entirely","exactly","example","going","greetings","hello","help","hopefully","ignored","inasmuch","indicate","indicated","indicates","inner","insofar","it'd","keep","keeps","novel","presumably","reasonably","second","secondly","sensible","serious","seriously","sure","t's","third","thorough","thoroughly","three","well","wonder"]

# %%
news_dict = {}
for headline in words_list:
    f = headline.split(' ')
    for word in f:
        x = word.lower()
        if x not in stop_words:
            if x not in news_dict:
                news_dict[x] = 1
            else:
                news_dict[x] += 1

# %%
 sort_telegraph = sorted(news_dict.items(), key=lambda x: x[1], reverse=True)

# %%
sort_telegraph
# Out:
# [('coronavirus', 4881),
#  ('lockdown', 2401),
#  ('covid', 2161),
#  ('covid19', 1138),
#  ('vaccine', 1093),
#  ('uk', 966),
#  ('government', 890),
#  ('boris', 847),
#  ('news', 647),
#  ('johnson', 647),
#  ('people', 603),
#  ('pandemic', 600),
#  ('nhs', 568),
#  ('face', 559),
#  ('crisis', 549),
#  ('warns', 537),
#  ('travel', 487),
#  ('cases', 460),
#  ('health', 453),
#  ('rules', 448),
#  ('quarantine', 448),
#  ('briefing', 440),
#  ('britain', 429),
#  ('time', 398),
#  ('care', 392),
#  ('schools', 388),
#  ('test', 381),
#  ('fears', 370),
#  ('public', 366),
#  ('amid', 358),
#  ('return', 358),
#  ('virus', 357),
#  ('restrictions', 351),
#  ('british', 350),
#  ('testing', 349),
#  ('children', 349),
#  ('risk', 345),
#  ('work', 331),
#  ('police', 327),
#  ('wave', 316),
#  ('letters', 309),
#  ('christmas', 308),
#  ('plan', 303),
#  ('positive', 303),
#  ('workers', 302),
#  ('economy', 295),
#  ('masks', 293),
#  ('tests', 293),
#  ('trump', 290),
#  ('patients', 286),
#  ('year', 282),
#  ('exclusive', 282),
#  ('warn', 280),
#  ('school', 272),
#  ('watch', 267),
#  ('death', 261),
#  ('china', 253),
#  ('day', 252),
#  ('study', 250),
#  ('morning', 250),
#  ('outbreak', 250),
#  ('league', 248),
#  ('staff', 245),
#  ('sturgeon', 244),
#  ('rise', 243),
#  ('deaths', 242),
#  ('england', 237),
#  ('donald', 236),
#  ('set', 232),
#  ('life', 229),
#  ('britons', 226),
#  ('reopen', 226),
#  ('nicola', 225),
#  ('finds', 222),
#  ('social', 220),
#  ('open', 219),
#  ('hospital', 218),
#  ('holiday', 217),
#  ('premier', 215),
#  ('told', 213),
#  ('summer', 207),
#  ('countries', 206),
#  ('chief', 205),
#  ('britains', 204),
#  ('eu', 203),
#  ('sunak', 200),
#  ('governments', 199),
#  ('vaccines', 197),
#  ('hit', 197),
#  ('evening', 195),
#  ('save', 194),
#  ('week', 194),
#  ('business', 193),
#  ('surge', 193),
#  ('stay', 189),
#  ('dont', 189),
#  ('global', 188),
#  ('rishi', 188),
#  ('london', 187),
#  ('plans', 186),
#  ('record', 185),
#  ('mps', 183),
#  ('ministers', 181),
#  ('fight', 180),
#  ('spread', 179),
#  ('matt', 179),
#  ('economic', 178),
#  ('tier', 178),
#  ('latest', 177),
#  ('pubs', 177),
#  ('ban', 177),
#  ('minister', 176),
#  ('days', 175),
#  ('homes', 174),
#  ('cruise', 172),
#  ('months', 171),
#  ('calls', 171),
#  ('holidays', 170),
#  ('hancock', 170),
#  ('good', 170),
#  ('recovery', 169),
#  ('scientists', 169),
#  ('experts', 168),
#  ('hospitals', 166),
#  ('data', 165),
#  ('support', 164),
#  ('clubs', 163),
#  ('pay', 162),
#  ('system', 161),
#  ('national', 161),
#  ('weeks', 160),
#  ('jobs', 159),
#  ('ahead', 156),
#  ('oxford', 155),
#  ('players', 155),
#  ('10', 153),
#  ('rule', 152),
#  ('doctors', 150),
#  ('france', 148),
#  ('south', 147),
#  ('high', 146),
#  ('cent', 146),
#  ('local', 145),
#  ('lockdowns', 145),
#  ('johnsons', 145),
#  ('businesses', 145),
#  ('scottish', 144),
#  ('claims', 144),
#  ('parents', 144),
#  ('europe', 143),
#  ('faces', 143),
#  ('fear', 142),
#  ('scotland', 140),
#  ('left', 140),
#  ('italy', 139),
#  ('country', 139),
#  ('uks', 138),
#  ('long', 138),
#  ('cut', 138),
#  ('years', 138),
#  ('number', 138),
#  ('forced', 138),
#  ('online', 138),
#  ('half', 137),
#  ('furlough', 137),
#  ('app', 137),
#  ('mask', 136),
#  ('brexit', 135),
#  ('toll', 134),
#  ('scheme', 134),
#  ('contact', 134),
#  ('women', 132),
#  ('telegraph', 132),
#  ('distancing', 132),
#  ('response', 132),
#  ('football', 131),
#  ('chaos', 130),
#  ('industry', 130),
#  ('season', 130),
#  ('war', 127),
#  ('germany', 125),
#  ('meet', 125),
#  ('close', 125),
#  ('sport', 125),
#  ('rollout', 124),
#  ('future', 124),
#  ('top', 123),
#  ('advice', 121),
#  ('family', 121),
#  ('reveals', 121),
#  ('key', 120),
#  ('list', 120),
#  ('monday', 120),
#  ('reopening', 120),
#  ('dominic', 120),
#  ('house', 120),
#  ('ppe', 120),
#  ('working', 119),
#  ('questions', 119),
#  ('city', 119),
#  ('firms', 119),
#  ('cancelled', 119),
#  ('strategy', 118),
#  ('trace', 118),
#  ('demand', 117),
#  ('accused', 116),
#  ('normal', 116),
#  ('start', 116),
#  ('urged', 116),
#  ('food', 116),
#  ('street', 114),
#  ('free', 114),
#  ('suggests', 113),
#  ('boss', 113),
#  ('thousands', 112),
#  ('spain', 112),
#  ('students', 112),
#  ('battle', 112),
#  ('safe', 111),
#  ('measures', 111),
#  ('rate', 111),
#  ('avoid', 110),
#  ('call', 109),
#  ('state', 109),
#  ('restaurants', 108),
#  ('office', 108),
#  ('deal', 107),
#  ('jab', 107),
#  ('lives', 107),
#  ('threat', 106),
#  ('readers', 105),
#  ('report', 105),
#  ('tuesday', 105),
#  ('young', 105),
#  ('cost', 105),
#  ('cash', 105),
#  ('market', 105),
#  ('tracing', 105),
#  ('symptoms', 104),
#  ('variant', 104),
#  ('mass', 103),
#  ('pressure', 103),
#  ('tells', 103),
#  ('infections', 103),
#  ('hope', 102),
#  ('pm', 101),
#  ('tory', 101),
#  ('hits', 101),
#  ('medical', 101),
#  ('shut', 100),
#  ('wednesday', 100),
#  ('markets', 100),
#  ('winter', 100),
#  ('lost', 99),
#  ('live', 99),
#  ('roundup', 99),
#  ('hotel', 98),
#  ('vaccination', 98),
#  ('facing', 98),
#  ('2020', 97),
#  ('french', 96),
#  ('fall', 96),
#  ('early', 96),
#  ('protect', 96),
#  ('hopes', 96),
#  ('isolation', 96),
#  ('action', 95),
#  ('row', 95),
#  ('friday', 95),
#  ('cancer', 95),
#  ('biggest', 95),
#  ('tax', 94),
#  ('millions', 94),
#  ('wear', 93),
#  ('case', 93),
#  ('big', 92),
#  ('sir', 92),
#  ('race', 92),
#  ('emergency', 91),
#  ('die', 91),
#  ('june', 91),
#  ('chinese', 91),
#  ('bank', 91),
#  ('hold', 90),
#  ('warning', 90),
#  ('inside', 90),
#  ('cummings', 90),
#  ('financial', 90),
#  ('worst', 89),
#  ('urges', 89),
#  ('revealed', 89),
#  ('families', 89),
#  ('rates', 88),
#  ('break', 88),
#  ('closed', 88),
#  ('immunity', 88),
#  ('astrazeneca', 87),
#  ('mental', 87),
#  ('turn', 87),
#  ('residents', 87),
#  ('thursday', 87),
#  ('private', 87),
#  ('elderly', 87),
#  ('daily', 87),
#  ('teachers', 87),
#  ('nation', 86),
#  ('times', 86),
#  ('air', 86),
#  ('shops', 85),
#  ('travellers', 85),
#  ('leave', 85),
#  ('sector', 85),
#  ('major', 85),
#  ('university', 85),
#  ('sales', 85),
#  ('infection', 84),
#  ('disease', 84),
#  ('companies', 84),
#  ('wrong', 83),
#  ('european', 83),
#  ('vulnerable', 83),
#  ('pupils', 83),
#  ('trial', 82),
#  ('allowed', 82),
#  ('change', 81),
#  ('expert', 81),
#  ('pfizer', 80),
#  ('scotlands', 80),
#  ('figures', 80),
#  ('worlds', 80),
#  ('job', 80),
#  ('panic', 80),
#  ('survive', 80),
#  ('2021', 79),
#  ('money', 79),
#  ('threatens', 79),
#  ('tested', 79),
#  ('campaign', 79),
#  ('german', 79),
#  ('man', 79),
#  ('leaders', 78),
#  ('boost', 78),
#  ('3', 78),
#  ('announces', 78),
#  ('qa', 77),
#  ('red', 77),
#  ('hours', 77),
#  ('york', 77),
#  ('warned', 77),
#  ('bailout', 77),
#  ('buy', 76),
#  ('small', 76),
#  ('month', 76),
#  ('restart', 76),
#  ('spike', 76),
#  ('tourists', 75),
#  ('claim', 75),
#  ('fans', 75),
#  ('areas', 74),
#  ('visit', 74),
#  ('wuhan', 74),
#  ('ready', 74),
#  ('bring', 74),
#  ('ive', 74),
#  ('adviser', 74),
#  ('admits', 74),
#  ('party', 73),
#  ('car', 73),
#  ('trumps', 73),
#  ('treatment', 73),
#  ('exit', 73),
#  ('lose', 73),
#  ('border', 72),
#  ('risks', 72),
#  ('full', 72),
#  ('closures', 72),
#  ('services', 71),
#  ('feel', 71),
#  ('legal', 71),
#  ('drive', 71),
#  ('impact', 71),
#  ('talks', 70),
#  ('virtual', 70),
#  ('remain', 70),
#  ('cuts', 70),
#  ('price', 70),
#  ('light', 69),
#  ('lead', 69),
#  ('longer', 69),
#  ('west', 69),
#  ('banks', 69),
#  ('review', 68),
#  ('sports', 68),
#  ('tackle', 68),
#  ('prevent', 68),
#  ('official', 68),
#  ('offers', 68),
#  ('rugby', 68),
#  ('wait', 67),
#  ('flights', 67),
#  ('pub', 67),
#  ('jabs', 67),
#  ('finally', 67),
#  ('delay', 67),
#  ('real', 67),
#  ('move', 66),
#  ('sage', 66),
#  ('prime', 66),
#  ('selfisolation', 66),
#  ('nations', 66),
#  ('africa', 65),
#  ('play', 65),
#  ('challenge', 65),
#  ('trust', 65),
#  ('stocks', 65),
#  ('urge', 65),
#  ('chinas', 65),
#  ('india', 64),
#  ('head', 64),
#  ('infected', 64),
#  ('foreign', 64),
#  ('place', 64),
#  ('wales', 63),
#  ('tourism', 63),
#  ('worse', 63),
#  ('rescue', 63),
#  ('passengers', 63),
#  ('learn', 63),
#  ('snp', 63),
#  ('royal', 63),
#  ('collapse', 63),
#  ('force', 63),
#  ('control', 63),
#  ('march', 62),
#  ('concerns', 62),
#  ('low', 62),
#  ('chancellor', 62),
#  ('drug', 62),
#  ('july', 62),
#  ('decision', 62),
#  ('dies', 62),
#  ('book', 61),
#  ('100', 61),
#  ('sense', 61),
#  ('holidaymakers', 61),
#  ('bill', 61),
#  ('great', 61),
#  ('increase', 61),
#  ('science', 61),
#  ('tom', 61),
#  ('trade', 60),
#  ('find', 60),
#  ('making', 60),
#  ('ease', 60),
#  ('1', 60),
#  ('scots', 60),
#  ('double', 60),
#  ('peak', 60),
#  ('army', 60),
#  ('antibody', 59),
#  ('manchester', 59),
#  ('labour', 59),
#  ('service', 59),
#  ('living', 59),
#  ('banned', 59),
#  ('australia', 59),
#  ('rises', 59),
#  ('childrens', 59),
#  ('ship', 59),
#  ('shopping', 59),
#  ('trials', 59),
#  ('takes', 58),
#  ('died', 58),
#  ('target', 58),
#  ('needed', 58),
#  ('tech', 58),
#  ('lack', 58),
#  ('strain', 58),
#  ('launch', 58),
#  ('4', 58),
#  ('charity', 58),
#  ('roadmap', 57),
#  ('front', 57),
#  ('continue', 57),
#  ('north', 57),
#  ('launches', 57),
#  ('education', 57),
#  ('flu', 57),
#  ('track', 57),
#  ('captain', 57),
#  ('treat', 57),
#  ('victims', 57),
#  ('curfew', 57),
#  ('selfisolate', 57),
#  ('hotels', 56),
#  ('secretary', 56),
#  ('selfemployed', 56),
#  ('easing', 56),
#  ('generation', 56),
#  ('soar', 56),
#  ('keeping', 56),
#  ('budget', 56),
#  ('tories', 56),
#  ('sweden', 56),
#  ('club', 56),
#  ('disaster', 55),
#  ('human', 55),
#  ('policy', 55),
#  ('doctor', 55),
#  ('highest', 55),
#  ('spending', 55),
#  ('shortage', 55),
#  ('numbers', 55),
#  ('councils', 55),
#  ('intensive', 55),
#  ('ftse', 55),
#  ('leading', 55),
#  ('prepare', 55),
#  ('union', 55),
#  ('extra', 54),
#  ('things', 54),
#  ('prince', 54),
#  ('airport', 54),
#  ('funding', 54),
#  ('orders', 54),
#  ('universities', 54),
#  ('coming', 54),
#  ('spanish', 54),
#  ('tiers', 54),
#  ('blow', 53),
#  ('history', 53),
#  ('passports', 53),
#  ('fund', 53),
#  ('evidence', 53),
#  ('portugal', 53),
#  ('returning', 53),
#  ('game', 53),
#  ('english', 53),
#  ('forces', 53),
#  ('politics', 52),
#  ('approach', 52),
#  ('team', 52),
#  ('recession', 52),
#  ('offer', 52),
#  ('cope', 52),
#  ('age', 52),
#  ('struggling', 52),
#  ('customers', 52),
#  ('green', 51),
#  ('breaking', 51),
#  ('isnt', 51),
#  ('catch', 51),
#  ('bid', 51),
#  ('doors', 51),
#  ('aid', 51),
#  ('centre', 51),
#  ('investors', 51),
#  ('mp', 51),
#  ('gps', 51),
#  ('debt', 51),
#  ('fighting', 51),
#  ('100000', 51),
#  ('ill', 51),
#  ('join', 51),
#  ('shoppers', 51),
#  ('doses', 50),
#  ('clear', 50),
#  ('europes', 50),
#  ('freedom', 50),
#  ('black', 50),
#  ('sunaks', 50),
#  ('fines', 50),
#  ('white', 50),
#  ('unions', 50),
#  ('spreading', 50),
#  ('safety', 49),
#  ('greece', 49),
#  ('blame', 49),
#  ('nurses', 49),
#  ('boom', 49),
#  ('deadly', 49),
#  ('guidance', 49),
#  ('rising', 49),
#  ('vote', 49),
#  ('analysis', 49),
#  ('tough', 49),
#  ('starmer', 49),
#  ('beat', 49),
#  ('englands', 48),
#  ('easter', 48),
#  ('dangerous', 48),
#  ('borders', 48),
#  ('effective', 48),
#  ('thing', 48),
#  ('falls', 48),
#  ('order', 48),
#  ('president', 48),
#  ('united', 48),
#  ('child', 48),
#  ('package', 48),
#  ('running', 48),
#  ('korea', 48),
#  ('negative', 48),
#  ('huge', 48),
#  ('patient', 47),
#  ('events', 47),
#  ('planning', 47),
#  ('confirms', 47),
#  ('waiting', 47),
#  ('supply', 47),
#  ('linked', 47),
#  ('loss', 47),
#  ('power', 47),
#  ('hand', 47),
#  ('levels', 47),
#  ('firm', 47),
#  ('fire', 47),
#  ('delayed', 47),
#  ('tour', 47),
#  ('follow', 47),
#  ('transport', 47),
#  ('keir', 47),
#  ('hundreds', 47),
#  ('turned', 47),
#  ('scientist', 47),
#  ('australian', 47),
#  ('failing', 47),
#  ('buying', 47),
#  ('training', 47),
#  ('struggle', 47),
#  ('stranded', 47),
#  ('shutdown', 47),
#  ('vaccinated', 46),
#  ('level', 46),
#  ('heart', 46),
#  ('grow', 46),
#  ('led', 46),
#  ('biden', 46),
#  ('lessons', 46),
#  ('quarter', 46),
#  ('moment', 46),
#  ('brink', 46),
#  ('frontline', 46),
#  ('20', 46),
#  ('returns', 46),
#  ('officer', 46),
#  ('oil', 45),
#  ('lift', 45),
#  ('gyms', 45),
#  ('friends', 45),
#  ('resume', 45),
#  ('exercise', 45),
#  ('downing', 45),
#  ('queen', 45),
#  ('reports', 45),
#  ('wearing', 45),
#  ('officials', 45),
#  ('receive', 45),
#  ('delays', 45),
#  ('delivery', 45),
#  ('records', 45),
#  ('centres', 45),
#  ('visitors', 45),
#  ('kids', 45),
#  ('international', 45),
#  ('prices', 45),
#  ('enforce', 45),
#  ('group', 45),
#  ('refunds', 45),
#  ('train', 45),
#  ('roll', 44),
#  ('fresh', 44),
#  ('airlines', 44),
#  ('political', 44),
#  ('signs', 44),
#  ('hard', 44),
#  ('stock', 44),
#  ('drop', 44),
#  ('puts', 44),
#  ('debate', 44),
#  ('blood', 43),
#  ('church', 43),
#  ('suffer', 43),
#  ('rush', 43),
#  ('shares', 43),
#  ('survey', 43),
#  ('confusion', 43),
#  ('backlash', 43),
#  ('leaves', 43),
#  ('outbreaks', 43),
#  ('empty', 43),
#  ('election', 43),
#  ('chance', 43),
#  ('reveal', 43),
#  ('april', 42),
#  ('changed', 42),
#  ('urgent', 42),
#  ('10000', 42),
#  ('forget', 42),
#  ('severe', 42),
#  ('weekend', 42),
#  ('joe', 42),
#  ('looms', 42),
#  ('damage', 42),
#  ('society', 42),
#  ('court', 42),
#  ('abuse', 42),
#  ('refuses', 42),
#  ('higher', 42),
#  ('refuse', 42),
#  ('council', 42),
#  ('considers', 42),
#  ('rail', 42),
#  ('sees', 42),
#  ('sturgeons', 42),
#  ('bans', 42),
#  ('zealand', 42),
#  ('zoom', 42),
#  ('slump', 42),
#  ('15', 41),
#  ('refund', 41),
#  ('nightmare', 41),
#  ('lifting', 41),
#  ('losses', 41),
#  ('common', 41),
#  ('exposed', 41),
#  ('video', 41),
#  ('send', 41),
#  ('reality', 41),
#  ('bad', 41),
#  ('raab', 41),
#  ('warnings', 41),
#  ('bosses', 41),
#  ('playing', 41),
#  ('drivers', 41),
#  ('italys', 41),
#  ('twometre', 41),
#  ('cabinet', 40),
#  ('crowds', 40),
#  ('step', 40),
#  ('asked', 40),
#  ('streets', 40),
#  ('shop', 40),
#  ('exams', 40),
#  ('illegal', 40),
#  ('duty', 40),
#  ('september', 40),
#  ('helping', 40),
#  ('fake', 40),
#  ('sporting', 40),
#  ('cricket', 40),
#  ('recover', 40),
#  ('commons', 40),
#  ('brazil', 39),
#  ('postlockdown', 39),
#  ('treasury', 39),
#  ('deliver', 39),
#  ('powers', 39),
#  ('extension', 39),
#  ('relief', 39),
#  ('message', 39),
#  ('project', 39),
#  ('flight', 39),
#  ('americans', 39),
#  ('class', 39),
#  ('eurozone', 39),
#  ('win', 39),
#  ('slow', 39),
#  ('hospitality', 39),
#  ('italian', 39),
#  ('share', 39),
#  ('domestic', 39),
#  ('investigation', 39),
#  ('property', 39),
#  ('ventilators', 39),
#  ('shielding', 39),
#  ('parliament', 39),
#  ('merkel', 38),
#  ('nightingale', 38),
#  ('wedding', 38),
#  ('bbc', 38),
#  ('loans', 38),
#  ('volunteers', 38),
#  ('michael', 38),
#  ('growing', 38),
#  ('escape', 38),
#  ('healthy', 38),
#  ('japan', 38),
#  ('efl', 38),
#  ('grows', 38),
#  ('charities', 38),
#  ('cities', 38),
#  ('stuck', 38),
#  ('trip', 38),
#  ('closure', 38),
#  ('premiership', 38),
#  ('2', 38),
#  ('supermarkets', 38),
#  ('liverpool', 38),
#  ('selfisolating', 38),
#  ('rebellion', 37),
#  ('protest', 37),
#  ('extend', 37),
#  ('access', 37),
#  ('missing', 37),
#  ('macron', 37),
#  ('perfect', 37),
#  ('unveils', 37),
#  ('hidden', 37),
#  ('ski', 37),
#  ('ons', 37),
#  ('billion', 37),
#  ('losing', 37),
#  ('states', 37),
#  ('america', 37),
#  ('media', 37),
#  ('fast', 37),
#  ('unable', 37),
#  ('continues', 37),
#  ('hands', 37),
#  ('moving', 37),
#  ('expected', 37),
#  ('road', 37),
#  ('storm', 37),
#  ('30', 36),
#  ('abroad', 36),
#  ('adults', 36),
#  ('men', 36),
#  ('whitty', 36),
#  ('combat', 36),
#  ('saved', 36),
#  ('dose', 36),
#  ('town', 36),
#  ('final', 36),
#  ('lifted', 36),
#  ('attacks', 36),
#  ('truth', 36),
#  ('postponed', 36),
#  ('leicester', 36),
#  ('attack', 36),
#  ('insurance', 36),
#  ('sick', 36),
#  ('prepares', 36),
#  ('answer', 36),
#  ('shortages', 36),
#  ('neighbours', 36),
#  ('sign', 36),
#  ('immune', 36),
#  ('reach', 36),
#  ('tokyo', 36),
#  ('medics', 36),
#  ('bubble', 36),
#  ('unemployment', 36),
#  ('conspiracy', 36),
#  ('answered', 35),
#  ('12', 35),
#  ('parties', 35),
#  ('chris', 35),
#  ('short', 35),
#  ('kill', 35),
#  ('backs', 35),
#  ('supplies', 35),
#  ('shouldnt', 35),
#  ('paying', 35),
#  ('failure', 35),
#  ('push', 35),
#  ('crash', 35),
#  ('fewer', 35),
#  ('watchdog', 35),
#  ('leaving', 35),
#  ('ignore', 35),
#  ('speech', 35),
#  ('raise', 35),
#  ('love', 35),
#  ('1000', 35),
#  ('politicians', 35),
#  ('vital', 35),
#  ('postcard', 35),
#  ('senior', 35),
#  ('diary', 35),
#  ('owner', 34),
#  ('retail', 34),
#  ('ways', 34),
#  ('northern', 34),
#  ('hour', 34),
#  ('citizens', 34),
#  ('amazon', 34),
#  ('heroes', 34),
#  ('indian', 34),
#  ('secret', 34),
#  ('caused', 34),
#  ('cambridge', 34),
#  ('poll', 34),
#  ('question', 34),
#  ('uturn', 34),
#  ('driving', 34),
#  ('scientific', 34),
#  ('wall', 34),
#  ('issues', 34),
#  ('google', 34),
#  ('thought', 34),
#  ('cover', 34),
#  ('priority', 33),
#  ('variants', 33),
#  ('chiefs', 33),
#  ('abandoned', 33),
#  ('expect', 33),
#  ('role', 33),
#  ('john', 33),
#  ('grant', 33),
#  ('pakistan', 33),
#  ('weve', 33),
#  ('cup', 33),
#  ('autumn', 33),
#  ('postcovid', 33),
#  ('baby', 33),
#  ('14', 33),
#  ('essential', 33),
#  ('rest', 33),
#  ('points', 33),
#  ('wake', 33),
#  ('extended', 33),
#  ('moore', 33),
#  ('games', 33),
#  ('alert', 33),
#  ('dead', 33),
#  ('population', 33),
#  ('supermarket', 33),
#  ('50', 33),
#  ('problems', 33),
#  ('security', 33),
#  ('missed', 33),
#  ('music', 33),
#  ('stories', 33),
#  ('herd', 33),
#  ('hong', 33),
#  ('point', 33),
#  ('teaching', 33),
#  ('meeting', 33),
#  ('questor', 33),
#  ('reasons', 32),
#  ('defends', 32),
#  ('rights', 32),
#  ('pregnant', 32),
#  ('programme', 32),
#  ('killed', 32),
#  ('worried', 32),
#  ('success', 32),
#  ('eases', 32),
#  ('sea', 32),
#  ('garden', 32),
#  ('protection', 32),
#  ('military', 32),
#  ('guidelines', 32),
#  ('match', 32),
#  ('tv', 32),
#  ('mayor', 32),
#  ('tougher', 32),
#  ('provide', 32),
#  ('cancel', 32),
#  ('total', 32),
#  ('player', 32),
#  ('eat', 32),
#  ('story', 31),
#  ('potential', 31),
#  ('ireland', 31),
#  ('gatherings', 31),
#  ('saturday', 31),
#  ('confidence', 31),
#  ('queue', 31),
#  ('dying', 31),
#  ('eased', 31),
#  ('park', 31),
#  ('law', 31),
#  ('guide', 31),
#  ('stimulus', 31),
#  ('pms', 31),
#  ('late', 31),
#  ('russia', 31),
#  ('islands', 31),
#  ('failed', 31),
#  ('obesity', 31),
#  ('single', 31),
#  ('landlords', 31),
#  ('overwhelmed', 31),
#  ('denies', 31),
#  ('release', 31),
#  ('leader', 31),
#  ('contract', 31),
#  ('fiasco', 31),
#  ('income', 31),
#  ('caught', 31),
#  ('danger', 31),
#  ('members', 31),
#  ('super', 31),
#  ('appeal', 31),
#  ('spreads', 31),
#  ('matches', 31),
#  ('shuts', 31),
#  ('equipment', 31),
#  ...]

# %%
guardian['new_web_title'] = guardian.web_title.apply(make_sentence)

# %%
def in_covid_dictionary():
    sent = sentence.split(' ')
    word = [word.lower() for word in sent]
    for x in word:
        if x in sort_telegraph.keys():
            return 'covid_related'
            break
        else:
            return 'n/a'

# %%
guardian['covid_related'] = guardian['new_web_title'].apply(in_covid_dictionary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-9c4686fcb5b8> in <module>
# ----> 1 guardian['covid_related'] = guardian['new_web_title'].apply(in_covid_dictionary())
#
# TypeError: in_covid_dictionary() missing 1 required positional argument: 'sentence'

# %%
guardian['covid_related']
# Out:
# 0        n/a
# 1        n/a
# 2        n/a
# 3        n/a
# 4        n/a
#         ...
# 32053    n/a
# 32054    n/a
# 32055    n/a
# 32056    n/a
# 32057    n/a
# Name: covid_related, Length: 32058, dtype: object

# %%
guardian
# Out:
#                                                       id  \
# 0          education/2021/mar/10/gillian-oxford-obituary
# 1      politics/2021/mar/19/boris-johnson-receives-fi...
# 2      books/2021/mar/24/campaign-to-buy-jrr-tolkiens...
# 3      world/2021/feb/19/german-politicians-counter-a...
# 4      world/2021/mar/18/thursday-briefing-eus-expert...
# ...                                                  ...
# 32053  sport/live/2020/apr/28/brazil-v-france-world-c...
# 32054  sport/live/2020/jul/11/england-v-west-indies-f...
# 32055  politics/live/2020/mar/09/boris-johnson-cobra-...
# 32056  us-news/live/2020/mar/11/joe-biden-bernie-sand...
# 32057  sport/live/2020/jul/20/england-v-west-indies-s...
#
#                                                web_title  \
# 0                                Gillian Oxford obituary
# 1      Boris Johnson receives Oxford/AstraZeneca Covi...
# 2        Campaign to buy JRR Tolkien's Oxford home fails
# 3      Scepticism over Oxford vaccine threatens Europ...
# 4      Thursday briefing: EU's experts to give Oxford...
# ...                                                  ...
# 32053  France edge Brazil in World Cup 1986 quarter-f...
# 32054  England v West Indies: first Test, day four – ...
# 32055  Containment of virus 'extremely unlikely to wo...
# 32056  Trump says US to suspend travel from Europe in...
# 32057  England beat West Indies by 113 runs: in secon...
#
#                                                  web_url  \
# 0      https://www.theguardian.com/education/2021/mar...
# 1      https://www.theguardian.com/politics/2021/mar/...
# 2      https://www.theguardian.com/books/2021/mar/24/...
# 3      https://www.theguardian.com/world/2021/feb/19/...
# 4      https://www.theguardian.com/world/2021/mar/18/...
# ...                                                  ...
# 32053  https://www.theguardian.com/sport/live/2020/ap...
# 32054  https://www.theguardian.com/sport/live/2020/ju...
# 32055  https://www.theguardian.com/politics/live/2020...
# 32056  https://www.theguardian.com/us-news/live/2020/...
# 32057  https://www.theguardian.com/sport/live/2020/ju...
#
#                       _date  \
# 0      2021-03-10T15:51:27Z
# 1      2021-03-19T19:23:04Z
# 2      2021-03-24T12:36:38Z
# 3      2021-02-19T13:53:59Z
# 4      2021-03-18T06:31:09Z
# ...                     ...
# 32053  2020-04-28T21:28:15Z
# 32054  2020-07-11T20:04:35Z
# 32055  2020-03-09T18:11:14Z
# 32056  2020-03-12T04:29:30Z
# 32057  2020-07-20T18:12:39Z
#
#                                            new_web_title covid_related
# 0                            [gillian, oxford, obituary]           n/a
# 1      [boris, johnson, receives, oxford/astrazeneca,...           n/a
# 2      [campaign, to, buy, jrr, tolkien's, oxford, ho...           n/a
# 3      [scepticism, over, oxford, vaccine, threatens,...           n/a
# 4      [thursday, briefing:, eu's, experts, to, give,...           n/a
# ...                                                  ...           ...
# 32053  [france, edge, brazil, in, world, cup, 1986, q...           n/a
# 32054  [england, v, west, indies:, first, test,, day,...           n/a
# 32055  [containment, of, virus, 'extremely, unlikely,...           n/a
# 32056  [trump, says, us, to, suspend, travel, from, e...           n/a
# 32057  [england, beat, west, indies, by, 113, runs:, ...           n/a
#
# [32058 rows x 6 columns]
